# %% [markdown]
# # On particle filters applied to electricity load forecasting

# %% [markdown]
# PyMC tuto
#
# https://pymc-devs.github.io/pymc/tutorial.html#fitting-the-model-with-mcmc
#
# http://sdsawtelle.github.io/blog/output/mcmc-in-python-with-pymc.html

# %% [markdown]
# NC Email:
#
# Voilà quelques pistes que vous pouvez suivre:
# * commencer par implémenter un bootstrap filter pour le modèle proposé, et des valeurs des paramètres choisis à la main ﴾en fonction des valeurs reportées dans l'article par exemple﴿ et des données que vous pouvez simuler. Déterminer à quel point l'algorithme marche bien:
# + graphe de l'ESS en fonction du temps; voir si effectivement certains outliers font fortement chuter l'ESS. Essayer la méthode proposée pour gérer ses outliers.
# + intervalles de confiance pour l'estimation de E[X_t|Y_{0:t}], basé sur plusieurs exécutions, par exemple.
#
# Deuxième étape: estimation des paramètres. Vous pouvez essayer une des trois approches suivantes, triées par ordre de difficulté:
# 1. maximisation de la vraisemblance ﴾estimée par votre filtre particulaire pour un theta donné﴿, en utilisant une méthode de maximisation pour fonction bruitée ﴾par ex Robbins‐Monroe﴿.
# 2. PMMH, voir le prochain cours. Principale difficulté: l'algorithme peut prendre du temps, et ne pas être très facile à calibrer, mais je vais en parler en cours.
# 3. Particle Gibbs: c'est peut‐être un peu compliqué pour ce modèle, mais si vous arrivez, gros bonus!

# %%
import pandas as pd
import numpy as np
import numpy.random as npr
import matplotlib as mtp
import matplotlib.pyplot as plt
import scipy as sp
from scipy.stats import truncnorm
import scipy.stats as stats
from scipy.stats import invgamma
from scipy import ndimage
import math

# %% [markdown]
# ### Parameters

# %%
M=10**3 #number of particles
n_pred=365  #number of predictions
N_daytype=8  #number of day types

# %% [markdown]
# ### Load temperatures data 2015-2016

# %%
df_temp=pd.read_csv('data/temp_1516.csv',sep=',')
df_temp=df_temp.drop(df_temp.columns[0],axis=1)
df_temp=df_temp.sort_values(by='date')
df_temp.head()
# Out:
#          date   hour         t
# 0  2015-01-01  00:00  5.057414
# 1  2015-01-01  03:00  4.609138
# 2  2015-01-01  06:00  4.729828
# 3  2015-01-01  09:00  6.052241
# 4  2015-01-01  12:00  9.347069

# %%
#temperatures every day at 3pm
temp_day=df_temp[df_temp.hour=="15:00"]
temp_day.head()
#Array vector of temperatures for each day of the year
T_h=list(temp_day.t)

# %% [markdown]
# ### Load electricity data

# %%
mypath="data/"
df=pd.read_csv(mypath+"cdc_conso_daytypes.csv",sep=",",encoding='latin-1')
df=df.drop(["daytype"+str(i) for i in range(0,9)],axis=1)
df=df.drop(df.columns[0],axis=1)
df.index=range(0,len(df))
df=df.sort_values(by=['Date'])
df['Date - Heure']=pd.to_datetime(df['Date - Heure'])
df.sort_values(by=["Date - Heure"])
#truncate to the data from 2015
df=df[(df.Date >='2015-01-01')]
df.head()
# Out:
#               Date - Heure        Date  Heure  Consommation (MW)  \
# 166957 2015-01-01 03:30:00  2015-01-01  04:30              64838
# 153294 2015-01-01 18:30:00  2015-01-01  19:30              72562
# 153293 2015-01-01 18:00:00  2015-01-01  19:00              71766
# 152017 2015-01-01 01:00:00  2015-01-01  02:00              71134
# 152018 2015-01-01 04:30:00  2015-01-01  05:30              64379
#
#        Qualite donnee  daytype
# 166957    DÃ©finitive        6
# 153294    DÃ©finitive        6
# 153293    DÃ©finitive        6
# 152017    DÃ©finitive        6
# 152018    DÃ©finitive        6

# %% [raw]
# plt.plot_date(df.Date,df['Consommation (MW)'],fmt='-')
# plt.show()

# %% [raw]
# bins=range(30000,100000,1000)
# plt.hist(df['Consommation (MW)'],normed=True,bins=bins)
# plt.show()

# %% [markdown]
# ### Set variables of electricity demand

# %%
from datetime import date
df['Consommation']=df['Consommation (MW)']   #leave it in MW
#For prediction, every day at 3pm
consumption_day_ahead = list(df[df['Heure']=='15:00']['Consommation'])
#for initialization
consumption = list(df[df['Heure']=='15:00']['Consommation'][:30])

# %% [markdown]
# ## Implementation of Algorithm 3.10

# %% [markdown]
# ## At time n=0:

# %% [markdown]
# ### 1.Definition of MCMC initial model at n=0 - sample $X_0^{j} \sim \mu(x_0)$

# %% [markdown]
# ### Option A: Set values by hand

# %% [raw]
# #Add a bit of noise with uniform random
# #s=8000*np.ones(M)*npr.uniform(0.5,1.5,size=M)
# #sigma2_g_star=(10**5)*npr.uniform(0.5,1.5,size=M)
# #sigma2_s_star=(10**5)*npr.uniform(0.5,1.5,size=M)
# sigma_g_init=1.27*10**(8/2)
# sigma_s_init=(2*7.9)*10**3
# u_h=14 #mean of N(14,1)
# kappa=np.array([1/9]*9)
# sigma2=2.7*10**7
# g_heat_init = stats.truncnorm.rvs(-np.inf,0,loc=0,scale=10**4,size=M)
# s_init = stats.truncnorm.rvs(np.inf,0,loc=0,scale=10**4,size=M)
# sigma_s_star_2_evol=7.9*10**7
# sigma_g_star_2_evol=1.27*10**8
#
# x_init=x_season(df.daytype[15],kappa,s_init,sigma_s_init)[0]+x_heat(g_heat_init,15,sigma_g_init)[0]
# w_init= np.exp(-(np.square(consumption[15]-x_init))/(2*sigma2))

# %% [markdown]
# ### Option C: MCMC using MHA or Gibbs (TBA)

# %% [markdown]
# #### Freeze parameters from Zak's simulation in gibbs-parameters_init_v1

# %%
N_daytype=9
k_day=npr.dirichlet(np.ones(N_daytype),1)
len_init=15
pred_forward=[0,1,2]

# %%
#Load pickle file
import pickle
output_file ='data/parameters_init_20180113-135329.pkl'
pkl_file = open(output_file, 'rb')
parameters_init = pickle.load(pkl_file)
parameters_init["x_init"][:20]
# Out:
# array([  6.27772271e+20,   7.74432522e+04,   7.18859618e+04,
#          6.49227561e+04,   6.66906797e+04,   6.45463399e+04,
#          7.44844711e+04,   7.35432483e+04,   7.28854527e+04,
#          7.64918960e+04,   6.16447396e+04,   6.96833028e+04,
#          6.56803045e+04,   6.42648669e+04,   6.05432962e+04,
#          5.99115354e+04,   6.06208026e+04,   7.04703987e+04,
#          7.03640065e+04,   7.41647499e+04])

# %%
parameters_init
# Out:
# {'g_heat_init': array([-814623.94530988,   -1103.5042025 ,  -13509.35223552,
#          -12839.18874712,  -13810.69394068,  -13621.95767042,
#          -16305.45122647,  -16251.90232773,  -16229.3696953 ,
x_init[0]=np.median(x_init)
g_heat_init[0]=np.median(g_heat_init)
s_init[0]=np.median(s_init)

# %% [markdown]
# ### Part 2: regularize weights and x if necessary

# %%
#STEP 2 OF PARTICLE FILTER
def resample(x_pred,w_prev,nbdays_pred_today,len_init,n,sigma_s,sigma_g,g_h,s,sigma,ESS):   
    #compute y_n
    delta_cons_gaus=-np.square(consumption_day_ahead[len_init+n+nbdays_pred_today]-x_pred)/(2*sigma**2)
    y_n=np.exp(delta_cons_gaus)
    #compute new weights
    if n>0:
        w_=w_prev*y_n
    else:
        w_=w_prev
    #likelihood of y_n
    lh_y_n=np.sum(delta_cons_gaus)
    #normalize weights
    w_h=w_/sum(w_)
    #calculate ESS
    ESS=1/sum(np.square(w_h))
    x =np.zeros(M)
    w =np.zeros(M)
    print("ESS of normalized weights=",round(ESS,6))
    if ESS <0.001*M: #reset the weights, keep x predicted as such
        print("ESS <0.001*M")
        x=x_pred
        if n==0:
            w=np.ones(M)*(1/M)
        w=w_prev
    elif (ESS>=0.001*M and ESS<0.5*M):  #reset all the weights, add some noise to a fraction of the x's
        print("ESS>=0.001*M and ESS_0<0.5*M")
        x,w,sigma_s,sigma_g,g_h,s=resample_multinomial(x_pred,w_h,sigma_s,sigma_g,g_h,s)
    elif ESS>=0.5*M:  #No degeneracy
        print("ESS>=0.5*M")
        x=x_pred
        w=w_h
    else:
        print("ESS critically low")
        x=x_pred
        if n==0:
            w=np.ones(M)*(1/M)
        w=w_prev
            
    print("new ESS=",round(1/sum(np.square(w)),6))
    return x,w,ESS,lh_y_n,sigma_s,sigma_g,g_h,s

# %%
def resample_multinomial(x_temp,w_temp,sigma_s,sigma_g,g_h,s):
    multinomial = np.random.multinomial(1,w_temp,M)
    new_x = np.zeros(M)
    new_s = np.zeros(M)
    new_g_heat = np.zeros(M)
    new_sigma_s = np.zeros(M)
    new_sigma_g = np.zeros(M)
    for i in range(M):
        new_x[i]=x_temp[np.argmax(multinomial[i,])]
        new_s[i]=s[np.argmax(multinomial[i,])]
        new_g_heat[i]=g_h[np.argmax(multinomial[i,])]
        new_sigma_s[i]=sigma_s[np.argmax(multinomial[i,])]
        new_sigma_g[i]=sigma_g[np.argmax(multinomial[i,])]
    new_w=(1/M)*np.ones(M)   
    return new_x,new_w,new_sigma_s,new_sigma_g,new_g_heat,new_s

# %%
#initialize matrix of x_heat, x_season
ESS=np.array(np.ones(n_pred+1))
x =np.zeros([n_pred+1,M])
w =np.zeros([n_pred+1,M])
lh_y_n =np.zeros(n_pred+1)
x_season =np.zeros([n_pred+1,M]) 
x_heat =np.zeros([n_pred+1,M])

x[0,:],w[0,:],ESS[0],lh_y,sigma_s_init,sigma_g_init,g_heat_init,s_init=resample(x_init,w_init,2,15,0,sigma_s_init,
                                                                                sigma_g_init,
                                                                                g_heat_init,s_init,sigma2**0.5,ESS)
# Out:
# ESS of normalized weights= 862.234232
# ESS>=0.5*M
# new ESS= 862.234232

# %% [markdown]
# ## Prediction and Filtering at time n>0

# %% [markdown]
# ### 1. Sample $x^j_n \mid X^j_{n-1} $ for all j=1...M particles

# %%
def x_season(day_type,k_day,s_prev,sigma_s_prev):
    nu=truncnorm.rvs(a = (-sigma_s_prev-0) / sigma_g_init , b = np.inf, loc= 0, scale = sigma_g_init, size=M)
    sigma_s=sigma_s_prev+nu
    err=truncnorm.rvs(a = -s_prev / sigma_s , b = np.inf, loc= 0, scale = sigma_s, size=M)
    s=s_prev+err
    x_s=s*k_day[day_type]
    return x_s, s, sigma_s

def x_heat(g_h_prev,day,sigma_g_prev):
    nu=truncnorm.rvs(a = -sigma_g_prev / sigma_g_init , b = np.inf, loc= 0, scale = sigma_g_init, size=M)
    sigma_g=sigma_g_prev+nu
    err=truncnorm.rvs(a = -np.inf , b =(-g_h_prev-0) / sigma_g, loc= 0, scale = sigma_g, size=M)
    g_h=g_h_prev+err
    if(u_h-T_h[day]<0):
        print("No heating effect")
    x_h=g_h*(T_h[day]-u_h)*max(np.sign(u_h-T_h[day]),0)
    return x_h, g_h, sigma_g

# %%
daytype=np.array(df.daytype)

# %% [raw]
# print(x_season(daytype[15],kappa,s_init,sigma_s_init)[2])
# print(x_heat(g_heat_init,16,sigma_g_init)[2])

# %%
#Initialize parameters
def particle_filter(nbdays_pred_today,len_init,len_filtering,s,g_h,sigma_s,sigma_g,sigma,lh_y):
    lh_y_n=np.zeros(len_filtering)
    x_pred=np.zeros([len_filtering,M])
    x_pred_mean=np.zeros(len_filtering)
    ESS=np.zeros(len_filtering)
    for n in range(1,len_filtering):
        print("n=",n)
        #prediction X[n] one day ahead, hourly forecast
        x_s=x_season(int(daytype[len_init+n+nbdays_pred_today]),kappa,s,sigma_s)
        x_h=x_heat(g_h,n+len_init+nbdays_pred_today,sigma_g)
        x_pred[n,:]=x_s[0]+x_h[0]
        #print("number of negative values:",len(x_pred[x_pred<0]))
        print("x_pred_mean =","{:.2e}".format(np.mean(x_pred[n,:])),
              "real consumption=","{:.2e}".format(consumption_day_ahead[n]))
        print("x_pred min=","{:.2e}".format(np.min(x_pred[n,:])),"x_pred max","{:.2e}".format(np.max(x_pred[n,:])))
        #take new values of parameters to feed x_season and x_heat in the next step
        s, sigma_s=x_s[1:]
        g_h, sigma_g=x_h[1:]
        #regularization
        x[n,:],w[n,:],ESS[n],lh_y_n[n],sigma_s,sigma_g,g_h,s=resample(x_pred[n,:],w[n-1,:],nbdays_pred_today,len_init,n,sigma_s,sigma_g,g_h,s,sigma,ESS)
        print("------------------------")
        x_pred_mean[n]=np.mean(x_pred[n,:])
    return lh_y_n,x_pred_mean,ESS

# %%
x_predict=np.zeros([len(pred_forward),n_pred])
ESS_calc=np.zeros([len(pred_forward),n_pred])
for i in range(len(pred_forward)):
    log_lh_init,x_predict[i,:],ESS_calc[i,:]=particle_filter(pred_forward[i],len_init,n_pred,s_init,g_heat_init,sigma_s_init,sigma_g_init,sigma2**0.5,lh_y_n)
# Out:
# n= 1
# x_pred_mean = 3.93e+04 real consumption= 6.86e+04
# x_pred min= 2.22e+02 x_pred max 1.59e+05
# ESS of normalized weights= 106.677576
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 2
# x_pred_mean = 8.33e+04 real consumption= 6.41e+04
# x_pred min= 3.37e+02 x_pred max 3.06e+05
# ESS of normalized weights= 196.196935
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 3
# x_pred_mean = 9.17e+04 real consumption= 5.74e+04
# x_pred min= 1.78e+03 x_pred max 2.94e+05
# ESS of normalized weights= 239.964032
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 4
# x_pred_mean = 1.01e+05 real consumption= 7.31e+04
# x_pred min= 2.35e+03 x_pred max 6.01e+05
# ESS of normalized weights= 223.241027
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 5
# x_pred_mean = 8.21e+04 real consumption= 7.68e+04
# x_pred min= 3.98e+03 x_pred max 3.23e+05
# ESS of normalized weights= 291.560989
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 6
# x_pred_mean = 8.63e+04 real consumption= 7.49e+04
# x_pred min= 2.21e+03 x_pred max 3.17e+05
# ESS of normalized weights= 329.131066
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 7
# x_pred_mean = 9.14e+04 real consumption= 7.21e+04
# x_pred min= 9.55e+02 x_pred max 3.34e+05
# ESS of normalized weights= 286.59104
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 8
# x_pred_mean = 6.80e+04 real consumption= 6.90e+04
# x_pred min= 3.95e+03 x_pred max 2.41e+05
# ESS of normalized weights= 330.123304
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 9
# x_pred_mean = 6.12e+04 real consumption= 5.72e+04
# x_pred min= 1.67e+03 x_pred max 2.25e+05
# ESS of normalized weights= 370.234058
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 10
# x_pred_mean = 6.28e+04 real consumption= 5.55e+04
# x_pred min= 5.90e+03 x_pred max 2.66e+05
# ESS of normalized weights= 205.388559
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 11
# x_pred_mean = 7.23e+04 real consumption= 6.91e+04
# x_pred min= 7.51e+03 x_pred max 2.49e+05
# ESS of normalized weights= 336.236614
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 12
# x_pred_mean = 3.53e+04 real consumption= 6.88e+04
# x_pred min= 6.39e+03 x_pred max 1.25e+05
# ESS of normalized weights= 16.09182
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 13
# x_pred_mean = 1.45e+05 real consumption= 6.92e+04
# x_pred min= 2.74e+04 x_pred max 3.53e+05
# ESS of normalized weights= 64.09061
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 14
# x_pred_mean = 1.27e+05 real consumption= 7.03e+04
# x_pred min= 1.50e+04 x_pred max 5.37e+05
# ESS of normalized weights= 120.154768
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 15
# x_pred_mean = 1.22e+05 real consumption= 7.00e+04
# x_pred min= 1.00e+04 x_pred max 4.87e+05
# ESS of normalized weights= 156.510815
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 16
# x_pred_mean = 1.20e+05 real consumption= 6.31e+04
# x_pred min= 6.90e+03 x_pred max 6.37e+05
# ESS of normalized weights= 165.766729
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 17
# x_pred_mean = 1.05e+05 real consumption= 6.25e+04
# x_pred min= 7.69e+03 x_pred max 6.23e+05
# ESS of normalized weights= 216.588892
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 18
# x_pred_mean = 1.20e+05 real consumption= 7.72e+04
# x_pred min= 7.09e+03 x_pred max 7.38e+05
# ESS of normalized weights= 207.670724
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 19
# x_pred_mean = 1.07e+05 real consumption= 7.79e+04
# x_pred min= 2.88e+03 x_pred max 4.80e+05
# ESS of normalized weights= 261.274183
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 20
# x_pred_mean = 1.16e+05 real consumption= 7.92e+04
# x_pred min= 9.14e+03 x_pred max 6.52e+05
# ESS of normalized weights= 245.694676
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 21
# x_pred_mean = 1.14e+05 real consumption= 7.84e+04
# x_pred min= 7.16e+03 x_pred max 5.24e+05
# ESS of normalized weights= 228.134185
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 22
# x_pred_mean = 9.01e+04 real consumption= 7.89e+04
# x_pred min= 3.79e+03 x_pred max 3.95e+05
# ESS of normalized weights= 302.26317
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 23
# x_pred_mean = 8.15e+04 real consumption= 7.12e+04
# x_pred min= 7.52e+03 x_pred max 3.23e+05
# ESS of normalized weights= 341.440164
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 24
# x_pred_mean = 6.61e+04 real consumption= 6.55e+04
# x_pred min= 5.98e+03 x_pred max 2.05e+05
# ESS of normalized weights= 325.345659
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 25
# x_pred_mean = 6.96e+04 real consumption= 7.75e+04
# x_pred min= 2.23e+04 x_pred max 1.80e+05
# ESS of normalized weights= 490.079131
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 26
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 7.54e+04
# x_pred min= 1.34e+04 x_pred max 9.91e+04
# ESS of normalized weights= 509.703033
# ESS>=0.5*M
# new ESS= 509.703033
# ------------------------
# n= 27
# No heating effect
# x_pred_mean = 6.19e+04 real consumption= 7.65e+04
# x_pred min= 3.63e+03 x_pred max 1.16e+05
# ESS of normalized weights= 340.933754
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 28
# No heating effect
# x_pred_mean = 6.99e+04 real consumption= 7.78e+04
# x_pred min= 4.41e+04 x_pred max 1.02e+05
# ESS of normalized weights= 792.487566
# ESS>=0.5*M
# new ESS= 792.487566
# ------------------------
# n= 29
# x_pred_mean = 9.64e+04 real consumption= 7.59e+04
# x_pred min= 5.07e+04 x_pred max 2.45e+05
# ESS of normalized weights= 107.85805
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 30
# x_pred_mean = 7.50e+04 real consumption= 6.84e+04
# x_pred min= 4.28e+04 x_pred max 1.74e+05
# ESS of normalized weights= 315.489811
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 31
# x_pred_mean = 7.22e+04 real consumption= 6.67e+04
# x_pred min= 2.15e+04 x_pred max 1.58e+05
# ESS of normalized weights= 503.830362
# ESS>=0.5*M
# new ESS= 503.830362
# ------------------------
# n= 32
# x_pred_mean = 7.27e+04 real consumption= 7.71e+04
# x_pred min= 1.76e+04 x_pred max 1.80e+05
# ESS of normalized weights= 280.403555
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 33
# x_pred_mean = 6.38e+04 real consumption= 7.99e+04
# x_pred min= 1.65e+04 x_pred max 1.07e+05
# ESS of normalized weights= 553.866419
# ESS>=0.5*M
# new ESS= 553.866419
# ------------------------
# n= 34
# No heating effect
# x_pred_mean = 6.06e+04 real consumption= 8.21e+04
# x_pred min= 5.10e+03 x_pred max 1.09e+05
# ESS of normalized weights= 344.840229
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 35
# No heating effect
# x_pred_mean = 6.91e+04 real consumption= 8.29e+04
# x_pred min= 4.64e+04 x_pred max 1.20e+05
# ESS of normalized weights= 766.485816
# ESS>=0.5*M
# new ESS= 766.485816
# ------------------------
# n= 36
# x_pred_mean = 1.55e+05 real consumption= 8.59e+04
# x_pred min= 5.21e+04 x_pred max 9.29e+05
# ESS of normalized weights= 39.412855
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 37
# x_pred_mean = 8.11e+04 real consumption= 7.30e+04
# x_pred min= 4.54e+04 x_pred max 1.90e+05
# ESS of normalized weights= 266.790201
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 38
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 6.70e+04
# x_pred min= 2.06e+04 x_pred max 8.66e+04
# ESS of normalized weights= 408.24298
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 39
# x_pred_mean = 8.35e+04 real consumption= 7.57e+04
# x_pred min= 4.28e+04 x_pred max 2.06e+05
# ESS of normalized weights= 499.87653
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 40
# No heating effect
# x_pred_mean = 6.49e+04 real consumption= 7.55e+04
# x_pred min= 2.85e+04 x_pred max 9.48e+04
# ESS of normalized weights= 695.299334
# ESS>=0.5*M
# new ESS= 695.299334
# ------------------------
# n= 41
# No heating effect
# x_pred_mean = 6.47e+04 real consumption= 7.16e+04
# x_pred min= 7.47e+03 x_pred max 1.03e+05
# ESS of normalized weights= 531.15132
# ESS>=0.5*M
# new ESS= 531.15132
# ------------------------
# n= 42
# x_pred_mean = 8.82e+04 real consumption= 7.21e+04
# x_pred min= 1.94e+04 x_pred max 2.19e+05
# ESS of normalized weights= 174.503575
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 43
# No heating effect
# x_pred_mean = 6.59e+04 real consumption= 7.10e+04
# x_pred min= 3.27e+04 x_pred max 9.08e+04
# ESS of normalized weights= 782.391594
# ESS>=0.5*M
# new ESS= 782.391594
# ------------------------
# n= 44
# No heating effect
# x_pred_mean = 6.57e+04 real consumption= 6.39e+04
# x_pred min= 2.68e+04 x_pred max 9.93e+04
# ESS of normalized weights= 378.929315
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 45
# No heating effect
# x_pred_mean = 6.08e+04 real consumption= 5.91e+04
# x_pred min= 2.33e+04 x_pred max 8.35e+04
# ESS of normalized weights= 780.646377
# ESS>=0.5*M
# new ESS= 780.646377
# ------------------------
# n= 46
# No heating effect
# x_pred_mean = 6.08e+04 real consumption= 7.23e+04
# x_pred min= 9.59e+03 x_pred max 9.56e+04
# ESS of normalized weights= 625.881248
# ESS>=0.5*M
# new ESS= 625.881248
# ------------------------
# n= 47
# x_pred_mean = 1.89e+05 real consumption= 7.28e+04
# x_pred min= 4.48e+04 x_pred max 9.22e+05
# ESS of normalized weights= 38.331156
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 48
# x_pred_mean = 6.74e+04 real consumption= 7.15e+04
# x_pred min= 2.00e+04 x_pred max 1.10e+05
# ESS of normalized weights= 732.919024
# ESS>=0.5*M
# new ESS= 732.919024
# ------------------------
# n= 49
# No heating effect
# x_pred_mean = 6.20e+04 real consumption= 7.06e+04
# x_pred min= 4.97e+03 x_pred max 1.19e+05
# ESS of normalized weights= 603.60512
# ESS>=0.5*M
# new ESS= 603.60512
# ------------------------
# n= 50
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 7.11e+04
# x_pred min= 3.40e+03 x_pred max 1.24e+05
# ESS of normalized weights= 437.304119
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 51
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 6.54e+04
# x_pred min= 3.33e+04 x_pred max 8.05e+04
# ESS of normalized weights= 462.955264
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 52
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.97e+04
# x_pred min= 3.04e+04 x_pred max 8.22e+04
# ESS of normalized weights= 741.614197
# ESS>=0.5*M
# new ESS= 741.614197
# ------------------------
# n= 53
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 7.10e+04
# x_pred min= 2.12e+04 x_pred max 8.86e+04
# ESS of normalized weights= 562.244786
# ESS>=0.5*M
# new ESS= 562.244786
# ------------------------
# n= 54
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 7.19e+04
# x_pred min= 1.04e+03 x_pred max 9.79e+04
# ESS of normalized weights= 464.660418
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 55
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 7.05e+04
# x_pred min= 2.41e+04 x_pred max 8.51e+04
# ESS of normalized weights= 907.359161
# ESS>=0.5*M
# new ESS= 907.359161
# ------------------------
# n= 56
# x_pred_mean = 1.07e+05 real consumption= 6.99e+04
# x_pred min= 3.90e+04 x_pred max 3.88e+05
# ESS of normalized weights= 139.104344
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 57
# x_pred_mean = 1.14e+05 real consumption= 6.90e+04
# x_pred min= 4.94e+04 x_pred max 4.82e+05
# ESS of normalized weights= 95.590326
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 58
# x_pred_mean = 9.28e+04 real consumption= 6.19e+04
# x_pred min= 4.19e+04 x_pred max 4.07e+05
# ESS of normalized weights= 232.899416
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 59
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.57e+04
# x_pred min= 2.05e+04 x_pred max 7.32e+04
# ESS of normalized weights= 606.066821
# ESS>=0.5*M
# new ESS= 606.066821
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 6.53e+04
# x_pred min= 1.84e+04 x_pred max 7.63e+04
# ESS of normalized weights= 494.782605
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.47e+04
# x_pred min= 4.43e+04 x_pred max 8.40e+04
# ESS of normalized weights= 927.185162
# ESS>=0.5*M
# new ESS= 927.185162
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.74e+04
# x_pred min= 4.19e+04 x_pred max 8.22e+04
# ESS of normalized weights= 780.958752
# ESS>=0.5*M
# new ESS= 780.958752
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 5.95e+04 real consumption= 6.53e+04
# x_pred min= 2.45e+04 x_pred max 9.27e+04
# ESS of normalized weights= 632.385102
# ESS>=0.5*M
# new ESS= 632.385102
# ------------------------
# n= 64
# x_pred_mean = 8.35e+04 real consumption= 6.30e+04
# x_pred min= 2.98e+04 x_pred max 2.09e+05
# ESS of normalized weights= 149.619994
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 65
# x_pred_mean = 7.65e+04 real consumption= 5.49e+04
# x_pred min= 4.38e+04 x_pred max 1.81e+05
# ESS of normalized weights= 259.052643
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 4.87e+04
# x_pred min= 3.05e+04 x_pred max 7.24e+04
# ESS of normalized weights= 713.311634
# ESS>=0.5*M
# new ESS= 713.311634
# ------------------------
# n= 67
# x_pred_mean = 6.90e+04 real consumption= 6.02e+04
# x_pred min= 2.89e+04 x_pred max 1.97e+05
# ESS of normalized weights= 419.87448
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 68
# x_pred_mean = 1.00e+05 real consumption= 6.20e+04
# x_pred min= 5.03e+04 x_pred max 3.27e+05
# ESS of normalized weights= 262.612966
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 69
# x_pred_mean = 6.01e+04 real consumption= 6.01e+04
# x_pred min= 2.82e+04 x_pred max 8.88e+04
# ESS of normalized weights= 612.515803
# ESS>=0.5*M
# new ESS= 612.515803
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 5.96e+04
# x_pred min= 2.67e+04 x_pred max 8.42e+04
# ESS of normalized weights= 491.457512
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 6.05e+04 real consumption= 6.18e+04
# x_pred min= 3.25e+04 x_pred max 8.04e+04
# ESS of normalized weights= 726.827117
# ESS>=0.5*M
# new ESS= 726.827117
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 6.05e+04 real consumption= 5.74e+04
# x_pred min= 3.02e+04 x_pred max 9.42e+04
# ESS of normalized weights= 454.544558
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 5.60e+04
# x_pred min= 3.39e+04 x_pred max 7.09e+04
# ESS of normalized weights= 798.299792
# ESS>=0.5*M
# new ESS= 798.299792
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 6.36e+04
# x_pred min= 1.97e+04 x_pred max 8.07e+04
# ESS of normalized weights= 642.838315
# ESS>=0.5*M
# new ESS= 642.838315
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 6.06e+04
# x_pred min= 8.02e+03 x_pred max 8.51e+04
# ESS of normalized weights= 497.160412
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 6.01e+04 real consumption= 5.89e+04
# x_pred min= 4.27e+04 x_pred max 8.39e+04
# ESS of normalized weights= 844.056171
# ESS>=0.5*M
# new ESS= 844.056171
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 6.01e+04 real consumption= 6.31e+04
# x_pred min= 2.88e+04 x_pred max 8.95e+04
# ESS of normalized weights= 726.665592
# ESS>=0.5*M
# new ESS= 726.665592
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 6.02e+04 real consumption= 6.33e+04
# x_pred min= 6.19e+02 x_pred max 1.00e+05
# ESS of normalized weights= 596.306419
# ESS>=0.5*M
# new ESS= 596.306419
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 6.02e+04 real consumption= 5.73e+04
# x_pred min= 6.37e+03 x_pred max 1.13e+05
# ESS of normalized weights= 311.552169
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.46e+04
# x_pred min= 3.29e+04 x_pred max 7.92e+04
# ESS of normalized weights= 758.329828
# ESS>=0.5*M
# new ESS= 758.329828
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 6.05e+04
# x_pred min= 2.24e+04 x_pred max 8.52e+04
# ESS of normalized weights= 653.181428
# ESS>=0.5*M
# new ESS= 653.181428
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 6.54e+04
# x_pred min= 2.27e+04 x_pred max 8.44e+04
# ESS of normalized weights= 548.225457
# ESS>=0.5*M
# new ESS= 548.225457
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 6.75e+04
# x_pred min= 1.80e+04 x_pred max 9.04e+04
# ESS of normalized weights= 466.645644
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 6.80e+04
# x_pred min= 3.46e+04 x_pred max 8.35e+04
# ESS of normalized weights= 874.361852
# ESS>=0.5*M
# new ESS= 874.361852
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 6.20e+04
# x_pred min= 2.65e+04 x_pred max 8.48e+04
# ESS of normalized weights= 584.791215
# ESS>=0.5*M
# new ESS= 584.791215
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 5.41e+04
# x_pred min= 1.74e+04 x_pred max 9.56e+04
# ESS of normalized weights= 218.733607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 5.19e+04
# x_pred min= 1.78e+04 x_pred max 6.56e+04
# ESS of normalized weights= 770.436646
# ESS>=0.5*M
# new ESS= 770.436646
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 6.07e+04
# x_pred min= 9.45e+03 x_pred max 7.68e+04
# ESS of normalized weights= 622.902425
# ESS>=0.5*M
# new ESS= 622.902425
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 6.07e+04
# x_pred min= 7.58e+03 x_pred max 7.99e+04
# ESS of normalized weights= 505.698034
# ESS>=0.5*M
# new ESS= 505.698034
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 4.78e+04 real consumption= 6.23e+04
# x_pred min= 5.53e+03 x_pred max 9.50e+04
# ESS of normalized weights= 411.317346
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 6.36e+04
# x_pred min= 2.87e+04 x_pred max 8.20e+04
# ESS of normalized weights= 886.437602
# ESS>=0.5*M
# new ESS= 886.437602
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 6.11e+04
# x_pred min= 2.21e+04 x_pred max 8.09e+04
# ESS of normalized weights= 668.888475
# ESS>=0.5*M
# new ESS= 668.888475
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.54e+04
# x_pred min= 1.10e+04 x_pred max 8.56e+04
# ESS of normalized weights= 393.338046
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.91e+04
# x_pred min= 2.28e+04 x_pred max 6.38e+04
# ESS of normalized weights= 753.275564
# ESS>=0.5*M
# new ESS= 753.275564
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 4.96e+04
# x_pred min= 1.03e+04 x_pred max 7.13e+04
# ESS of normalized weights= 580.938343
# ESS>=0.5*M
# new ESS= 580.938343
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 4.62e+04 real consumption= 5.87e+04
# x_pred min= 1.57e+04 x_pred max 8.06e+04
# ESS of normalized weights= 471.89162
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 5.70e+04
# x_pred min= 3.25e+04 x_pred max 7.09e+04
# ESS of normalized weights= 899.982911
# ESS>=0.5*M
# new ESS= 899.982911
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.49e+04
# x_pred min= 2.69e+04 x_pred max 7.79e+04
# ESS of normalized weights= 785.509667
# ESS>=0.5*M
# new ESS= 785.509667
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.35e+04
# x_pred min= 2.28e+04 x_pred max 8.40e+04
# ESS of normalized weights= 638.085871
# ESS>=0.5*M
# new ESS= 638.085871
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 4.79e+04
# x_pred min= 1.78e+04 x_pred max 8.80e+04
# ESS of normalized weights= 389.211759
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.60e+04 real consumption= 4.19e+04
# x_pred min= 1.83e+04 x_pred max 6.52e+04
# ESS of normalized weights= 642.60339
# ESS>=0.5*M
# new ESS= 642.60339
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 4.59e+04 real consumption= 5.26e+04
# x_pred min= 1.56e+04 x_pred max 7.44e+04
# ESS of normalized weights= 420.362103
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.22e+04
# x_pred min= 3.20e+04 x_pred max 7.36e+04
# ESS of normalized weights= 839.15761
# ESS>=0.5*M
# new ESS= 839.15761
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.23e+04
# x_pred min= 2.12e+04 x_pred max 8.70e+04
# ESS of normalized weights= 631.532122
# ESS>=0.5*M
# new ESS= 631.532122
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.27e+04
# x_pred min= 2.08e+04 x_pred max 8.31e+04
# ESS of normalized weights= 533.525363
# ESS>=0.5*M
# new ESS= 533.525363
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.24e+04
# x_pred min= 1.57e+04 x_pred max 8.23e+04
# ESS of normalized weights= 429.955709
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 4.93e+04 real consumption= 4.52e+04
# x_pred min= 1.91e+04 x_pred max 6.63e+04
# ESS of normalized weights= 710.55112
# ESS>=0.5*M
# new ESS= 710.55112
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 4.20e+04
# x_pred min= 1.75e+04 x_pred max 7.41e+04
# ESS of normalized weights= 663.661925
# ESS>=0.5*M
# new ESS= 663.661925
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 4.93e+04 real consumption= 5.22e+04
# x_pred min= 1.71e+04 x_pred max 8.45e+04
# ESS of normalized weights= 547.354936
# ESS>=0.5*M
# new ESS= 547.354936
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 4.91e+04 real consumption= 5.22e+04
# x_pred min= 5.45e+03 x_pred max 8.41e+04
# ESS of normalized weights= 460.331394
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.14e+04 real consumption= 5.20e+04
# x_pred min= 3.04e+04 x_pred max 7.68e+04
# ESS of normalized weights= 892.844748
# ESS>=0.5*M
# new ESS= 892.844748
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.22e+04
# x_pred min= 1.86e+04 x_pred max 8.71e+04
# ESS of normalized weights= 646.304086
# ESS>=0.5*M
# new ESS= 646.304086
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.14e+04
# x_pred min= 1.99e+04 x_pred max 9.40e+04
# ESS of normalized weights= 441.907223
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 4.68e+04 real consumption= 4.47e+04
# x_pred min= 2.56e+04 x_pred max 6.42e+04
# ESS of normalized weights= 638.406398
# ESS>=0.5*M
# new ESS= 638.406398
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 4.14e+04
# x_pred min= 1.44e+04 x_pred max 6.97e+04
# ESS of normalized weights= 602.295094
# ESS>=0.5*M
# new ESS= 602.295094
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 4.68e+04 real consumption= 5.42e+04
# x_pred min= 1.11e+04 x_pred max 7.48e+04
# ESS of normalized weights= 471.260944
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.47e+04
# x_pred min= 2.96e+04 x_pred max 7.20e+04
# ESS of normalized weights= 862.552116
# ESS>=0.5*M
# new ESS= 862.552116
# ------------------------
# n= 118
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.47e+04
# x_pred min= 1.82e+04 x_pred max 8.38e+04
# ESS of normalized weights= 679.246235
# ESS>=0.5*M
# new ESS= 679.246235
# ------------------------
# n= 119
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.60e+04
# x_pred min= 7.33e+03 x_pred max 8.80e+04
# ESS of normalized weights= 603.706412
# ESS>=0.5*M
# new ESS= 603.706412
# ------------------------
# n= 120
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 4.54e+04
# x_pred min= 1.78e+03 x_pred max 1.15e+05
# ESS of normalized weights= 491.108843
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 121
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 4.68e+04
# x_pred min= 2.61e+04 x_pred max 6.84e+04
# ESS of normalized weights= 692.685881
# ESS>=0.5*M
# new ESS= 692.685881
# ------------------------
# n= 122
# No heating effect
# x_pred_mean = 4.65e+04 real consumption= 4.28e+04
# x_pred min= 1.44e+04 x_pred max 7.25e+04
# ESS of normalized weights= 660.80726
# ESS>=0.5*M
# new ESS= 660.80726
# ------------------------
# n= 123
# No heating effect
# x_pred_mean = 4.65e+04 real consumption= 5.29e+04
# x_pred min= 6.97e+03 x_pred max 7.36e+04
# ESS of normalized weights= 491.981499
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 124
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 5.25e+04
# x_pred min= 2.61e+04 x_pred max 7.73e+04
# ESS of normalized weights= 796.185785
# ESS>=0.5*M
# new ESS= 796.185785
# ------------------------
# n= 125
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.30e+04
# x_pred min= 2.21e+04 x_pred max 8.12e+04
# ESS of normalized weights= 623.282154
# ESS>=0.5*M
# new ESS= 623.282154
# ------------------------
# n= 126
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.26e+04
# x_pred min= 1.78e+04 x_pred max 8.90e+04
# ESS of normalized weights= 528.164262
# ESS>=0.5*M
# new ESS= 528.164262
# ------------------------
# n= 127
# No heating effect
# x_pred_mean = 4.93e+04 real consumption= 4.37e+04
# x_pred min= 1.12e+04 x_pred max 8.86e+04
# ESS of normalized weights= 425.10906
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 128
# No heating effect
# x_pred_mean = 4.89e+04 real consumption= 4.34e+04
# x_pred min= 2.14e+04 x_pred max 6.64e+04
# ESS of normalized weights= 506.203007
# ESS>=0.5*M
# new ESS= 506.203007
# ------------------------
# n= 129
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 3.94e+04
# x_pred min= 2.40e+04 x_pred max 7.42e+04
# ESS of normalized weights= 385.783652
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 130
# No heating effect
# x_pred_mean = 4.38e+04 real consumption= 5.15e+04
# x_pred min= 1.78e+04 x_pred max 7.08e+04
# ESS of normalized weights= 594.717873
# ESS>=0.5*M
# new ESS= 594.717873
# ------------------------
# n= 131
# No heating effect
# x_pred_mean = 4.40e+04 real consumption= 5.20e+04
# x_pred min= 2.39e+03 x_pred max 7.91e+04
# ESS of normalized weights= 394.567881
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 132
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.20e+04
# x_pred min= 2.66e+04 x_pred max 8.37e+04
# ESS of normalized weights= 827.777439
# ESS>=0.5*M
# new ESS= 827.777439
# ------------------------
# n= 133
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 4.28e+04
# x_pred min= 2.59e+04 x_pred max 8.22e+04
# ESS of normalized weights= 692.380769
# ESS>=0.5*M
# new ESS= 692.380769
# ------------------------
# n= 134
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 4.84e+04
# x_pred min= 1.04e+04 x_pred max 9.10e+04
# ESS of normalized weights= 553.126958
# ESS>=0.5*M
# new ESS= 553.126958
# ------------------------
# n= 135
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 4.47e+04
# x_pred min= 1.61e+04 x_pred max 9.26e+04
# ESS of normalized weights= 324.444476
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 136
# No heating effect
# x_pred_mean = 4.54e+04 real consumption= 3.98e+04
# x_pred min= 1.77e+04 x_pred max 6.65e+04
# ESS of normalized weights= 715.207689
# ESS>=0.5*M
# new ESS= 715.207689
# ------------------------
# n= 137
# No heating effect
# x_pred_mean = 4.56e+04 real consumption= 5.18e+04
# x_pred min= 7.15e+03 x_pred max 7.49e+04
# ESS of normalized weights= 505.467953
# ESS>=0.5*M
# new ESS= 505.467953
# ------------------------
# n= 138
# No heating effect
# x_pred_mean = 4.57e+04 real consumption= 5.32e+04
# x_pred min= 5.13e+03 x_pred max 8.26e+04
# ESS of normalized weights= 378.571885
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 139
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.41e+04
# x_pred min= 3.18e+04 x_pred max 7.56e+04
# ESS of normalized weights= 845.523671
# ESS>=0.5*M
# new ESS= 845.523671
# ------------------------
# n= 140
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.36e+04
# x_pred min= 2.63e+04 x_pred max 9.09e+04
# ESS of normalized weights= 673.571087
# ESS>=0.5*M
# new ESS= 673.571087
# ------------------------
# n= 141
# No heating effect
# x_pred_mean = 5.14e+04 real consumption= 5.20e+04
# x_pred min= 1.96e+04 x_pred max 9.44e+04
# ESS of normalized weights= 544.47882
# ESS>=0.5*M
# new ESS= 544.47882
# ------------------------
# n= 142
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 4.45e+04
# x_pred min= 1.83e+04 x_pred max 9.85e+04
# ESS of normalized weights= 256.274437
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 143
# No heating effect
# x_pred_mean = 4.55e+04 real consumption= 3.90e+04
# x_pred min= 1.85e+04 x_pred max 6.51e+04
# ESS of normalized weights= 686.346933
# ESS>=0.5*M
# new ESS= 686.346933
# ------------------------
# n= 144
# No heating effect
# x_pred_mean = 4.55e+04 real consumption= 4.27e+04
# x_pred min= 1.56e+04 x_pred max 7.48e+04
# ESS of normalized weights= 502.506697
# ESS>=0.5*M
# new ESS= 502.506697
# ------------------------
# n= 145
# No heating effect
# x_pred_mean = 4.58e+04 real consumption= 5.24e+04
# x_pred min= 1.53e+04 x_pred max 8.43e+04
# ESS of normalized weights= 392.529048
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 146
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.24e+04
# x_pred min= 2.12e+04 x_pred max 7.25e+04
# ESS of normalized weights= 848.439302
# ESS>=0.5*M
# new ESS= 848.439302
# ------------------------
# n= 147
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.28e+04
# x_pred min= 2.65e+04 x_pred max 7.83e+04
# ESS of normalized weights= 717.62514
# ESS>=0.5*M
# new ESS= 717.62514
# ------------------------
# n= 148
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.18e+04
# x_pred min= 2.36e+04 x_pred max 8.69e+04
# ESS of normalized weights= 553.670734
# ESS>=0.5*M
# new ESS= 553.670734
# ------------------------
# n= 149
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 4.41e+04
# x_pred min= 1.47e+04 x_pred max 9.68e+04
# ESS of normalized weights= 254.082054
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 150
# No heating effect
# x_pred_mean = 4.53e+04 real consumption= 4.00e+04
# x_pred min= 1.80e+04 x_pred max 6.91e+04
# ESS of normalized weights= 703.058541
# ESS>=0.5*M
# new ESS= 703.058541
# ------------------------
# n= 151
# No heating effect
# x_pred_mean = 4.51e+04 real consumption= 5.20e+04
# x_pred min= 5.50e+03 x_pred max 6.62e+04
# ESS of normalized weights= 515.775358
# ESS>=0.5*M
# new ESS= 515.775358
# ------------------------
# n= 152
# No heating effect
# x_pred_mean = 4.51e+04 real consumption= 5.31e+04
# x_pred min= 5.72e+03 x_pred max 7.88e+04
# ESS of normalized weights= 403.983192
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 153
# No heating effect
# x_pred_mean = 5.08e+04 real consumption= 5.38e+04
# x_pred min= 2.68e+04 x_pred max 7.51e+04
# ESS of normalized weights= 875.060007
# ESS>=0.5*M
# new ESS= 875.060007
# ------------------------
# n= 154
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.43e+04
# x_pred min= 2.12e+04 x_pred max 8.66e+04
# ESS of normalized weights= 752.150851
# ESS>=0.5*M
# new ESS= 752.150851
# ------------------------
# n= 155
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.44e+04
# x_pred min= 1.82e+04 x_pred max 9.98e+04
# ESS of normalized weights= 562.385565
# ESS>=0.5*M
# new ESS= 562.385565
# ------------------------
# n= 156
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 4.49e+04
# x_pred min= 1.59e+04 x_pred max 9.50e+04
# ESS of normalized weights= 274.149254
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 157
# No heating effect
# x_pred_mean = 4.46e+04 real consumption= 3.99e+04
# x_pred min= 2.17e+04 x_pred max 6.57e+04
# ESS of normalized weights= 630.214067
# ESS>=0.5*M
# new ESS= 630.214067
# ------------------------
# n= 158
# No heating effect
# x_pred_mean = 4.45e+04 real consumption= 5.25e+04
# x_pred min= 6.37e+03 x_pred max 7.46e+04
# ESS of normalized weights= 416.797343
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 159
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 5.29e+04
# x_pred min= 2.68e+04 x_pred max 8.87e+04
# ESS of normalized weights= 866.620876
# ESS>=0.5*M
# new ESS= 866.620876
# ------------------------
# n= 160
# No heating effect
# x_pred_mean = 5.06e+04 real consumption= 5.30e+04
# x_pred min= 2.79e+04 x_pred max 8.60e+04
# ESS of normalized weights= 699.750606
# ESS>=0.5*M
# new ESS= 699.750606
# ------------------------
# n= 161
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 5.43e+04
# x_pred min= 1.53e+04 x_pred max 9.46e+04
# ESS of normalized weights= 568.907235
# ESS>=0.5*M
# new ESS= 568.907235
# ------------------------
# n= 162
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.26e+04
# x_pred min= 1.57e+04 x_pred max 9.10e+04
# ESS of normalized weights= 470.06054
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 163
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 4.41e+04
# x_pred min= 2.60e+04 x_pred max 7.29e+04
# ESS of normalized weights= 590.716707
# ESS>=0.5*M
# new ESS= 590.716707
# ------------------------
# n= 164
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 3.96e+04
# x_pred min= 2.57e+04 x_pred max 8.94e+04
# ESS of normalized weights= 547.80547
# ESS>=0.5*M
# new ESS= 547.80547
# ------------------------
# n= 165
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 5.18e+04
# x_pred min= 2.29e+04 x_pred max 9.34e+04
# ESS of normalized weights= 356.139211
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 166
# No heating effect
# x_pred_mean = 5.27e+04 real consumption= 5.23e+04
# x_pred min= 2.62e+04 x_pred max 8.12e+04
# ESS of normalized weights= 777.14078
# ESS>=0.5*M
# new ESS= 777.14078
# ------------------------
# n= 167
# No heating effect
# x_pred_mean = 5.26e+04 real consumption= 5.27e+04
# x_pred min= 1.30e+04 x_pred max 8.36e+04
# ESS of normalized weights= 594.412811
# ESS>=0.5*M
# new ESS= 594.412811
# ------------------------
# n= 168
# No heating effect
# x_pred_mean = 5.26e+04 real consumption= 5.34e+04
# x_pred min= 4.35e+02 x_pred max 9.40e+04
# ESS of normalized weights= 459.4226
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 169
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 5.13e+04
# x_pred min= 3.35e+04 x_pred max 8.10e+04
# ESS of normalized weights= 663.300727
# ESS>=0.5*M
# new ESS= 663.300727
# ------------------------
# n= 170
# No heating effect
# x_pred_mean = 5.59e+04 real consumption= 4.36e+04
# x_pred min= 2.72e+04 x_pred max 9.90e+04
# ESS of normalized weights= 272.139671
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 171
# No heating effect
# x_pred_mean = 4.81e+04 real consumption= 3.96e+04
# x_pred min= 1.51e+04 x_pred max 6.80e+04
# ESS of normalized weights= 606.312642
# ESS>=0.5*M
# new ESS= 606.312642
# ------------------------
# n= 172
# No heating effect
# x_pred_mean = 4.80e+04 real consumption= 5.29e+04
# x_pred min= 1.07e+04 x_pred max 7.65e+04
# ESS of normalized weights= 399.255055
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 173
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 5.31e+04
# x_pred min= 3.62e+04 x_pred max 8.26e+04
# ESS of normalized weights= 876.443139
# ESS>=0.5*M
# new ESS= 876.443139
# ------------------------
# n= 174
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.31e+04
# x_pred min= 1.97e+04 x_pred max 9.40e+04
# ESS of normalized weights= 740.544878
# ESS>=0.5*M
# new ESS= 740.544878
# ------------------------
# n= 175
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.41e+04
# x_pred min= 1.98e+04 x_pred max 1.18e+05
# ESS of normalized weights= 624.889302
# ESS>=0.5*M
# new ESS= 624.889302
# ------------------------
# n= 176
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.40e+04
# x_pred min= 1.60e+04 x_pred max 1.30e+05
# ESS of normalized weights= 445.943964
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 177
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 4.52e+04
# x_pred min= 2.21e+04 x_pred max 6.82e+04
# ESS of normalized weights= 481.014194
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 178
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.11e+04
# x_pred min= 1.53e+04 x_pred max 6.93e+04
# ESS of normalized weights= 806.136858
# ESS>=0.5*M
# new ESS= 806.136858
# ------------------------
# n= 179
# No heating effect
# x_pred_mean = 4.68e+04 real consumption= 5.50e+04
# x_pred min= 2.04e+04 x_pred max 7.53e+04
# ESS of normalized weights= 650.468095
# ESS>=0.5*M
# new ESS= 650.468095
# ------------------------
# n= 180
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 5.66e+04
# x_pred min= 1.18e+04 x_pred max 7.92e+04
# ESS of normalized weights= 462.166849
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 181
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 5.77e+04
# x_pred min= 3.07e+04 x_pred max 7.75e+04
# ESS of normalized weights= 685.466314
# ESS>=0.5*M
# new ESS= 685.466314
# ------------------------
# n= 182
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.71e+04
# x_pred min= 2.35e+04 x_pred max 8.47e+04
# ESS of normalized weights= 500.744562
# ESS>=0.5*M
# new ESS= 500.744562
# ------------------------
# n= 183
# No heating effect
# x_pred_mean = 5.06e+04 real consumption= 5.70e+04
# x_pred min= 1.57e+04 x_pred max 8.95e+04
# ESS of normalized weights= 444.928413
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 184
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 4.83e+04
# x_pred min= 2.01e+04 x_pred max 7.49e+04
# ESS of normalized weights= 549.451713
# ESS>=0.5*M
# new ESS= 549.451713
# ------------------------
# n= 185
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.27e+04
# x_pred min= 1.26e+04 x_pred max 7.91e+04
# ESS of normalized weights= 523.293704
# ESS>=0.5*M
# new ESS= 523.293704
# ------------------------
# n= 186
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.63e+04
# x_pred min= 1.51e+04 x_pred max 8.60e+04
# ESS of normalized weights= 388.142366
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 187
# No heating effect
# x_pred_mean = 5.31e+04 real consumption= 5.71e+04
# x_pred min= 3.18e+04 x_pred max 7.94e+04
# ESS of normalized weights= 843.200123
# ESS>=0.5*M
# new ESS= 843.200123
# ------------------------
# n= 188
# No heating effect
# x_pred_mean = 5.31e+04 real consumption= 5.45e+04
# x_pred min= 2.40e+04 x_pred max 8.33e+04
# ESS of normalized weights= 703.416887
# ESS>=0.5*M
# new ESS= 703.416887
# ------------------------
# n= 189
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.43e+04
# x_pred min= 1.73e+04 x_pred max 9.19e+04
# ESS of normalized weights= 588.292335
# ESS>=0.5*M
# new ESS= 588.292335
# ------------------------
# n= 190
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.41e+04
# x_pred min= 1.09e+04 x_pred max 1.06e+05
# ESS of normalized weights= 400.061335
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 191
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 4.65e+04
# x_pred min= 2.65e+04 x_pred max 6.77e+04
# ESS of normalized weights= 466.98396
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 192
# No heating effect
# x_pred_mean = 4.61e+04 real consumption= 4.12e+04
# x_pred min= 1.45e+04 x_pred max 7.62e+04
# ESS of normalized weights= 748.531294
# ESS>=0.5*M
# new ESS= 748.531294
# ------------------------
# n= 193
# No heating effect
# x_pred_mean = 4.59e+04 real consumption= 4.97e+04
# x_pred min= 8.91e+03 x_pred max 7.32e+04
# ESS of normalized weights= 573.852537
# ESS>=0.5*M
# new ESS= 573.852537
# ------------------------
# n= 194
# No heating effect
# x_pred_mean = 4.59e+04 real consumption= 4.40e+04
# x_pred min= 1.07e+04 x_pred max 7.83e+04
# ESS of normalized weights= 465.439162
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 195
# No heating effect
# x_pred_mean = 5.01e+04 real consumption= 5.62e+04
# x_pred min= 3.05e+04 x_pred max 7.20e+04
# ESS of normalized weights= 898.602324
# ESS>=0.5*M
# new ESS= 898.602324
# ------------------------
# n= 196
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 5.75e+04
# x_pred min= 2.40e+04 x_pred max 7.48e+04
# ESS of normalized weights= 769.421576
# ESS>=0.5*M
# new ESS= 769.421576
# ------------------------
# n= 197
# No heating effect
# x_pred_mean = 5.01e+04 real consumption= 5.62e+04
# x_pred min= 2.07e+04 x_pred max 8.36e+04
# ESS of normalized weights= 522.70469
# ESS>=0.5*M
# new ESS= 522.70469
# ------------------------
# n= 198
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 4.70e+04
# x_pred min= 1.50e+04 x_pred max 8.47e+04
# ESS of normalized weights= 258.470664
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 199
# No heating effect
# x_pred_mean = 4.36e+04 real consumption= 4.16e+04
# x_pred min= 2.03e+04 x_pred max 6.22e+04
# ESS of normalized weights= 749.845118
# ESS>=0.5*M
# new ESS= 749.845118
# ------------------------
# n= 200
# No heating effect
# x_pred_mean = 4.35e+04 real consumption= 5.55e+04
# x_pred min= 1.29e+04 x_pred max 6.40e+04
# ESS of normalized weights= 604.278812
# ESS>=0.5*M
# new ESS= 604.278812
# ------------------------
# n= 201
# No heating effect
# x_pred_mean = 4.36e+04 real consumption= 5.70e+04
# x_pred min= 1.41e+04 x_pred max 7.86e+04
# ESS of normalized weights= 473.401708
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 202
# No heating effect
# x_pred_mean = 4.76e+04 real consumption= 5.58e+04
# x_pred min= 2.88e+04 x_pred max 6.87e+04
# ESS of normalized weights= 882.908592
# ESS>=0.5*M
# new ESS= 882.908592
# ------------------------
# n= 203
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 5.48e+04
# x_pred min= 1.41e+04 x_pred max 7.66e+04
# ESS of normalized weights= 756.41562
# ESS>=0.5*M
# new ESS= 756.41562
# ------------------------
# n= 204
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 5.42e+04
# x_pred min= 4.71e+01 x_pred max 7.57e+04
# ESS of normalized weights= 629.375204
# ESS>=0.5*M
# new ESS= 629.375204
# ------------------------
# n= 205
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 4.42e+04
# x_pred min= 5.03e+03 x_pred max 8.17e+04
# ESS of normalized weights= 339.903397
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 206
# No heating effect
# x_pred_mean = 4.28e+04 real consumption= 4.01e+04
# x_pred min= 1.85e+04 x_pred max 6.34e+04
# ESS of normalized weights= 855.193424
# ESS>=0.5*M
# new ESS= 855.193424
# ------------------------
# n= 207
# No heating effect
# x_pred_mean = 4.28e+04 real consumption= 5.12e+04
# x_pred min= 8.51e+03 x_pred max 7.47e+04
# ESS of normalized weights= 679.181626
# ESS>=0.5*M
# new ESS= 679.181626
# ------------------------
# n= 208
# No heating effect
# x_pred_mean = 4.28e+04 real consumption= 5.15e+04
# x_pred min= 3.47e+03 x_pred max 8.41e+04
# ESS of normalized weights= 533.414346
# ESS>=0.5*M
# new ESS= 533.414346
# ------------------------
# n= 209
# No heating effect
# x_pred_mean = 4.29e+04 real consumption= 5.11e+04
# x_pred min= 9.66e+02 x_pred max 1.01e+05
# ESS of normalized weights= 444.059958
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 210
# No heating effect
# x_pred_mean = 4.70e+04 real consumption= 5.02e+04
# x_pred min= 3.01e+04 x_pred max 6.91e+04
# ESS of normalized weights= 892.623293
# ESS>=0.5*M
# new ESS= 892.623293
# ------------------------
# n= 211
# No heating effect
# x_pred_mean = 4.72e+04 real consumption= 4.86e+04
# x_pred min= 2.03e+04 x_pred max 8.28e+04
# ESS of normalized weights= 610.926679
# ESS>=0.5*M
# new ESS= 610.926679
# ------------------------
# n= 212
# No heating effect
# x_pred_mean = 4.73e+04 real consumption= 4.21e+04
# x_pred min= 6.29e+03 x_pred max 8.55e+04
# ESS of normalized weights= 327.045103
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 213
# No heating effect
# x_pred_mean = 4.11e+04 real consumption= 3.84e+04
# x_pred min= 1.70e+04 x_pred max 5.87e+04
# ESS of normalized weights= 789.438076
# ESS>=0.5*M
# new ESS= 789.438076
# ------------------------
# n= 214
# No heating effect
# x_pred_mean = 4.11e+04 real consumption= 4.91e+04
# x_pred min= 8.13e+03 x_pred max 6.99e+04
# ESS of normalized weights= 625.484771
# ESS>=0.5*M
# new ESS= 625.484771
# ------------------------
# n= 215
# No heating effect
# x_pred_mean = 4.12e+04 real consumption= 4.80e+04
# x_pred min= 1.96e+03 x_pred max 7.50e+04
# ESS of normalized weights= 508.081915
# ESS>=0.5*M
# new ESS= 508.081915
# ------------------------
# n= 216
# No heating effect
# x_pred_mean = 4.11e+04 real consumption= 4.93e+04
# x_pred min= 4.11e+02 x_pred max 9.03e+04
# ESS of normalized weights= 406.463846
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 217
# No heating effect
# x_pred_mean = 4.60e+04 real consumption= 4.99e+04
# x_pred min= 2.74e+04 x_pred max 7.08e+04
# ESS of normalized weights= 891.684007
# ESS>=0.5*M
# new ESS= 891.684007
# ------------------------
# n= 218
# No heating effect
# x_pred_mean = 4.58e+04 real consumption= 4.95e+04
# x_pred min= 1.50e+04 x_pred max 8.09e+04
# ESS of normalized weights= 772.956232
# ESS>=0.5*M
# new ESS= 772.956232
# ------------------------
# n= 219
# No heating effect
# x_pred_mean = 4.58e+04 real consumption= 4.25e+04
# x_pred min= 1.11e+04 x_pred max 9.06e+04
# ESS of normalized weights= 545.016729
# ESS>=0.5*M
# new ESS= 545.016729
# ------------------------
# n= 220
# No heating effect
# x_pred_mean = 4.56e+04 real consumption= 3.76e+04
# x_pred min= 2.51e+03 x_pred max 1.02e+05
# ESS of normalized weights= 493.488227
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 221
# No heating effect
# x_pred_mean = 4.55e+04 real consumption= 4.57e+04
# x_pred min= 1.95e+04 x_pred max 7.63e+04
# ESS of normalized weights= 803.364804
# ESS>=0.5*M
# new ESS= 803.364804
# ------------------------
# n= 222
# No heating effect
# x_pred_mean = 4.57e+04 real consumption= 4.74e+04
# x_pred min= 1.89e+04 x_pred max 8.25e+04
# ESS of normalized weights= 564.381732
# ESS>=0.5*M
# new ESS= 564.381732
# ------------------------
# n= 223
# No heating effect
# x_pred_mean = 4.57e+04 real consumption= 4.85e+04
# x_pred min= 1.27e+04 x_pred max 7.94e+04
# ESS of normalized weights= 392.422607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 224
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 4.77e+04
# x_pred min= 3.10e+04 x_pred max 7.48e+04
# ESS of normalized weights= 879.22181
# ESS>=0.5*M
# new ESS= 879.22181
# ------------------------
# n= 225
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 4.59e+04
# x_pred min= 2.59e+04 x_pred max 7.97e+04
# ESS of normalized weights= 711.139394
# ESS>=0.5*M
# new ESS= 711.139394
# ------------------------
# n= 226
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 3.89e+04
# x_pred min= 7.35e+03 x_pred max 8.77e+04
# ESS of normalized weights= 457.662777
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 227
# No heating effect
# x_pred_mean = 4.54e+04 real consumption= 3.65e+04
# ...
# ESS of normalized weights= 536.563097
# ESS>=0.5*M
# new ESS= 536.563097
# ------------------------
# n= 289
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.27e+04
# x_pred min= 2.01e+04 x_pred max 8.65e+04
# ESS of normalized weights= 348.591805
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 290
# No heating effect
# x_pred_mean = 5.53e+04 real consumption= 4.87e+04
# x_pred min= 3.30e+04 x_pred max 7.84e+04
# ESS of normalized weights= 848.742305
# ESS>=0.5*M
# new ESS= 848.742305
# ------------------------
# n= 291
# No heating effect
# x_pred_mean = 5.53e+04 real consumption= 5.92e+04
# x_pred min= 9.74e+03 x_pred max 8.72e+04
# ESS of normalized weights= 714.31114
# ESS>=0.5*M
# new ESS= 714.31114
# ------------------------
# n= 292
# No heating effect
# x_pred_mean = 5.54e+04 real consumption= 5.99e+04
# x_pred min= 6.17e+03 x_pred max 9.60e+04
# ESS of normalized weights= 594.866481
# ESS>=0.5*M
# new ESS= 594.866481
# ------------------------
# n= 293
# No heating effect
# x_pred_mean = 5.52e+04 real consumption= 6.04e+04
# x_pred min= 5.52e+03 x_pred max 1.03e+05
# ESS of normalized weights= 392.394093
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 294
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 6.07e+04
# x_pred min= 1.48e+04 x_pred max 7.50e+04
# ESS of normalized weights= 529.831789
# ESS>=0.5*M
# new ESS= 529.831789
# ------------------------
# n= 295
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.75e+04
# x_pred min= 5.93e+03 x_pred max 7.61e+04
# ESS of normalized weights= 513.075055
# ESS>=0.5*M
# new ESS= 513.075055
# ------------------------
# n= 296
# No heating effect
# x_pred_mean = 5.14e+04 real consumption= 4.92e+04
# x_pred min= 9.92e+03 x_pred max 9.81e+04
# ESS of normalized weights= 425.755112
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 297
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 4.42e+04
# x_pred min= 3.12e+04 x_pred max 8.55e+04
# ESS of normalized weights= 748.096312
# ESS>=0.5*M
# new ESS= 748.096312
# ------------------------
# n= 298
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 5.57e+04
# x_pred min= 2.18e+04 x_pred max 8.46e+04
# ESS of normalized weights= 641.348471
# ESS>=0.5*M
# new ESS= 641.348471
# ------------------------
# n= 299
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.66e+04
# x_pred min= 5.80e+03 x_pred max 9.15e+04
# ESS of normalized weights= 486.004876
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 300
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.72e+04
# x_pred min= 2.99e+04 x_pred max 7.96e+04
# ESS of normalized weights= 854.730008
# ESS>=0.5*M
# new ESS= 854.730008
# ------------------------
# n= 301
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.67e+04
# x_pred min= 1.94e+04 x_pred max 9.19e+04
# ESS of normalized weights= 566.493548
# ESS>=0.5*M
# new ESS= 566.493548
# ------------------------
# n= 302
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.47e+04
# x_pred min= 1.16e+04 x_pred max 9.78e+04
# ESS of normalized weights= 520.850482
# ESS>=0.5*M
# new ESS= 520.850482
# ------------------------
# n= 303
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 4.68e+04
# x_pred min= 5.52e+03 x_pred max 9.85e+04
# ESS of normalized weights= 389.907597
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 304
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 4.35e+04
# x_pred min= 2.44e+04 x_pred max 8.05e+04
# ESS of normalized weights= 899.993273
# ESS>=0.5*M
# new ESS= 899.993273
# ------------------------
# n= 305
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.76e+04
# x_pred min= 1.52e+04 x_pred max 9.61e+04
# ESS of normalized weights= 736.440972
# ESS>=0.5*M
# new ESS= 736.440972
# ------------------------
# n= 306
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.87e+04
# x_pred min= 6.62e+03 x_pred max 9.93e+04
# ESS of normalized weights= 556.677094
# ESS>=0.5*M
# new ESS= 556.677094
# ------------------------
# n= 307
# x_pred_mean = 9.92e+05 real consumption= 5.74e+04
# x_pred min= 6.54e+04 x_pred max 1.21e+07
# ESS of normalized weights= 3.38903
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 308
# x_pred_mean = 1.23e+05 real consumption= 5.60e+04
# x_pred min= 4.44e+04 x_pred max 5.42e+05
# ESS of normalized weights= 121.124597
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 309
# x_pred_mean = 1.06e+05 real consumption= 5.50e+04
# x_pred min= 4.02e+04 x_pred max 8.40e+05
# ESS of normalized weights= 318.359779
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 310
# x_pred_mean = 1.02e+05 real consumption= 4.60e+04
# x_pred min= 4.51e+04 x_pred max 3.82e+05
# ESS of normalized weights= 294.368957
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 311
# x_pred_mean = 6.74e+04 real consumption= 4.24e+04
# x_pred min= 3.68e+04 x_pred max 1.45e+05
# ESS of normalized weights= 529.694444
# ESS>=0.5*M
# new ESS= 529.694444
# ------------------------
# n= 312
# x_pred_mean = 9.19e+04 real consumption= 5.31e+04
# x_pred min= 2.84e+04 x_pred max 4.68e+05
# ESS of normalized weights= 183.559954
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 313
# x_pred_mean = 8.97e+04 real consumption= 5.49e+04
# x_pred min= 4.62e+04 x_pred max 2.96e+05
# ESS of normalized weights= 396.358598
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 314
# x_pred_mean = 7.62e+04 real consumption= 4.69e+04
# x_pred min= 3.95e+04 x_pred max 2.46e+05
# ESS of normalized weights= 416.407974
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 315
# No heating effect
# x_pred_mean = 5.50e+04 real consumption= 5.65e+04
# x_pred min= 1.53e+04 x_pred max 7.92e+04
# ESS of normalized weights= 761.35963
# ESS>=0.5*M
# new ESS= 761.35963
# ------------------------
# n= 316
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.67e+04
# x_pred min= 4.36e+03 x_pred max 8.28e+04
# ESS of normalized weights= 467.592256
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 317
# No heating effect
# x_pred_mean = 6.01e+04 real consumption= 5.10e+04
# x_pred min= 4.14e+04 x_pred max 8.33e+04
# ESS of normalized weights= 793.505962
# ESS>=0.5*M
# new ESS= 793.505962
# ------------------------
# n= 318
# x_pred_mean = 6.36e+04 real consumption= 4.54e+04
# x_pred min= 2.82e+04 x_pred max 1.00e+05
# ESS of normalized weights= 637.608357
# ESS>=0.5*M
# new ESS= 637.608357
# ------------------------
# n= 319
# x_pred_mean = 8.52e+04 real consumption= 5.80e+04
# x_pred min= 2.25e+04 x_pred max 2.61e+05
# ESS of normalized weights= 243.359072
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 320
# x_pred_mean = 7.43e+04 real consumption= 5.87e+04
# x_pred min= 4.36e+04 x_pred max 1.62e+05
# ESS of normalized weights= 538.031581
# ESS>=0.5*M
# new ESS= 538.031581
# ------------------------
# n= 321
# x_pred_mean = 8.71e+04 real consumption= 5.66e+04
# x_pred min= 3.60e+04 x_pred max 2.29e+05
# ESS of normalized weights= 181.11306
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 322
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 5.84e+04
# x_pred min= 2.56e+04 x_pred max 8.28e+04
# ESS of normalized weights= 757.597026
# ESS>=0.5*M
# new ESS= 757.597026
# ------------------------
# n= 323
# No heating effect
# x_pred_mean = 5.70e+04 real consumption= 5.99e+04
# x_pred min= 1.09e+04 x_pred max 8.39e+04
# ESS of normalized weights= 637.412422
# ESS>=0.5*M
# new ESS= 637.412422
# ------------------------
# n= 324
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 5.78e+04
# x_pred min= 1.75e+04 x_pred max 8.65e+04
# ESS of normalized weights= 466.489626
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 325
# x_pred_mean = 9.37e+04 real consumption= 5.51e+04
# x_pred min= 4.64e+04 x_pred max 3.29e+05
# ESS of normalized weights= 278.94003
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 326
# x_pred_mean = 1.09e+05 real consumption= 6.84e+04
# x_pred min= 4.62e+04 x_pred max 4.13e+05
# ESS of normalized weights= 252.220195
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 327
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 7.37e+04
# x_pred min= 3.10e+04 x_pred max 8.45e+04
# ESS of normalized weights= 654.001386
# ESS>=0.5*M
# new ESS= 654.001386
# ------------------------
# n= 328
# No heating effect
# x_pred_mean = 5.95e+04 real consumption= 6.96e+04
# x_pred min= 3.20e+04 x_pred max 8.72e+04
# ESS of normalized weights= 641.581149
# ESS>=0.5*M
# new ESS= 641.581149
# ------------------------
# n= 329
# x_pred_mean = 8.50e+04 real consumption= 6.73e+04
# x_pred min= 4.11e+04 x_pred max 2.25e+05
# ESS of normalized weights= 131.687454
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 330
# x_pred_mean = 5.96e+04 real consumption= 6.82e+04
# x_pred min= 3.10e+04 x_pred max 8.56e+04
# ESS of normalized weights= 638.23756
# ESS>=0.5*M
# new ESS= 638.23756
# ------------------------
# n= 331
# No heating effect
# x_pred_mean = 5.77e+04 real consumption= 6.04e+04
# x_pred min= 2.83e+04 x_pred max 1.17e+05
# ESS of normalized weights= 381.149883
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 332
# No heating effect
# x_pred_mean = 6.32e+04 real consumption= 5.67e+04
# x_pred min= 4.23e+04 x_pred max 8.73e+04
# ESS of normalized weights= 893.045781
# ESS>=0.5*M
# new ESS= 893.045781
# ------------------------
# n= 333
# No heating effect
# x_pred_mean = 6.32e+04 real consumption= 6.49e+04
# x_pred min= 3.69e+04 x_pred max 9.76e+04
# ESS of normalized weights= 770.531864
# ESS>=0.5*M
# new ESS= 770.531864
# ------------------------
# n= 334
# No heating effect
# x_pred_mean = 6.31e+04 real consumption= 6.40e+04
# x_pred min= 2.48e+04 x_pred max 9.24e+04
# ESS of normalized weights= 644.247938
# ESS>=0.5*M
# new ESS= 644.247938
# ------------------------
# n= 335
# No heating effect
# x_pred_mean = 6.32e+04 real consumption= 6.45e+04
# x_pred min= 1.82e+04 x_pred max 1.03e+05
# ESS of normalized weights= 389.032259
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 336
# No heating effect
# x_pred_mean = 5.82e+04 real consumption= 6.62e+04
# x_pred min= 3.69e+04 x_pred max 7.11e+04
# ESS of normalized weights= 633.574196
# ESS>=0.5*M
# new ESS= 633.574196
# ------------------------
# n= 337
# No heating effect
# x_pred_mean = 5.83e+04 real consumption= 6.40e+04
# x_pred min= 2.51e+04 x_pred max 8.27e+04
# ESS of normalized weights= 617.605311
# ESS>=0.5*M
# new ESS= 617.605311
# ------------------------
# n= 338
# No heating effect
# x_pred_mean = 5.82e+04 real consumption= 5.90e+04
# x_pred min= 2.70e+04 x_pred max 8.39e+04
# ESS of normalized weights= 531.911487
# ESS>=0.5*M
# new ESS= 531.911487
# ------------------------
# n= 339
# No heating effect
# x_pred_mean = 5.80e+04 real consumption= 5.30e+04
# x_pred min= 1.33e+04 x_pred max 8.98e+04
# ESS of normalized weights= 451.304125
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 340
# No heating effect
# x_pred_mean = 5.79e+04 real consumption= 6.14e+04
# x_pred min= 3.92e+04 x_pred max 7.73e+04
# ESS of normalized weights= 878.889899
# ESS>=0.5*M
# new ESS= 878.889899
# ------------------------
# n= 341
# No heating effect
# x_pred_mean = 5.78e+04 real consumption= 6.45e+04
# x_pred min= 2.54e+04 x_pred max 8.01e+04
# ESS of normalized weights= 328.187575
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 342
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 6.41e+04
# x_pred min= 2.58e+04 x_pred max 6.89e+04
# ESS of normalized weights= 813.490457
# ESS>=0.5*M
# new ESS= 813.490457
# ------------------------
# n= 343
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 6.88e+04
# x_pred min= 1.96e+04 x_pred max 8.74e+04
# ESS of normalized weights= 599.625153
# ESS>=0.5*M
# new ESS= 599.625153
# ------------------------
# n= 344
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 6.72e+04
# x_pred min= 1.59e+04 x_pred max 8.69e+04
# ESS of normalized weights= 483.812243
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 345
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 5.78e+04
# x_pred min= 2.76e+04 x_pred max 7.93e+04
# ESS of normalized weights= 813.199982
# ESS>=0.5*M
# new ESS= 813.199982
# ------------------------
# n= 346
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.71e+04
# x_pred min= 1.85e+04 x_pred max 8.66e+04
# ESS of normalized weights= 613.174676
# ESS>=0.5*M
# new ESS= 613.174676
# ------------------------
# n= 347
# x_pred_mean = 6.21e+04 real consumption= 6.72e+04
# x_pred min= 3.04e+04 x_pred max 1.15e+05
# ESS of normalized weights= 396.912726
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 348
# x_pred_mean = 1.72e+05 real consumption= 6.71e+04
# x_pred min= 5.01e+04 x_pred max 7.11e+05
# ESS of normalized weights= 25.646694
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 349
# x_pred_mean = 9.05e+04 real consumption= 6.40e+04
# x_pred min= 2.99e+04 x_pred max 3.52e+05
# ESS of normalized weights= 302.810176
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 350
# x_pred_mean = 9.39e+04 real consumption= 6.13e+04
# x_pred min= 3.24e+04 x_pred max 5.08e+05
# ESS of normalized weights= 310.132171
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 351
# x_pred_mean = 6.76e+04 real consumption= 6.01e+04
# x_pred min= 2.30e+04 x_pred max 2.88e+05
# ESS of normalized weights= 478.055596
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 352
# x_pred_mean = 1.02e+05 real consumption= 5.26e+04
# x_pred min= 2.57e+04 x_pred max 4.62e+05
# ESS of normalized weights= 276.745748
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 353
# x_pred_mean = 7.36e+04 real consumption= 5.06e+04
# x_pred min= 3.33e+04 x_pred max 2.22e+05
# ESS of normalized weights= 468.347048
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 354
# x_pred_mean = 5.78e+04 real consumption= 6.01e+04
# x_pred min= 9.96e+03 x_pred max 8.28e+04
# ESS of normalized weights= 432.255726
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 355
# x_pred_mean = 6.04e+04 real consumption= 5.93e+04
# x_pred min= 3.52e+04 x_pred max 8.53e+04
# ESS of normalized weights= 616.360761
# ESS>=0.5*M
# new ESS= 616.360761
# ------------------------
# n= 356
# x_pred_mean = 6.28e+04 real consumption= 5.77e+04
# x_pred min= 3.41e+04 x_pred max 9.61e+04
# ESS of normalized weights= 465.859348
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 357
# x_pred_mean = 7.78e+04 real consumption= 5.54e+04
# x_pred min= 4.37e+04 x_pred max 1.74e+05
# ESS of normalized weights= 246.944349
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 358
# x_pred_mean = 7.52e+04 real consumption= 4.47e+04
# x_pred min= 3.90e+04 x_pred max 1.89e+05
# ESS of normalized weights= 525.47056
# ESS>=0.5*M
# new ESS= 525.47056
# ------------------------
# n= 359
# x_pred_mean = 1.16e+05 real consumption= 4.89e+04
# x_pred min= 4.31e+04 x_pred max 7.76e+05
# ESS of normalized weights= 149.755417
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 360
# x_pred_mean = 9.76e+04 real consumption= 4.79e+04
# x_pred min= 3.14e+04 x_pred max 3.19e+05
# ESS of normalized weights= 350.84176
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 361
# x_pred_mean = 1.13e+05 real consumption= 5.70e+04
# x_pred min= 2.68e+04 x_pred max 4.82e+05
# ESS of normalized weights= 293.046599
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 362
# x_pred_mean = 1.13e+05 real consumption= 5.72e+04
# x_pred min= 3.74e+04 x_pred max 4.69e+05
# ESS of normalized weights= 285.19841
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 363
# x_pred_mean = 1.03e+05 real consumption= 5.78e+04
# x_pred min= 2.48e+04 x_pred max 4.95e+05
# ESS of normalized weights= 286.142441
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------
# n= 364
# x_pred_mean = 1.08e+05 real consumption= 5.77e+04
# x_pred min= 1.26e+04 x_pred max 3.91e+05
# ESS of normalized weights= 258.38173
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# ------------------------

# %%
fig=plt.figure(figsize=(12,6))
plt.plot(range(1,n_pred),ESS_calc[0,1:n_pred]/M)
plt.plot(range(1,n_pred),ESS_calc[1,1:n_pred]/M)
plt.plot(range(1,n_pred),ESS_calc[2,1:n_pred]/M)

plt.title("Evolution of ESS",fontweight='bold')
plt.xlabel('forecasted day')
plt.xlim(0,n_pred)
plt.show()

# %%
fig=plt.figure(figsize=(12,6))


plt.plot(range(n_pred),(x_predict[0,:]-consumption_day_ahead[:n_pred])/consumption_day_ahead[:n_pred],color='blue')
plt.plot(range(n_pred),(x_predict[1,:]-consumption_day_ahead[1:n_pred+1])/consumption_day_ahead[1:n_pred+1],color='orange')
plt.plot(range(n_pred),(x_predict[2,:]-consumption_day_ahead[2:n_pred+2])/consumption_day_ahead[2:n_pred+2],color='green')

plt.plot(range(n_pred-1),np.zeros(n_pred-1),color='red',linestyle='--')
plt.ylim(-1,1)
plt.xlim(0,n_pred)
plt.xlabel('forecasted day')
plt.title("Relative forecast error",fontweight='bold')
plt.show()

# %%
fig=plt.figure(figsize=(12,6))
plt.plot(range(n_pred),x_predict[0,:])
plt.plot(range(n_pred),x_predict[1,:])
plt.plot(range(n_pred),x_predict[2,:])
plt.plot(range(n_pred),consumption_day_ahead[:n_pred],linestyle='--')
plt.xlabel('forecasted day')
plt.ylim(10**4,10**5)
plt.title("Electricity load forecast in W",fontweight='bold')
plt.show()

# %% [markdown]
# Goal: re-estimate the one-dimensional parameters ($\sigma_g,\sigma_s,\mu_h,\kappa,\sigma$)<br>
# Proposal distribution for these parameters: truncated gaussian random walk<br>
# We set kappa constant at 1/8

# %% [markdown]
# ## PMMH

# %% [markdown]
# #### Initialization of parameters

# %%
u_h_current=13
sigma_current=10**4
sigma_g_current=10**4
sigma_s_current=10**4

# %%
len_filter_pmmh=365
len_iter_mha=100
accept_log_proba=np.zeros(len_filter_pmmh)
accept_rate=0
log_lh_init=np.zeros(len_filter_pmmh)
lh_y_prop=np.zeros(len_filter_pmmh)

# %%
#store the accepted value in lists
u_h_list=[]
sigma_list=[]
sigma_g_list=[]
sigma_s_list=[]

# %% [markdown]
# #### Initialization of hyperparameters

# %%
#standard deviation of normal/trunc normal proposals on parameters
std_hyp_sigma_g,std_hyp_sigma_s,std_hyp_sigma=np.ones(3)*5*10**3
std_hyp_u=1

# %%
#joint prior density of parameters
def log_joint_prior(u_h,sigma,sigma_g,sigma_s):
    res=0
    res=(-(u_h-14)**2)/2
    res=res+(-0.01-1)*np.log(sigma**2) - (0.01/sigma**2)
    res=res+(-0.01-1)*np.log(sigma_g**2) - (0.01/sigma_g**2)
    res=res+(-0.01-1)*np.log(sigma_s**2) - (0.01/sigma_s**2)
    return res

# %%
#joint log prior density initialize
log_prior_init=log_joint_prior(u_h_current,sigma_current,sigma_g_current,sigma_s_current)
print(log_prior_init)
#initial parameters otbained from Gibbs. These initialized parameters will not change through iterations
# Out:
# -56.3146626545

# %% [markdown]
# #### Run initial particle filter and get the log likelihood

# %%
log_lh_init=particle_filter(len_init,len_filter_pmmh,s_init,g_heat_init,sigma_s_current,sigma_g_current,sigma_current,lh_y_n)
# Out:
# n= 1
# x_pred_mean = 3.87e+04 real consumption= 6.86e+04
# x_pred min= 3.11e+02 x_pred max 2.01e+05
# ESS of normalized weights= 2098.24203
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 2
# x_pred_mean = 7.98e+04 real consumption= 6.41e+04
# x_pred min= 3.91e+02 x_pred max 3.89e+05
# ESS of normalized weights= 3844.213798
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 3
# x_pred_mean = 9.24e+04 real consumption= 5.74e+04
# x_pred min= 3.18e+02 x_pred max 6.05e+05
# ESS of normalized weights= 3788.696288
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 4
# x_pred_mean = 9.76e+04 real consumption= 7.31e+04
# x_pred min= 1.84e+02 x_pred max 5.80e+05
# ESS of normalized weights= 3795.480197
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 5
# x_pred_mean = 8.30e+04 real consumption= 7.68e+04
# x_pred min= 1.28e+03 x_pred max 4.57e+05
# ESS of normalized weights= 4427.549798
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 6
# x_pred_mean = 8.64e+04 real consumption= 7.49e+04
# x_pred min= 2.06e+03 x_pred max 4.72e+05
# ESS of normalized weights= 4599.980297
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 7
# x_pred_mean = 9.23e+04 real consumption= 7.21e+04
# x_pred min= 5.81e+02 x_pred max 5.86e+05
# ESS of normalized weights= 4389.972202
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 8
# x_pred_mean = 7.03e+04 real consumption= 6.90e+04
# x_pred min= 1.29e+03 x_pred max 4.93e+05
# ESS of normalized weights= 5017.803195
# ESS>=0.5*M
# new ESS= 5017.803195
# ------------------------
# n= 9
# x_pred_mean = 6.53e+04 real consumption= 5.72e+04
# x_pred min= 1.03e+03 x_pred max 5.13e+05
# ESS of normalized weights= 2546.00012
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 10
# x_pred_mean = 6.29e+04 real consumption= 5.55e+04
# x_pred min= 5.94e+02 x_pred max 3.20e+05
# ESS of normalized weights= 3904.563744
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 11
# x_pred_mean = 7.14e+04 real consumption= 6.91e+04
# x_pred min= 1.45e+03 x_pred max 2.78e+05
# ESS of normalized weights= 5093.083449
# ESS>=0.5*M
# new ESS= 5093.083449
# ------------------------
# n= 12
# x_pred_mean = 3.47e+04 real consumption= 6.88e+04
# x_pred min= 6.21e+02 x_pred max 1.89e+05
# ESS of normalized weights= 264.53563
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 13
# x_pred_mean = 1.29e+05 real consumption= 6.92e+04
# x_pred min= 7.50e+03 x_pred max 4.64e+05
# ESS of normalized weights= 2245.702289
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 14
# x_pred_mean = 1.20e+05 real consumption= 7.03e+04
# x_pred min= 4.13e+03 x_pred max 4.73e+05
# ESS of normalized weights= 2380.377135
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 15
# x_pred_mean = 1.08e+05 real consumption= 7.00e+04
# x_pred min= 3.71e+03 x_pred max 6.37e+05
# ESS of normalized weights= 2987.135875
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 16
# x_pred_mean = 1.06e+05 real consumption= 6.31e+04
# x_pred min= 2.38e+03 x_pred max 7.89e+05
# ESS of normalized weights= 3289.314923
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 17
# x_pred_mean = 9.63e+04 real consumption= 6.25e+04
# x_pred min= 2.03e+03 x_pred max 5.49e+05
# ESS of normalized weights= 4201.742558
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 18
# x_pred_mean = 1.14e+05 real consumption= 7.72e+04
# x_pred min= 1.77e+03 x_pred max 6.77e+05
# ESS of normalized weights= 3608.535687
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 19
# x_pred_mean = 1.06e+05 real consumption= 7.79e+04
# x_pred min= 9.44e+02 x_pred max 5.64e+05
# ESS of normalized weights= 4106.474607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 20
# x_pred_mean = 1.15e+05 real consumption= 7.92e+04
# x_pred min= 8.61e+02 x_pred max 6.27e+05
# ESS of normalized weights= 3806.651556
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 21
# x_pred_mean = 1.19e+05 real consumption= 7.84e+04
# x_pred min= 4.22e+03 x_pred max 6.80e+05
# ESS of normalized weights= 3620.761432
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 22
# x_pred_mean = 9.10e+04 real consumption= 7.89e+04
# x_pred min= 3.09e+03 x_pred max 5.24e+05
# ESS of normalized weights= 4688.147804
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 23
# x_pred_mean = 8.03e+04 real consumption= 7.12e+04
# x_pred min= 4.25e+03 x_pred max 4.18e+05
# ESS of normalized weights= 5333.184314
# ESS>=0.5*M
# new ESS= 5333.184314
# ------------------------
# n= 24
# x_pred_mean = 7.01e+04 real consumption= 6.55e+04
# x_pred min= 2.12e+03 x_pred max 3.01e+05
# ESS of normalized weights= 2650.093757
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 25
# x_pred_mean = 6.69e+04 real consumption= 7.75e+04
# x_pred min= 5.77e+03 x_pred max 1.70e+05
# ESS of normalized weights= 6455.12844
# ESS>=0.5*M
# new ESS= 6455.12844
# ------------------------
# n= 26
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 7.54e+04
# x_pred min= 2.26e+01 x_pred max 1.46e+05
# ESS of normalized weights= 3627.9347
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 27
# No heating effect
# x_pred_mean = 6.60e+04 real consumption= 7.65e+04
# x_pred min= 2.37e+04 x_pred max 1.23e+05
# ESS of normalized weights= 8135.33857
# ESS>=0.5*M
# new ESS= 8135.33857
# ------------------------
# n= 28
# No heating effect
# x_pred_mean = 6.61e+04 real consumption= 7.78e+04
# x_pred min= 6.24e+03 x_pred max 1.42e+05
# ESS of normalized weights= 6516.221481
# ESS>=0.5*M
# new ESS= 6516.221481
# ------------------------
# n= 29
# x_pred_mean = 9.45e+04 real consumption= 7.59e+04
# x_pred min= 1.28e+04 x_pred max 3.60e+05
# ESS of normalized weights= 2293.722023
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 30
# x_pred_mean = 7.74e+04 real consumption= 6.84e+04
# x_pred min= 1.79e+04 x_pred max 2.35e+05
# ESS of normalized weights= 5300.804567
# ESS>=0.5*M
# new ESS= 5300.804567
# ------------------------
# n= 31
# x_pred_mean = 9.03e+04 real consumption= 6.67e+04
# x_pred min= 8.56e+03 x_pred max 4.55e+05
# ESS of normalized weights= 3650.565223
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 32
# x_pred_mean = 7.43e+04 real consumption= 7.71e+04
# x_pred min= 7.70e+03 x_pred max 1.79e+05
# ESS of normalized weights= 7681.319586
# ESS>=0.5*M
# new ESS= 7681.319586
# ------------------------
# n= 33
# x_pred_mean = 6.35e+04 real consumption= 7.99e+04
# x_pred min= 1.99e+03 x_pred max 1.48e+05
# ESS of normalized weights= 5988.786218
# ESS>=0.5*M
# new ESS= 5988.786218
# ------------------------
# n= 34
# No heating effect
# x_pred_mean = 5.94e+04 real consumption= 8.21e+04
# x_pred min= 4.93e+02 x_pred max 1.70e+05
# ESS of normalized weights= 4607.351488
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 35
# No heating effect
# x_pred_mean = 6.64e+04 real consumption= 8.29e+04
# x_pred min= 2.36e+04 x_pred max 1.18e+05
# ESS of normalized weights= 8921.481948
# ESS>=0.5*M
# new ESS= 8921.481948
# ------------------------
# n= 36
# x_pred_mean = 1.55e+05 real consumption= 8.59e+04
# x_pred min= 2.22e+04 x_pred max 8.16e+05
# ESS of normalized weights= 1104.020863
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 37
# x_pred_mean = 8.07e+04 real consumption= 7.30e+04
# x_pred min= 2.09e+04 x_pred max 2.03e+05
# ESS of normalized weights= 5055.050696
# ESS>=0.5*M
# new ESS= 5055.050696
# ------------------------
# n= 38
# No heating effect
# x_pred_mean = 6.39e+04 real consumption= 6.70e+04
# x_pred min= 3.45e+02 x_pred max 1.12e+05
# ESS of normalized weights= 4529.453674
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 39
# x_pred_mean = 8.46e+04 real consumption= 7.57e+04
# x_pred min= 3.32e+04 x_pred max 2.74e+05
# ESS of normalized weights= 6628.485534
# ESS>=0.5*M
# new ESS= 6628.485534
# ------------------------
# n= 40
# No heating effect
# x_pred_mean = 6.46e+04 real consumption= 7.55e+04
# x_pred min= 7.01e+03 x_pred max 1.16e+05
# ESS of normalized weights= 5733.125148
# ESS>=0.5*M
# new ESS= 5733.125148
# ------------------------
# n= 41
# No heating effect
# x_pred_mean = 6.46e+04 real consumption= 7.16e+04
# x_pred min= 3.55e+02 x_pred max 1.32e+05
# ESS of normalized weights= 4927.705872
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 42
# x_pred_mean = 9.24e+04 real consumption= 7.21e+04
# x_pred min= 3.57e+04 x_pred max 3.30e+05
# ESS of normalized weights= 4911.92395
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 43
# No heating effect
# x_pred_mean = 6.49e+04 real consumption= 7.10e+04
# x_pred min= 2.00e+04 x_pred max 1.05e+05
# ESS of normalized weights= 9304.370169
# ESS>=0.5*M
# new ESS= 9304.370169
# ------------------------
# n= 44
# No heating effect
# x_pred_mean = 6.50e+04 real consumption= 6.39e+04
# x_pred min= 1.73e+04 x_pred max 1.17e+05
# ESS of normalized weights= 7584.264134
# ESS>=0.5*M
# new ESS= 7584.264134
# ------------------------
# n= 45
# No heating effect
# x_pred_mean = 6.50e+04 real consumption= 5.91e+04
# x_pred min= 3.25e+03 x_pred max 1.20e+05
# ESS of normalized weights= 7162.701928
# ESS>=0.5*M
# new ESS= 7162.701928
# ------------------------
# n= 46
# No heating effect
# x_pred_mean = 6.50e+04 real consumption= 7.23e+04
# x_pred min= 2.24e+03 x_pred max 1.26e+05
# ESS of normalized weights= 6562.829593
# ESS>=0.5*M
# new ESS= 6562.829593
# ------------------------
# n= 47
# x_pred_mean = 2.08e+05 real consumption= 7.28e+04
# x_pred min= 2.53e+04 x_pred max 1.64e+06
# ESS of normalized weights= 641.336282
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 48
# x_pred_mean = 6.76e+04 real consumption= 7.15e+04
# x_pred min= 1.53e+04 x_pred max 1.30e+05
# ESS of normalized weights= 8837.219644
# ESS>=0.5*M
# new ESS= 8837.219644
# ------------------------
# n= 49
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 7.06e+04
# x_pred min= 3.21e+03 x_pred max 1.06e+05
# ESS of normalized weights= 8133.31005
# ESS>=0.5*M
# new ESS= 8133.31005
# ------------------------
# n= 50
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 7.11e+04
# x_pred min= 4.97e+03 x_pred max 1.17e+05
# ESS of normalized weights= 7167.100726
# ESS>=0.5*M
# new ESS= 7167.100726
# ------------------------
# n= 51
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 6.54e+04
# x_pred min= 2.74e+03 x_pred max 1.21e+05
# ESS of normalized weights= 5263.654811
# ESS>=0.5*M
# new ESS= 5263.654811
# ------------------------
# n= 52
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 5.97e+04
# x_pred min= 3.52e+02 x_pred max 1.31e+05
# ESS of normalized weights= 5040.427073
# ESS>=0.5*M
# new ESS= 5040.427073
# ------------------------
# n= 53
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 7.10e+04
# x_pred min= 1.91e+02 x_pred max 1.35e+05
# ESS of normalized weights= 4655.849067
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 54
# No heating effect
# x_pred_mean = 5.96e+04 real consumption= 7.19e+04
# x_pred min= 2.74e+04 x_pred max 1.00e+05
# ESS of normalized weights= 9523.985742
# ESS>=0.5*M
# new ESS= 9523.985742
# ------------------------
# n= 55
# No heating effect
# x_pred_mean = 5.96e+04 real consumption= 7.05e+04
# x_pred min= 9.83e+03 x_pred max 1.14e+05
# ESS of normalized weights= 8777.944417
# ESS>=0.5*M
# new ESS= 8777.944417
# ------------------------
# n= 56
# x_pred_mean = 1.08e+05 real consumption= 6.99e+04
# x_pred min= 3.01e+04 x_pred max 5.08e+05
# ESS of normalized weights= 2475.72426
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 57
# x_pred_mean = 1.26e+05 real consumption= 6.90e+04
# x_pred min= 3.56e+04 x_pred max 5.87e+05
# ESS of normalized weights= 1603.997247
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 58
# x_pred_mean = 9.94e+04 real consumption= 6.19e+04
# x_pred min= 2.91e+04 x_pred max 7.02e+05
# ESS of normalized weights= 3379.947234
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 59
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 5.57e+04
# x_pred min= 1.84e+03 x_pred max 9.19e+04
# ESS of normalized weights= 7725.200509
# ESS>=0.5*M
# new ESS= 7725.200509
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 6.53e+04
# x_pred min= 1.87e+03 x_pred max 9.96e+04
# ESS of normalized weights= 6606.750961
# ESS>=0.5*M
# new ESS= 6606.750961
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 6.47e+04
# x_pred min= 8.72e+02 x_pred max 1.01e+05
# ESS of normalized weights= 5920.8014
# ESS>=0.5*M
# new ESS= 5920.8014
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 6.74e+04
# x_pred min= 1.04e+02 x_pred max 1.14e+05
# ESS of normalized weights= 4995.126574
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 5.96e+04 real consumption= 6.53e+04
# x_pred min= 2.71e+04 x_pred max 1.11e+05
# ESS of normalized weights= 9351.698552
# ESS>=0.5*M
# new ESS= 9351.698552
# ------------------------
# n= 64
# x_pred_mean = 8.65e+04 real consumption= 6.30e+04
# x_pred min= 2.64e+04 x_pred max 4.16e+05
# ESS of normalized weights= 3781.008786
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 65
# x_pred_mean = 8.05e+04 real consumption= 5.49e+04
# x_pred min= 3.41e+04 x_pred max 3.01e+05
# ESS of normalized weights= 4139.146754
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 4.87e+04
# x_pred min= 8.59e+03 x_pred max 8.78e+04
# ESS of normalized weights= 8867.916056
# ESS>=0.5*M
# new ESS= 8867.916056
# ------------------------
# n= 67
# x_pred_mean = 7.24e+04 real consumption= 6.02e+04
# x_pred min= 1.21e+04 x_pred max 2.49e+05
# ESS of normalized weights= 6378.952301
# ESS>=0.5*M
# new ESS= 6378.952301
# ------------------------
# n= 68
# x_pred_mean = 1.31e+05 real consumption= 6.20e+04
# x_pred min= 1.85e+04 x_pred max 9.53e+05
# ESS of normalized weights= 2091.145993
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 69
# x_pred_mean = 6.01e+04 real consumption= 6.01e+04
# x_pred min= 9.19e+03 x_pred max 1.05e+05
# ESS of normalized weights= 8432.389613
# ESS>=0.5*M
# new ESS= 8432.389613
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.96e+04
# x_pred min= 1.22e+03 x_pred max 1.09e+05
# ESS of normalized weights= 7419.111825
# ESS>=0.5*M
# new ESS= 7419.111825
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 6.18e+04
# x_pred min= 2.09e+03 x_pred max 1.23e+05
# ESS of normalized weights= 7062.339387
# ESS>=0.5*M
# new ESS= 7062.339387
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.74e+04
# x_pred min= 3.60e+02 x_pred max 1.29e+05
# ESS of normalized weights= 6374.163857
# ESS>=0.5*M
# new ESS= 6374.163857
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.60e+04
# x_pred min= 7.77e+02 x_pred max 1.51e+05
# ESS of normalized weights= 5805.558172
# ESS>=0.5*M
# new ESS= 5805.558172
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 6.36e+04
# x_pred min= 2.19e+01 x_pred max 1.34e+05
# ESS of normalized weights= 5209.048299
# ESS>=0.5*M
# new ESS= 5209.048299
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 6.06e+04
# x_pred min= 1.22e+02 x_pred max 1.39e+05
# ESS of normalized weights= 4615.036358
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 5.89e+04
# x_pred min= 2.46e+04 x_pred max 1.01e+05
# ESS of normalized weights= 9328.882949
# ESS>=0.5*M
# new ESS= 9328.882949
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 6.31e+04
# x_pred min= 1.14e+04 x_pred max 1.05e+05
# ESS of normalized weights= 8596.074525
# ESS>=0.5*M
# new ESS= 8596.074525
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.33e+04
# x_pred min= 2.52e+03 x_pred max 1.19e+05
# ESS of normalized weights= 7965.222387
# ESS>=0.5*M
# new ESS= 7965.222387
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 5.73e+04
# x_pred min= 4.48e+03 x_pred max 1.21e+05
# ESS of normalized weights= 6674.696908
# ESS>=0.5*M
# new ESS= 6674.696908
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 5.46e+04
# x_pred min= 2.74e+03 x_pred max 1.33e+05
# ESS of normalized weights= 5461.576173
# ESS>=0.5*M
# new ESS= 5461.576173
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.05e+04
# x_pred min= 2.73e+02 x_pred max 1.41e+05
# ESS of normalized weights= 5224.989453
# ESS>=0.5*M
# new ESS= 5224.989453
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.54e+04
# x_pred min= 4.76e+01 x_pred max 1.53e+05
# ESS of normalized weights= 4768.637168
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 6.75e+04
# x_pred min= 1.53e+04 x_pred max 9.32e+04
# ESS of normalized weights= 9526.478466
# ESS>=0.5*M
# new ESS= 9526.478466
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 6.80e+04
# x_pred min= 3.90e+01 x_pred max 9.96e+04
# ESS of normalized weights= 8721.424101
# ESS>=0.5*M
# new ESS= 8721.424101
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 6.20e+04
# x_pred min= 6.49e+02 x_pred max 1.17e+05
# ESS of normalized weights= 7360.99777
# ESS>=0.5*M
# new ESS= 7360.99777
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.41e+04
# x_pred min= 1.58e+03 x_pred max 1.26e+05
# ESS of normalized weights= 5174.082208
# ESS>=0.5*M
# new ESS= 5174.082208
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.19e+04
# x_pred min= 2.78e+02 x_pred max 1.22e+05
# ESS of normalized weights= 4925.724655
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 6.07e+04
# x_pred min= 1.16e+04 x_pred max 8.52e+04
# ESS of normalized weights= 9471.677745
# ESS>=0.5*M
# new ESS= 9471.677745
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 6.07e+04
# x_pred min= 5.24e+03 x_pred max 9.52e+04
# ESS of normalized weights= 8705.061149
# ESS>=0.5*M
# new ESS= 8705.061149
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 6.23e+04
# x_pred min= 5.91e+02 x_pred max 1.15e+05
# ESS of normalized weights= 7909.136947
# ESS>=0.5*M
# new ESS= 7909.136947
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 6.36e+04
# x_pred min= 8.13e+02 x_pred max 1.09e+05
# ESS of normalized weights= 7163.663774
# ESS>=0.5*M
# new ESS= 7163.663774
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 6.11e+04
# x_pred min= 8.23e+02 x_pred max 1.21e+05
# ESS of normalized weights= 6294.0853
# ESS>=0.5*M
# new ESS= 6294.0853
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 5.54e+04
# x_pred min= 1.35e+03 x_pred max 1.38e+05
# ESS of normalized weights= 5141.378095
# ESS>=0.5*M
# new ESS= 5141.378095
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 4.91e+04
# x_pred min= 3.71e+02 x_pred max 1.39e+05
# ESS of normalized weights= 4809.690237
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 4.96e+04
# x_pred min= 5.22e+03 x_pred max 8.63e+04
# ESS of normalized weights= 9495.270188
# ESS>=0.5*M
# new ESS= 9495.270188
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 5.87e+04
# x_pred min= 7.13e+03 x_pred max 9.85e+04
# ESS of normalized weights= 8738.122527
# ESS>=0.5*M
# new ESS= 8738.122527
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 5.70e+04
# x_pred min= 6.84e+03 x_pred max 9.86e+04
# ESS of normalized weights= 7972.668665
# ESS>=0.5*M
# new ESS= 7972.668665
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 5.49e+04
# x_pred min= 1.08e+03 x_pred max 1.17e+05
# ESS of normalized weights= 7271.408783
# ESS>=0.5*M
# new ESS= 7271.408783
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 5.35e+04
# x_pred min= 6.59e+02 x_pred max 1.12e+05
# ESS of normalized weights= 6577.745057
# ESS>=0.5*M
# new ESS= 6577.745057
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 4.79e+04
# x_pred min= 3.12e+02 x_pred max 1.20e+05
# ESS of normalized weights= 5550.725284
# ESS>=0.5*M
# new ESS= 5550.725284
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 4.19e+04
# x_pred min= 2.25e+02 x_pred max 1.38e+05
# ESS of normalized weights= 5198.183635
# ESS>=0.5*M
# new ESS= 5198.183635
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 5.26e+04
# x_pred min= 9.33e+02 x_pred max 1.42e+05
# ESS of normalized weights= 4635.124837
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.22e+04
# x_pred min= 2.13e+04 x_pred max 9.39e+04
# ESS of normalized weights= 9400.750816
# ESS>=0.5*M
# new ESS= 9400.750816
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.23e+04
# x_pred min= 4.55e+03 x_pred max 1.01e+05
# ESS of normalized weights= 8368.189065
# ESS>=0.5*M
# new ESS= 8368.189065
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.27e+04
# x_pred min= 2.15e+03 x_pred max 1.04e+05
# ESS of normalized weights= 7886.380683
# ESS>=0.5*M
# new ESS= 7886.380683
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.24e+04
# x_pred min= 7.23e+02 x_pred max 1.18e+05
# ESS of normalized weights= 7113.678772
# ESS>=0.5*M
# new ESS= 7113.678772
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.52e+04
# x_pred min= 7.92e+02 x_pred max 1.30e+05
# ESS of normalized weights= 6067.900813
# ESS>=0.5*M
# new ESS= 6067.900813
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 4.20e+04
# x_pred min= 2.42e+02 x_pred max 1.38e+05
# ESS of normalized weights= 5711.517573
# ESS>=0.5*M
# new ESS= 5711.517573
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.22e+04
# x_pred min= 6.03e+02 x_pred max 1.38e+05
# ESS of normalized weights= 5200.809448
# ESS>=0.5*M
# new ESS= 5200.809448
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.22e+04
# x_pred min= 1.04e+02 x_pred max 1.45e+05
# ESS of normalized weights= 4697.654183
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.20e+04
# x_pred min= 1.37e+04 x_pred max 9.03e+04
# ESS of normalized weights= 9540.299492
# ESS>=0.5*M
# new ESS= 9540.299492
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.08e+04 real consumption= 5.22e+04
# x_pred min= 2.47e+03 x_pred max 1.06e+05
# ESS of normalized weights= 8535.424898
# ESS>=0.5*M
# new ESS= 8535.424898
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 5.08e+04 real consumption= 5.14e+04
# x_pred min= 4.23e+03 x_pred max 9.87e+04
# ESS of normalized weights= 7320.476308
# ESS>=0.5*M
# new ESS= 7320.476308
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.47e+04
# x_pred min= 1.06e+03 x_pred max 1.16e+05
# ESS of normalized weights= 5740.968031
# ESS>=0.5*M
# new ESS= 5740.968031
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.14e+04
# x_pred min= 3.44e+02 x_pred max 1.26e+05
# ESS of normalized weights= 5648.87647
# ESS>=0.5*M
# new ESS= 5648.87647
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.42e+04
# x_pred min= 1.11e+02 x_pred max 1.50e+05
# ESS of normalized weights= 5234.649003
# ESS>=0.5*M
# new ESS= 5234.649003
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.47e+04
# x_pred min= 1.15e+02 x_pred max 1.54e+05
# ESS of normalized weights= 4795.468568
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 118
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.47e+04
# x_pred min= 1.07e+04 x_pred max 8.01e+04
# ESS of normalized weights= 9075.723196
# ESS>=0.5*M
# new ESS= 9075.723196
# ------------------------
# n= 119
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.60e+04
# x_pred min= 1.09e+03 x_pred max 9.43e+04
# ESS of normalized weights= 8546.555417
# ESS>=0.5*M
# new ESS= 8546.555417
# ------------------------
# n= 120
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 4.54e+04
# x_pred min= 1.28e+03 x_pred max 9.72e+04
# ESS of normalized weights= 7646.277054
# ESS>=0.5*M
# new ESS= 7646.277054
# ------------------------
# n= 121
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 4.68e+04
# x_pred min= 1.45e+03 x_pred max 1.14e+05
# ESS of normalized weights= 6340.886128
# ESS>=0.5*M
# new ESS= 6340.886128
# ------------------------
# n= 122
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 4.28e+04
# x_pred min= 1.86e+02 x_pred max 1.34e+05
# ESS of normalized weights= 6102.425464
# ESS>=0.5*M
# new ESS= 6102.425464
# ------------------------
# n= 123
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.29e+04
# x_pred min= 7.54e+01 x_pred max 1.30e+05
# ESS of normalized weights= 5581.835623
# ESS>=0.5*M
# new ESS= 5581.835623
# ------------------------
# n= 124
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.25e+04
# x_pred min= 4.51e+02 x_pred max 1.36e+05
# ESS of normalized weights= 4955.486902
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 125
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 5.30e+04
# x_pred min= 1.96e+04 x_pred max 9.39e+04
# ESS of normalized weights= 9393.670479
# ESS>=0.5*M
# new ESS= 9393.670479
# ------------------------
# n= 126
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 5.26e+04
# x_pred min= 8.08e+03 x_pred max 1.03e+05
# ESS of normalized weights= 8628.523648
# ESS>=0.5*M
# new ESS= 8628.523648
# ------------------------
# n= 127
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 4.37e+04
# x_pred min= 1.10e+03 x_pred max 1.10e+05
# ESS of normalized weights= 7927.453928
# ESS>=0.5*M
# new ESS= 7927.453928
# ------------------------
# n= 128
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 4.34e+04
# x_pred min= 3.70e+03 x_pred max 1.05e+05
# ESS of normalized weights= 6517.54038
# ESS>=0.5*M
# new ESS= 6517.54038
# ------------------------
# n= 129
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 3.94e+04
# x_pred min= 5.78e+02 x_pred max 1.12e+05
# ESS of normalized weights= 5658.867751
# ESS>=0.5*M
# new ESS= 5658.867751
# ------------------------
# n= 130
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 5.15e+04
# x_pred min= 1.06e+02 x_pred max 1.23e+05
# ESS of normalized weights= 5404.712177
# ESS>=0.5*M
# new ESS= 5404.712177
# ------------------------
# n= 131
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 5.20e+04
# x_pred min= 1.04e+02 x_pred max 1.30e+05
# ESS of normalized weights= 4895.204223
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 132
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 5.20e+04
# x_pred min= 7.92e+03 x_pred max 9.57e+04
# ESS of normalized weights= 9361.230475
# ESS>=0.5*M
# new ESS= 9361.230475
# ------------------------
# n= 133
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 4.28e+04
# x_pred min= 5.33e+03 x_pred max 9.83e+04
# ESS of normalized weights= 8541.115545
# ESS>=0.5*M
# new ESS= 8541.115545
# ------------------------
# n= 134
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 4.84e+04
# x_pred min= 9.64e+02 x_pred max 1.12e+05
# ESS of normalized weights= 7936.398659
# ESS>=0.5*M
# new ESS= 7936.398659
# ------------------------
# n= 135
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 4.47e+04
# x_pred min= 2.95e+03 x_pred max 1.15e+05
# ESS of normalized weights= 6808.200842
# ESS>=0.5*M
# new ESS= 6808.200842
# ------------------------
# n= 136
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 3.98e+04
# x_pred min= 5.32e+02 x_pred max 1.17e+05
# ESS of normalized weights= 6398.562829
# ESS>=0.5*M
# new ESS= 6398.562829
# ------------------------
# n= 137
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 5.18e+04
# x_pred min= 3.48e+02 x_pred max 1.31e+05
# ESS of normalized weights= 5723.254841
# ESS>=0.5*M
# new ESS= 5723.254841
# ------------------------
# n= 138
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 5.32e+04
# x_pred min= 1.04e+03 x_pred max 1.29e+05
# ESS of normalized weights= 5051.646027
# ESS>=0.5*M
# new ESS= 5051.646027
# ------------------------
# n= 139
# No heating effect
# x_pred_mean = 4.89e+04 real consumption= 5.41e+04
# x_pred min= 1.23e+02 x_pred max 1.43e+05
# ESS of normalized weights= 4433.753357
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 140
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.36e+04
# x_pred min= 2.10e+04 x_pred max 9.17e+04
# ESS of normalized weights= 9441.323874
# ESS>=0.5*M
# new ESS= 9441.323874
# ------------------------
# n= 141
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.20e+04
# x_pred min= 1.51e+04 x_pred max 9.57e+04
# ESS of normalized weights= 8628.326391
# ESS>=0.5*M
# new ESS= 8628.326391
# ------------------------
# n= 142
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 4.45e+04
# x_pred min= 4.33e+03 x_pred max 1.01e+05
# ESS of normalized weights= 6924.16942
# ESS>=0.5*M
# new ESS= 6924.16942
# ------------------------
# n= 143
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 3.90e+04
# x_pred min= 1.46e+03 x_pred max 1.08e+05
# ESS of normalized weights= 6715.410924
# ESS>=0.5*M
# new ESS= 6715.410924
# ------------------------
# n= 144
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 4.27e+04
# x_pred min= 2.88e+02 x_pred max 1.20e+05
# ESS of normalized weights= 6212.839865
# ESS>=0.5*M
# new ESS= 6212.839865
# ------------------------
# n= 145
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.24e+04
# x_pred min= 2.97e+02 x_pred max 1.27e+05
# ESS of normalized weights= 5662.697085
# ESS>=0.5*M
# new ESS= 5662.697085
# ------------------------
# n= 146
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.24e+04
# x_pred min= 1.33e+03 x_pred max 1.17e+05
# ESS of normalized weights= 5086.795437
# ESS>=0.5*M
# new ESS= 5086.795437
# ------------------------
# n= 147
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 5.28e+04
# x_pred min= 4.93e+02 x_pred max 1.34e+05
# ESS of normalized weights= 4603.592645
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 148
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.18e+04
# x_pred min= 1.57e+04 x_pred max 9.09e+04
# ESS of normalized weights= 8892.965019
# ESS>=0.5*M
# new ESS= 8892.965019
# ------------------------
# n= 149
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 4.41e+04
# x_pred min= 2.62e+00 x_pred max 9.59e+04
# ESS of normalized weights= 6613.464236
# ESS>=0.5*M
# new ESS= 6613.464236
# ------------------------
# n= 150
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 4.00e+04
# x_pred min= 4.10e+03 x_pred max 1.00e+05
# ESS of normalized weights= 6694.338735
# ESS>=0.5*M
# new ESS= 6694.338735
# ------------------------
# n= 151
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.20e+04
# x_pred min= 4.19e+03 x_pred max 1.20e+05
# ESS of normalized weights= 6320.472052
# ESS>=0.5*M
# new ESS= 6320.472052
# ------------------------
# n= 152
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.31e+04
# x_pred min= 4.17e+03 x_pred max 1.12e+05
# ESS of normalized weights= 5829.974202
# ESS>=0.5*M
# new ESS= 5829.974202
# ------------------------
# n= 153
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.38e+04
# x_pred min= 1.66e+03 x_pred max 1.21e+05
# ESS of normalized weights= 5311.277608
# ESS>=0.5*M
# new ESS= 5311.277608
# ------------------------
# n= 154
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.43e+04
# x_pred min= 8.63e+01 x_pred max 1.23e+05
# ESS of normalized weights= 4833.371273
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 155
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.44e+04
# x_pred min= 1.33e+04 x_pred max 8.25e+04
# ESS of normalized weights= 8900.381422
# ESS>=0.5*M
# new ESS= 8900.381422
# ------------------------
# n= 156
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.49e+04
# x_pred min= 1.90e+03 x_pred max 8.89e+04
# ESS of normalized weights= 6787.239496
# ESS>=0.5*M
# new ESS= 6787.239496
# ------------------------
# n= 157
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 3.99e+04
# x_pred min= 2.82e+03 x_pred max 1.00e+05
# ESS of normalized weights= 6939.231848
# ESS>=0.5*M
# new ESS= 6939.231848
# ------------------------
# n= 158
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.25e+04
# x_pred min= 2.74e+02 x_pred max 1.07e+05
# ESS of normalized weights= 6509.073418
# ESS>=0.5*M
# new ESS= 6509.073418
# ------------------------
# n= 159
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.29e+04
# x_pred min= 4.41e+02 x_pred max 1.11e+05
# ESS of normalized weights= 5974.16682
# ESS>=0.5*M
# new ESS= 5974.16682
# ------------------------
# n= 160
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.30e+04
# x_pred min= 3.17e+02 x_pred max 1.28e+05
# ESS of normalized weights= 5397.118622
# ESS>=0.5*M
# new ESS= 5397.118622
# ------------------------
# n= 161
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 5.43e+04
# x_pred min= 2.27e+02 x_pred max 1.32e+05
# ESS of normalized weights= 4854.189987
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 162
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.26e+04
# x_pred min= 1.44e+04 x_pred max 8.82e+04
# ESS of normalized weights= 8976.644667
# ESS>=0.5*M
# new ESS= 8976.644667
# ------------------------
# n= 163
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 4.41e+04
# x_pred min= 7.42e+03 x_pred max 1.01e+05
# ESS of normalized weights= 7007.487367
# ESS>=0.5*M
# new ESS= 7007.487367
# ------------------------
# n= 164
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 3.96e+04
# x_pred min= 3.26e+03 x_pred max 1.15e+05
# ESS of normalized weights= 7109.913044
# ESS>=0.5*M
# new ESS= 7109.913044
# ------------------------
# n= 165
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.18e+04
# x_pred min= 4.13e+03 x_pred max 1.22e+05
# ESS of normalized weights= 6531.973629
# ESS>=0.5*M
# new ESS= 6531.973629
# ------------------------
# n= 166
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 5.23e+04
# x_pred min= 7.27e+02 x_pred max 1.27e+05
# ESS of normalized weights= 5726.334507
# ESS>=0.5*M
# new ESS= 5726.334507
# ------------------------
# n= 167
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.27e+04
# x_pred min= 1.06e+03 x_pred max 1.45e+05
# ESS of normalized weights= 5012.336756
# ESS>=0.5*M
# new ESS= 5012.336756
# ------------------------
# n= 168
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.34e+04
# x_pred min= 5.45e+02 x_pred max 1.45e+05
# ESS of normalized weights= 4397.904552
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 169
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.13e+04
# x_pred min= 1.39e+04 x_pred max 9.27e+04
# ESS of normalized weights= 9012.42278
# ESS>=0.5*M
# new ESS= 9012.42278
# ------------------------
# n= 170
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 4.36e+04
# x_pred min= 1.32e+03 x_pred max 1.05e+05
# ESS of normalized weights= 6834.964768
# ESS>=0.5*M
# new ESS= 6834.964768
# ------------------------
# n= 171
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 3.96e+04
# x_pred min= 6.62e+03 x_pred max 1.13e+05
# ESS of normalized weights= 6907.570954
# ESS>=0.5*M
# new ESS= 6907.570954
# ------------------------
# n= 172
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.29e+04
# x_pred min= 4.14e+03 x_pred max 1.26e+05
# ESS of normalized weights= 6442.867106
# ESS>=0.5*M
# new ESS= 6442.867106
# ------------------------
# n= 173
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 5.31e+04
# x_pred min= 7.34e+02 x_pred max 1.43e+05
# ESS of normalized weights= 5895.134325
# ESS>=0.5*M
# new ESS= 5895.134325
# ------------------------
# n= 174
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 5.31e+04
# x_pred min= 2.86e+03 x_pred max 1.47e+05
# ESS of normalized weights= 5350.789412
# ESS>=0.5*M
# new ESS= 5350.789412
# ------------------------
# n= 175
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.41e+04
# x_pred min= 1.45e+03 x_pred max 1.39e+05
# ESS of normalized weights= 4844.622036
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 176
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.40e+04
# x_pred min= 1.55e+04 x_pred max 8.48e+04
# ESS of normalized weights= 8925.731939
# ESS>=0.5*M
# new ESS= 8925.731939
# ------------------------
# n= 177
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 4.52e+04
# x_pred min= 7.86e+03 x_pred max 9.34e+04
# ESS of normalized weights= 6517.465437
# ESS>=0.5*M
# new ESS= 6517.465437
# ------------------------
# n= 178
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 4.11e+04
# x_pred min= 1.09e+04 x_pred max 9.90e+04
# ESS of normalized weights= 6173.636474
# ESS>=0.5*M
# new ESS= 6173.636474
# ------------------------
# n= 179
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.50e+04
# x_pred min= 1.04e+03 x_pred max 1.15e+05
# ESS of normalized weights= 5078.742819
# ESS>=0.5*M
# new ESS= 5078.742819
# ------------------------
# n= 180
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.66e+04
# x_pred min= 4.34e+03 x_pred max 1.16e+05
# ESS of normalized weights= 5052.071649
# ESS>=0.5*M
# new ESS= 5052.071649
# ------------------------
# n= 181
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.77e+04
# x_pred min= 3.62e+03 x_pred max 1.23e+05
# ESS of normalized weights= 4593.114339
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 182
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.71e+04
# x_pred min= 1.51e+04 x_pred max 9.18e+04
# ESS of normalized weights= 9362.515555
# ESS>=0.5*M
# new ESS= 9362.515555
# ------------------------
# n= 183
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.70e+04
# x_pred min= 1.01e+04 x_pred max 9.76e+04
# ESS of normalized weights= 8703.985666
# ESS>=0.5*M
# new ESS= 8703.985666
# ------------------------
# n= 184
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 4.83e+04
# x_pred min= 4.56e+03 x_pred max 1.07e+05
# ESS of normalized weights= 7135.971941
# ESS>=0.5*M
# new ESS= 7135.971941
# ------------------------
# n= 185
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 4.27e+04
# x_pred min= 1.59e+03 x_pred max 1.08e+05
# ESS of normalized weights= 6903.649572
# ESS>=0.5*M
# new ESS= 6903.649572
# ------------------------
# n= 186
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.63e+04
# x_pred min= 3.88e+03 x_pred max 1.13e+05
# ESS of normalized weights= 6172.156202
# ESS>=0.5*M
# new ESS= 6172.156202
# ------------------------
# n= 187
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.71e+04
# x_pred min= 1.20e+02 x_pred max 1.19e+05
# ESS of normalized weights= 5527.672372
# ESS>=0.5*M
# new ESS= 5527.672372
# ------------------------
# n= 188
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.45e+04
# x_pred min= 4.57e+02 x_pred max 1.32e+05
# ESS of normalized weights= 4982.366177
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 189
# No heating effect
# x_pred_mean = 5.34e+04 real consumption= 5.43e+04
# x_pred min= 1.54e+04 x_pred max 8.98e+04
# ESS of normalized weights= 9540.2574
# ESS>=0.5*M
# new ESS= 9540.2574
# ------------------------
# n= 190
# No heating effect
# x_pred_mean = 5.34e+04 real consumption= 5.41e+04
# x_pred min= 5.46e+03 x_pred max 9.13e+04
# ESS of normalized weights= 8216.115817
# ESS>=0.5*M
# new ESS= 8216.115817
# ------------------------
# n= 191
# No heating effect
# x_pred_mean = 5.34e+04 real consumption= 4.65e+04
# x_pred min= 9.78e+02 x_pred max 1.00e+05
# ESS of normalized weights= 6000.048895
# ESS>=0.5*M
# new ESS= 6000.048895
# ------------------------
# n= 192
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 4.12e+04
# x_pred min= 9.48e+02 x_pred max 1.05e+05
# ESS of normalized weights= 5852.929208
# ESS>=0.5*M
# new ESS= 5852.929208
# ------------------------
# n= 193
# No heating effect
# x_pred_mean = 5.34e+04 real consumption= 4.97e+04
# x_pred min= 1.90e+03 x_pred max 1.16e+05
# ESS of normalized weights= 5471.967306
# ESS>=0.5*M
# new ESS= 5471.967306
# ------------------------
# n= 194
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 4.40e+04
# x_pred min= 3.64e+02 x_pred max 1.30e+05
# ESS of normalized weights= 5028.524721
# ESS>=0.5*M
# new ESS= 5028.524721
# ------------------------
# n= 195
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 5.62e+04
# x_pred min= 1.06e+03 x_pred max 1.39e+05
# ESS of normalized weights= 4580.820804
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 196
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 5.75e+04
# x_pred min= 5.50e+03 x_pred max 8.32e+04
# ESS of normalized weights= 9544.602118
# ESS>=0.5*M
# new ESS= 9544.602118
# ------------------------
# n= 197
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.62e+04
# x_pred min= 5.78e+02 x_pred max 1.12e+05
# ESS of normalized weights= 8164.436213
# ESS>=0.5*M
# new ESS= 8164.436213
# ------------------------
# n= 198
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 4.70e+04
# x_pred min= 1.87e+03 x_pred max 1.17e+05
# ESS of normalized weights= 6141.024189
# ESS>=0.5*M
# new ESS= 6141.024189
# ------------------------
# n= 199
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 4.16e+04
# x_pred min= 3.28e+03 x_pred max 1.28e+05
# ESS of normalized weights= 5979.138541
# ESS>=0.5*M
# new ESS= 5979.138541
# ------------------------
# n= 200
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 5.55e+04
# x_pred min= 2.89e+02 x_pred max 1.24e+05
# ESS of normalized weights= 5513.510793
# ESS>=0.5*M
# new ESS= 5513.510793
# ------------------------
# n= 201
# No heating effect
# x_pred_mean = 5.06e+04 real consumption= 5.70e+04
# x_pred min= 2.51e+02 x_pred max 1.24e+05
# ESS of normalized weights= 5062.085331
# ESS>=0.5*M
# new ESS= 5062.085331
# ------------------------
# n= 202
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 5.58e+04
# x_pred min= 9.20e+02 x_pred max 1.39e+05
# ESS of normalized weights= 4628.880752
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 203
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 5.48e+04
# x_pred min= 7.85e+03 x_pred max 9.01e+04
# ESS of normalized weights= 9540.35295
# ESS>=0.5*M
# new ESS= 9540.35295
# ------------------------
# n= 204
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 5.42e+04
# x_pred min= 2.85e+03 x_pred max 9.66e+04
# ESS of normalized weights= 8653.868221
# ESS>=0.5*M
# new ESS= 8653.868221
# ------------------------
# n= 205
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 4.42e+04
# x_pred min= 3.33e+02 x_pred max 1.05e+05
# ESS of normalized weights= 6966.980841
# ESS>=0.5*M
# new ESS= 6966.980841
# ------------------------
# n= 206
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 4.01e+04
# x_pred min= 9.94e+02 x_pred max 1.26e+05
# ESS of normalized weights= 6479.084927
# ESS>=0.5*M
# new ESS= 6479.084927
# ------------------------
# n= 207
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 5.12e+04
# x_pred min= 1.88e+03 x_pred max 1.28e+05
# ESS of normalized weights= 6007.502484
# ESS>=0.5*M
# new ESS= 6007.502484
# ------------------------
# n= 208
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 5.15e+04
# x_pred min= 2.80e+02 x_pred max 1.28e+05
# ESS of normalized weights= 5510.787748
# ESS>=0.5*M
# new ESS= 5510.787748
# ------------------------
# n= 209
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 5.11e+04
# x_pred min= 1.34e+01 x_pred max 1.33e+05
# ESS of normalized weights= 5015.280348
# ESS>=0.5*M
# new ESS= 5015.280348
# ------------------------
# n= 210
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 5.02e+04
# x_pred min= 2.84e+01 x_pred max 1.33e+05
# ESS of normalized weights= 4531.363534
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 211
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.86e+04
# x_pred min= 1.13e+03 x_pred max 8.35e+04
# ESS of normalized weights= 8862.003113
# ESS>=0.5*M
# new ESS= 8862.003113
# ------------------------
# n= 212
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.21e+04
# x_pred min= 4.78e+03 x_pred max 8.63e+04
# ESS of normalized weights= 6974.939239
# ESS>=0.5*M
# new ESS= 6974.939239
# ------------------------
# n= 213
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 3.84e+04
# x_pred min= 6.66e+02 x_pred max 8.94e+04
# ESS of normalized weights= 6810.148656
# ESS>=0.5*M
# new ESS= 6810.148656
# ------------------------
# n= 214
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.91e+04
# x_pred min= 3.67e+02 x_pred max 1.09e+05
# ESS of normalized weights= 6424.057387
# ESS>=0.5*M
# new ESS= 6424.057387
# ------------------------
# n= 215
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.80e+04
# x_pred min= 1.09e+03 x_pred max 1.10e+05
# ESS of normalized weights= 5948.228484
# ESS>=0.5*M
# new ESS= 5948.228484
# ------------------------
# n= 216
# No heating effect
# x_pred_mean = 4.66e+04 real consumption= 4.93e+04
# x_pred min= 4.09e+02 x_pred max 1.23e+05
# ESS of normalized weights= 5459.540017
# ESS>=0.5*M
# new ESS= 5459.540017
# ------------------------
# n= 217
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 4.99e+04
# x_pred min= 2.23e+02 x_pred max 1.29e+05
# ESS of normalized weights= 4954.029404
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 218
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 4.95e+04
# x_pred min= 1.20e+04 x_pred max 8.09e+04
# ESS of normalized weights= 9424.754683
# ESS>=0.5*M
# new ESS= 9424.754683
# ------------------------
# n= 219
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 4.25e+04
# x_pred min= 2.15e+03 x_pred max 8.94e+04
# ESS of normalized weights= 8060.036311
# ESS>=0.5*M
# new ESS= 8060.036311
# ------------------------
# n= 220
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 3.76e+04
# x_pred min= 3.14e+03 x_pred max 9.87e+04
# ESS of normalized weights= 7793.403499
# ESS>=0.5*M
# new ESS= 7793.403499
# ------------------------
# n= 221
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.57e+04
# x_pred min= 1.53e+03 x_pred max 1.01e+05
# ESS of normalized weights= 7096.196155
# ESS>=0.5*M
# new ESS= 7096.196155
# ------------------------
# n= 222
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.74e+04
# x_pred min= 1.10e+02 x_pred max 1.08e+05
# ESS of normalized weights= 6255.012726
# ESS>=0.5*M
# new ESS= 6255.012726
# ------------------------
# n= 223
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.85e+04
# x_pred min= 3.93e+02 x_pred max 1.07e+05
# ESS of normalized weights= 5409.668992
# ESS>=0.5*M
# new ESS= 5409.668992
# ------------------------
# n= 224
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.77e+04
# x_pred min= 3.09e+02 x_pred max 1.22e+05
# ESS of normalized weights= 4778.585876
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 225
# No heating effect
# x_pred_mean = 4.92e+04 real consumption= 4.59e+04
# x_pred min= 2.17e+04 x_pred max 8.71e+04
# ESS of normalized weights= 9277.634245
# ESS>=0.5*M
# new ESS= 9277.634245
# ------------------------
# n= 226
# No heating effect
# x_pred_mean = 4.92e+04 real consumption= 3.89e+04
# x_pred min= 4.43e+03 x_pred max 1.09e+05
# ESS of normalized weights= 7864.862308
# ESS>=0.5*M
# new ESS= 7864.862308
# ------------------------
# n= 227
# No heating effect
# x_pred_mean = 4.91e+04 real consumption= 3.65e+04
# x_pred min= 2.64e+03 x_pred max 1.24e+05
# ESS of normalized weights= 7562.299796
# ESS>=0.5*M
# new ESS= 7562.299796
# ...
# ESS>=0.5*M
# new ESS= 7745.182965
# ------------------------
# n= 289
# No heating effect
# x_pred_mean = 5.50e+04 real consumption= 5.27e+04
# x_pred min= 6.90e+02 x_pred max 1.32e+05
# ESS of normalized weights= 6133.762926
# ESS>=0.5*M
# new ESS= 6133.762926
# ------------------------
# n= 290
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 4.87e+04
# x_pred min= 1.24e+02 x_pred max 1.30e+05
# ESS of normalized weights= 6011.446388
# ESS>=0.5*M
# new ESS= 6011.446388
# ------------------------
# n= 291
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 5.92e+04
# x_pred min= 2.09e+02 x_pred max 1.34e+05
# ESS of normalized weights= 5453.292395
# ESS>=0.5*M
# new ESS= 5453.292395
# ------------------------
# n= 292
# No heating effect
# x_pred_mean = 5.50e+04 real consumption= 5.99e+04
# x_pred min= 9.98e+02 x_pred max 1.62e+05
# ESS of normalized weights= 4904.291315
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 293
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 6.04e+04
# x_pred min= 2.68e+04 x_pred max 8.67e+04
# ESS of normalized weights= 9532.953594
# ESS>=0.5*M
# new ESS= 9532.953594
# ------------------------
# n= 294
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 6.07e+04
# x_pred min= 1.58e+04 x_pred max 9.34e+04
# ESS of normalized weights= 8808.273322
# ESS>=0.5*M
# new ESS= 8808.273322
# ------------------------
# n= 295
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 5.75e+04
# x_pred min= 7.86e+03 x_pred max 1.08e+05
# ESS of normalized weights= 7636.636335
# ESS>=0.5*M
# new ESS= 7636.636335
# ------------------------
# n= 296
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 4.92e+04
# x_pred min= 1.68e+03 x_pred max 1.21e+05
# ESS of normalized weights= 5818.007646
# ESS>=0.5*M
# new ESS= 5818.007646
# ------------------------
# n= 297
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 4.42e+04
# x_pred min= 4.96e+01 x_pred max 1.28e+05
# ESS of normalized weights= 5592.650228
# ESS>=0.5*M
# new ESS= 5592.650228
# ------------------------
# n= 298
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 5.57e+04
# x_pred min= 1.00e+03 x_pred max 1.26e+05
# ESS of normalized weights= 5202.6539
# ESS>=0.5*M
# new ESS= 5202.6539
# ------------------------
# n= 299
# No heating effect
# x_pred_mean = 5.50e+04 real consumption= 5.66e+04
# x_pred min= 6.27e+02 x_pred max 1.46e+05
# ESS of normalized weights= 4539.978315
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 300
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.72e+04
# x_pred min= 8.38e+03 x_pred max 8.20e+04
# ESS of normalized weights= 9130.09871
# ESS>=0.5*M
# new ESS= 9130.09871
# ------------------------
# n= 301
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.67e+04
# x_pred min= 3.92e+03 x_pred max 8.98e+04
# ESS of normalized weights= 8012.188368
# ESS>=0.5*M
# new ESS= 8012.188368
# ------------------------
# n= 302
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.47e+04
# x_pred min= 2.10e+03 x_pred max 9.94e+04
# ESS of normalized weights= 7537.168014
# ESS>=0.5*M
# new ESS= 7537.168014
# ------------------------
# n= 303
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.68e+04
# x_pred min= 4.93e+03 x_pred max 1.05e+05
# ESS of normalized weights= 6878.141409
# ESS>=0.5*M
# new ESS= 6878.141409
# ------------------------
# n= 304
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 4.35e+04
# x_pred min= 9.16e+02 x_pred max 1.15e+05
# ESS of normalized weights= 6173.398766
# ESS>=0.5*M
# new ESS= 6173.398766
# ------------------------
# n= 305
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.76e+04
# x_pred min= 9.00e+02 x_pred max 1.32e+05
# ESS of normalized weights= 5343.765969
# ESS>=0.5*M
# new ESS= 5343.765969
# ------------------------
# n= 306
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.87e+04
# x_pred min= 1.72e+02 x_pred max 1.36e+05
# ESS of normalized weights= 4741.842617
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 307
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.74e+04
# x_pred min= 1.89e+04 x_pred max 9.13e+04
# ESS of normalized weights= 9408.995838
# ESS>=0.5*M
# new ESS= 9408.995838
# ------------------------
# n= 308
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.60e+04
# x_pred min= 9.62e+03 x_pred max 1.06e+05
# ESS of normalized weights= 8364.1675
# ESS>=0.5*M
# new ESS= 8364.1675
# ------------------------
# n= 309
# x_pred_mean = 9.53e+05 real consumption= 5.50e+04
# x_pred min= 4.34e+04 x_pred max 9.82e+06
# ESS of normalized weights= 95.370825
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 310
# x_pred_mean = 1.81e+05 real consumption= 4.60e+04
# x_pred min= 2.76e+04 x_pred max 2.43e+06
# ESS of normalized weights= 1681.245119
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 311
# x_pred_mean = 1.27e+05 real consumption= 4.24e+04
# x_pred min= 1.41e+04 x_pred max 1.61e+06
# ESS of normalized weights= 3931.910032
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 312
# x_pred_mean = 1.07e+05 real consumption= 5.31e+04
# x_pred min= 7.31e+03 x_pred max 1.31e+06
# ESS of normalized weights= 4584.586259
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 313
# x_pred_mean = 6.63e+04 real consumption= 5.49e+04
# x_pred min= 5.39e+03 x_pred max 2.18e+05
# ESS of normalized weights= 7425.366984
# ESS>=0.5*M
# new ESS= 7425.366984
# ------------------------
# n= 314
# x_pred_mean = 9.27e+04 real consumption= 4.69e+04
# x_pred min= 9.83e+03 x_pred max 5.51e+05
# ESS of normalized weights= 3815.639679
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 315
# x_pred_mean = 9.25e+04 real consumption= 5.65e+04
# x_pred min= 1.44e+04 x_pred max 3.84e+05
# ESS of normalized weights= 5076.387635
# ESS>=0.5*M
# new ESS= 5076.387635
# ------------------------
# n= 316
# x_pred_mean = 8.89e+04 real consumption= 5.67e+04
# x_pred min= 1.07e+04 x_pred max 4.06e+05
# ESS of normalized weights= 2992.680077
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 317
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 5.10e+04
# x_pred min= 2.30e+03 x_pred max 9.86e+04
# ESS of normalized weights= 8921.253802
# ESS>=0.5*M
# new ESS= 8921.253802
# ------------------------
# n= 318
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 4.54e+04
# x_pred min= 8.04e+00 x_pred max 9.89e+04
# ESS of normalized weights= 6930.231513
# ESS>=0.5*M
# new ESS= 6930.231513
# ------------------------
# n= 319
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 5.80e+04
# x_pred min= 3.24e+02 x_pred max 1.20e+05
# ESS of normalized weights= 5527.633797
# ESS>=0.5*M
# new ESS= 5527.633797
# ------------------------
# n= 320
# x_pred_mean = 5.69e+04 real consumption= 5.87e+04
# x_pred min= 5.65e+02 x_pred max 1.51e+05
# ESS of normalized weights= 4788.959601
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 321
# x_pred_mean = 8.48e+04 real consumption= 5.66e+04
# x_pred min= 3.20e+04 x_pred max 2.37e+05
# ESS of normalized weights= 5655.778301
# ESS>=0.5*M
# new ESS= 5655.778301
# ------------------------
# n= 322
# x_pred_mean = 9.27e+04 real consumption= 5.84e+04
# x_pred min= 2.42e+04 x_pred max 3.28e+05
# ESS of normalized weights= 3429.489518
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 323
# x_pred_mean = 8.01e+04 real consumption= 5.99e+04
# x_pred min= 3.18e+04 x_pred max 2.49e+05
# ESS of normalized weights= 4985.688166
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 324
# No heating effect
# x_pred_mean = 5.55e+04 real consumption= 5.78e+04
# x_pred min= 4.72e+03 x_pred max 1.01e+05
# ESS of normalized weights= 9164.88313
# ESS>=0.5*M
# new ESS= 9164.88313
# ------------------------
# n= 325
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.51e+04
# x_pred min= 2.96e+03 x_pred max 1.14e+05
# ESS of normalized weights= 8218.671283
# ESS>=0.5*M
# new ESS= 8218.671283
# ------------------------
# n= 326
# No heating effect
# x_pred_mean = 5.55e+04 real consumption= 6.84e+04
# x_pred min= 7.78e+02 x_pred max 1.23e+05
# ESS of normalized weights= 6981.861609
# ESS>=0.5*M
# new ESS= 6981.861609
# ------------------------
# n= 327
# x_pred_mean = 9.71e+04 real consumption= 7.37e+04
# x_pred min= 8.84e+03 x_pred max 4.86e+05
# ESS of normalized weights= 2748.68688
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 328
# x_pred_mean = 1.17e+05 real consumption= 6.96e+04
# x_pred min= 2.75e+04 x_pred max 5.93e+05
# ESS of normalized weights= 3054.307565
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 329
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 6.73e+04
# x_pred min= 1.12e+04 x_pred max 9.40e+04
# ESS of normalized weights= 8098.091082
# ESS>=0.5*M
# new ESS= 8098.091082
# ------------------------
# n= 330
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 6.82e+04
# x_pred min= 9.50e+02 x_pred max 9.45e+04
# ESS of normalized weights= 7781.474995
# ESS>=0.5*M
# new ESS= 7781.474995
# ------------------------
# n= 331
# x_pred_mean = 8.54e+04 real consumption= 6.04e+04
# x_pred min= 1.40e+04 x_pred max 4.47e+05
# ESS of normalized weights= 3252.361107
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 332
# x_pred_mean = 5.91e+04 real consumption= 5.67e+04
# x_pred min= 9.12e+03 x_pred max 1.01e+05
# ESS of normalized weights= 8554.263752
# ESS>=0.5*M
# new ESS= 8554.263752
# ------------------------
# n= 333
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 6.49e+04
# x_pred min= 1.86e+03 x_pred max 1.01e+05
# ESS of normalized weights= 6755.044083
# ESS>=0.5*M
# new ESS= 6755.044083
# ------------------------
# n= 334
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 6.40e+04
# x_pred min= 3.01e+03 x_pred max 1.22e+05
# ESS of normalized weights= 5892.992758
# ESS>=0.5*M
# new ESS= 5892.992758
# ------------------------
# n= 335
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 6.45e+04
# x_pred min= 7.24e+02 x_pred max 1.12e+05
# ESS of normalized weights= 5429.761783
# ESS>=0.5*M
# new ESS= 5429.761783
# ------------------------
# n= 336
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 6.62e+04
# x_pred min= 7.86e+02 x_pred max 1.15e+05
# ESS of normalized weights= 4988.100946
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 337
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 6.40e+04
# x_pred min= 2.55e+04 x_pred max 9.21e+04
# ESS of normalized weights= 8664.510429
# ESS>=0.5*M
# new ESS= 8664.510429
# ------------------------
# n= 338
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 5.90e+04
# x_pred min= 9.97e+03 x_pred max 1.13e+05
# ESS of normalized weights= 6689.391588
# ESS>=0.5*M
# new ESS= 6689.391588
# ------------------------
# n= 339
# No heating effect
# x_pred_mean = 6.09e+04 real consumption= 5.30e+04
# x_pred min= 8.06e+03 x_pred max 1.20e+05
# ESS of normalized weights= 6590.42335
# ESS>=0.5*M
# new ESS= 6590.42335
# ------------------------
# n= 340
# No heating effect
# x_pred_mean = 6.09e+04 real consumption= 6.14e+04
# x_pred min= 3.61e+03 x_pred max 1.33e+05
# ESS of normalized weights= 6112.884795
# ESS>=0.5*M
# new ESS= 6112.884795
# ------------------------
# n= 341
# No heating effect
# x_pred_mean = 6.08e+04 real consumption= 6.45e+04
# x_pred min= 3.38e+02 x_pred max 1.44e+05
# ESS of normalized weights= 5531.769683
# ESS>=0.5*M
# new ESS= 5531.769683
# ------------------------
# n= 342
# No heating effect
# x_pred_mean = 6.08e+04 real consumption= 6.41e+04
# x_pred min= 4.62e+02 x_pred max 1.64e+05
# ESS of normalized weights= 4905.543431
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 343
# No heating effect
# x_pred_mean = 5.75e+04 real consumption= 6.88e+04
# x_pred min= 2.66e+04 x_pred max 9.30e+04
# ESS of normalized weights= 7528.136057
# ESS>=0.5*M
# new ESS= 7528.136057
# ------------------------
# n= 344
# No heating effect
# x_pred_mean = 5.76e+04 real consumption= 6.72e+04
# x_pred min= 7.95e+03 x_pred max 1.06e+05
# ESS of normalized weights= 6095.170563
# ESS>=0.5*M
# new ESS= 6095.170563
# ------------------------
# n= 345
# No heating effect
# x_pred_mean = 5.75e+04 real consumption= 5.78e+04
# x_pred min= 8.13e+03 x_pred max 1.09e+05
# ESS of normalized weights= 4891.072048
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 346
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.71e+04
# x_pred min= 5.38e+03 x_pred max 8.18e+04
# ESS of normalized weights= 9003.573495
# ESS>=0.5*M
# new ESS= 9003.573495
# ------------------------
# n= 347
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 6.72e+04
# x_pred min= 6.48e+03 x_pred max 8.62e+04
# ESS of normalized weights= 7893.274265
# ESS>=0.5*M
# new ESS= 7893.274265
# ------------------------
# n= 348
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 6.71e+04
# x_pred min= 5.16e+02 x_pred max 1.04e+05
# ESS of normalized weights= 6908.613178
# ESS>=0.5*M
# new ESS= 6908.613178
# ------------------------
# n= 349
# x_pred_mean = 6.13e+04 real consumption= 6.40e+04
# x_pred min= 6.25e+03 x_pred max 1.30e+05
# ESS of normalized weights= 5597.302601
# ESS>=0.5*M
# new ESS= 5597.302601
# ------------------------
# n= 350
# x_pred_mean = 2.67e+05 real consumption= 6.13e+04
# x_pred min= 1.30e+04 x_pred max 1.89e+06
# ESS of normalized weights= 291.753069
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 351
# x_pred_mean = 9.21e+04 real consumption= 6.01e+04
# x_pred min= 1.52e+04 x_pred max 6.19e+05
# ESS of normalized weights= 4224.789212
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 352
# x_pred_mean = 9.79e+04 real consumption= 5.26e+04
# x_pred min= 1.85e+04 x_pred max 6.82e+05
# ESS of normalized weights= 3917.703963
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 353
# x_pred_mean = 6.97e+04 real consumption= 5.06e+04
# x_pred min= 6.29e+03 x_pred max 3.33e+05
# ESS of normalized weights= 6894.985062
# ESS>=0.5*M
# new ESS= 6894.985062
# ------------------------
# n= 354
# x_pred_mean = 1.18e+05 real consumption= 6.01e+04
# x_pred min= 1.33e+04 x_pred max 8.48e+05
# ESS of normalized weights= 2784.874468
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 355
# x_pred_mean = 7.44e+04 real consumption= 5.93e+04
# x_pred min= 1.32e+04 x_pred max 2.82e+05
# ESS of normalized weights= 6783.626626
# ESS>=0.5*M
# new ESS= 6783.626626
# ------------------------
# n= 356
# x_pred_mean = 5.69e+04 real consumption= 5.77e+04
# x_pred min= 4.37e+03 x_pred max 1.14e+05
# ESS of normalized weights= 4719.859503
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 357
# x_pred_mean = 5.72e+04 real consumption= 5.54e+04
# x_pred min= 1.85e+04 x_pred max 9.76e+04
# ESS of normalized weights= 7916.604884
# ESS>=0.5*M
# new ESS= 7916.604884
# ------------------------
# n= 358
# x_pred_mean = 6.00e+04 real consumption= 4.47e+04
# x_pred min= 1.92e+04 x_pred max 1.12e+05
# ESS of normalized weights= 7464.94835
# ESS>=0.5*M
# new ESS= 7464.94835
# ------------------------
# n= 359
# x_pred_mean = 7.98e+04 real consumption= 4.89e+04
# x_pred min= 1.82e+04 x_pred max 2.66e+05
# ESS of normalized weights= 3618.151911
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 360
# x_pred_mean = 7.94e+04 real consumption= 4.79e+04
# x_pred min= 2.69e+04 x_pred max 2.50e+05
# ESS of normalized weights= 6731.478108
# ESS>=0.5*M
# new ESS= 6731.478108
# ------------------------
# n= 361
# x_pred_mean = 1.25e+05 real consumption= 5.70e+04
# x_pred min= 2.14e+04 x_pred max 6.60e+05
# ESS of normalized weights= 2421.85333
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 362
# x_pred_mean = 1.00e+05 real consumption= 5.72e+04
# x_pred min= 2.49e+04 x_pred max 4.58e+05
# ESS of normalized weights= 4753.387815
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 363
# x_pred_mean = 1.13e+05 real consumption= 5.78e+04
# x_pred min= 1.69e+04 x_pred max 6.40e+05
# ESS of normalized weights= 4037.117696
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 364
# x_pred_mean = 1.14e+05 real consumption= 5.77e+04
# x_pred min= 9.53e+03 x_pred max 6.06e+05
# ESS of normalized weights= 4124.863314
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------

# %%
print(log_lh_init[len_filter_pmmh-1])
# Out:
# -242317.617466

# %% [markdown]
# #### PMMH Algorithm

# %%
for step in range(len_iter_mha):
    print("___________________________________________________________")
    print("Metropolis Hastings step:",step)
    #we need 6 inputs to compute the (log) acceptance probability log(r):
    #log_likelihood, joint prior density, log proposal density for both current parameters and proposed parameters
    #sample proposal for u_h, sigma, sigma_g, sigma_s
    u_h_prop=npr.normal(u_h_current,std_hyp_u,size=1)
    sigma_prop=stats.truncnorm.rvs(a=(0-sigma_current)/std_hyp_sigma,b=np.inf,scale=std_hyp_sigma,size=1)
    sigma_g_prop=stats.truncnorm.rvs(a=(0-sigma_g_current)/std_hyp_sigma_g,b=np.inf,scale=std_hyp_sigma_g,size=1)
    sigma_s_prop=stats.truncnorm.rvs(a=(0-sigma_s_current)/std_hyp_sigma_s,b=np.inf,scale=std_hyp_sigma_s,size=1)
    print("proposed parameters:","u_heat:",u_h_prop,"sigma:",sigma_prop,"sigma_g:",sigma_g_prop,"sigma_s:",sigma_s_prop)
    #1/run a particle filter with the proposed parameters to obtain a an estimation of likelihood proposed
    #  consider the likelihood of the last day of the fitering
    lh_y_prop=particle_filter(len_init,len_filter_pmmh,s_init,g_heat_init,sigma_s_prop,sigma_g_prop,sigma_prop,lh_y_n)
    print("log likelihood proposal of y:",np.sum(lh_y_prop))
    #2/generate prior proposals and compute joint log density of them
    log_prior_prop = log_joint_prior(u_h_prop,sigma_prop,sigma_g_prop,sigma_s_prop)
    print("proposed log prior:",log_prior_prop)
    #3/compute log proposal density h(current parameter|proposed parameter)
    current_log_density=np.log(stats.norm.cdf(sigma_current/std_hyp_sigma,loc=0,scale=1))+np.log(
        stats.norm.cdf(sigma_s_current/std_hyp_sigma_s,loc=0,scale=1))+np.log(
        stats.norm.cdf(sigma_g_current/std_hyp_sigma_g,loc=0,scale=1))
    print("proposal log density initial parameters given proposed param:",current_log_density)
    #4/log likelihood from initial parameters --> already done: log_lh_init
    #5/joint prior of the initial parameters: we already have them
    #6/compute log proposal density h(proposed parameter|current parameter)
    prop_log_density=np.log(stats.norm.cdf(sigma_prop/std_hyp_sigma,loc=0,scale=1))+np.log(
    stats.norm.cdf(sigma_s_prop/std_hyp_sigma_s,loc=0,scale=1))+np.log(
    stats.norm.cdf(sigma_g_prop/std_hyp_sigma_g,loc=0,scale=1))
    print("proposal log density proposed parameters given current param:",prop_log_density)
    #we add up these elements to construct the log acceptance probability
    #numerator
    accept_log_proba[step]=np.sum(lh_y_prop)+log_prior_prop+current_log_density
    #denominator
    accept_log_proba[step]=accept_log_proba[step]-np.sum(log_lh_init)-log_prior_init-prop_log_density
    print("acceptance log probability:",accept_log_proba[step])
    u=npr.random()
    #to get an acceptance rate > 5%, we need log_proba to be at least -3
    if(np.log(u)<min(0,accept_log_proba[step])):
        print("ACCEPT")
        accept_rate=accept_rate+1
        log_lh_init=lh_y_prop
        sigma_current=sigma_prop
        sigma_g_current=sigma_g_prop
        sigma_s_current=sigma_s_prop
        u_h_current=u_h_prop
        #store the accepted values
        u_h_list.append(u_h_current)
        sigma_list.append(sigma_current)
        sigma_g_list.append(sigma_g_current)
        sigma_s_list.append(sigma_s_current)
    else:
        print("REJECT")
# Out:
# ___________________________________________________________
# Metropolis Hastings step: 0
# proposed parameters: u_heat: [ 13.29860407] sigma: [-2045.40922051] sigma_g: [ 9804.88399488] sigma_s: [ 515.77711475]
# n= 1
# number of negative values: 0
# x_pred_mean = 9.40e+04 real consumption= 5.75e+04
# x_pred min= 1.10e+02 x_pred max 5.82e+05
# ESS of normalized weights= 777.956847
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 2
# number of negative values: 0
# x_pred_mean = 1.18e+05 real consumption= 6.65e+04
# x_pred min= 1.37e+03 x_pred max 8.19e+05
# ESS of normalized weights= 511.275031
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 3
# number of negative values: 0
# x_pred_mean = 1.23e+05 real consumption= 6.92e+04
# x_pred min= 6.49e+02 x_pred max 7.48e+05
# ESS of normalized weights= 616.93877
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 4
# number of negative values: 0
# x_pred_mean = 1.96e+05 real consumption= 6.97e+04
# x_pred min= 6.01e+03 x_pred max 1.20e+06
# ESS of normalized weights= 372.702453
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 5
# number of negative values: 0
# x_pred_mean = 1.59e+05 real consumption= 6.88e+04
# x_pred min= 1.74e+03 x_pred max 8.95e+05
# ESS of normalized weights= 348.54147
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 6
# number of negative values: 0
# x_pred_mean = 1.29e+05 real consumption= 6.73e+04
# x_pred min= 4.88e+03 x_pred max 4.93e+05
# ESS of normalized weights= 353.641157
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 7
# number of negative values: 0
# x_pred_mean = 5.09e+04 real consumption= 5.90e+04
# x_pred min= 2.44e+03 x_pred max 1.78e+05
# ESS of normalized weights= 7.173101
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 8
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.56e+04 real consumption= 5.74e+04
# x_pred min= 5.31e+01 x_pred max 1.05e+05
# ESS of normalized weights= 106.998345
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 9
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.25e+04 real consumption= 6.93e+04
# x_pred min= 1.36e+01 x_pred max 9.43e+04
# ESS of normalized weights= 12.12651
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 10
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.75e+04 real consumption= 7.06e+04
# x_pred min= 2.04e+01 x_pred max 9.02e+04
# ESS of normalized weights= 8.141149
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 11
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.77e+04 real consumption= 7.21e+04
# x_pred min= 4.91e-01 x_pred max 9.59e+04
# ESS of normalized weights= 14.299534
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 12
# number of negative values: 0
# x_pred_mean = 2.34e+04 real consumption= 7.34e+04
# x_pred min= 4.38e+02 x_pred max 8.52e+04
# ESS of normalized weights= 123.784495
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 13
# number of negative values: 0
# x_pred_mean = 6.12e+04 real consumption= 7.46e+04
# x_pred min= 3.69e+02 x_pred max 2.05e+05
# ESS of normalized weights= 1020.174644
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 14
# number of negative values: 0
# x_pred_mean = 8.49e+04 real consumption= 6.83e+04
# x_pred min= 1.61e+02 x_pred max 2.82e+05
# ESS of normalized weights= 461.813449
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 15
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.88e+04 real consumption= 6.50e+04
# x_pred min= 1.35e+02 x_pred max 6.57e+04
# ESS of normalized weights= 3.100933
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 16
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.90e+04 real consumption= 8.17e+04
# x_pred min= 2.14e+01 x_pred max 7.57e+04
# ESS of normalized weights= 34.962818
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 17
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.15e+04 real consumption= 8.01e+04
# x_pred min= 3.46e+01 x_pred max 7.24e+04
# ESS of normalized weights= 2.238905
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 18
# number of negative values: 0
# x_pred_mean = 2.39e+05 real consumption= 7.90e+04
# x_pred min= 3.25e+03 x_pred max 1.04e+06
# ESS of normalized weights= 276.469729
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 19
# number of negative values: 0
# x_pred_mean = 1.62e+05 real consumption= 7.77e+04
# x_pred min= 7.45e+02 x_pred max 5.77e+05
# ESS of normalized weights= 253.956133
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 20
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.58e+04 real consumption= 7.82e+04
# x_pred min= 2.97e+00 x_pred max 1.11e+05
# ESS of normalized weights= 953.111347
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 21
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.67e+04 real consumption= 6.41e+04
# x_pred min= 1.28e+01 x_pred max 1.16e+05
# ESS of normalized weights= 1220.61177
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 22
# number of negative values: 0
# x_pred_mean = 3.66e+05 real consumption= 5.73e+04
# x_pred min= 2.45e+04 x_pred max 1.45e+06
# ESS of normalized weights= 78.476688
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 23
# number of negative values: 0
# x_pred_mean = 5.77e+04 real consumption= 6.58e+04
# x_pred min= 1.11e+04 x_pred max 1.26e+05
# ESS of normalized weights= 687.365299
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 24
# number of negative values: 0
# x_pred_mean = 4.71e+05 real consumption= 6.64e+04
# x_pred min= 4.31e+04 x_pred max 1.35e+06
# ESS of normalized weights= 81.801334
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 25
# number of negative values: 0
# x_pred_mean = 5.83e+05 real consumption= 6.76e+04
# x_pred min= 3.49e+04 x_pred max 1.85e+06
# ESS of normalized weights= 25.272283
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 26
# number of negative values: 0
# x_pred_mean = 4.01e+05 real consumption= 6.68e+04
# x_pred min= 2.76e+04 x_pred max 1.74e+06
# ESS of normalized weights= 39.399511
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 27
# number of negative values: 0
# x_pred_mean = 4.15e+05 real consumption= 6.73e+04
# x_pred min= 5.06e+04 x_pred max 1.84e+06
# ESS of normalized weights= 13.179082
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 28
# number of negative values: 0
# x_pred_mean = 8.45e+04 real consumption= 6.15e+04
# x_pred min= 3.13e+04 x_pred max 1.58e+05
# ESS of normalized weights= 624.021895
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 29
# number of negative values: 0
# x_pred_mean = 3.27e+05 real consumption= 5.56e+04
# x_pred min= 3.29e+04 x_pred max 1.02e+06
# ESS of normalized weights= 79.370523
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 30
# number of negative values: 0
# x_pred_mean = 6.36e+05 real consumption= 6.44e+04
# x_pred min= 2.10e+04 x_pred max 2.31e+06
# ESS of normalized weights= 40.643531
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 31
# number of negative values: 0
# x_pred_mean = 7.46e+05 real consumption= 6.48e+04
# x_pred min= 9.34e+03 x_pred max 2.42e+06
# ESS of normalized weights= 17.40643
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 32
# number of negative values: 0
# x_pred_mean = 8.52e+05 real consumption= 6.78e+04
# x_pred min= 7.66e+03 x_pred max 2.29e+06
# ESS of normalized weights= 20.063802
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 33
# number of negative values: 0
# x_pred_mean = 7.09e+05 real consumption= 7.07e+04
# x_pred min= 2.11e+04 x_pred max 1.94e+06
# ESS of normalized weights= 24.215715
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 34
# number of negative values: 0
# x_pred_mean = 3.93e+05 real consumption= 6.51e+04
# x_pred min= 2.09e+04 x_pred max 9.58e+05
# ESS of normalized weights= 37.287212
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 35
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.50e+04 real consumption= 5.67e+04
# x_pred min= 1.98e+01 x_pred max 1.06e+05
# ESS of normalized weights= 1915.95164
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 36
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.56e+04 real consumption= 5.50e+04
# x_pred min= 6.68e+00 x_pred max 9.90e+04
# ESS of normalized weights= 1349.447439
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 37
# number of negative values: 0
# x_pred_mean = 5.18e+04 real consumption= 6.69e+04
# x_pred min= 5.69e+02 x_pred max 9.48e+04
# ESS of normalized weights= 1703.504793
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 38
# number of negative values: 0
# x_pred_mean = 8.04e+04 real consumption= 7.02e+04
# x_pred min= 4.07e+03 x_pred max 2.21e+05
# ESS of normalized weights= 835.284544
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 39
# number of negative values: 0
# x_pred_mean = 9.78e+04 real consumption= 7.12e+04
# x_pred min= 4.95e+03 x_pred max 2.92e+05
# ESS of normalized weights= 431.529836
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 40
# number of negative values: 0
# x_pred_mean = 3.32e+05 real consumption= 7.03e+04
# x_pred min= 1.34e+04 x_pred max 1.37e+06
# ESS of normalized weights= 103.605657
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 41
# number of negative values: 0
# x_pred_mean = 3.86e+05 real consumption= 7.26e+04
# x_pred min= 2.18e+03 x_pred max 1.40e+06
# ESS of normalized weights= 143.637323
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 42
# number of negative values: 0
# x_pred_mean = 5.34e+05 real consumption= 6.22e+04
# x_pred min= 2.78e+04 x_pred max 1.83e+06
# ESS of normalized weights= 10.062018
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 43
# number of negative values: 0
# x_pred_mean = 3.60e+05 real consumption= 5.75e+04
# x_pred min= 2.30e+04 x_pred max 1.49e+06
# ESS of normalized weights= 61.240585
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 44
# number of negative values: 0
# x_pred_mean = 3.12e+05 real consumption= 7.33e+04
# x_pred min= 1.81e+04 x_pred max 1.04e+06
# ESS of normalized weights= 77.882159
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 45
# number of negative values: 0
# x_pred_mean = 8.90e+04 real consumption= 7.28e+04
# x_pred min= 1.14e+04 x_pred max 2.09e+05
# ESS of normalized weights= 853.946055
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 46
# number of negative values: 0
# x_pred_mean = 1.50e+05 real consumption= 7.48e+04
# x_pred min= 1.73e+04 x_pred max 3.94e+05
# ESS of normalized weights= 291.802056
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 47
# number of negative values: 0
# x_pred_mean = 2.35e+05 real consumption= 7.64e+04
# x_pred min= 2.48e+04 x_pred max 6.48e+05
# ESS of normalized weights= 73.69278
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 48
# number of negative values: 0
# x_pred_mean = 2.16e+05 real consumption= 7.02e+04
# x_pred min= 1.93e+04 x_pred max 5.78e+05
# ESS of normalized weights= 41.211064
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 49
# number of negative values: 0
# x_pred_mean = 3.49e+05 real consumption= 6.25e+04
# x_pred min= 9.07e+03 x_pred max 1.05e+06
# ESS of normalized weights= 82.512385
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 50
# number of negative values: 0
# x_pred_mean = 4.31e+05 real consumption= 5.31e+04
# x_pred min= 8.47e+03 x_pred max 1.33e+06
# ESS of normalized weights= 39.380378
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 51
# number of negative values: 0
# x_pred_mean = 5.07e+05 real consumption= 6.66e+04
# x_pred min= 3.05e+03 x_pred max 1.25e+06
# ESS of normalized weights= 35.237557
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 52
# number of negative values: 0
# x_pred_mean = 4.63e+05 real consumption= 6.66e+04
# x_pred min= 2.72e+04 x_pred max 9.93e+05
# ESS of normalized weights= 9.230764
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 53
# number of negative values: 0
# x_pred_mean = 4.45e+05 real consumption= 6.83e+04
# x_pred min= 2.69e+04 x_pred max 1.10e+06
# ESS of normalized weights= 10.614152
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 54
# number of negative values: 0
# x_pred_mean = 1.71e+05 real consumption= 6.80e+04
# x_pred min= 2.24e+04 x_pred max 3.32e+05
# ESS of normalized weights= 28.114158
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 55
# number of negative values: 0
# x_pred_mean = 1.56e+05 real consumption= 6.77e+04
# x_pred min= 6.83e+04 x_pred max 3.08e+05
# ESS of normalized weights= 1.000991
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 56
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.83e+04 real consumption= 6.33e+04
# x_pred min= 1.17e+04 x_pred max 1.65e+05
# ESS of normalized weights= 310.493639
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 57
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.75e+04 real consumption= 5.98e+04
# x_pred min= 2.55e+01 x_pred max 1.82e+05
# ESS of normalized weights= 610.550185
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 58
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.56e+04 real consumption= 7.21e+04
# x_pred min= 1.60e+04 x_pred max 1.87e+05
# ESS of normalized weights= 1527.584349
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 59
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.50e+04 real consumption= 7.21e+04
# x_pred min= 2.53e+04 x_pred max 1.72e+05
# ESS of normalized weights= 1259.556343
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 60
# number of negative values: 0
# x_pred_mean = 6.81e+05 real consumption= 6.93e+04
# x_pred min= 5.45e+04 x_pred max 2.10e+06
# ESS of normalized weights= 20.540241
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 61
# number of negative values: 0
# x_pred_mean = 1.07e+05 real consumption= 7.07e+04
# x_pred min= 5.11e+04 x_pred max 2.08e+05
# ESS of normalized weights= 574.708443
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 62
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.92e+04 real consumption= 6.88e+04
# x_pred min= 1.32e+04 x_pred max 1.08e+05
# ESS of normalized weights= 1538.772438
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 63
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.55e+04 real consumption= 6.19e+04
# x_pred min= 2.10e+04 x_pred max 1.05e+05
# ESS of normalized weights= 252.499317
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 64
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.02e+04 real consumption= 5.89e+04
# x_pred min= 4.12e+04 x_pred max 1.17e+05
# ESS of normalized weights= 662.994559
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 65
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.31e+04 real consumption= 7.10e+04
# x_pred min= 4.50e+04 x_pred max 1.16e+05
# ESS of normalized weights= 388.998694
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 66
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.07e+04 real consumption= 7.09e+04
# x_pred min= 3.30e+04 x_pred max 1.22e+05
# ESS of normalized weights= 419.956006
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 67
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.68e+04 real consumption= 7.17e+04
# x_pred min= 2.89e+04 x_pred max 1.21e+05
# ESS of normalized weights= 1461.344052
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 68
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.71e+04 real consumption= 6.90e+04
# x_pred min= 2.95e+04 x_pred max 1.30e+05
# ESS of normalized weights= 1557.219246
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 69
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.98e+04 real consumption= 6.59e+04
# x_pred min= 1.20e+04 x_pred max 1.20e+05
# ESS of normalized weights= 962.203961
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 70
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.32e+04 real consumption= 5.67e+04
# x_pred min= 1.10e+03 x_pred max 1.34e+05
# ESS of normalized weights= 755.026838
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 71
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.64e+04 real consumption= 5.34e+04
# x_pred min= 2.78e+02 x_pred max 1.13e+05
# ESS of normalized weights= 749.883364
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 72
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.34e+04 real consumption= 6.39e+04
# x_pred min= 3.52e+02 x_pred max 1.28e+05
# ESS of normalized weights= 1703.268537
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 73
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.63e+04 real consumption= 6.24e+04
# x_pred min= 4.27e+01 x_pred max 1.46e+05
# ESS of normalized weights= 1043.361675
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 74
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.28e+04 real consumption= 7.02e+04
# x_pred min= 4.71e+01 x_pred max 1.40e+05
# ESS of normalized weights= 574.916872
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 75
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.60e+04 real consumption= 6.47e+04
# x_pred min= 3.73e+00 x_pred max 1.38e+05
# ESS of normalized weights= 1503.627407
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 76
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.67e+04 real consumption= 6.19e+04
# x_pred min= 4.35e+01 x_pred max 1.47e+05
# ESS of normalized weights= 971.204935
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 77
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.78e+04 real consumption= 5.69e+04
# x_pred min= 6.88e+01 x_pred max 1.12e+05
# ESS of normalized weights= 784.658831
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 78
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.33e+04 real consumption= 5.38e+04
# x_pred min= 3.91e+01 x_pred max 1.42e+05
# ESS of normalized weights= 1542.899805
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 79
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.92e+04 real consumption= 6.27e+04
# x_pred min= 1.26e+00 x_pred max 1.20e+05
# ESS of normalized weights= 556.691879
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 80
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.76e+04 real consumption= 6.07e+04
# x_pred min= 6.08e+00 x_pred max 1.09e+05
# ESS of normalized weights= 63.716259
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 81
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.86e+04 real consumption= 6.33e+04
# x_pred min= 1.06e+01 x_pred max 1.14e+05
# ESS of normalized weights= 24.037096
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 82
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.22e+04 real consumption= 6.20e+04
# x_pred min= 3.28e+00 x_pred max 1.13e+05
# ESS of normalized weights= 16.419265
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 83
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.67e+04 real consumption= 6.23e+04
# x_pred min= 3.86e+01 x_pred max 1.08e+05
# ESS of normalized weights= 105.788818
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 84
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.62e+04 real consumption= 5.16e+04
# x_pred min= 1.90e+01 x_pred max 1.12e+05
# ESS of normalized weights= 12.479753
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 85
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.29e+04 real consumption= 4.93e+04
# x_pred min= 1.68e+01 x_pred max 1.29e+05
# ESS of normalized weights= 1.002827
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 86
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.36e+04 real consumption= 5.09e+04
# x_pred min= 6.65e+00 x_pred max 1.40e+05
# ESS of normalized weights= 1.17328
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 87
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.41e+04 real consumption= 6.09e+04
# x_pred min= 8.82e+00 x_pred max 1.40e+05
# ESS of normalized weights= 3.997434
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 88
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.46e+04 real consumption= 6.09e+04
# x_pred min= 1.44e+01 x_pred max 1.52e+05
# ESS of normalized weights= 13.340572
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 89
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.02e+04 real consumption= 6.19e+04
# x_pred min= 8.28e+00 x_pred max 1.38e+05
# ESS of normalized weights= 20.266802
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 90
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.04e+04 real consumption= 6.16e+04
# x_pred min= 1.44e+01 x_pred max 1.12e+05
# ESS of normalized weights= 185.363148
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 91
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.74e+04 real consumption= 5.46e+04
# x_pred min= 1.47e+01 x_pred max 1.26e+05
# ESS of normalized weights= 351.025985
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 92
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.64e+04 real consumption= 4.58e+04
# x_pred min= 9.68e+00 x_pred max 1.22e+05
# ESS of normalized weights= 161.991837
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 93
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.51e+04 real consumption= 5.76e+04
# x_pred min= 1.31e+01 x_pred max 1.16e+05
# ESS of normalized weights= 125.654746
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 94
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.43e+04 real consumption= 5.79e+04
# x_pred min= 4.20e+01 x_pred max 1.31e+05
# ESS of normalized weights= 176.980676
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 95
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.94e+04 real consumption= 5.79e+04
# x_pred min= 1.57e+00 x_pred max 1.38e+05
# ESS of normalized weights= 122.388916
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 96
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.27e+04 real consumption= 5.94e+04
# x_pred min= 1.06e+00 x_pred max 1.19e+05
# ESS of normalized weights= 325.504045
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 97
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.56e+04 real consumption= 5.96e+04
# x_pred min= 1.04e+01 x_pred max 1.14e+05
# ESS of normalized weights= 479.684394
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 98
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.01e+04 real consumption= 5.25e+04
# x_pred min= 1.08e+00 x_pred max 9.83e+04
# ESS of normalized weights= 312.315118
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 99
# number of negative values: 0
# x_pred_mean = 3.77e+04 real consumption= 4.59e+04
# x_pred min= 5.81e+03 x_pred max 1.15e+05
# ESS of normalized weights= 600.430138
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 100
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.73e+04 real consumption= 5.68e+04
# x_pred min= 7.53e-01 x_pred max 1.17e+05
# ESS of normalized weights= 424.055236
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 101
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.56e+04 real consumption= 5.52e+04
# x_pred min= 2.90e+00 x_pred max 1.43e+05
# ESS of normalized weights= 94.819615
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 102
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.16e+04 real consumption= 5.58e+04
# x_pred min= 2.27e+00 x_pred max 1.44e+05
# ESS of normalized weights= 321.206047
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 103
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.67e+04 real consumption= 5.57e+04
# x_pred min= 2.76e+00 x_pred max 1.49e+05
# ESS of normalized weights= 110.761715
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 104
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.75e+04 real consumption= 5.45e+04
# x_pred min= 4.23e-01 x_pred max 1.33e+05
# ESS of normalized weights= 356.433758
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 105
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.40e+04 real consumption= 4.74e+04
# x_pred min= 3.74e+00 x_pred max 1.14e+05
# ESS of normalized weights= 911.910046
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 106
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.93e+04 real consumption= 4.55e+04
# x_pred min= 3.35e-01 x_pred max 1.21e+05
# ESS of normalized weights= 488.729983
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 107
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.12e+04 real consumption= 5.69e+04
# x_pred min= 2.27e+00 x_pred max 1.29e+05
# ESS of normalized weights= 686.109121
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 108
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.22e+04 real consumption= 5.50e+04
# x_pred min= 4.74e+01 x_pred max 1.63e+05
# ESS of normalized weights= 758.829463
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 109
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.89e+04 real consumption= 5.42e+04
# x_pred min= 9.95e+00 x_pred max 1.08e+05
# ESS of normalized weights= 755.560062
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 110
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.54e+04 real consumption= 5.43e+04
# x_pred min= 1.98e+01 x_pred max 1.41e+05
# ESS of normalized weights= 866.495757
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 111
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.58e+04 real consumption= 5.31e+04
# x_pred min= 6.39e+01 x_pred max 1.53e+05
# ESS of normalized weights= 798.769605
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 112
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.10e+04 real consumption= 4.93e+04
# x_pred min= 2.11e+03 x_pred max 1.39e+05
# ESS of normalized weights= 505.094268
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 113
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.20e+04 real consumption= 4.79e+04
# x_pred min= 3.24e+04 x_pred max 8.56e+04
# ESS of normalized weights= 1342.486699
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 114
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.53e+04 real consumption= 6.07e+04
# x_pred min= 3.55e+04 x_pred max 8.92e+04
# ESS of normalized weights= 659.267482
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 115
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.37e+04 real consumption= 6.10e+04
# x_pred min= 3.58e+04 x_pred max 9.30e+04
# ESS of normalized weights= 2074.572502
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 116
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.48e+04 real consumption= 6.08e+04
# x_pred min= 3.14e+04 x_pred max 1.03e+05
# ESS of normalized weights= 1084.983376
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 117
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.62e+04 real consumption= 5.90e+04
# x_pred min= 1.47e+04 x_pred max 1.08e+05
# ESS of normalized weights= 1046.585739
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 118
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.81e+04 real consumption= 5.73e+04
# x_pred min= 1.97e+02 x_pred max 1.18e+05
# ESS of normalized weights= 84.612146
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 119
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.84e+04 real consumption= 5.25e+04
# x_pred min= 2.71e+03 x_pred max 1.14e+05
# ESS of normalized weights= 176.686431
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 120
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.58e+04 real consumption= 4.69e+04
# x_pred min= 6.19e+02 x_pred max 1.09e+05
# ESS of normalized weights= 815.847657
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 121
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.41e+04 real consumption= 5.53e+04
# x_pred min= 1.34e+04 x_pred max 1.15e+05
# ESS of normalized weights= 477.442627
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 122
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.45e+04 real consumption= 5.46e+04
# x_pred min= 2.46e+04 x_pred max 1.47e+05
# ESS of normalized weights= 405.543152
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 123
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.86e+04 real consumption= 5.31e+04
# x_pred min= 3.02e+04 x_pred max 1.59e+05
# ESS of normalized weights= 410.734427
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 124
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.09e+04 real consumption= 4.24e+04
# x_pred min= 1.35e+04 x_pred max 1.65e+05
# ESS of normalized weights= 323.136669
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 125
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.74e+04 real consumption= 4.60e+04
# x_pred min= 2.47e+03 x_pred max 1.65e+05
# ESS of normalized weights= 167.07537
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 126
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.07e+05 real consumption= 4.25e+04
# x_pred min= 4.32e+03 x_pred max 1.84e+05
# ESS of normalized weights= 384.828363
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 127
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.32e+04 real consumption= 3.93e+04
# x_pred min= 1.44e+02 x_pred max 1.48e+05
# ESS of normalized weights= 303.169425
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 128
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.94e+04 real consumption= 5.17e+04
# x_pred min= 5.87e+01 x_pred max 1.60e+05
# ESS of normalized weights= 221.816608
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 129
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.90e+04 real consumption= 5.19e+04
# x_pred min= 6.73e+04 x_pred max 1.61e+05
# ESS of normalized weights= 1.000272
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 130
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.91e+04 real consumption= 5.30e+04
# x_pred min= 5.27e+04 x_pred max 1.65e+05
# ESS of normalized weights= 1.058649
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 131
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.91e+04 real consumption= 5.29e+04
# x_pred min= 3.85e+04 x_pred max 1.88e+05
# ESS of normalized weights= 3.997081
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 132
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.91e+04 real consumption= 5.22e+04
# x_pred min= 3.15e+04 x_pred max 1.93e+05
# ESS of normalized weights= 6.127692
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 133
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.92e+04 real consumption= 4.56e+04
# x_pred min= 8.64e+03 x_pred max 2.13e+05
# ESS of normalized weights= 8.811746
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 134
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.91e+04 real consumption= 4.11e+04
# x_pred min= 1.39e+04 x_pred max 2.24e+05
# ESS of normalized weights= 76.732105
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 135
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.93e+04 real consumption= 4.37e+04
# x_pred min= 6.23e+04 x_pred max 1.62e+05
# ESS of normalized weights= 1.0
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 136
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.94e+04 real consumption= 5.19e+04
# x_pred min= 4.62e+04 x_pred max 1.88e+05
# ESS of normalized weights= 1.273832
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 137
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.94e+04 real consumption= 5.26e+04
# x_pred min= 3.80e+04 x_pred max 1.95e+05
# ESS of normalized weights= 6.812203
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 138
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.94e+04 real consumption= 5.31e+04
# x_pred min= 3.24e+04 x_pred max 2.05e+05
# ESS of normalized weights= 9.97393
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 139
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.95e+04 real consumption= 5.16e+04
# x_pred min= 3.13e+04 x_pred max 2.21e+05
# ESS of normalized weights= 8.588104
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 140
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.95e+04 real consumption= 4.35e+04
# x_pred min= 2.22e+04 x_pred max 2.27e+05
# ESS of normalized weights= 13.590834
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 141
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.05e+05 real consumption= 4.09e+04
# x_pred min= 5.45e+04 x_pred max 1.64e+05
# ESS of normalized weights= 1.136045
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 142
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.05e+05 real consumption= 5.29e+04
# x_pred min= 4.50e+04 x_pred max 1.75e+05
# ESS of normalized weights= 7.415228
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 143
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.05e+05 real consumption= 5.28e+04
# x_pred min= 4.01e+04 x_pred max 2.04e+05
# ESS of normalized weights= 25.312436
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 144
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.17e+04
# x_pred min= 4.20e+04 x_pred max 1.53e+05
# ESS of normalized weights= 7.59082
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 145
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.07e+04
# x_pred min= 3.53e+04 x_pred max 1.70e+05
# ESS of normalized weights= 14.628507
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 146
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.22e+04 real consumption= 5.02e+04
# x_pred min= 3.81e+04 x_pred max 1.36e+05
# ESS of normalized weights= 10.375979
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 147
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.13e+04 real consumption= 4.30e+04
# x_pred min= 1.86e+04 x_pred max 1.34e+05
# ESS of normalized weights= 102.468475
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 148
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.33e+04 real consumption= 3.92e+04
# x_pred min= 2.59e+04 x_pred max 1.34e+05
# ESS of normalized weights= 358.261286
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 149
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.86e+04 real consumption= 5.22e+04
# x_pred min= 2.71e+04 x_pred max 1.33e+05
# ESS of normalized weights= 846.787701
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 150
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.65e+04 real consumption= 5.37e+04
# x_pred min= 1.47e+04 x_pred max 1.33e+05
# ESS of normalized weights= 573.744461
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 151
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.68e+04 real consumption= 5.29e+04
# x_pred min= 1.74e+03 x_pred max 1.36e+05
# ESS of normalized weights= 590.040047
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 152
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.28e+04 real consumption= 5.38e+04
# x_pred min= 5.38e+03 x_pred max 1.32e+05
# ESS of normalized weights= 476.361942
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 153
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.84e+04 real consumption= 5.21e+04
# x_pred min= 2.13e+04 x_pred max 1.45e+05
# ESS of normalized weights= 28.431556
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 154
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.12e+04 real consumption= 4.42e+04
# x_pred min= 1.55e+04 x_pred max 1.57e+05
# ESS of normalized weights= 42.302068
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 155
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 3.98e+04
# x_pred min= 3.49e+04 x_pred max 1.87e+05
# ESS of normalized weights= 109.627933
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 156
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.01e+05 real consumption= 5.07e+04
# x_pred min= 3.92e+04 x_pred max 1.97e+05
# ESS of normalized weights= 33.720668
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 157
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.61e+04 real consumption= 5.12e+04
# x_pred min= 6.77e+04 x_pred max 1.37e+05
# ESS of normalized weights= 1.000546
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 158
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.61e+04 real consumption= 5.14e+04
# x_pred min= 6.14e+04 x_pred max 1.49e+05
# ESS of normalized weights= 1.485931
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 159
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.61e+04 real consumption= 5.14e+04
# x_pred min= 4.69e+04 x_pred max 1.68e+05
# ESS of normalized weights= 1.799309
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 160
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.60e+04 real consumption= 5.01e+04
# x_pred min= 2.29e+04 x_pred max 1.67e+05
# ESS of normalized weights= 1.006248
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 161
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.60e+04 real consumption= 4.30e+04
# x_pred min= 1.97e+04 x_pred max 1.69e+05
# ESS of normalized weights= 1.000104
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 162
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.60e+04 real consumption= 3.95e+04
# x_pred min= 3.01e+04 x_pred max 1.77e+05
# ESS of normalized weights= 18.142891
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 163
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.08e+05 real consumption= 5.10e+04
# x_pred min= 5.96e+04 x_pred max 1.45e+05
# ESS of normalized weights= 2.560998
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 164
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.08e+05 real consumption= 5.08e+04
# x_pred min= 5.64e+04 x_pred max 1.57e+05
# ESS of normalized weights= 3.146114
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 165
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.08e+05 real consumption= 5.16e+04
# x_pred min= 4.88e+04 x_pred max 1.61e+05
# ESS of normalized weights= 5.028913
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 166
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.08e+05 real consumption= 5.16e+04
# x_pred min= 5.14e+04 x_pred max 1.76e+05
# ESS of normalized weights= 10.453429
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 167
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.07e+04
# x_pred min= 6.63e+04 x_pred max 1.48e+05
# ESS of normalized weights= 2.125496
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 168
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 4.37e+04
# x_pred min= 6.02e+04 x_pred max 1.56e+05
# ESS of normalized weights= 1.741376
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 169
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 3.96e+04
# x_pred min= 4.81e+04 x_pred max 1.63e+05
# ESS of normalized weights= 2.913844
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 170
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.18e+04
# x_pred min= 4.02e+04 x_pred max 1.73e+05
# ESS of normalized weights= 5.225691
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 171
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.29e+04
# x_pred min= 2.64e+04 x_pred max 1.76e+05
# ESS of normalized weights= 7.913862
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 172
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.04e+05 real consumption= 5.39e+04
# x_pred min= 2.22e+04 x_pred max 2.00e+05
# ESS of normalized weights= 26.330258
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 173
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.91e+04 real consumption= 5.44e+04
# x_pred min= 4.00e+04 x_pred max 1.86e+05
# ESS of normalized weights= 489.77554
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 174
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.38e+04 real consumption= 5.25e+04
# x_pred min= 2.31e+04 x_pred max 1.24e+05
# ESS of normalized weights= 1170.631678
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 175
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.50e+04 real consumption= 4.39e+04
# x_pred min= 2.37e+04 x_pred max 1.22e+05
# ESS of normalized weights= 523.245383
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 176
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.04e+04 real consumption= 4.00e+04
# x_pred min= 3.43e+04 x_pred max 1.19e+05
# ESS of normalized weights= 1287.158843
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 177
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.66e+04 real consumption= 5.19e+04
# x_pred min= 3.09e+04 x_pred max 1.14e+05
# ESS of normalized weights= 403.869509
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 178
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.90e+04 real consumption= 5.25e+04
# x_pred min= 3.28e+04 x_pred max 1.03e+05
# ESS of normalized weights= 842.805103
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 179
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.47e+04 real consumption= 5.31e+04
# x_pred min= 3.81e+04 x_pred max 9.25e+04
# ESS of normalized weights= 430.177359
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 180
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.59e+04 real consumption= 5.34e+04
# x_pred min= 3.01e+04 x_pred max 9.67e+04
# ESS of normalized weights= 1835.703113
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 181
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.93e+04 real consumption= 5.24e+04
# x_pred min= 2.03e+04 x_pred max 1.15e+05
# ESS of normalized weights= 2124.30399
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 182
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.21e+04 real consumption= 4.41e+04
# x_pred min= 3.21e+04 x_pred max 1.01e+05
# ESS of normalized weights= 470.711627
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 183
# No heating effect
# number of negative values: 0
# x_pred_mean = 7.02e+04 real consumption= 4.01e+04
# x_pred min= 3.49e+04 x_pred max 1.04e+05
# ESS of normalized weights= 549.051502
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 184
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.34e+04 real consumption= 5.27e+04
# x_pred min= 3.21e+04 x_pred max 1.02e+05
# ESS of normalized weights= 2217.583033
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 185
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.30e+04 real consumption= 5.35e+04
# x_pred min= 2.09e+04 x_pred max 1.06e+05
# ESS of normalized weights= 1505.709897
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 186
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.17e+04 real consumption= 5.36e+04
# x_pred min= 1.82e+04 x_pred max 1.07e+05
# ESS of normalized weights= 2166.764956
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 187
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.87e+04 real consumption= 5.47e+04
# x_pred min= 2.72e+04 x_pred max 1.04e+05
# ESS of normalized weights= 2274.621101
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 188
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.79e+04 real consumption= 5.40e+04
# x_pred min= 3.00e+04 x_pred max 1.03e+05
# ESS of normalized weights= 1382.342363
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 189
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.04e+04 real consumption= 4.62e+04
# x_pred min= 2.91e+04 x_pred max 9.86e+04
# ESS of normalized weights= 527.847124
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 190
# No heating effect
# number of negative values: 0
# x_pred_mean = 6.73e+04 real consumption= 4.25e+04
# x_pred min= 1.62e+04 x_pred max 1.03e+05
# ESS of normalized weights= 1483.667609
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 191
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.42e+04 real consumption= 5.39e+04
# x_pred min= 2.44e+04 x_pred max 8.77e+04
# ESS of normalized weights= 2011.225903
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 192
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.97e+04 real consumption= 5.31e+04
# x_pred min= 2.37e+04 x_pred max 8.90e+04
# ESS of normalized weights= 860.47934
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 193
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.47e+04 real consumption= 5.21e+04
# x_pred min= 1.01e+04 x_pred max 9.25e+04
# ESS of normalized weights= 957.595832
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 194
# No heating effect
# number of negative values: 0
# x_pred_mean = 5.44e+04 real consumption= 4.22e+04
# x_pred min= 2.00e+04 x_pred max 9.18e+04
# ESS of normalized weights= 1937.408991
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 195
# No heating effect
# number of negative values: 0
# x_pred_mean = 4.86e+04 real consumption= 4.72e+04
# ...
# n= 284
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.14e+04 real consumption= 5.83e+04
# x_pred min= 8.06e+01 x_pred max 2.49e+05
# ESS of normalized weights= 785.029824
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 285
# No heating effect
# number of negative values: 0
# x_pred_mean = 8.37e+04 real consumption= 6.12e+04
# x_pred min= 5.00e+01 x_pred max 2.16e+05
# ESS of normalized weights= 963.475528
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 286
# No heating effect
# number of negative values: 0
# x_pred_mean = 9.17e+04 real consumption= 5.96e+04
# x_pred min= 1.36e+02 x_pred max 2.12e+05
# ESS of normalized weights= 723.196319
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 287
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.00e+05 real consumption= 4.86e+04
# x_pred min= 9.74e+01 x_pred max 2.25e+05
# ESS of normalized weights= 433.451857
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 288
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.19e+05 real consumption= 4.44e+04
# x_pred min= 1.40e+01 x_pred max 2.71e+05
# ESS of normalized weights= 489.216417
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 289
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.24e+05 real consumption= 5.59e+04
# x_pred min= 2.63e+01 x_pred max 3.34e+05
# ESS of normalized weights= 467.09918
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 290
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.05e+05 real consumption= 5.61e+04
# x_pred min= 2.17e+00 x_pred max 3.60e+05
# ESS of normalized weights= 494.036209
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 291
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.12e+05 real consumption= 5.82e+04
# x_pred min= 2.60e-01 x_pred max 3.60e+05
# ESS of normalized weights= 567.395466
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 292
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.45e+05 real consumption= 5.86e+04
# x_pred min= 1.18e+01 x_pred max 3.58e+05
# ESS of normalized weights= 435.995422
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 293
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.79e+05 real consumption= 5.78e+04
# x_pred min= 4.86e+01 x_pred max 3.82e+05
# ESS of normalized weights= 268.855792
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 294
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.97e+05 real consumption= 5.08e+04
# x_pred min= 5.34e+04 x_pred max 3.49e+05
# ESS of normalized weights= 1.967385
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 295
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.98e+05 real consumption= 4.94e+04
# x_pred min= 2.70e+04 x_pred max 3.82e+05
# ESS of normalized weights= 38.340001
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 296
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.90e+05 real consumption= 5.85e+04
# x_pred min= 3.95e+03 x_pred max 4.24e+05
# ESS of normalized weights= 153.594913
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 297
# number of negative values: 0
# x_pred_mean = 4.26e+05 real consumption= 5.83e+04
# x_pred min= 1.59e+05 x_pred max 6.96e+05
# ESS of normalized weights= 1.0
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 298
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.15e+05 real consumption= 5.84e+04
# x_pred min= 3.64e+02 x_pred max 4.73e+05
# ESS of normalized weights= 141.09637
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 299
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.81e+05 real consumption= 5.79e+04
# x_pred min= 2.63e+02 x_pred max 4.93e+05
# ESS of normalized weights= 202.334695
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 300
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.70e+05 real consumption= 5.72e+04
# x_pred min= 4.10e+01 x_pred max 4.10e+05
# ESS of normalized weights= 436.593227
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 301
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.97e+05 real consumption= 5.02e+04
# x_pred min= 2.56e+01 x_pred max 4.55e+05
# ESS of normalized weights= 378.817987
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 302
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.02e+05 real consumption= 4.42e+04
# x_pred min= 4.57e+01 x_pred max 4.65e+05
# ESS of normalized weights= 146.433521
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 303
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.05e+05 real consumption= 5.10e+04
# x_pred min= 3.99e+01 x_pred max 4.98e+05
# ESS of normalized weights= 379.872016
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 304
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.45e+05 real consumption= 4.62e+04
# x_pred min= 3.44e+01 x_pred max 4.46e+05
# ESS of normalized weights= 142.904774
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 305
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.34e+05 real consumption= 5.84e+04
# x_pred min= 6.87e+04 x_pred max 4.13e+05
# ESS of normalized weights= 1.0
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 306
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.33e+05 real consumption= 5.92e+04
# x_pred min= 4.09e+04 x_pred max 4.34e+05
# ESS of normalized weights= 4.500187
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 307
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.33e+05 real consumption= 6.22e+04
# x_pred min= 1.17e+04 x_pred max 5.01e+05
# ESS of normalized weights= 20.806539
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 308
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.26e+05 real consumption= 5.39e+04
# x_pred min= 2.29e+03 x_pred max 4.66e+05
# ESS of normalized weights= 178.205762
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 309
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.38e+05 real consumption= 5.17e+04
# x_pred min= 6.76e+03 x_pred max 4.33e+05
# ESS of normalized weights= 81.590937
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 310
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.88e+05 real consumption= 6.75e+04
# x_pred min= 7.63e+03 x_pred max 4.98e+05
# ESS of normalized weights= 41.966486
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 311
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.73e+05 real consumption= 6.90e+04
# x_pred min= 1.46e+04 x_pred max 4.94e+05
# ESS of normalized weights= 50.628483
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 312
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.85e+05 real consumption= 7.00e+04
# x_pred min= 3.29e+04 x_pred max 5.41e+05
# ESS of normalized weights= 31.52783
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 313
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.63e+05 real consumption= 6.71e+04
# x_pred min= 2.52e+03 x_pred max 6.08e+05
# ESS of normalized weights= 35.944253
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 314
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.88e+05 real consumption= 5.54e+04
# x_pred min= 2.24e+04 x_pred max 3.74e+05
# ESS of normalized weights= 23.645587
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 315
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.79e+05 real consumption= 5.98e+04
# x_pred min= 3.15e+03 x_pred max 4.17e+05
# ESS of normalized weights= 73.436388
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 316
# No heating effect
# number of negative values: 0
# x_pred_mean = 1.67e+05 real consumption= 5.49e+04
# x_pred min= 1.29e+03 x_pred max 3.89e+05
# ESS of normalized weights= 317.940206
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 317
# number of negative values: 0
# x_pred_mean = 1.16e+06 real consumption= 6.67e+04
# x_pred min= 8.45e+05 x_pred max 1.45e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 318
# number of negative values: 0
# x_pred_mean = 3.50e+06 real consumption= 6.60e+04
# x_pred min= 2.39e+06 x_pred max 4.48e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 319
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.15e+05 real consumption= 6.47e+04
# x_pred min= 9.41e+01 x_pred max 5.24e+05
# ESS of normalized weights= 171.951115
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 320
# number of negative values: 0
# x_pred_mean = 4.91e+05 real consumption= 6.25e+04
# x_pred min= 1.45e+05 x_pred max 8.45e+05
# ESS of normalized weights= 1.580532
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 321
# number of negative values: 0
# x_pred_mean = 9.47e+05 real consumption= 6.37e+04
# x_pred min= 3.95e+05 x_pred max 1.44e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 322
# number of negative values: 0
# x_pred_mean = 1.38e+06 real consumption= 5.66e+04
# x_pred min= 5.06e+05 x_pred max 2.06e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 323
# number of negative values: 0
# x_pred_mean = 1.24e+06 real consumption= 5.19e+04
# x_pred min= 4.63e+05 x_pred max 1.93e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 324
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.94e+05 real consumption= 6.25e+04
# x_pred min= 1.90e+02 x_pred max 8.14e+05
# ESS of normalized weights= 213.923981
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 325
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.37e+05 real consumption= 6.38e+04
# x_pred min= 3.26e+02 x_pred max 5.86e+05
# ESS of normalized weights= 61.25189
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 326
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.30e+05 real consumption= 6.37e+04
# x_pred min= 6.81e+04 x_pred max 6.65e+05
# ESS of normalized weights= 1.0
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 327
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.29e+05 real consumption= 6.32e+04
# x_pred min= 1.64e+04 x_pred max 7.40e+05
# ESS of normalized weights= 2.553678
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 328
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.30e+05 real consumption= 6.44e+04
# x_pred min= 6.29e+03 x_pred max 7.54e+05
# ESS of normalized weights= 18.920296
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 329
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.33e+05 real consumption= 5.69e+04
# x_pred min= 5.83e+04 x_pred max 5.37e+05
# ESS of normalized weights= 2.005579
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 330
# number of negative values: 0
# x_pred_mean = 3.75e+05 real consumption= 5.33e+04
# x_pred min= 5.95e+04 x_pred max 6.56e+05
# ESS of normalized weights= 5.391788
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 331
# number of negative values: 0
# x_pred_mean = 1.02e+06 real consumption= 6.74e+04
# x_pred min= 5.62e+05 x_pred max 1.44e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 332
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.33e+05 real consumption= 7.18e+04
# x_pred min= 3.59e+02 x_pred max 6.98e+05
# ESS of normalized weights= 25.280289
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 333
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.79e+05 real consumption= 7.05e+04
# x_pred min= 3.72e+04 x_pred max 5.47e+05
# ESS of normalized weights= 4.034033
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 334
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.79e+05 real consumption= 7.11e+04
# x_pred min= 4.08e+03 x_pred max 5.76e+05
# ESS of normalized weights= 15.386778
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 335
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.15e+05 real consumption= 7.27e+04
# x_pred min= 7.04e+04 x_pred max 5.24e+05
# ESS of normalized weights= 1.00379
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 336
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.14e+05 real consumption= 6.42e+04
# x_pred min= 3.33e+04 x_pred max 5.71e+05
# ESS of normalized weights= 11.971378
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 337
# number of negative values: 0
# x_pred_mean = 3.01e+06 real consumption= 6.08e+04
# x_pred min= 2.05e+06 x_pred max 4.09e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 338
# number of negative values: 0
# x_pred_mean = 4.78e+06 real consumption= 6.92e+04
# x_pred min= 2.94e+06 x_pred max 6.91e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 339
# number of negative values: 0
# x_pred_mean = 5.88e+06 real consumption= 6.89e+04
# x_pred min= 3.31e+06 x_pred max 1.02e+07
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 340
# number of negative values: 0
# x_pred_mean = 2.21e+06 real consumption= 6.97e+04
# x_pred min= 1.07e+06 x_pred max 3.84e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 341
# number of negative values: 0
# x_pred_mean = 1.01e+06 real consumption= 6.89e+04
# x_pred min= 3.84e+05 x_pred max 1.72e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 342
# number of negative values: 0
# x_pred_mean = 8.93e+05 real consumption= 6.70e+04
# x_pred min= 2.71e+05 x_pred max 1.54e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 343
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.04e+05 real consumption= 6.18e+04
# x_pred min= 4.21e+02 x_pred max 9.50e+05
# ESS of normalized weights= 97.783477
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 344
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.24e+05 real consumption= 5.88e+04
# x_pred min= 2.76e+01 x_pred max 5.21e+05
# ESS of normalized weights= 170.838855
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 345
# No heating effect
# number of negative values: 0
# x_pred_mean = 2.77e+05 real consumption= 7.02e+04
# x_pred min= 1.77e+02 x_pred max 5.79e+05
# ESS of normalized weights= 65.821441
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 10000.0
# ------------------------
# n= 346
# number of negative values: 0
# x_pred_mean = 2.01e+06 real consumption= 6.93e+04
# x_pred min= 1.11e+06 x_pred max 3.24e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# n= 347
# No heating effect
# number of negative values: 0
# x_pred_mean = 3.18e+05 real consumption= 6.80e+04
# x_pred min= 3.63e+04 x_pred max 6.59e+05
# ESS of normalized weights= 3.171312
# ESS <0.001*M
# new ESS= 10000.0
# ------------------------
# n= 348
# number of negative values: 0
# x_pred_mean = 4.46e+06 real consumption= 7.01e+04
# x_pred min= 2.02e+06 x_pred max 8.14e+06
# ESS of normalized weights= nan
# ESS critically low
# new ESS= 10000.0
# ------------------------
# log likelihood proposal of y: -47316143366.7
# proposed log prior: [-51.23412459]
# proposal log density initial parameters given proposed param: [-0.72308003]
# proposal log density proposed parameters given current param: [-0.59916722]
# acceptance log probability: -44445810384.8
# REJECT

# %%
print(accept_rate/len_iter_mha)
# Out:
# 0.1

# %%
print(sigma_current)
print(sigma_g_current)
print(sigma_s_current)
print(u_h_current)
# Out:
# [ 7883.17556731]
# [ 1380.05313528]
# [ 5091.64594793]
# [ 13.71910093]
