# %% [markdown]
# # On particle filters applied to electricity load forecasting

# %% [markdown]
# PyMC tuto
#
# https://pymc-devs.github.io/pymc/tutorial.html#fitting-the-model-with-mcmc
#
# http://sdsawtelle.github.io/blog/output/mcmc-in-python-with-pymc.html

# %% [markdown]
# NC Email:
#
# Voilà quelques pistes que vous pouvez suivre:
# * commencer par implémenter un bootstrap filter pour le modèle proposé, et des valeurs des paramètres choisis à la main ﴾en fonction des valeurs reportées dans l'article par exemple﴿ et des données que vous pouvez simuler. Déterminer à quel point l'algorithme marche bien:
# + graphe de l'ESS en fonction du temps; voir si effectivement certains outliers font fortement chuter l'ESS. Essayer la méthode proposée pour gérer ses outliers.
# + intervalles de confiance pour l'estimation de E[X_t|Y_{0:t}], basé sur plusieurs exécutions, par exemple.
#
# Deuxième étape: estimation des paramètres. Vous pouvez essayer une des trois approches suivantes, triées par ordre de difficulté:
# 1. maximisation de la vraisemblance ﴾estimée par votre filtre particulaire pour un theta donné﴿, en utilisant une méthode de maximisation pour fonction bruitée ﴾par ex Robbins‐Monroe﴿.
# 2. PMMH, voir le prochain cours. Principale difficulté: l'algorithme peut prendre du temps, et ne pas être très facile à calibrer, mais je vais en parler en cours.
# 3. Particle Gibbs: c'est peut‐être un peu compliqué pour ce modèle, mais si vous arrivez, gros bonus!

# %%
import pandas as pd
import numpy as np
import numpy.random as npr
import matplotlib as mtp
import matplotlib.pyplot as plt
import scipy as sp
from scipy.stats import truncnorm
import scipy.stats as stats
from scipy.stats import invgamma
from scipy import ndimage
import math

# %% [markdown]
# ### Parameters

# %%
M=10**3 #number of particles
n_pred=710  #number of predictions
N_daytype=8  #number of day types

# %% [markdown]
# ### Load temperatures data 2015-2016

# %%
df_temp=pd.read_csv('data/temp_1516.csv',sep=',')
df_temp=df_temp.drop(df_temp.columns[0],axis=1)
df_temp=df_temp.sort_values(by='date')
df_temp.head()
# Out:
#          date   hour         t
# 0  2015-01-01  00:00  5.057414
# 1  2015-01-01  03:00  4.609138
# 2  2015-01-01  06:00  4.729828
# 3  2015-01-01  09:00  6.052241
# 4  2015-01-01  12:00  9.347069

# %%
#temperatures every day at 3pm
temp_day=df_temp[df_temp.hour=="15:00"]
temp_day.head()
#Array vector of temperatures for each day of the year
T_h=list(temp_day.t)

# %% [markdown]
# ### Load electricity data

# %%
mypath="data/"
df=pd.read_csv(mypath+"cdc_conso_daytypes.csv",sep=",",encoding='latin-1')
df=df.drop(["daytype"+str(i) for i in range(0,9)],axis=1)
df=df.drop(df.columns[0],axis=1)
df.index=range(0,len(df))
df=df.sort_values(by=['Date'])
df['Date - Heure']=pd.to_datetime(df['Date - Heure'])
df.sort_values(by=["Date - Heure"])
#truncate to the data from 2015
df=df[(df.Date >='2015-01-01')]
df.head()
# Out:
#               Date - Heure        Date  Heure  Consommation (MW)  \
# 166957 2015-01-01 03:30:00  2015-01-01  04:30              64838
# 153294 2015-01-01 18:30:00  2015-01-01  19:30              72562
# 153293 2015-01-01 18:00:00  2015-01-01  19:00              71766
# 152017 2015-01-01 01:00:00  2015-01-01  02:00              71134
# 152018 2015-01-01 04:30:00  2015-01-01  05:30              64379
#
#        Qualite donnee  daytype
# 166957    DÃ©finitive        6
# 153294    DÃ©finitive        6
# 153293    DÃ©finitive        6
# 152017    DÃ©finitive        6
# 152018    DÃ©finitive        6

# %% [raw]
# plt.plot_date(df.Date,df['Consommation (MW)'],fmt='-')
# plt.show()

# %% [raw]
# bins=range(30000,100000,1000)
# plt.hist(df['Consommation (MW)'],normed=True,bins=bins)
# plt.show()

# %% [markdown]
# ### Set variables of electricity demand

# %%
from datetime import date
df['Consommation']=df['Consommation (MW)']   #leave it in MW
#For prediction, every day at 3pm
consumption_day_ahead = list(df[df['Heure']=='15:00']['Consommation'])
#for initialization
consumption = list(df[df['Heure']=='15:00']['Consommation'][:30])

# %% [markdown]
# ## Implementation of Algorithm 3.10

# %% [markdown]
# ## At time n=0:

# %% [markdown]
# ### 1.Definition of MCMC initial model at n=0 - sample $X_0^{j} \sim \mu(x_0)$

# %% [markdown]
# ### Option A: Set values by hand

# %% [raw]
# #Add a bit of noise with uniform random
# #s=8000*np.ones(M)*npr.uniform(0.5,1.5,size=M)
# #sigma2_g_star=(10**5)*npr.uniform(0.5,1.5,size=M)
# #sigma2_s_star=(10**5)*npr.uniform(0.5,1.5,size=M)
# sigma_g_init=1.27*10**(8/2)
# sigma_s_init=(2*7.9)*10**3
# u_h=14 #mean of N(14,1)
# kappa=np.array([1/9]*9)
# sigma2=2.7*10**7
# g_heat_init = stats.truncnorm.rvs(-np.inf,0,loc=0,scale=10**4,size=M)
# s_init = stats.truncnorm.rvs(np.inf,0,loc=0,scale=10**4,size=M)
# sigma_s_star_2_evol=7.9*10**7
# sigma_g_star_2_evol=1.27*10**8
#
# x_init=x_season(df.daytype[15],kappa,s_init,sigma_s_init)[0]+x_heat(g_heat_init,15,sigma_g_init)[0]
# w_init= np.exp(-(np.square(consumption[15]-x_init))/(2*sigma2))

# %% [markdown]
# ### Option C: MCMC using MHA or Gibbs (TBA)

# %% [markdown]
# #### Freeze parameters from Zak's simulation in gibbs-parameters_init_v1

# %%
N_daytype=9
k_day=npr.dirichlet(np.ones(N_daytype),1)
len_init=15
pred_forward=[0,1,2,3,4]

# %%
#Load pickle file
import pickle
output_file ='data/parameters_init_20180113-135329.pkl'
pkl_file = open(output_file, 'rb')
parameters_init = pickle.load(pkl_file)
parameters_init["x_init"][:20]
# Out:
# array([  6.27772271e+20,   7.74432522e+04,   7.18859618e+04,
#          6.49227561e+04,   6.66906797e+04,   6.45463399e+04,
#          7.44844711e+04,   7.35432483e+04,   7.28854527e+04,
#          7.64918960e+04,   6.16447396e+04,   6.96833028e+04,
#          6.56803045e+04,   6.42648669e+04,   6.05432962e+04,
#          5.99115354e+04,   6.06208026e+04,   7.04703987e+04,
#          7.03640065e+04,   7.41647499e+04])

# %%
parameters_init
# Out:
# {'g_heat_init': array([-814623.94530988,   -1103.5042025 ,  -13509.35223552,
#          -12839.18874712,  -13810.69394068,  -13621.95767042,
sigma2=parameters_init['sigma2']
u_h=parameters_init['u_h']
kappa=parameters_init['kappa']
w_init=parameters_init['w_init']

# %% [markdown]
# #### Parameters set by hand

# %%
sigma2=np.ones(M)*3*10**7
sigma_g_init=np.ones(M)*10**4
sigma_s_init=np.ones(M)*10**4
kappa=np.ones(M)

# %% [markdown]
# #### Parameters from PMMH

# %%
#sigma2=np.ones(M)*np.square(1.6*10**5)
#sigma_g_init=np.ones(M)*5.7*10**4
#sigma_s_init=np.ones(M)*2.5*10**4
#u_h=12.8
#kappa=np.ones(M)

# %% [markdown]
# ### Part 2: regularize weights and x if necessary

# %%
#STEP 2 OF PARTICLE FILTER
def resample(x_pred,w_prev,nbdays_pred_today,len_init,n,sigma_s,sigma_g,g_h,s,sigma,ESS):   
    #compute y_n
    delta_cons_gaus=-np.square(consumption_day_ahead[len_init+n+nbdays_pred_today]-x_pred)/(2*sigma**2)
    y_n=np.exp(delta_cons_gaus)
    #compute new weights
    if n>0:
        w_=w_prev*y_n
    else:
        w_=w_prev
    #likelihood of y_n
    lh_y_n=np.sum(delta_cons_gaus)
    #normalize weights
    w_h=w_/sum(w_)
    #calculate ESS
    ESS=1/sum(np.square(w_h))
    x =np.zeros(M)
    w =np.zeros(M)
    print("ESS of normalized weights=",round(ESS,6))
    if ESS <0.001*M: #reset the weights, keep x predicted as such
        print("ESS <0.001*M")
        x=x_pred
        if n==0:
            w=np.ones(M)*(1/M)
        w=w_prev
    elif (ESS>=0.001*M and ESS<0.5*M):  #reset all the weights, add some noise to a fraction of the x's
        print("ESS>=0.001*M and ESS_0<0.5*M")
        x,w,sigma_s,sigma_g,g_h,s=resample_multinomial(x_pred,w_h,sigma_s,sigma_g,g_h,s)
    elif ESS>=0.5*M:  #No degeneracy
        print("ESS>=0.5*M")
        x=x_pred
        w=w_h
    else:
        print("ESS critically low")
        x=x_pred
        if n==0:
            w=np.ones(M)*(1/M)
        w=w_prev
            
    print("new ESS=",round(1/sum(np.square(w)),6))
    return x,w,ESS,lh_y_n,sigma_s,sigma_g,g_h,s,w_h

# %%
def resample_multinomial(x_temp,w_temp,sigma_s,sigma_g,g_h,s):
    multinomial = np.random.multinomial(1,w_temp,M)
    new_x = np.zeros(M)
    new_s = np.zeros(M)
    new_g_heat = np.zeros(M)
    new_sigma_s = np.zeros(M)
    new_sigma_g = np.zeros(M)
    for i in range(M):
        new_x[i]=x_temp[np.argmax(multinomial[i,])]
        new_s[i]=s[np.argmax(multinomial[i,])]
        new_g_heat[i]=g_h[np.argmax(multinomial[i,])]
        new_sigma_s[i]=sigma_s[np.argmax(multinomial[i,])]
        new_sigma_g[i]=sigma_g[np.argmax(multinomial[i,])]
    new_w=(1/M)*np.ones(M)   
    return new_x,new_w,new_sigma_s,new_sigma_g,new_g_heat,new_s

# %%
#initialize matrix of x_heat, x_season
ESS=np.array(np.ones(n_pred+1))
x =np.zeros([n_pred+1,M])
w =np.zeros([n_pred+1,M])
lh_y_n =np.zeros(n_pred-1)
x_season =np.zeros([n_pred+1,M]) 
x_heat =np.zeros([n_pred+1,M])
entrop=np.zeros([len(pred_forward),n_pred])

x[0,:],w[0,:],ESS[0],lh_y,sigma_s_init,sigma_g_init,g_heat_init,s_init=resample(x_init,w_init,2,15,0,sigma_s_init,
                                                                                sigma_g_init,
                                                                                g_heat_init,s_init,sigma2**0.5,ESS)[:8]
# Out:
# ESS of normalized weights= 862.234232
# ESS>=0.5*M
# new ESS= 862.234232

# %% [markdown]
# ## Prediction and Filtering at time n>0

# %% [markdown]
# ### 1. Sample $x^j_n \mid X^j_{n-1} $ for all j=1...M particles

# %%
def x_season(day_type,k_day,s_prev,sigma_s_prev):
    nu=truncnorm.rvs(a = (-sigma_s_prev-0) / sigma_g_init , b = np.inf, loc= 0, scale = sigma_g_init, size=M)
    sigma_s=sigma_s_prev+nu
    err=truncnorm.rvs(a = -s_prev / sigma_s , b = np.inf, loc= 0, scale = sigma_s, size=M)
    s=s_prev+err
    x_s=s*k_day[day_type]
    return x_s, s, sigma_s

def x_heat(g_h_prev,day,sigma_g_prev):
    nu=truncnorm.rvs(a = -sigma_g_prev / sigma_g_init , b = np.inf, loc= 0, scale = sigma_g_init, size=M)
    sigma_g=sigma_g_prev+nu
    err=truncnorm.rvs(a = -np.inf , b =(-g_h_prev-0) / sigma_g, loc= 0, scale = sigma_g, size=M)
    g_h=g_h_prev+err
    if(u_h-T_h[day]<0):
        print("No heating effect")
    x_h=g_h*(T_h[day]-u_h)*max(np.sign(u_h-T_h[day]),0)
    return x_h, g_h, sigma_g

# %%
daytype=np.array(df.daytype)

# %% [raw]
# print(x_season(daytype[15],kappa,s_init,sigma_s_init)[2])
# print(x_heat(g_heat_init,16,sigma_g_init)[2])

# %%
#Initialize parameters
def particle_filter(nbdays_pred_today,len_init,len_filtering,s,g_h,sigma_s,sigma_g,sigma,lh_y):
    lh_y_n=np.zeros(len_filtering)
    x_pred=np.zeros([len_filtering,M])
    x_pred_mean=np.zeros(len_filtering)
    ESS=np.zeros(len_filtering)
    w_h=np.zeros([len_filtering,M])
    entrop_n=np.zeros(len_filtering)
    for n in range(1,len_filtering):
        print("n=",n)
        #prediction X[n] one day ahead, hourly forecast
        x_s=x_season(int(daytype[len_init+n+nbdays_pred_today]),kappa,s,sigma_s)
        x_h=x_heat(g_h,n+len_init+nbdays_pred_today,sigma_g)
        x_pred[n,:]=x_s[0]+x_h[0]
        x_pred_mean[n]=np.mean(x_pred[n,:])
        print("x_pred_mean =","{:.2e}".format(np.mean(x_pred[n,:])),
              "real consumption=","{:.2e}".format(consumption_day_ahead[n]))
        print("x_pred min=","{:.2e}".format(np.min(x_pred[n,:])),"x_pred max","{:.2e}".format(np.max(x_pred[n,:])))
        #take new values of parameters to feed x_season and x_heat in the next step
        s, sigma_s=x_s[1:]
        g_h, sigma_g=x_h[1:]
        #regularization
        x_pred[n,:],w[n,:],ESS[n],lh_y_n[n],sigma_s,sigma_g,g_h,s,w_h[n,:]=resample(x_pred[n,:],w[n-1,:],nbdays_pred_today,len_init,n,sigma_s,sigma_g,g_h,s,sigma,ESS)
        entrop_n[n]=-sum(w_h[n,:]*np.log(w_h[n,:]))
        print(entrop_n[n])
        print("likelihood:",lh_y_n[n])
        print("------------------------")
    return lh_y_n,x_pred_mean,ESS,entrop_n

# %%
x_predict=np.zeros([len(pred_forward),n_pred])
ESS_calc=np.zeros([len(pred_forward),n_pred])

for i in range(len(pred_forward)):
    print("prediction forward n+",i)
    x_predict[i,:],ESS_calc[i,:],entrop[i,:]=particle_filter(pred_forward[i],len_init,n_pred,s_init,
                                                             g_heat_init,sigma_s_init,
                                                             sigma_g_init,sigma2**0.5,lh_y_n)[1:]
# Out:
# prediction forward n+ 0
# n= 1
# x_pred_mean = 4.71e+04 real consumption= 6.86e+04
# x_pred min= 7.67e+02 x_pred max 6.69e+05
# ESS of normalized weights= 153.121572
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -21401.7180172
# ------------------------
# n= 2
# x_pred_mean = 8.82e+04 real consumption= 6.41e+04
# x_pred min= 4.54e+03 x_pred max 3.25e+05
# ESS of normalized weights= 220.59607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -38857.3777843
# ------------------------
# n= 3
# x_pred_mean = 9.40e+04 real consumption= 5.74e+04
# x_pred min= 3.36e+03 x_pred max 3.14e+05
# ESS of normalized weights= 214.300501
# ESS>=0.001*M and ESS_0<0.5*M
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in multiply
# new ESS= 1000.0
# nan
# likelihood: -38107.4740294
# ------------------------
# n= 4
# x_pred_mean = 1.02e+05 real consumption= 7.31e+04
# x_pred min= 5.58e+03 x_pred max 3.98e+05
# ESS of normalized weights= 209.233347
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -46697.3290356
# ------------------------
# n= 5
# x_pred_mean = 9.21e+04 real consumption= 7.68e+04
# x_pred min= 5.56e+03 x_pred max 4.12e+05
# ESS of normalized weights= 247.677052
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -33584.2184782
# ------------------------
# n= 6
# x_pred_mean = 9.72e+04 real consumption= 7.49e+04
# x_pred min= 1.22e+04 x_pred max 3.85e+05
# ESS of normalized weights= 251.102711
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -41068.3958301
# ------------------------
# n= 7
# x_pred_mean = 1.01e+05 real consumption= 7.21e+04
# x_pred min= 2.54e+03 x_pred max 3.31e+05
# ESS of normalized weights= 247.289416
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -43732.571159
# ------------------------
# n= 8
# x_pred_mean = 8.28e+04 real consumption= 6.90e+04
# x_pred min= 4.81e+03 x_pred max 4.30e+05
# ESS of normalized weights= 309.110441
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -31119.388289
# ------------------------
# n= 9
# x_pred_mean = 7.45e+04 real consumption= 5.72e+04
# x_pred min= 5.87e+03 x_pred max 2.12e+05
# ESS of normalized weights= 315.121964
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.88226580129
# likelihood: -17289.8676546
# ------------------------
# n= 10
# x_pred_mean = 7.48e+04 real consumption= 5.55e+04
# x_pred min= 4.98e+03 x_pred max 2.37e+05
# ESS of normalized weights= 273.882458
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.77296053168
# likelihood: -17093.5899146
# ------------------------
# n= 11
# x_pred_mean = 8.26e+04 real consumption= 6.91e+04
# x_pred min= 1.61e+04 x_pred max 3.62e+05
# ESS of normalized weights= 317.769355
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -17728.0713351
# ------------------------
# n= 12
# x_pred_mean = 5.68e+04 real consumption= 6.88e+04
# x_pred min= 2.17e+03 x_pred max 2.13e+05
# ESS of normalized weights= 200.152942
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.42872019443
# likelihood: -17499.5686326
# ------------------------
# n= 13
# x_pred_mean = 1.05e+05 real consumption= 6.92e+04
# x_pred min= 1.42e+04 x_pred max 2.74e+05
# ESS of normalized weights= 220.291826
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.51906638222
# likelihood: -34561.0175117
# ------------------------
# n= 14
# x_pred_mean = 1.08e+05 real consumption= 7.03e+04
# x_pred min= 1.32e+04 x_pred max 3.07e+05
# ESS of normalized weights= 206.800652
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -45615.6485588
# ------------------------
# n= 15
# x_pred_mean = 1.00e+05 real consumption= 7.00e+04
# x_pred min= 3.50e+03 x_pred max 3.00e+05
# ESS of normalized weights= 204.684749
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -43705.8722698
# ------------------------
# n= 16
# x_pred_mean = 9.92e+04 real consumption= 6.31e+04
# x_pred min= 1.72e+03 x_pred max 5.43e+05
# ESS of normalized weights= 210.656018
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -53478.6866945
# ------------------------
# n= 17
# x_pred_mean = 9.69e+04 real consumption= 6.25e+04
# x_pred min= 9.95e+03 x_pred max 5.50e+05
# ESS of normalized weights= 257.038749
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -47761.1364628
# ------------------------
# n= 18
# x_pred_mean = 1.16e+05 real consumption= 7.72e+04
# x_pred min= 1.57e+04 x_pred max 5.01e+05
# ESS of normalized weights= 197.16571
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -76835.4636975
# ------------------------
# n= 19
# x_pred_mean = 1.09e+05 real consumption= 7.79e+04
# x_pred min= 1.65e+03 x_pred max 6.08e+05
# ESS of normalized weights= 221.441349
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -70276.1107355
# ------------------------
# n= 20
# x_pred_mean = 1.19e+05 real consumption= 7.92e+04
# x_pred min= 1.24e+04 x_pred max 5.00e+05
# ESS of normalized weights= 232.761836
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -81851.8486182
# ------------------------
# n= 21
# x_pred_mean = 1.22e+05 real consumption= 7.84e+04
# x_pred min= 3.44e+03 x_pred max 7.38e+05
# ESS of normalized weights= 177.6226
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -95231.2971921
# ------------------------
# n= 22
# x_pred_mean = 9.46e+04 real consumption= 7.89e+04
# x_pred min= 9.77e+03 x_pred max 4.12e+05
# ESS of normalized weights= 281.670014
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -39198.0108936
# ------------------------
# n= 23
# x_pred_mean = 8.50e+04 real consumption= 7.12e+04
# x_pred min= 1.44e+04 x_pred max 2.85e+05
# ESS of normalized weights= 297.36802
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -27323.2815455
# ------------------------
# n= 24
# x_pred_mean = 6.56e+04 real consumption= 6.55e+04
# x_pred min= 3.54e+03 x_pred max 1.91e+05
# ESS of normalized weights= 285.724187
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.79991070766
# likelihood: -11859.4962868
# ------------------------
# n= 25
# x_pred_mean = 7.10e+04 real consumption= 7.75e+04
# x_pred min= 1.03e+04 x_pred max 2.04e+05
# ESS of normalized weights= 398.722017
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10985442005
# likelihood: -8246.36527494
# ------------------------
# n= 26
# No heating effect
# x_pred_mean = 6.65e+04 real consumption= 7.54e+04
# x_pred min= 1.59e+03 x_pred max 3.13e+05
# ESS of normalized weights= 410.243002
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -9445.1208069
# ------------------------
# n= 27
# No heating effect
# x_pred_mean = 7.12e+04 real consumption= 7.65e+04
# x_pred min= 7.63e+01 x_pred max 2.55e+05
# ESS of normalized weights= 521.309241
# ESS>=0.5*M
# new ESS= 521.309241
# 6.35733577236
# likelihood: -6223.0954412
# ------------------------
# n= 28
# No heating effect
# x_pred_mean = 7.22e+04 real consumption= 7.78e+04
# x_pred min= 1.23e+02 x_pred max 2.23e+05
# ESS of normalized weights= 270.362881
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -11899.1981867
# ------------------------
# n= 29
# x_pred_mean = 9.26e+04 real consumption= 7.59e+04
# x_pred min= 1.18e+04 x_pred max 2.66e+05
# ESS of normalized weights= 174.623607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.33130057697
# likelihood: -26855.9437346
# ------------------------
# n= 30
# x_pred_mean = 7.07e+04 real consumption= 6.84e+04
# x_pred min= 6.52e+03 x_pred max 1.78e+05
# ESS of normalized weights= 349.388716
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.99672691699
# likelihood: -10338.1585838
# ------------------------
# n= 31
# x_pred_mean = 7.19e+04 real consumption= 6.67e+04
# x_pred min= 9.73e+03 x_pred max 1.71e+05
# ESS of normalized weights= 381.065132
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07361426175
# likelihood: -8098.32560294
# ------------------------
# n= 32
# x_pred_mean = 6.91e+04 real consumption= 7.71e+04
# x_pred min= 1.16e+04 x_pred max 1.71e+05
# ESS of normalized weights= 408.345794
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13396258125
# likelihood: -7070.59314329
# ------------------------
# n= 33
# No heating effect
# x_pred_mean = 6.07e+04 real consumption= 7.99e+04
# x_pred min= 4.56e+03 x_pred max 1.49e+05
# ESS of normalized weights= 329.757564
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.93335047234
# likelihood: -9043.23597587
# ------------------------
# n= 34
# No heating effect
# x_pred_mean = 6.98e+04 real consumption= 8.21e+04
# x_pred min= 3.57e+02 x_pred max 2.51e+05
# ESS of normalized weights= 500.968007
# ESS>=0.5*M
# new ESS= 500.968007
# 6.31320517046
# likelihood: -7014.69889371
# ------------------------
# n= 35
# No heating effect
# x_pred_mean = 7.13e+04 real consumption= 8.29e+04
# x_pred min= 2.27e+03 x_pred max 2.53e+05
# ESS of normalized weights= 253.918
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -14140.9155138
# ------------------------
# n= 36
# x_pred_mean = 1.51e+05 real consumption= 8.59e+04
# x_pred min= 2.94e+04 x_pred max 5.38e+05
# ESS of normalized weights= 57.457856
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -197860.472784
# ------------------------
# n= 37
# x_pred_mean = 7.02e+04 real consumption= 7.30e+04
# x_pred min= 9.20e+03 x_pred max 1.92e+05
# ESS of normalized weights= 308.348867
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.88039058642
# likelihood: -13911.9837872
# ------------------------
# n= 38
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 6.70e+04
# x_pred min= 4.10e+01 x_pred max 1.85e+05
# ESS of normalized weights= 216.723526
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.56889572001
# likelihood: -13457.7643907
# ------------------------
# n= 39
# x_pred_mean = 8.74e+04 real consumption= 7.57e+04
# x_pred min= 9.77e+03 x_pred max 2.18e+05
# ESS of normalized weights= 314.33053
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.87685892426
# likelihood: -16930.6216858
# ------------------------
# n= 40
# No heating effect
# x_pred_mean = 6.52e+04 real consumption= 7.55e+04
# x_pred min= 3.77e+02 x_pred max 1.95e+05
# ESS of normalized weights= 440.903249
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19761479483
# likelihood: -8439.81952036
# ------------------------
# n= 41
# No heating effect
# x_pred_mean = 7.02e+04 real consumption= 7.16e+04
# x_pred min= 4.84e+03 x_pred max 1.59e+05
# ESS of normalized weights= 507.711153
# ESS>=0.5*M
# new ESS= 507.711153
# 6.32226973775
# likelihood: -6563.6941002
# ------------------------
# n= 42
# x_pred_mean = 9.26e+04 real consumption= 7.21e+04
# x_pred min= 9.14e+03 x_pred max 2.56e+05
# ESS of normalized weights= 141.751446
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.17591932294
# likelihood: -29076.8639131
# ------------------------
# n= 43
# No heating effect
# x_pred_mean = 6.40e+04 real consumption= 7.10e+04
# x_pred min= 2.76e+03 x_pred max 2.12e+05
# ESS of normalized weights= 484.271583
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29968466086
# likelihood: -6075.06764541
# ------------------------
# n= 44
# No heating effect
# x_pred_mean = 6.29e+04 real consumption= 6.39e+04
# x_pred min= 2.24e+03 x_pred max 2.10e+05
# ESS of normalized weights= 474.875777
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2861939966
# likelihood: -5687.56799153
# ------------------------
# n= 45
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 5.91e+04
# x_pred min= 1.09e+03 x_pred max 1.64e+05
# ESS of normalized weights= 471.587578
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27814771943
# likelihood: -5740.32266176
# ------------------------
# n= 46
# No heating effect
# x_pred_mean = 6.40e+04 real consumption= 7.23e+04
# x_pred min= 7.48e+03 x_pred max 1.30e+05
# ESS of normalized weights= 552.919531
# ESS>=0.5*M
# new ESS= 552.919531
# 6.41101300548
# likelihood: -4238.68777474
# ------------------------
# n= 47
# x_pred_mean = 2.02e+05 real consumption= 7.28e+04
# x_pred min= 1.60e+04 x_pred max 1.23e+06
# ESS of normalized weights= 33.224634
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -610258.569628
# ------------------------
# n= 48
# x_pred_mean = 5.84e+04 real consumption= 7.15e+04
# x_pred min= 6.08e+03 x_pred max 1.51e+05
# ESS of normalized weights= 441.296817
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19941784529
# likelihood: -6780.24840017
# ------------------------
# n= 49
# No heating effect
# x_pred_mean = 6.44e+04 real consumption= 7.06e+04
# x_pred min= 8.25e+02 x_pred max 1.80e+05
# ESS of normalized weights= 505.875876
# ESS>=0.5*M
# new ESS= 505.875876
# 6.31628810306
# likelihood: -7232.79218233
# ------------------------
# n= 50
# No heating effect
# x_pred_mean = 6.66e+04 real consumption= 7.11e+04
# x_pred min= 1.02e+03 x_pred max 2.13e+05
# ESS of normalized weights= 216.376463
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.59220500935
# likelihood: -15001.0194454
# ------------------------
# n= 51
# No heating effect
# x_pred_mean = 5.91e+04 real consumption= 6.54e+04
# x_pred min= 2.07e+03 x_pred max 1.54e+05
# ESS of normalized weights= 408.817553
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14375820875
# likelihood: -7909.78624942
# ------------------------
# n= 52
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 5.97e+04
# x_pred min= 9.51e+00 x_pred max 1.67e+05
# ESS of normalized weights= 398.000218
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12460423815
# likelihood: -7266.52700753
# ------------------------
# n= 53
# No heating effect
# x_pred_mean = 5.86e+04 real consumption= 7.10e+04
# x_pred min= 6.33e+02 x_pred max 1.95e+05
# ESS of normalized weights= 495.5456
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.31304088926
# likelihood: -5619.79192005
# ------------------------
# n= 54
# No heating effect
# x_pred_mean = 6.22e+04 real consumption= 7.19e+04
# x_pred min= 4.55e+03 x_pred max 1.47e+05
# ESS of normalized weights= 535.707192
# ESS>=0.5*M
# new ESS= 535.707192
# 6.37345446018
# likelihood: -5618.15214302
# ------------------------
# n= 55
# No heating effect
# x_pred_mean = 6.36e+04 real consumption= 7.05e+04
# x_pred min= 6.68e+02 x_pred max 2.20e+05
# ESS of normalized weights= 295.905927
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.83961111967
# likelihood: -10830.9459527
# ------------------------
# n= 56
# x_pred_mean = 9.61e+04 real consumption= 6.99e+04
# x_pred min= 7.56e+03 x_pred max 3.33e+05
# ESS of normalized weights= 192.896228
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -39872.6124827
# ------------------------
# n= 57
# x_pred_mean = 1.35e+05 real consumption= 6.90e+04
# x_pred min= 1.29e+04 x_pred max 6.28e+05
# ESS of normalized weights= 90.038462
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -187561.918093
# ------------------------
# n= 58
# x_pred_mean = 9.56e+04 real consumption= 6.19e+04
# x_pred min= 9.84e+03 x_pred max 5.47e+05
# ESS of normalized weights= 210.517338
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -76963.1835338
# ------------------------
# n= 59
# No heating effect
# x_pred_mean = 4.42e+04 real consumption= 5.57e+04
# x_pred min= 1.47e+03 x_pred max 1.60e+05
# ESS of normalized weights= 221.091817
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.58753380253
# likelihood: -13838.4002575
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 6.19e+04 real consumption= 6.53e+04
# x_pred min= 6.46e+02 x_pred max 1.44e+05
# ESS of normalized weights= 476.282471
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26711505525
# likelihood: -7056.24638866
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 6.12e+04 real consumption= 6.47e+04
# x_pred min= 2.51e+03 x_pred max 1.51e+05
# ESS of normalized weights= 525.364073
# ESS>=0.5*M
# new ESS= 525.364073
# 6.35460727216
# likelihood: -6041.35151968
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 6.16e+04 real consumption= 6.74e+04
# x_pred min= 1.01e+03 x_pred max 3.03e+05
# ESS of normalized weights= 277.901832
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -11522.2426985
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 6.30e+04 real consumption= 6.53e+04
# x_pred min= 5.13e+03 x_pred max 1.48e+05
# ESS of normalized weights= 572.83559
# ESS>=0.5*M
# new ESS= 572.83559
# 6.43562764408
# likelihood: -4474.09184494
# ------------------------
# n= 64
# x_pred_mean = 8.02e+04 real consumption= 6.30e+04
# x_pred min= 6.18e+03 x_pred max 2.37e+05
# ESS of normalized weights= 132.515957
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.14357944528
# likelihood: -22175.6530701
# ------------------------
# n= 65
# x_pred_mean = 7.49e+04 real consumption= 5.49e+04
# x_pred min= 8.21e+03 x_pred max 2.10e+05
# ESS of normalized weights= 268.402072
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.74623894107
# likelihood: -17973.0341427
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 4.87e+04
# x_pred min= 2.49e+02 x_pred max 1.42e+05
# ESS of normalized weights= 329.07191
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.94615442371
# likelihood: -8792.42789673
# ------------------------
# n= 67
# x_pred_mean = 7.31e+04 real consumption= 6.02e+04
# x_pred min= 7.04e+03 x_pred max 1.98e+05
# ESS of normalized weights= 417.849803
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14951099176
# likelihood: -10085.2147237
# ------------------------
# n= 68
# x_pred_mean = 1.10e+05 real consumption= 6.20e+04
# x_pred min= 1.15e+04 x_pred max 3.68e+05
# ESS of normalized weights= 177.160003
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -63304.3186234
# ------------------------
# n= 69
# x_pred_mean = 5.43e+04 real consumption= 6.01e+04
# x_pred min= 2.36e+03 x_pred max 1.88e+05
# ESS of normalized weights= 319.078406
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.91618511232
# likelihood: -9892.07544529
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 6.58e+04 real consumption= 5.96e+04
# x_pred min= 5.02e+02 x_pred max 1.86e+05
# ESS of normalized weights= 457.514091
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24532369231
# likelihood: -6602.47549072
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 6.26e+04 real consumption= 6.18e+04
# x_pred min= 5.07e+02 x_pred max 1.33e+05
# ESS of normalized weights= 413.014636
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16842315864
# likelihood: -5613.63925255
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 5.74e+04
# x_pred min= 2.27e+02 x_pred max 1.73e+05
# ESS of normalized weights= 497.58605
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.32683002956
# likelihood: -5325.13537791
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.60e+04
# x_pred min= 1.81e+03 x_pred max 1.45e+05
# ESS of normalized weights= 474.370835
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.28046646544
# likelihood: -5452.10209175
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.96e+04 real consumption= 6.36e+04
# x_pred min= 2.07e+03 x_pred max 2.02e+05
# ESS of normalized weights= 530.150837
# ESS>=0.5*M
# new ESS= 530.150837
# 6.37198302259
# likelihood: -5874.71058956
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 6.09e+04 real consumption= 6.06e+04
# x_pred min= 8.33e+02 x_pred max 1.84e+05
# ESS of normalized weights= 274.653576
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.79029268927
# likelihood: -10662.0153354
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 6.15e+04 real consumption= 5.89e+04
# x_pred min= 2.28e+02 x_pred max 1.39e+05
# ESS of normalized weights= 579.678759
# ESS>=0.5*M
# new ESS= 579.678759
# 6.45085672407
# likelihood: -3924.7745635
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 6.25e+04 real consumption= 6.31e+04
# x_pred min= 3.39e+02 x_pred max 1.87e+05
# ESS of normalized weights= 298.18107
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.86844918004
# likelihood: -8612.45283873
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 6.17e+04 real consumption= 6.33e+04
# x_pred min= 8.49e+02 x_pred max 1.40e+05
# ESS of normalized weights= 499.139862
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.32877183293
# likelihood: -4901.27348863
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 5.73e+04
# x_pred min= 1.36e+03 x_pred max 1.26e+05
# ESS of normalized weights= 423.487994
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19085895234
# likelihood: -5940.55838363
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.46e+04
# x_pred min= 6.87e+00 x_pred max 1.53e+05
# ESS of normalized weights= 531.974563
# ESS>=0.5*M
# new ESS= 531.974563
# 6.36859005756
# likelihood: -5080.134604
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 6.05e+04
# x_pred min= 2.17e+02 x_pred max 1.99e+05
# ESS of normalized weights= 247.813949
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.714671341
# likelihood: -11138.32897
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 6.54e+04
# x_pred min= 1.25e+03 x_pred max 1.35e+05
# ESS of normalized weights= 527.928843
# ESS>=0.5*M
# new ESS= 527.928843
# 6.36579254644
# likelihood: -4834.34503467
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.82e+04 real consumption= 6.75e+04
# x_pred min= 2.27e+03 x_pred max 1.86e+05
# ESS of normalized weights= 278.2157
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.79115347772
# likelihood: -10582.230119
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 6.80e+04
# x_pred min= 1.12e+03 x_pred max 1.70e+05
# ESS of normalized weights= 554.32714
# ESS>=0.5*M
# new ESS= 554.32714
# 6.40781860158
# likelihood: -4969.62922571
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 5.72e+04 real consumption= 6.20e+04
# x_pred min= 8.82e+02 x_pred max 2.17e+05
# ESS of normalized weights= 255.479951
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.71019711829
# likelihood: -12235.2512774
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 5.41e+04
# x_pred min= 6.55e+02 x_pred max 1.50e+05
# ESS of normalized weights= 435.384107
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21346089361
# likelihood: -5855.1062652
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 4.57e+04 real consumption= 5.19e+04
# x_pred min= 1.45e+02 x_pred max 1.38e+05
# ESS of normalized weights= 440.243668
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21624979894
# likelihood: -5378.35233637
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 5.14e+04 real consumption= 6.07e+04
# x_pred min= 3.11e+02 x_pred max 1.19e+05
# ESS of normalized weights= 552.584128
# ESS>=0.5*M
# new ESS= 552.584128
# 6.40761532994
# likelihood: -4178.80207437
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 6.07e+04
# x_pred min= 1.42e+02 x_pred max 2.16e+05
# ESS of normalized weights= 281.6117
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.80437197326
# likelihood: -8909.29943434
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 6.23e+04
# x_pred min= 1.34e+03 x_pred max 1.91e+05
# ESS of normalized weights= 553.185282
# ESS>=0.5*M
# new ESS= 553.185282
# 6.41210570831
# likelihood: -5080.96389915
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.54e+04 real consumption= 6.36e+04
# x_pred min= 1.88e+03 x_pred max 2.16e+05
# ESS of normalized weights= 283.62283
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.81378884344
# likelihood: -10711.8182699
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 6.11e+04
# x_pred min= 1.70e+03 x_pred max 1.32e+05
# ESS of normalized weights= 463.664412
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26162695089
# likelihood: -5590.41057041
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 4.81e+04 real consumption= 5.54e+04
# x_pred min= 2.83e+02 x_pred max 1.26e+05
# ESS of normalized weights= 485.50777
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29940030457
# likelihood: -5130.81252168
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 4.52e+04 real consumption= 4.91e+04
# x_pred min= 9.30e+02 x_pred max 1.26e+05
# ESS of normalized weights= 460.475776
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2681326296
# likelihood: -5131.08018499
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 4.96e+04
# x_pred min= 6.15e+02 x_pred max 1.60e+05
# ESS of normalized weights= 513.29299
# ESS>=0.5*M
# new ESS= 513.29299
# 6.34194158727
# likelihood: -6124.32567437
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.87e+04
# x_pred min= 1.47e+02 x_pred max 2.28e+05
# ESS of normalized weights= 266.057308
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.76205891727
# likelihood: -12271.3022882
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.70e+04
# x_pred min= 2.62e+03 x_pred max 2.29e+05
# ESS of normalized weights= 557.957044
# ESS>=0.5*M
# new ESS= 557.957044
# 6.4149227613
# likelihood: -4688.84997188
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 5.49e+04
# x_pred min= 1.45e+02 x_pred max 1.97e+05
# ESS of normalized weights= 286.60192
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -9708.79339045
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.35e+04
# x_pred min= 4.35e+02 x_pred max 1.38e+05
# ESS of normalized weights= 527.416929
# ESS>=0.5*M
# new ESS= 527.416929
# 6.38301255658
# likelihood: -4779.40734299
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 4.79e+04
# x_pred min= 9.50e+01 x_pred max 1.71e+05
# ESS of normalized weights= 228.246856
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.64076559245
# likelihood: -11905.2070229
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.37e+04 real consumption= 4.19e+04
# x_pred min= 1.05e+03 x_pred max 1.62e+05
# ESS of normalized weights= 366.062608
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05508179401
# likelihood: -6766.51193519
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.26e+04
# x_pred min= 3.14e+02 x_pred max 1.58e+05
# ESS of normalized weights= 501.661045
# ESS>=0.5*M
# new ESS= 501.661045
# 6.31675219717
# likelihood: -5607.42326932
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.36e+04 real consumption= 5.22e+04
# x_pred min= 3.83e+02 x_pred max 2.43e+05
# ESS of normalized weights= 247.672168
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.68121464965
# likelihood: -12537.9244387
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.23e+04
# x_pred min= 1.68e+02 x_pred max 1.55e+05
# ESS of normalized weights= 538.154246
# ESS>=0.5*M
# new ESS= 538.154246
# 6.37967319669
# likelihood: -5365.94489918
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.63e+04 real consumption= 5.27e+04
# x_pred min= 5.10e+02 x_pred max 1.71e+05
# ESS of normalized weights= 225.0094
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.6456148931
# likelihood: -11481.4011764
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 4.90e+04 real consumption= 5.24e+04
# x_pred min= 3.86e+02 x_pred max 1.37e+05
# ESS of normalized weights= 526.851623
# ESS>=0.5*M
# new ESS= 526.851623
# 6.36836978951
# likelihood: -4766.22579715
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 5.11e+04 real consumption= 4.52e+04
# x_pred min= 3.29e+02 x_pred max 1.69e+05
# ESS of normalized weights= 242.789593
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.68447433497
# likelihood: -10757.8761068
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 4.43e+04 real consumption= 4.20e+04
# x_pred min= 2.79e+02 x_pred max 1.42e+05
# ESS of normalized weights= 438.895312
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21866206856
# likelihood: -5310.50392558
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 5.22e+04
# x_pred min= 1.18e+03 x_pred max 1.54e+05
# ESS of normalized weights= 481.388508
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.28233425336
# likelihood: -6141.24016741
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 5.22e+04
# x_pred min= 1.13e+03 x_pred max 1.33e+05
# ESS of normalized weights= 534.387547
# ESS>=0.5*M
# new ESS= 534.387547
# 6.3751948477
# likelihood: -4586.67270958
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.20e+04
# x_pred min= 1.93e+02 x_pred max 1.73e+05
# ESS of normalized weights= 278.343347
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.79871745843
# likelihood: -9435.35692725
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 5.22e+04
# x_pred min= 7.45e+02 x_pred max 1.46e+05
# ESS of normalized weights= 440.494688
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22716341717
# likelihood: -5391.91559791
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 5.14e+04
# x_pred min= 9.45e+02 x_pred max 1.65e+05
# ESS of normalized weights= 529.216051
# ESS>=0.5*M
# new ESS= 529.216051
# 6.3675919877
# likelihood: -5212.94765056
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 5.01e+04 real consumption= 4.47e+04
# x_pred min= 1.98e+02 x_pred max 2.40e+05
# ESS of normalized weights= 245.436288
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.67718898226
# likelihood: -13114.9628485
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 4.31e+04 real consumption= 4.14e+04
# x_pred min= 4.60e+02 x_pred max 1.48e+05
# ESS of normalized weights= 403.82096
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15170797414
# likelihood: -5506.55762853
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 5.42e+04
# x_pred min= 8.20e+02 x_pred max 1.34e+05
# ESS of normalized weights= 505.376533
# ESS>=0.5*M
# new ESS= 505.376533
# 6.33376530275
# likelihood: -5504.68514708
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 5.47e+04
# x_pred min= 7.11e+02 x_pred max 1.73e+05
# ESS of normalized weights= 263.655707
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.76146316813
# likelihood: -10294.7371441
# ------------------------
# n= 118
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.47e+04
# x_pred min= 1.88e+02 x_pred max 1.38e+05
# ESS of normalized weights= 432.385026
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21228544104
# likelihood: -5834.67429044
# ------------------------
# n= 119
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 5.60e+04
# x_pred min= 1.50e+03 x_pred max 1.66e+05
# ESS of normalized weights= 520.463568
# ESS>=0.5*M
# new ESS= 520.463568
# 6.35650789836
# likelihood: -4595.06943571
# ------------------------
# n= 120
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 4.54e+04
# x_pred min= 5.81e+01 x_pred max 1.77e+05
# ESS of normalized weights= 270.534949
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.77062946018
# likelihood: -8950.57270691
# ------------------------
# n= 121
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 4.68e+04
# x_pred min= 1.43e+03 x_pred max 1.52e+05
# ESS of normalized weights= 475.277134
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29035673748
# likelihood: -5147.05944688
# ------------------------
# n= 122
# No heating effect
# x_pred_mean = 4.29e+04 real consumption= 4.28e+04
# x_pred min= 2.74e+02 x_pred max 1.21e+05
# ESS of normalized weights= 410.323772
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16908845672
# likelihood: -5495.67569746
# ------------------------
# n= 123
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 5.29e+04
# x_pred min= 4.88e+02 x_pred max 1.89e+05
# ESS of normalized weights= 469.203982
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26788130421
# likelihood: -5789.92708386
# ------------------------
# n= 124
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.25e+04
# x_pred min= 1.30e+02 x_pred max 1.40e+05
# ESS of normalized weights= 502.800457
# ESS>=0.5*M
# new ESS= 502.800457
# 6.31834327096
# likelihood: -5554.35951838
# ------------------------
# n= 125
# No heating effect
# x_pred_mean = 5.59e+04 real consumption= 5.30e+04
# x_pred min= 2.02e+02 x_pred max 1.78e+05
# ESS of normalized weights= 241.301605
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.65619910395
# likelihood: -11365.7631805
# ------------------------
# n= 126
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.26e+04
# x_pred min= 2.86e+03 x_pred max 1.76e+05
# ESS of normalized weights= 543.983642
# ESS>=0.5*M
# new ESS= 543.983642
# 6.39251290432
# likelihood: -4959.33822799
# ------------------------
# n= 127
# No heating effect
# x_pred_mean = 5.63e+04 real consumption= 4.37e+04
# x_pred min= 1.61e+03 x_pred max 2.39e+05
# ESS of normalized weights= 242.870393
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -12404.0892251
# ------------------------
# n= 128
# No heating effect
# x_pred_mean = 4.78e+04 real consumption= 4.34e+04
# x_pred min= 8.93e+02 x_pred max 1.13e+05
# ESS of normalized weights= 466.610596
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26833717343
# likelihood: -5680.57853824
# ------------------------
# n= 129
# No heating effect
# x_pred_mean = 4.25e+04 real consumption= 3.94e+04
# x_pred min= 2.14e+03 x_pred max 1.12e+05
# ESS of normalized weights= 524.212532
# ESS>=0.5*M
# new ESS= 524.212532
# 6.35799299884
# likelihood: -4675.75366533
# ------------------------
# n= 130
# No heating effect
# x_pred_mean = 4.53e+04 real consumption= 5.15e+04
# x_pred min= 1.08e+02 x_pred max 1.89e+05
# ESS of normalized weights= 213.858683
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.56078699409
# likelihood: -10786.8935385
# ------------------------
# n= 131
# No heating effect
# x_pred_mean = 5.08e+04 real consumption= 5.20e+04
# x_pred min= 1.64e+03 x_pred max 1.29e+05
# ESS of normalized weights= 503.563891
# ESS>=0.5*M
# new ESS= 503.563891
# 6.31950459819
# likelihood: -5250.53457034
# ------------------------
# n= 132
# No heating effect
# x_pred_mean = 5.29e+04 real consumption= 5.20e+04
# x_pred min= 5.53e+02 x_pred max 2.16e+05
# ESS of normalized weights= 253.021166
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.70375835339
# likelihood: -10013.5143234
# ------------------------
# n= 133
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 4.28e+04
# x_pred min= 2.61e+03 x_pred max 1.54e+05
# ESS of normalized weights= 581.211518
# ESS>=0.5*M
# new ESS= 581.211518
# 6.44108555901
# likelihood: -5072.21599018
# ------------------------
# n= 134
# No heating effect
# x_pred_mean = 5.51e+04 real consumption= 4.84e+04
# x_pred min= 3.56e+02 x_pred max 1.97e+05
# ESS of normalized weights= 262.575874
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.75488113054
# likelihood: -12457.4424128
# ------------------------
# n= 135
# No heating effect
# x_pred_mean = 4.74e+04 real consumption= 4.47e+04
# x_pred min= 3.34e+02 x_pred max 1.37e+05
# ESS of normalized weights= 471.300849
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27685478255
# likelihood: -5722.88465695
# ------------------------
# n= 136
# No heating effect
# x_pred_mean = 4.31e+04 real consumption= 3.98e+04
# x_pred min= 5.99e+02 x_pred max 1.33e+05
# ESS of normalized weights= 388.02008
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10507367134
# likelihood: -6229.74890312
# ------------------------
# n= 137
# No heating effect
# x_pred_mean = 5.07e+04 real consumption= 5.18e+04
# x_pred min= 7.04e+02 x_pred max 1.43e+05
# ESS of normalized weights= 492.637399
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30772070674
# likelihood: -5442.32945958
# ------------------------
# n= 138
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.32e+04
# x_pred min= 1.83e+02 x_pred max 1.82e+05
# ESS of normalized weights= 535.910148
# ESS>=0.5*M
# new ESS= 535.910148
# 6.37383396863
# likelihood: -5394.56715059
# ------------------------
# n= 139
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.41e+04
# x_pred min= 1.13e+03 x_pred max 2.63e+05
# ESS of normalized weights= 271.192969
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -11933.1110756
# ------------------------
# n= 140
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.36e+04
# x_pred min= 2.60e+03 x_pred max 1.64e+05
# ESS of normalized weights= 571.965481
# ESS>=0.5*M
# new ESS= 571.965481
# 6.43620387427
# likelihood: -4631.51507022
# ------------------------
# n= 141
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.20e+04
# x_pred min= 3.08e+02 x_pred max 1.75e+05
# ESS of normalized weights= 252.10091
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.73877704205
# likelihood: -11218.3770208
# ------------------------
# n= 142
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 4.45e+04
# x_pred min= 7.33e+02 x_pred max 1.73e+05
# ESS of normalized weights= 430.348801
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20316085157
# likelihood: -6132.86586077
# ------------------------
# n= 143
# No heating effect
# x_pred_mean = 4.35e+04 real consumption= 3.90e+04
# x_pred min= 5.19e+02 x_pred max 2.16e+05
# ESS of normalized weights= 392.037573
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11049589201
# likelihood: -7452.75733485
# ------------------------
# n= 144
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 4.27e+04
# x_pred min= 3.70e+03 x_pred max 1.98e+05
# ESS of normalized weights= 487.403076
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29222127234
# likelihood: -6062.07411359
# ------------------------
# n= 145
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.24e+04
# x_pred min= 6.73e+02 x_pred max 1.61e+05
# ESS of normalized weights= 548.18087
# ESS>=0.5*M
# new ESS= 548.18087
# 6.39944451016
# likelihood: -5013.14073462
# ------------------------
# n= 146
# No heating effect
# x_pred_mean = 5.31e+04 real consumption= 5.24e+04
# x_pred min= 2.05e+02 x_pred max 1.74e+05
# ESS of normalized weights= 294.974944
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.83972667929
# likelihood: -8891.31355904
# ------------------------
# n= 147
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 5.28e+04
# x_pred min= 6.03e+02 x_pred max 1.38e+05
# ESS of normalized weights= 574.823609
# ESS>=0.5*M
# new ESS= 574.823609
# 6.43383822502
# likelihood: -4879.04322839
# ------------------------
# n= 148
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.18e+04
# x_pred min= 7.66e+02 x_pred max 2.39e+05
# ESS of normalized weights= 267.175557
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.77781496687
# likelihood: -12397.006728
# ------------------------
# n= 149
# No heating effect
# x_pred_mean = 4.75e+04 real consumption= 4.41e+04
# x_pred min= 1.85e+02 x_pred max 1.49e+05
# ESS of normalized weights= 432.5226
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20673121694
# likelihood: -6298.58450346
# ------------------------
# n= 150
# No heating effect
# x_pred_mean = 4.38e+04 real consumption= 4.00e+04
# x_pred min= 4.43e+02 x_pred max 1.90e+05
# ESS of normalized weights= 396.262504
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1258469219
# likelihood: -6758.06171013
# ------------------------
# n= 151
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 5.20e+04
# x_pred min= 1.24e+03 x_pred max 1.41e+05
# ESS of normalized weights= 508.736934
# ESS>=0.5*M
# new ESS= 508.736934
# 6.33859755633
# likelihood: -5465.32569022
# ------------------------
# n= 152
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.31e+04
# x_pred min= 1.09e+02 x_pred max 1.83e+05
# ESS of normalized weights= 237.536894
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.66875583077
# likelihood: -11515.6608121
# ------------------------
# n= 153
# No heating effect
# x_pred_mean = 5.27e+04 real consumption= 5.38e+04
# x_pred min= 8.73e+02 x_pred max 1.37e+05
# ESS of normalized weights= 555.516903
# ESS>=0.5*M
# new ESS= 555.516903
# 6.40829963135
# likelihood: -4231.31465226
# ------------------------
# n= 154
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.43e+04
# x_pred min= 9.66e+01 x_pred max 1.98e+05
# ESS of normalized weights= 285.305343
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.82160905563
# likelihood: -10443.7008686
# ------------------------
# n= 155
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 5.44e+04
# x_pred min= 3.43e+02 x_pred max 1.51e+05
# ESS of normalized weights= 469.731765
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27655781004
# likelihood: -5688.63794851
# ------------------------
# n= 156
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 4.49e+04
# x_pred min= 5.24e+02 x_pred max 1.19e+05
# ESS of normalized weights= 450.894699
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24300658116
# likelihood: -5197.51434904
# ------------------------
# n= 157
# No heating effect
# x_pred_mean = 4.34e+04 real consumption= 3.99e+04
# x_pred min= 3.37e+02 x_pred max 1.14e+05
# ESS of normalized weights= 381.665789
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10138286776
# likelihood: -6119.52036215
# ------------------------
# n= 158
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 5.25e+04
# x_pred min= 1.37e+03 x_pred max 1.52e+05
# ESS of normalized weights= 494.298777
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.3110931805
# likelihood: -5984.2556283
# ------------------------
# n= 159
# No heating effect
# x_pred_mean = 5.39e+04 real consumption= 5.29e+04
# x_pred min= 7.45e+02 x_pred max 1.45e+05
# ESS of normalized weights= 524.314827
# ESS>=0.5*M
# new ESS= 524.314827
# 6.36417638935
# likelihood: -5388.46184549
# ------------------------
# n= 160
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 5.30e+04
# x_pred min= 2.40e+02 x_pred max 2.19e+05
# ESS of normalized weights= 263.129603
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.75011681569
# likelihood: -11666.3534865
# ------------------------
# n= 161
# No heating effect
# x_pred_mean = 5.42e+04 real consumption= 5.43e+04
# x_pred min= 9.62e+01 x_pred max 1.25e+05
# ESS of normalized weights= 589.474933
# ESS>=0.5*M
# new ESS= 589.474933
# 6.4557818714
# likelihood: -4116.68350296
# ------------------------
# n= 162
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.26e+04
# x_pred min= 3.18e+02 x_pred max 1.60e+05
# ESS of normalized weights= 263.719796
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.77575822711
# likelihood: -10059.3775657
# ------------------------
# n= 163
# No heating effect
# x_pred_mean = 4.86e+04 real consumption= 4.41e+04
# x_pred min= 2.33e+03 x_pred max 1.50e+05
# ESS of normalized weights= 431.464801
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20253411051
# likelihood: -5362.90017657
# ------------------------
# n= 164
# No heating effect
# x_pred_mean = 4.39e+04 real consumption= 3.96e+04
# x_pred min= 1.19e+03 x_pred max 1.16e+05
# ESS of normalized weights= 368.161932
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06510454962
# likelihood: -5969.83518857
# ------------------------
# n= 165
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 5.18e+04
# x_pred min= 1.77e+03 x_pred max 1.43e+05
# ESS of normalized weights= 446.328911
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2193709438
# likelihood: -6417.44599998
# ------------------------
# n= 166
# No heating effect
# x_pred_mean = 5.69e+04 real consumption= 5.23e+04
# x_pred min= 1.35e+03 x_pred max 1.58e+05
# ESS of normalized weights= 486.759887
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29279645949
# likelihood: -6550.85437245
# ------------------------
# n= 167
# No heating effect
# x_pred_mean = 5.76e+04 real consumption= 5.27e+04
# x_pred min= 2.52e+03 x_pred max 1.56e+05
# ESS of normalized weights= 546.915307
# ESS>=0.5*M
# new ESS= 546.915307
# 6.3975277473
# likelihood: -4705.88468673
# ------------------------
# n= 168
# No heating effect
# x_pred_mean = 5.88e+04 real consumption= 5.34e+04
# x_pred min= 1.61e+03 x_pred max 1.93e+05
# ESS of normalized weights= 293.541041
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.83100506404
# likelihood: -9200.59588231
# ------------------------
# n= 169
# No heating effect
# x_pred_mean = 5.79e+04 real consumption= 5.13e+04
# x_pred min= 5.72e+03 x_pred max 1.26e+05
# ESS of normalized weights= 427.608955
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20354625293
# likelihood: -6219.64361774
# ------------------------
# n= 170
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 4.36e+04
# x_pred min= 2.59e+01 x_pred max 1.39e+05
# ESS of normalized weights= 439.658568
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21843028479
# likelihood: -6225.32434497
# ------------------------
# n= 171
# No heating effect
# x_pred_mean = 4.67e+04 real consumption= 3.96e+04
# x_pred min= 2.51e+02 x_pred max 1.28e+05
# ESS of normalized weights= 368.828119
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06748451713
# likelihood: -6473.745112
# ------------------------
# n= 172
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.29e+04
# x_pred min= 2.06e+02 x_pred max 1.41e+05
# ESS of normalized weights= 471.666575
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26244244448
# likelihood: -6312.69891055
# ------------------------
# n= 173
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 5.31e+04
# x_pred min= 1.78e+03 x_pred max 1.72e+05
# ESS of normalized weights= 533.760336
# ESS>=0.5*M
# new ESS= 533.760336
# 6.37319943296
# likelihood: -5707.65609369
# ------------------------
# n= 174
# No heating effect
# x_pred_mean = 5.85e+04 real consumption= 5.31e+04
# x_pred min= 5.55e+02 x_pred max 2.31e+05
# ESS of normalized weights= 296.26535
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.84751247815
# likelihood: -10223.0437459
# ------------------------
# n= 175
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 5.41e+04
# x_pred min= 4.77e+03 x_pred max 1.65e+05
# ESS of normalized weights= 571.847732
# ESS>=0.5*M
# new ESS= 571.847732
# 6.43613828422
# likelihood: -4681.10390715
# ------------------------
# n= 176
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.40e+04
# x_pred min= 4.71e+02 x_pred max 2.15e+05
# ESS of normalized weights= 274.075541
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.7927691016
# likelihood: -10664.2550916
# ------------------------
# n= 177
# No heating effect
# x_pred_mean = 4.90e+04 real consumption= 4.52e+04
# x_pred min= 1.52e+01 x_pred max 1.65e+05
# ESS of normalized weights= 457.148233
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26128313629
# likelihood: -5390.38710232
# ------------------------
# n= 178
# No heating effect
# x_pred_mean = 4.46e+04 real consumption= 4.11e+04
# x_pred min= 2.06e+02 x_pred max 1.23e+05
# ESS of normalized weights= 473.077021
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27354760529
# likelihood: -5348.06407767
# ------------------------
# n= 179
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.50e+04
# x_pred min= 4.81e+02 x_pred max 1.97e+05
# ESS of normalized weights= 502.230184
# ESS>=0.5*M
# new ESS= 502.230184
# 6.32109993669
# likelihood: -6770.83457689
# ------------------------
# n= 180
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.66e+04
# x_pred min= 1.82e+02 x_pred max 2.12e+05
# ESS of normalized weights= 207.518342
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.58347039991
# likelihood: -12395.3472762
# ------------------------
# n= 181
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.77e+04
# x_pred min= 8.82e+02 x_pred max 1.44e+05
# ESS of normalized weights= 487.288574
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29529105366
# likelihood: -5631.96467979
# ------------------------
# n= 182
# No heating effect
# x_pred_mean = 5.67e+04 real consumption= 5.71e+04
# x_pred min= 1.81e+03 x_pred max 1.91e+05
# ESS of normalized weights= 520.750227
# ESS>=0.5*M
# new ESS= 520.750227
# 6.34885103309
# likelihood: -5448.86674465
# ------------------------
# n= 183
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 5.70e+04
# x_pred min= 1.96e+02 x_pred max 2.04e+05
# ESS of normalized weights= 235.427062
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.66206735864
# likelihood: -13015.8509593
# ------------------------
# n= 184
# No heating effect
# x_pred_mean = 5.07e+04 real consumption= 4.83e+04
# x_pred min= 4.01e+00 x_pred max 1.49e+05
# ESS of normalized weights= 408.169796
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16557825588
# likelihood: -6747.02544097
# ------------------------
# n= 185
# No heating effect
# x_pred_mean = 4.51e+04 real consumption= 4.27e+04
# x_pred min= 1.43e+03 x_pred max 1.22e+05
# ESS of normalized weights= 361.498453
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05410958555
# likelihood: -6381.14054569
# ------------------------
# n= 186
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.63e+04
# x_pred min= 1.66e+03 x_pred max 2.06e+05
# ESS of normalized weights= 489.319049
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30121701036
# likelihood: -6182.40368446
# ------------------------
# n= 187
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 5.71e+04
# x_pred min= 2.45e+03 x_pred max 1.85e+05
# ESS of normalized weights= 539.180253
# ESS>=0.5*M
# new ESS= 539.180253
# 6.3837783351
# likelihood: -5002.94160362
# ------------------------
# n= 188
# No heating effect
# ...
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.80880551995
# likelihood: -9324.94385464
# ------------------------
# n= 648
# No heating effect
# x_pred_mean = 5.79e+04 real consumption= 5.58e+04
# x_pred min= 6.24e+03 x_pred max 2.15e+05
# ESS of normalized weights= 488.83182
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.31195733161
# likelihood: -5199.75819834
# ------------------------
# n= 649
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 5.70e+04
# x_pred min= 1.84e+03 x_pred max 1.64e+05
# ESS of normalized weights= 402.758399
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15600905519
# likelihood: -6467.66830674
# ------------------------
# n= 650
# No heating effect
# x_pred_mean = 4.73e+04 real consumption= 5.83e+04
# x_pred min= 5.11e+02 x_pred max 1.82e+05
# ESS of normalized weights= 518.008811
# ESS>=0.5*M
# new ESS= 518.008811
# 6.35094894425
# likelihood: -4706.85129461
# ------------------------
# n= 651
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 6.12e+04
# x_pred min= 2.02e+02 x_pred max 2.06e+05
# ESS of normalized weights= 258.787273
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.74166781048
# likelihood: -9542.51469044
# ------------------------
# n= 652
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 5.96e+04
# x_pred min= 5.97e+02 x_pred max 1.33e+05
# ESS of normalized weights= 372.973934
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.09858019655
# likelihood: -6372.92262886
# ------------------------
# n= 653
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 4.86e+04
# x_pred min= 3.46e+02 x_pred max 1.64e+05
# ESS of normalized weights= 489.062879
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30868978685
# likelihood: -6170.79446867
# ------------------------
# n= 654
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 4.44e+04
# x_pred min= 6.43e+03 x_pred max 1.32e+05
# ESS of normalized weights= 512.466051
# ESS>=0.5*M
# new ESS= 512.466051
# 6.34836507448
# likelihood: -4718.74976303
# ------------------------
# n= 655
# No heating effect
# x_pred_mean = 6.00e+04 real consumption= 5.59e+04
# x_pred min= 3.37e+01 x_pred max 2.03e+05
# ESS of normalized weights= 244.629905
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.71192797197
# likelihood: -10565.6315229
# ------------------------
# n= 656
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.61e+04
# x_pred min= 3.83e+02 x_pred max 1.73e+05
# ESS of normalized weights= 516.649612
# ESS>=0.5*M
# new ESS= 516.649612
# 6.35294556823
# likelihood: -5406.23332659
# ------------------------
# n= 657
# No heating effect
# x_pred_mean = 5.78e+04 real consumption= 5.82e+04
# x_pred min= 7.73e+01 x_pred max 2.15e+05
# ESS of normalized weights= 156.890447
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.3788347899
# likelihood: -12472.1154938
# ------------------------
# n= 658
# No heating effect
# x_pred_mean = 6.48e+04 real consumption= 5.86e+04
# x_pred min= 2.86e+03 x_pred max 1.90e+05
# ESS of normalized weights= 442.75936
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21090766159
# likelihood: -6814.79533352
# ------------------------
# n= 659
# No heating effect
# x_pred_mean = 6.69e+04 real consumption= 5.78e+04
# x_pred min= 2.91e+03 x_pred max 1.56e+05
# ESS of normalized weights= 505.788388
# ESS>=0.5*M
# new ESS= 505.788388
# 6.32797032139
# likelihood: -6059.31830888
# ------------------------
# n= 660
# No heating effect
# x_pred_mean = 6.75e+04 real consumption= 5.08e+04
# x_pred min= 9.22e+02 x_pred max 1.86e+05
# ESS of normalized weights= 255.571725
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.70950609909
# likelihood: -11204.9748528
# ------------------------
# n= 661
# No heating effect
# x_pred_mean = 6.79e+04 real consumption= 4.94e+04
# x_pred min= 8.42e+03 x_pred max 1.87e+05
# ESS of normalized weights= 344.997112
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.02954920196
# likelihood: -7579.04824308
# ------------------------
# n= 662
# No heating effect
# x_pred_mean = 5.99e+04 real consumption= 5.85e+04
# x_pred min= 1.82e+03 x_pred max 1.50e+05
# ESS of normalized weights= 515.560293
# ESS>=0.5*M
# new ESS= 515.560293
# 6.33346331915
# likelihood: -5690.87203594
# ------------------------
# n= 663
# No heating effect
# x_pred_mean = 6.13e+04 real consumption= 5.83e+04
# x_pred min= 5.48e+02 x_pred max 2.14e+05
# ESS of normalized weights= 266.535557
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.75352113723
# likelihood: -12008.9749215
# ------------------------
# n= 664
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 5.84e+04
# x_pred min= 5.30e+03 x_pred max 1.51e+05
# ESS of normalized weights= 413.49508
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16710878899
# likelihood: -6195.91807734
# ------------------------
# n= 665
# No heating effect
# x_pred_mean = 6.43e+04 real consumption= 5.79e+04
# x_pred min= 6.09e+01 x_pred max 1.58e+05
# ESS of normalized weights= 497.743728
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.31661821035
# likelihood: -6227.54452982
# ------------------------
# n= 666
# No heating effect
# x_pred_mean = 6.57e+04 real consumption= 5.72e+04
# x_pred min= 6.72e+03 x_pred max 1.55e+05
# ESS of normalized weights= 561.305013
# ESS>=0.5*M
# new ESS= 561.305013
# 6.41653953517
# likelihood: -5213.28628075
# ------------------------
# n= 667
# No heating effect
# x_pred_mean = 6.62e+04 real consumption= 5.02e+04
# x_pred min= 3.49e+03 x_pred max 1.91e+05
# ESS of normalized weights= 280.309419
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.80095828007
# likelihood: -10235.3561752
# ------------------------
# n= 668
# No heating effect
# x_pred_mean = 6.26e+04 real consumption= 4.42e+04
# x_pred min= 3.95e+03 x_pred max 1.47e+05
# ESS of normalized weights= 538.727236
# ESS>=0.5*M
# new ESS= 538.727236
# 6.37794143276
# likelihood: -5150.38522089
# ------------------------
# n= 669
# No heating effect
# x_pred_mean = 6.27e+04 real consumption= 5.10e+04
# x_pred min= 4.09e+02 x_pred max 1.83e+05
# ESS of normalized weights= 271.127026
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.78011479811
# likelihood: -10420.7096631
# ------------------------
# n= 670
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 4.62e+04
# x_pred min= 8.59e+02 x_pred max 1.29e+05
# ESS of normalized weights= 467.443791
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27712542975
# likelihood: -5029.47250325
# ------------------------
# n= 671
# No heating effect
# x_pred_mean = 5.39e+04 real consumption= 5.84e+04
# x_pred min= 1.16e+03 x_pred max 1.30e+05
# ESS of normalized weights= 423.028311
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18712364964
# likelihood: -5995.28713162
# ------------------------
# n= 672
# No heating effect
# x_pred_mean = 6.06e+04 real consumption= 5.92e+04
# x_pred min= 3.37e+03 x_pred max 2.03e+05
# ESS of normalized weights= 500.49791
# ESS>=0.5*M
# new ESS= 500.49791
# 6.32489127075
# likelihood: -6326.63102916
# ------------------------
# n= 673
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 6.22e+04
# x_pred min= 1.58e+03 x_pred max 2.37e+05
# ESS of normalized weights= 245.539617
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -13206.1072242
# ------------------------
# n= 674
# No heating effect
# x_pred_mean = 6.33e+04 real consumption= 5.39e+04
# x_pred min= 3.02e+03 x_pred max 1.46e+05
# ESS of normalized weights= 558.812858
# ESS>=0.5*M
# new ESS= 558.812858
# 6.41309216393
# likelihood: -4500.32039589
# ------------------------
# n= 675
# No heating effect
# x_pred_mean = 6.54e+04 real consumption= 5.17e+04
# x_pred min= 4.21e+02 x_pred max 2.03e+05
# ESS of normalized weights= 286.693471
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.83063859613
# likelihood: -10368.7933164
# ------------------------
# n= 676
# No heating effect
# x_pred_mean = 6.44e+04 real consumption= 6.75e+04
# x_pred min= 8.05e+03 x_pred max 1.46e+05
# ESS of normalized weights= 495.393593
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.3347605495
# likelihood: -5523.88475461
# ------------------------
# n= 677
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.90e+04
# x_pred min= 1.12e+03 x_pred max 1.38e+05
# ESS of normalized weights= 515.474259
# ESS>=0.5*M
# new ESS= 515.474259
# 6.35619349084
# likelihood: -4815.26958868
# ------------------------
# n= 678
# x_pred_mean = 3.61e+05 real consumption= 7.00e+04
# x_pred min= 2.17e+04 x_pred max 1.35e+06
# ESS of normalized weights= 18.713513
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -2113088.70356
# ------------------------
# n= 679
# x_pred_mean = 2.06e+05 real consumption= 6.71e+04
# x_pred min= 2.44e+04 x_pred max 1.09e+06
# ESS of normalized weights= 68.05206
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -548686.976573
# ------------------------
# n= 680
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 5.54e+04
# x_pred min= 6.12e+01 x_pred max 1.38e+05
# ESS of normalized weights= 268.915291
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.7599129875
# likelihood: -11790.0076078
# ------------------------
# n= 681
# No heating effect
# x_pred_mean = 6.89e+04 real consumption= 5.98e+04
# x_pred min= 3.79e+03 x_pred max 2.22e+05
# ESS of normalized weights= 489.22516
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29758435166
# likelihood: -7099.7163946
# ------------------------
# n= 682
# x_pred_mean = 8.32e+04 real consumption= 5.49e+04
# x_pred min= 1.25e+04 x_pred max 2.25e+05
# ESS of normalized weights= 400.22819
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10401942636
# likelihood: -11171.3488658
# ------------------------
# n= 683
# x_pred_mean = 9.25e+04 real consumption= 6.67e+04
# x_pred min= 1.52e+04 x_pred max 2.76e+05
# ESS of normalized weights= 192.65949
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -25826.8391402
# ------------------------
# n= 684
# x_pred_mean = 7.20e+04 real consumption= 6.60e+04
# x_pred min= 1.02e+04 x_pred max 1.98e+05
# ESS of normalized weights= 374.264483
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05474026794
# likelihood: -9774.23463296
# ------------------------
# n= 685
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 6.47e+04
# x_pred min= 1.94e+01 x_pred max 1.64e+05
# ESS of normalized weights= 296.357883
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.85884103841
# likelihood: -9557.52887766
# ------------------------
# n= 686
# No heating effect
# x_pred_mean = 6.60e+04 real consumption= 6.25e+04
# x_pred min= 2.58e+03 x_pred max 1.67e+05
# ESS of normalized weights= 459.523035
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2388805978
# likelihood: -7417.95264163
# ------------------------
# n= 687
# No heating effect
# x_pred_mean = 6.88e+04 real consumption= 6.37e+04
# x_pred min= 4.26e+03 x_pred max 1.69e+05
# ESS of normalized weights= 533.680006
# ESS>=0.5*M
# new ESS= 533.680006
# 6.37216648335
# likelihood: -5718.8739154
# ------------------------
# n= 688
# No heating effect
# x_pred_mean = 7.09e+04 real consumption= 5.66e+04
# x_pred min= 1.15e+03 x_pred max 2.18e+05
# ESS of normalized weights= 276.087845
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.78341014105
# likelihood: -13272.6893731
# ------------------------
# n= 689
# No heating effect
# x_pred_mean = 6.95e+04 real consumption= 5.19e+04
# x_pred min= 8.48e+03 x_pred max 1.46e+05
# ESS of normalized weights= 556.646684
# ESS>=0.5*M
# new ESS= 556.646684
# 6.41266221888
# likelihood: -4387.61350732
# ------------------------
# n= 690
# No heating effect
# x_pred_mean = 7.01e+04 real consumption= 6.25e+04
# x_pred min= 1.22e+02 x_pred max 2.12e+05
# ESS of normalized weights= 298.054649
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.85783813648
# likelihood: -10545.0594277
# ------------------------
# n= 691
# No heating effect
# x_pred_mean = 6.27e+04 real consumption= 6.38e+04
# x_pred min= 1.01e+03 x_pred max 1.23e+05
# ESS of normalized weights= 529.148129
# ESS>=0.5*M
# new ESS= 529.148129
# 6.37910958125
# likelihood: -4202.01727694
# ------------------------
# n= 692
# x_pred_mean = 7.64e+04 real consumption= 6.37e+04
# x_pred min= 3.57e+03 x_pred max 1.87e+05
# ESS of normalized weights= 229.801492
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.64188847883
# likelihood: -11576.1135074
# ------------------------
# n= 693
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 6.32e+04
# x_pred min= 3.72e+03 x_pred max 1.74e+05
# ESS of normalized weights= 431.891975
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19214324336
# likelihood: -6533.85643296
# ------------------------
# n= 694
# No heating effect
# x_pred_mean = 6.77e+04 real consumption= 6.44e+04
# x_pred min= 7.79e+03 x_pred max 1.78e+05
# ESS of normalized weights= 526.725701
# ESS>=0.5*M
# new ESS= 526.725701
# 6.36356123983
# likelihood: -5337.50289209
# ------------------------
# n= 695
# No heating effect
# x_pred_mean = 6.90e+04 real consumption= 5.69e+04
# x_pred min= 1.98e+03 x_pred max 1.97e+05
# ESS of normalized weights= 261.136076
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.74170203195
# likelihood: -11564.9233448
# ------------------------
# n= 696
# No heating effect
# x_pred_mean = 7.03e+04 real consumption= 5.33e+04
# x_pred min= 3.50e+03 x_pred max 1.67e+05
# ESS of normalized weights= 537.901771
# ESS>=0.5*M
# new ESS= 537.901771
# 6.38341389849
# likelihood: -5350.76351005
# ------------------------
# n= 697
# No heating effect
# x_pred_mean = 7.11e+04 real consumption= 6.74e+04
# x_pred min= 4.21e+03 x_pred max 1.86e+05
# ESS of normalized weights= 257.324325
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.71932080285
# likelihood: -11915.4127549
# ------------------------
# n= 698
# x_pred_mean = 1.91e+05 real consumption= 7.18e+04
# x_pred min= 3.01e+04 x_pred max 9.19e+05
# ESS of normalized weights= 40.83062
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -492720.941561
# ------------------------
# n= 699
# x_pred_mean = 1.20e+05 real consumption= 7.05e+04
# x_pred min= 1.38e+04 x_pred max 6.87e+05
# ESS of normalized weights= 212.268434
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -114554.004662
# ------------------------
# n= 700
# x_pred_mean = 1.22e+05 real consumption= 7.11e+04
# x_pred min= 9.43e+03 x_pred max 5.88e+05
# ESS of normalized weights= 172.318168
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -107050.726587
# ------------------------
# n= 701
# x_pred_mean = 7.00e+04 real consumption= 7.27e+04
# x_pred min= 2.22e+03 x_pred max 2.45e+05
# ESS of normalized weights= 337.542537
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.94847465623
# likelihood: -12022.7810767
# ------------------------
# n= 702
# x_pred_mean = 6.51e+04 real consumption= 6.42e+04
# x_pred min= 2.63e+03 x_pred max 2.03e+05
# ESS of normalized weights= 420.66545
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15908953441
# likelihood: -7501.84717598
# ------------------------
# n= 703
# x_pred_mean = 6.94e+04 real consumption= 6.08e+04
# x_pred min= 3.42e+03 x_pred max 1.48e+05
# ESS of normalized weights= 486.441239
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29362207277
# likelihood: -5897.78977174
# ------------------------
# n= 704
# No heating effect
# x_pred_mean = 6.24e+04 real consumption= 6.92e+04
# x_pred min= 2.35e+02 x_pred max 1.93e+05
# ESS of normalized weights= 468.154005
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26884303717
# likelihood: -6066.33329408
# ------------------------
# n= 705
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 6.89e+04
# x_pred min= 1.76e+03 x_pred max 1.48e+05
# ESS of normalized weights= 425.044596
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19460603893
# likelihood: -6394.28082627
# ------------------------
# n= 706
# No heating effect
# x_pred_mean = 5.53e+04 real consumption= 6.97e+04
# x_pred min= 1.91e+03 x_pred max 1.96e+05
# ESS of normalized weights= 474.374799
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27072830414
# likelihood: -7356.70576833
# ------------------------
# n= 707
# x_pred_mean = 1.04e+05 real consumption= 6.89e+04
# x_pred min= 1.34e+04 x_pred max 2.82e+05
# ESS of normalized weights= 169.379128
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -59070.1830978
# ------------------------
# n= 708
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 6.70e+04
# x_pred min= 3.16e+03 x_pred max 1.57e+05
# ESS of normalized weights= 335.317458
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.97669849145
# likelihood: -8204.75061748
# ------------------------
# n= 709
# x_pred_mean = 1.37e+05 real consumption= 6.18e+04
# x_pred min= 1.80e+04 x_pred max 5.54e+05
# ESS of normalized weights= 115.540149
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -163111.915577
# ------------------------

# %% [raw]
# print(np.sum(log_lh_init))

# %%
fig=plt.figure(figsize=(12,6))

for i in pred_forward:
    plt.plot(range(0,n_pred),entrop[i,:n_pred])
plt.title("Evolution of Entropy",fontweight='bold')
plt.legend(facecolor='white',labels=['Prediction n|n-1','Prediction n+1|n-1','Prediction n+2|n-1','Prediction n+3|n-1'])
plt.xlabel('forecasted day')
plt.xlim(0,n_pred)
plt.show()

# %%
fig=plt.figure(figsize=(12,6))

plt.plot(range(1,n_pred),ESS_calc[0,1:n_pred]/M)
plt.plot(range(1,n_pred),ESS_calc[1,1:n_pred]/M)
plt.plot(range(1,n_pred),ESS_calc[2,1:n_pred]/M)
plt.plot(range(1,n_pred),ESS_calc[3,1:n_pred]/M)

plt.title("Evolution of ESS - prediction at 3am",fontweight='bold')
plt.legend(facecolor='white',labels=['Prediction n|n-1','Prediction n+1|n-1','Prediction n+2|n-1','Prediction n+3|n-1'])
plt.xlabel('forecasted day')
plt.xlim(0,n_pred)
plt.show()

# %%
#MAPE
mape_one_day_forecast=abs((x_predict[0,:]-consumption_day_ahead[:n_pred])/consumption_day_ahead[:n_pred])
mape_value = (1/(n_pred-pred_forward[0]))*sum(mape_one_day_forecast) 
print(mape_value)
# Out:
# 0.199315354405

# %%
fig=plt.figure(figsize=(12,6))

for i in pred_forward:
    plt.plot(range(n_pred),(x_predict[i,:]-consumption_day_ahead[:n_pred])/consumption_day_ahead[i:n_pred+i])

plt.plot(range(n_pred-1),np.zeros(n_pred-1),color='red',linestyle='--')
plt.ylim(-1,1)
plt.xlim(0,n_pred)
plt.xlabel('forecasted day')
plt.legend(facecolor='white',labels=['Prediction n|n-1','Prediction n+1|n-1','Prediction n+2|n-1','Prediction n+3|n-1'])
plt.title("Relative forecast error",fontweight='bold')
plt.show()

# %%
fig=plt.figure(figsize=(12,6))
for i in pred_forward[:1]:
    plt.plot(range(n_pred),x_predict[i,:])
#plt.plot(range(n_pred),x_predict[1,:])
#plt.plot(range(n_pred),x_predict[2,:])
plt.plot(range(n_pred),consumption_day_ahead[:n_pred],linestyle='--',color='orange')
plt.legend(facecolor='white',labels=['Prediction n|n-1','Real value'])
plt.xlabel('forecasted day')
plt.xlim(0,n_pred)
plt.ylim(3*10**4,8*10**4)
plt.title("Electricity load forecast in MW",fontweight='bold')
plt.show()

# %% [markdown]
# Goal: re-estimate the one-dimensional parameters ($\sigma_g,\sigma_s,\mu_h,\kappa,\sigma$)<br>
# Proposal distribution for these parameters: truncated gaussian random walk<br>
# We set kappa constant at 1/8

# %% [markdown]
# ## PMMH

# %% [markdown]
# #### Initialization of parameters

# %%
u_h_current=13
sigma_current=10**4
sigma_g_current=10**4
sigma_s_current=10**4

# %%
len_filter_pmmh=715
len_iter_mha=200
accept_log_proba=np.zeros(len_filter_pmmh)
accept_rate=0
log_lh_init=np.zeros(len_filter_pmmh)
lh_y_prop=np.zeros(len_filter_pmmh)

# %%
#store the accepted value in lists
u_h_list=[]
sigma_list=[]
sigma_g_list=[]
sigma_s_list=[]

# %% [markdown]
# #### Initialization of hyperparameters

# %%
#standard deviation of normal/trunc normal proposals on parameters
std_hyp_sigma_g,std_hyp_sigma_s,std_hyp_sigma=np.ones(3)*5*10**3
std_hyp_u=1

# %%
#joint prior density of parameters
def log_joint_prior(u_h,sigma,sigma_g,sigma_s):
    res=0
    res=(-(u_h-14)**2)/2
    res=res+(-0.01-1)*np.log(sigma**2) - (0.01/sigma**2)
    res=res+(-0.01-1)*np.log(sigma_g**2) - (0.01/sigma_g**2)
    res=res+(-0.01-1)*np.log(sigma_s**2) - (0.01/sigma_s**2)
    return res

# %%
#joint log prior density initialize
log_prior_init=log_joint_prior(u_h_current,sigma_current,sigma_g_current,sigma_s_current)
print(log_prior_init)
#initial parameters otbained from Gibbs. These initialized parameters will not change through iterations
# Out:
# -56.3146626545

# %% [markdown]
# #### Run initial particle filter and get the log likelihood

# %%
log_lh_init=particle_filter(0,len_init,
                            len_filter_pmmh,s_init,
                            g_heat_init,sigma_s_current,sigma_g_current,sigma_current,lh_y_n)[0]
# Out:
# n= 1
# x_pred_mean = 4.92e+04 real consumption= 6.86e+04
# x_pred min= 2.07e+03 x_pred max 6.61e+05
# ESS of normalized weights= 315.014015
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -6624.38037195
# ------------------------
# n= 2
# x_pred_mean = 8.06e+04 real consumption= 6.41e+04
# x_pred min= 4.79e+03 x_pred max 2.47e+05
# ESS of normalized weights= 411.870519
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13989644465
# likelihood: -9038.11549099
# ------------------------
# n= 3
# x_pred_mean = 9.30e+04 real consumption= 5.74e+04
# x_pred min= 5.03e+03 x_pred max 4.08e+05
# ESS of normalized weights= 365.688114
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.03421341489
# likelihood: -12191.8963621
# ------------------------
# n= 4
# x_pred_mean = 1.05e+05 real consumption= 7.31e+04
# x_pred min= 9.10e+02 x_pred max 3.59e+05
# ESS of normalized weights= 341.437214
# ESS>=0.001*M and ESS_0<0.5*M
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in multiply
# new ESS= 1000.0
# 5.96925021485
# likelihood: -17826.8458068
# ------------------------
# n= 5
# x_pred_mean = 9.28e+04 real consumption= 7.68e+04
# x_pred min= 9.19e+03 x_pred max 3.51e+05
# ESS of normalized weights= 424.970704
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16413031983
# likelihood: -10606.1663625
# ------------------------
# n= 6
# x_pred_mean = 9.54e+04 real consumption= 7.49e+04
# x_pred min= 7.52e+03 x_pred max 2.85e+05
# ESS of normalized weights= 385.969432
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07826814366
# likelihood: -10634.3327786
# ------------------------
# n= 7
# x_pred_mean = 1.01e+05 real consumption= 7.21e+04
# x_pred min= 5.48e+03 x_pred max 5.37e+05
# ESS of normalized weights= 378.617516
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -15139.2291879
# ------------------------
# n= 8
# x_pred_mean = 8.47e+04 real consumption= 6.90e+04
# x_pred min= 1.76e+03 x_pred max 3.30e+05
# ESS of normalized weights= 465.209159
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24519242866
# likelihood: -8333.33326122
# ------------------------
# n= 9
# x_pred_mean = 7.60e+04 real consumption= 5.72e+04
# x_pred min= 8.04e+03 x_pred max 3.63e+05
# ESS of normalized weights= 501.380558
# ESS>=0.5*M
# new ESS= 501.380558
# 6.32544775671
# likelihood: -6383.84847483
# ------------------------
# n= 10
# x_pred_mean = 8.91e+04 real consumption= 5.55e+04
# x_pred min= 4.16e+03 x_pred max 4.09e+05
# ESS of normalized weights= 209.15957
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -11593.7880691
# ------------------------
# n= 11
# x_pred_mean = 8.07e+04 real consumption= 6.91e+04
# x_pred min= 9.33e+03 x_pred max 2.24e+05
# ESS of normalized weights= 455.879595
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23775827331
# likelihood: -5331.52150033
# ------------------------
# n= 12
# x_pred_mean = 5.59e+04 real consumption= 6.88e+04
# x_pred min= 6.17e+03 x_pred max 2.03e+05
# ESS of normalized weights= 356.1162
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.03703059441
# likelihood: -5014.87327001
# ------------------------
# n= 13
# x_pred_mean = 1.05e+05 real consumption= 6.92e+04
# x_pred min= 1.66e+04 x_pred max 3.01e+05
# ESS of normalized weights= 354.466447
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.98872858435
# likelihood: -12073.2267025
# ------------------------
# n= 14
# x_pred_mean = 1.13e+05 real consumption= 7.03e+04
# x_pred min= 1.37e+04 x_pred max 3.46e+05
# ESS of normalized weights= 327.918335
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.917256203
# likelihood: -16689.9725687
# ------------------------
# n= 15
# x_pred_mean = 1.07e+05 real consumption= 7.00e+04
# x_pred min= 6.05e+03 x_pred max 3.85e+05
# ESS of normalized weights= 288.54693
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.81513583651
# likelihood: -18343.9986769
# ------------------------
# n= 16
# x_pred_mean = 1.05e+05 real consumption= 6.31e+04
# x_pred min= 1.34e+04 x_pred max 4.05e+05
# ESS of normalized weights= 320.427675
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.89908066313
# likelihood: -19927.0661897
# ------------------------
# n= 17
# x_pred_mean = 1.00e+05 real consumption= 6.25e+04
# x_pred min= 1.15e+04 x_pred max 5.60e+05
# ESS of normalized weights= 363.007069
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -17192.6508092
# ------------------------
# n= 18
# x_pred_mean = 1.20e+05 real consumption= 7.72e+04
# x_pred min= 1.10e+04 x_pred max 6.23e+05
# ESS of normalized weights= 346.870721
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -29080.1945799
# ------------------------
# n= 19
# x_pred_mean = 1.14e+05 real consumption= 7.79e+04
# x_pred min= 1.13e+04 x_pred max 4.35e+05
# ESS of normalized weights= 341.819658
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.96188690638
# likelihood: -23429.6218962
# ------------------------
# n= 20
# x_pred_mean = 1.21e+05 real consumption= 7.92e+04
# x_pred min= 1.06e+04 x_pred max 6.04e+05
# ESS of normalized weights= 343.748482
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -28728.6521166
# ------------------------
# n= 21
# x_pred_mean = 1.26e+05 real consumption= 7.84e+04
# x_pred min= 2.33e+04 x_pred max 6.41e+05
# ESS of normalized weights= 324.727792
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -32137.5858481
# ------------------------
# n= 22
# x_pred_mean = 9.71e+04 real consumption= 7.89e+04
# x_pred min= 1.66e+04 x_pred max 4.01e+05
# ESS of normalized weights= 397.137555
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.09800177244
# likelihood: -14012.9098101
# ------------------------
# n= 23
# x_pred_mean = 8.76e+04 real consumption= 7.12e+04
# x_pred min= 7.33e+03 x_pred max 3.36e+05
# ESS of normalized weights= 433.437681
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18996658635
# likelihood: -8883.72977014
# ------------------------
# n= 24
# x_pred_mean = 6.59e+04 real consumption= 6.55e+04
# x_pred min= 6.45e+03 x_pred max 2.11e+05
# ESS of normalized weights= 451.603274
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24282162037
# likelihood: -3901.85583575
# ------------------------
# n= 25
# x_pred_mean = 7.21e+04 real consumption= 7.75e+04
# x_pred min= 7.39e+03 x_pred max 1.67e+05
# ESS of normalized weights= 539.459229
# ESS>=0.5*M
# new ESS= 539.459229
# 6.40623635419
# likelihood: -3036.20153914
# ------------------------
# n= 26
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 7.54e+04
# x_pred min= 1.31e+03 x_pred max 2.13e+05
# ESS of normalized weights= 284.137114
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.85497575185
# likelihood: -4774.7014478
# ------------------------
# n= 27
# No heating effect
# x_pred_mean = 7.06e+04 real consumption= 7.65e+04
# x_pred min= 1.31e+03 x_pred max 2.06e+05
# ESS of normalized weights= 627.667789
# ESS>=0.5*M
# new ESS= 627.667789
# 6.52664604786
# likelihood: -2522.18947326
# ------------------------
# n= 28
# No heating effect
# x_pred_mean = 7.29e+04 real consumption= 7.78e+04
# x_pred min= 3.31e+02 x_pred max 2.83e+05
# ESS of normalized weights= 392.212642
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12326329847
# likelihood: -4587.01934203
# ------------------------
# n= 29
# x_pred_mean = 9.91e+04 real consumption= 7.59e+04
# x_pred min= 3.63e+03 x_pred max 2.38e+05
# ESS of normalized weights= 295.852516
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.83504100169
# likelihood: -11612.3750276
# ------------------------
# n= 30
# x_pred_mean = 7.44e+04 real consumption= 6.84e+04
# x_pred min= 1.82e+03 x_pred max 1.90e+05
# ESS of normalized weights= 495.523642
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.33182841022
# likelihood: -3980.85743733
# ------------------------
# n= 31
# x_pred_mean = 7.69e+04 real consumption= 6.67e+04
# x_pred min= 3.75e+03 x_pred max 1.97e+05
# ESS of normalized weights= 555.843687
# ESS>=0.5*M
# new ESS= 555.843687
# 6.41670809061
# likelihood: -3788.27749478
# ------------------------
# n= 32
# x_pred_mean = 7.88e+04 real consumption= 7.71e+04
# x_pred min= 4.02e+03 x_pred max 2.66e+05
# ESS of normalized weights= 311.282553
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.92055623787
# likelihood: -5540.80975322
# ------------------------
# n= 33
# x_pred_mean = 6.25e+04 real consumption= 7.99e+04
# x_pred min= 1.87e+03 x_pred max 1.97e+05
# ESS of normalized weights= 548.217287
# ESS>=0.5*M
# new ESS= 548.217287
# 6.41929167911
# likelihood: -3137.5516191
# ------------------------
# n= 34
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 8.21e+04
# x_pred min= 2.69e+01 x_pred max 2.58e+05
# ESS of normalized weights= 308.44304
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.90349759679
# likelihood: -5615.87286709
# ------------------------
# n= 35
# No heating effect
# x_pred_mean = 6.92e+04 real consumption= 8.29e+04
# x_pred min= 5.69e+02 x_pred max 2.14e+05
# ESS of normalized weights= 656.300659
# ESS>=0.5*M
# new ESS= 656.300659
# 6.56104772983
# likelihood: -2495.11316282
# ------------------------
# n= 36
# x_pred_mean = 1.60e+05 real consumption= 8.59e+04
# x_pred min= 8.59e+03 x_pred max 8.42e+05
# ESS of normalized weights= 71.429502
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -84270.8017422
# ------------------------
# n= 37
# x_pred_mean = 7.57e+04 real consumption= 7.30e+04
# x_pred min= 3.65e+03 x_pred max 2.80e+05
# ESS of normalized weights= 486.334241
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30096295632
# likelihood: -5539.02983759
# ------------------------
# n= 38
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 6.70e+04
# x_pred min= 5.55e+02 x_pred max 1.76e+05
# ESS of normalized weights= 460.895961
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.25911574159
# likelihood: -4076.54819372
# ------------------------
# n= 39
# x_pred_mean = 8.71e+04 real consumption= 7.57e+04
# x_pred min= 6.10e+03 x_pred max 2.51e+05
# ESS of normalized weights= 488.968649
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30547552664
# likelihood: -5760.95934717
# ------------------------
# n= 40
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 7.55e+04
# x_pred min= 5.74e+01 x_pred max 1.91e+05
# ESS of normalized weights= 614.747804
# ESS>=0.5*M
# new ESS= 614.747804
# 6.51090342738
# likelihood: -2556.61050697
# ------------------------
# n= 41
# No heating effect
# x_pred_mean = 6.37e+04 real consumption= 7.16e+04
# x_pred min= 1.35e+03 x_pred max 2.46e+05
# ESS of normalized weights= 374.632829
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07772014487
# likelihood: -4109.56993529
# ------------------------
# n= 42
# x_pred_mean = 9.69e+04 real consumption= 7.21e+04
# x_pred min= 1.23e+04 x_pred max 2.30e+05
# ESS of normalized weights= 375.119999
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05835064476
# likelihood: -9146.69740459
# ------------------------
# n= 43
# No heating effect
# x_pred_mean = 6.18e+04 real consumption= 7.10e+04
# x_pred min= 1.32e+02 x_pred max 2.05e+05
# ESS of normalized weights= 629.57152
# ESS>=0.5*M
# new ESS= 629.57152
# 6.53395218043
# likelihood: -2254.57621212
# ------------------------
# n= 44
# No heating effect
# x_pred_mean = 6.40e+04 real consumption= 6.39e+04
# x_pred min= 8.61e+01 x_pred max 2.21e+05
# ESS of normalized weights= 364.76393
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06905353387
# likelihood: -4567.56983951
# ------------------------
# n= 45
# No heating effect
# x_pred_mean = 5.91e+04 real consumption= 5.91e+04
# x_pred min= 3.82e+03 x_pred max 1.36e+05
# ESS of normalized weights= 670.004555
# ESS>=0.5*M
# new ESS= 670.004555
# 6.58381459138
# likelihood: -1836.14517963
# ------------------------
# n= 46
# No heating effect
# x_pred_mean = 5.90e+04 real consumption= 7.23e+04
# x_pred min= 7.34e+02 x_pred max 1.91e+05
# ESS of normalized weights= 444.88649
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22560035761
# likelihood: -3059.50910752
# ------------------------
# n= 47
# x_pred_mean = 2.04e+05 real consumption= 7.28e+04
# x_pred min= 2.96e+04 x_pred max 1.00e+06
# ESS of normalized weights= 101.962596
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -183927.303846
# ------------------------
# n= 48
# x_pred_mean = 6.13e+04 real consumption= 7.15e+04
# x_pred min= 3.23e+03 x_pred max 1.80e+05
# ESS of normalized weights= 583.086523
# ESS>=0.5*M
# new ESS= 583.086523
# 6.4635266996
# likelihood: -2688.63808864
# ------------------------
# n= 49
# No heating effect
# x_pred_mean = 5.79e+04 real consumption= 7.06e+04
# x_pred min= 8.98e+01 x_pred max 2.87e+05
# ESS of normalized weights= 335.134295
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.97978536891
# likelihood: -4756.64178413
# ------------------------
# n= 50
# No heating effect
# x_pred_mean = 6.25e+04 real consumption= 7.11e+04
# x_pred min= 1.72e+03 x_pred max 1.49e+05
# ESS of normalized weights= 632.683228
# ESS>=0.5*M
# new ESS= 632.683228
# 6.53742399633
# likelihood: -2182.49883767
# ------------------------
# n= 51
# No heating effect
# x_pred_mean = 6.57e+04 real consumption= 6.54e+04
# x_pred min= 2.36e+03 x_pred max 2.21e+05
# ESS of normalized weights= 349.955726
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.03505693775
# likelihood: -5184.46163212
# ------------------------
# n= 52
# No heating effect
# x_pred_mean = 5.36e+04 real consumption= 5.97e+04
# x_pred min= 6.88e+02 x_pred max 1.44e+05
# ESS of normalized weights= 631.739784
# ESS>=0.5*M
# new ESS= 631.739784
# 6.53752908962
# likelihood: -2031.00775662
# ------------------------
# n= 53
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 7.10e+04
# x_pred min= 8.96e+02 x_pred max 1.71e+05
# ESS of normalized weights= 378.822296
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10116984631
# likelihood: -3632.95461252
# ------------------------
# n= 54
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 7.19e+04
# x_pred min= 4.78e+03 x_pred max 2.07e+05
# ESS of normalized weights= 680.321166
# ESS>=0.5*M
# new ESS= 680.321166
# 6.59646226561
# likelihood: -1883.32241042
# ------------------------
# n= 55
# No heating effect
# x_pred_mean = 6.15e+04 real consumption= 7.05e+04
# x_pred min= 9.60e+02 x_pred max 2.26e+05
# ESS of normalized weights= 439.570021
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21687577
# likelihood: -3476.32352985
# ------------------------
# n= 56
# x_pred_mean = 1.10e+05 real consumption= 6.99e+04
# x_pred min= 1.13e+04 x_pred max 5.18e+05
# ESS of normalized weights= 268.051907
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -27577.4328733
# ------------------------
# n= 57
# x_pred_mean = 1.38e+05 real consumption= 6.90e+04
# x_pred min= 2.42e+04 x_pred max 7.46e+05
# ESS of normalized weights= 153.024771
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -64979.8882224
# ------------------------
# n= 58
# x_pred_mean = 9.45e+04 real consumption= 6.19e+04
# x_pred min= 9.40e+03 x_pred max 3.69e+05
# ESS of normalized weights= 332.023166
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.93233783599
# likelihood: -21026.7012694
# ------------------------
# n= 59
# No heating effect
# x_pred_mean = 4.31e+04 real consumption= 5.57e+04
# x_pred min= 4.07e+02 x_pred max 1.47e+05
# ESS of normalized weights= 403.019993
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13678977912
# likelihood: -4404.40405505
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.53e+04
# x_pred min= 4.53e+02 x_pred max 1.87e+05
# ESS of normalized weights= 650.684784
# ESS>=0.5*M
# new ESS= 650.684784
# 6.56461320356
# likelihood: -2253.06631312
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 6.15e+04 real consumption= 6.47e+04
# x_pred min= 4.70e+02 x_pred max 2.69e+05
# ESS of normalized weights= 393.58831
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13013736239
# likelihood: -4583.54553054
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 6.74e+04
# x_pred min= 1.02e+03 x_pred max 1.62e+05
# ESS of normalized weights= 644.26398
# ESS>=0.5*M
# new ESS= 644.26398
# 6.55055615837
# likelihood: -2171.10523562
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 6.28e+04 real consumption= 6.53e+04
# x_pred min= 4.93e+02 x_pred max 1.95e+05
# ESS of normalized weights= 408.829607
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1536718807
# likelihood: -3894.4520476
# ------------------------
# n= 64
# x_pred_mean = 8.99e+04 real consumption= 6.30e+04
# x_pred min= 1.05e+04 x_pred max 3.04e+05
# ESS of normalized weights= 308.988693
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.88810256265
# likelihood: -11052.8745786
# ------------------------
# n= 65
# x_pred_mean = 7.99e+04 real consumption= 5.49e+04
# x_pred min= 2.62e+03 x_pred max 3.48e+05
# ESS of normalized weights= 396.732435
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11194448534
# likelihood: -7435.17236008
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 4.87e+04
# x_pred min= 7.92e+01 x_pred max 1.59e+05
# ESS of normalized weights= 527.745597
# ESS>=0.5*M
# new ESS= 527.745597
# 6.38133811299
# likelihood: -3107.02127279
# ------------------------
# n= 67
# x_pred_mean = 7.20e+04 real consumption= 6.02e+04
# x_pred min= 4.71e+03 x_pred max 2.20e+05
# ESS of normalized weights= 251.753853
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.76122498927
# likelihood: -5453.61747259
# ------------------------
# n= 68
# x_pred_mean = 1.13e+05 real consumption= 6.20e+04
# x_pred min= 1.19e+04 x_pred max 3.79e+05
# ESS of normalized weights= 278.270691
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.74748671836
# likelihood: -23663.1923725
# ------------------------
# n= 69
# x_pred_mean = 5.50e+04 real consumption= 6.01e+04
# x_pred min= 2.23e+03 x_pred max 1.48e+05
# ESS of normalized weights= 524.895141
# ESS>=0.5*M
# new ESS= 524.895141
# 6.36723756251
# likelihood: -3233.13086077
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.96e+04
# x_pred min= 1.71e+02 x_pred max 1.90e+05
# ESS of normalized weights= 320.927518
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.93115017185
# likelihood: -4409.35544013
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 6.19e+04 real consumption= 6.18e+04
# x_pred min= 4.70e+03 x_pred max 1.54e+05
# ESS of normalized weights= 648.395867
# ESS>=0.5*M
# new ESS= 648.395867
# 6.555938549
# likelihood: -2179.76789888
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 6.48e+04 real consumption= 5.74e+04
# x_pred min= 2.02e+02 x_pred max 2.21e+05
# ESS of normalized weights= 391.886384
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12169326451
# likelihood: -4752.25658061
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.60e+04
# x_pred min= 3.93e+02 x_pred max 1.81e+05
# ESS of normalized weights= 666.571039
# ESS>=0.5*M
# new ESS= 666.571039
# 6.57972141709
# likelihood: -2021.84002521
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.74e+04 real consumption= 6.36e+04
# x_pred min= 5.12e+02 x_pred max 2.03e+05
# ESS of normalized weights= 403.512712
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1381283957
# likelihood: -3642.71919031
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 6.11e+04 real consumption= 6.06e+04
# x_pred min= 4.04e+03 x_pred max 1.71e+05
# ESS of normalized weights= 676.19644
# ESS>=0.5*M
# new ESS= 676.19644
# 6.59123271685
# likelihood: -2024.54425349
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 6.29e+04 real consumption= 5.89e+04
# x_pred min= 9.83e+02 x_pred max 2.27e+05
# ESS of normalized weights= 451.518205
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23816771738
# likelihood: -3793.49560893
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 6.31e+04 real consumption= 6.31e+04
# x_pred min= 7.21e+02 x_pred max 2.00e+05
# ESS of normalized weights= 695.980584
# ESS>=0.5*M
# new ESS= 695.980584
# 6.61891338073
# likelihood: -1952.34434659
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 6.35e+04 real consumption= 6.33e+04
# x_pred min= 4.80e+02 x_pred max 2.43e+05
# ESS of normalized weights= 441.314585
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21865818882
# likelihood: -4054.82996277
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 5.73e+04
# x_pred min= 1.52e+03 x_pred max 1.82e+05
# ESS of normalized weights= 631.758793
# ESS>=0.5*M
# new ESS= 631.758793
# 6.55048858468
# likelihood: -2175.55410629
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 5.89e+04 real consumption= 5.46e+04
# x_pred min= 1.80e+01 x_pred max 2.34e+05
# ESS of normalized weights= 395.382599
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15195579292
# likelihood: -3737.13293425
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.07e+04 real consumption= 6.05e+04
# x_pred min= 3.45e+02 x_pred max 1.77e+05
# ESS of normalized weights= 643.918819
# ESS>=0.5*M
# new ESS= 643.918819
# 6.55320856196
# likelihood: -2072.10521827
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 5.27e+04 real consumption= 6.54e+04
# x_pred min= 3.43e+02 x_pred max 1.74e+05
# ESS of normalized weights= 407.568554
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1604307405
# likelihood: -3094.39947924
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.87e+04 real consumption= 6.75e+04
# x_pred min= 4.83e+02 x_pred max 1.75e+05
# ESS of normalized weights= 669.042397
# ESS>=0.5*M
# new ESS= 669.042397
# 6.58273109756
# likelihood: -2247.96823337
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 6.14e+04 real consumption= 6.80e+04
# x_pred min= 3.99e+02 x_pred max 2.22e+05
# ESS of normalized weights= 427.789189
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19869361141
# likelihood: -4506.56065715
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 6.20e+04
# x_pred min= 1.56e+03 x_pred max 1.79e+05
# ESS of normalized weights= 666.202251
# ESS>=0.5*M
# new ESS= 666.202251
# 6.57983370743
# likelihood: -2065.39228334
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.70e+04 real consumption= 5.41e+04
# x_pred min= 6.00e+02 x_pred max 1.80e+05
# ESS of normalized weights= 390.198231
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12643666106
# likelihood: -4572.2852361
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 4.73e+04 real consumption= 5.19e+04
# x_pred min= 2.37e+02 x_pred max 1.56e+05
# ESS of normalized weights= 662.212512
# ESS>=0.5*M
# new ESS= 662.212512
# 6.58126270304
# likelihood: -1753.11287902
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 5.08e+04 real consumption= 6.07e+04
# x_pred min= 7.80e+00 x_pred max 1.73e+05
# ESS of normalized weights= 411.623178
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16811231693
# likelihood: -3548.20944047
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 6.07e+04
# x_pred min= 5.09e+00 x_pred max 2.55e+05
# ESS of normalized weights= 678.141606
# ESS>=0.5*M
# new ESS= 678.141606
# 6.59909034996
# likelihood: -2003.81157114
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 6.23e+04
# x_pred min= 2.69e+02 x_pred max 2.54e+05
# ESS of normalized weights= 440.425271
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22795619554
# likelihood: -3610.19052915
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 6.36e+04
# x_pred min= 1.94e+03 x_pred max 1.63e+05
# ESS of normalized weights= 715.888589
# ESS>=0.5*M
# new ESS= 715.888589
# 6.64046321764
# likelihood: -1652.00843238
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 6.11e+04
# x_pred min= 7.52e+01 x_pred max 1.85e+05
# ESS of normalized weights= 473.888658
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.28929071207
# likelihood: -3424.21321669
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 4.94e+04 real consumption= 5.54e+04
# x_pred min= 5.24e+02 x_pred max 1.49e+05
# ESS of normalized weights= 675.31573
# ESS>=0.5*M
# new ESS= 675.31573
# 6.59811873577
# likelihood: -1696.15597672
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 4.91e+04
# x_pred min= 2.51e+02 x_pred max 2.44e+05
# ESS of normalized weights= 471.673277
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29358847422
# likelihood: -3365.65127769
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 5.17e+04 real consumption= 4.96e+04
# x_pred min= 2.64e+03 x_pred max 1.85e+05
# ESS of normalized weights= 712.416334
# ESS>=0.5*M
# new ESS= 712.416334
# 6.63552247957
# likelihood: -1954.27283988
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.87e+04
# x_pred min= 9.14e+01 x_pred max 2.33e+05
# ESS of normalized weights= 475.931423
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29852965357
# likelihood: -3365.0353721
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 5.26e+04 real consumption= 5.70e+04
# x_pred min= 4.99e+02 x_pred max 1.89e+05
# ESS of normalized weights= 704.431707
# ESS>=0.5*M
# new ESS= 704.431707
# 6.62955051366
# likelihood: -1708.17985243
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.49e+04
# x_pred min= 1.96e+02 x_pred max 1.85e+05
# ESS of normalized weights= 447.489513
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23294492485
# likelihood: -3561.93864133
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.35e+04
# x_pred min= 2.96e+02 x_pred max 1.71e+05
# ESS of normalized weights= 664.259092
# ESS>=0.5*M
# new ESS= 664.259092
# 6.58295219302
# likelihood: -2101.54364845
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 5.51e+04 real consumption= 4.79e+04
# x_pred min= 5.74e+02 x_pred max 1.88e+05
# ESS of normalized weights= 411.2883
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16916813035
# likelihood: -4507.88215326
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.58e+04 real consumption= 4.19e+04
# x_pred min= 9.95e+01 x_pred max 1.34e+05
# ESS of normalized weights= 634.091419
# ESS>=0.5*M
# new ESS= 634.091419
# 6.54688212228
# likelihood: -1923.57464149
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 4.92e+04 real consumption= 5.26e+04
# x_pred min= 1.39e+02 x_pred max 2.16e+05
# ESS of normalized weights= 381.301506
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10619830578
# likelihood: -3533.10672333
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.44e+04 real consumption= 5.22e+04
# x_pred min= 6.05e+02 x_pred max 1.47e+05
# ESS of normalized weights= 700.680559
# ESS>=0.5*M
# new ESS= 700.680559
# 6.62000523619
# likelihood: -1724.89210694
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.68e+04 real consumption= 5.23e+04
# x_pred min= 1.95e+02 x_pred max 2.01e+05
# ESS of normalized weights= 465.378951
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2628276902
# likelihood: -3196.76122173
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.27e+04
# x_pred min= 1.37e+03 x_pred max 1.59e+05
# ESS of normalized weights= 638.854894
# ESS>=0.5*M
# new ESS= 638.854894
# 6.54739966954
# likelihood: -2493.39091414
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 5.75e+04 real consumption= 5.24e+04
# x_pred min= 3.18e+02 x_pred max 1.92e+05
# ESS of normalized weights= 395.090503
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13463748331
# likelihood: -4341.88282702
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 4.91e+04 real consumption= 4.52e+04
# x_pred min= 2.30e+02 x_pred max 1.54e+05
# ESS of normalized weights= 663.424906
# ESS>=0.5*M
# new ESS= 663.424906
# 6.58351793954
# likelihood: -1946.97296492
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 4.20e+04
# x_pred min= 6.71e+01 x_pred max 1.67e+05
# ESS of normalized weights= 423.308741
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2056582341
# likelihood: -2971.74378529
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.22e+04
# x_pred min= 5.69e+02 x_pred max 1.70e+05
# ESS of normalized weights= 689.375066
# ESS>=0.5*M
# new ESS= 689.375066
# 6.60678016993
# likelihood: -1861.53372535
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 5.39e+04 real consumption= 5.22e+04
# x_pred min= 1.32e+02 x_pred max 2.34e+05
# ESS of normalized weights= 441.338505
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22314360279
# likelihood: -3784.80055228
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 5.20e+04
# x_pred min= 9.28e+02 x_pred max 1.48e+05
# ESS of normalized weights= 719.404956
# ESS>=0.5*M
# new ESS= 719.404956
# 6.64545159695
# likelihood: -1674.18457697
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.22e+04
# x_pred min= 5.45e+02 x_pred max 2.24e+05
# ESS of normalized weights= 436.296675
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2220714434
# likelihood: -4349.54111094
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 4.75e+04 real consumption= 5.14e+04
# x_pred min= 5.55e+02 x_pred max 1.50e+05
# ESS of normalized weights= 690.156733
# ESS>=0.5*M
# new ESS= 690.156733
# 6.60982744614
# likelihood: -1725.37590929
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 4.47e+04
# x_pred min= 4.51e+02 x_pred max 2.96e+05
# ESS of normalized weights= 430.153593
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20605012194
# likelihood: -4274.10691254
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 4.32e+04 real consumption= 4.14e+04
# x_pred min= 6.46e+01 x_pred max 1.58e+05
# ESS of normalized weights= 612.963128
# ESS>=0.5*M
# new ESS= 612.963128
# 6.51556372224
# likelihood: -2278.80995856
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 4.64e+04 real consumption= 5.42e+04
# x_pred min= 1.94e+02 x_pred max 2.57e+05
# ESS of normalized weights= 373.135778
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07510788635
# likelihood: -3799.55868261
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 5.47e+04
# x_pred min= 4.49e+02 x_pred max 1.34e+05
# ESS of normalized weights= 693.177199
# ESS>=0.5*M
# new ESS= 693.177199
# 6.6142739641
# likelihood: -1626.35128142
# ------------------------
# n= 118
# No heating effect
# x_pred_mean = 5.34e+04 real consumption= 5.47e+04
# x_pred min= 1.50e+02 x_pred max 2.22e+05
# ESS of normalized weights= 440.998653
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23071818241
# likelihood: -3840.18723678
# ------------------------
# n= 119
# No heating effect
# x_pred_mean = 4.70e+04 real consumption= 5.60e+04
# x_pred min= 6.99e+02 x_pred max 1.44e+05
# ESS of normalized weights= 674.395751
# ESS>=0.5*M
# new ESS= 674.395751
# 6.5957523486
# likelihood: -1730.38863198
# ------------------------
# n= 120
# No heating effect
# x_pred_mean = 4.90e+04 real consumption= 4.54e+04
# x_pred min= 3.54e+02 x_pred max 1.77e+05
# ESS of normalized weights= 427.209706
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2001259319
# likelihood: -3440.77046926
# ------------------------
# n= 121
# No heating effect
# x_pred_mean = 4.56e+04 real consumption= 4.68e+04
# x_pred min= 6.58e+02 x_pred max 1.70e+05
# ESS of normalized weights= 727.670889
# ESS>=0.5*M
# new ESS= 727.670889
# 6.66010332517
# likelihood: -1774.15195211
# ------------------------
# n= 122
# No heating effect
# x_pred_mean = 4.92e+04 real consumption= 4.28e+04
# x_pred min= 2.39e+02 x_pred max 2.23e+05
# ESS of normalized weights= 446.906031
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2512316964
# likelihood: -3732.74694042
# ------------------------
# n= 123
# No heating effect
# x_pred_mean = 4.88e+04 real consumption= 5.29e+04
# x_pred min= 6.42e+02 x_pred max 1.57e+05
# ESS of normalized weights= 664.13529
# ESS>=0.5*M
# new ESS= 664.13529
# 6.5799549097
# likelihood: -1993.90451907
# ------------------------
# n= 124
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.25e+04
# x_pred min= 3.47e+01 x_pred max 2.16e+05
# ESS of normalized weights= 412.257395
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.17274728903
# likelihood: -4038.17203562
# ------------------------
# n= 125
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.30e+04
# x_pred min= 6.64e+02 x_pred max 2.12e+05
# ESS of normalized weights= 694.920655
# ESS>=0.5*M
# new ESS= 694.920655
# 6.61495155152
# likelihood: -2034.36967915
# ------------------------
# n= 126
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.26e+04
# x_pred min= 1.62e+02 x_pred max 1.68e+05
# ESS of normalized weights= 451.234948
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23761658376
# likelihood: -3648.69938918
# ------------------------
# n= 127
# No heating effect
# x_pred_mean = 5.36e+04 real consumption= 4.37e+04
# x_pred min= 7.53e+02 x_pred max 1.47e+05
# ESS of normalized weights= 643.080881
# ESS>=0.5*M
# new ESS= 643.080881
# 6.55485530294
# likelihood: -2133.08187922
# ------------------------
# n= 128
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 4.34e+04
# x_pred min= 1.35e+03 x_pred max 2.34e+05
# ESS of normalized weights= 369.018455
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07684863652
# likelihood: -4958.98060878
# ------------------------
# n= 129
# No heating effect
# x_pred_mean = 4.34e+04 real consumption= 3.94e+04
# x_pred min= 5.33e+01 x_pred max 1.64e+05
# ESS of normalized weights= 677.536957
# ESS>=0.5*M
# new ESS= 677.536957
# 6.59856340329
# likelihood: -1719.1392813
# ------------------------
# n= 130
# No heating effect
# x_pred_mean = 4.63e+04 real consumption= 5.15e+04
# x_pred min= 1.14e+02 x_pred max 1.87e+05
# ESS of normalized weights= 419.368082
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18446657061
# likelihood: -3305.35664843
# ------------------------
# n= 131
# No heating effect
# x_pred_mean = 5.04e+04 real consumption= 5.20e+04
# x_pred min= 3.50e+02 x_pred max 1.54e+05
# ESS of normalized weights= 634.414357
# ESS>=0.5*M
# new ESS= 634.414357
# 6.53973425153
# likelihood: -2237.64931574
# ------------------------
# n= 132
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.20e+04
# x_pred min= 4.89e+01 x_pred max 2.30e+05
# ESS of normalized weights= 389.54218
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10775663724
# likelihood: -4366.913964
# ------------------------
# n= 133
# No heating effect
# x_pred_mean = 5.24e+04 real consumption= 4.28e+04
# x_pred min= 6.46e+01 x_pred max 1.37e+05
# ESS of normalized weights= 685.6078
# ESS>=0.5*M
# new ESS= 685.6078
# 6.60372583415
# likelihood: -1710.5411755
# ------------------------
# n= 134
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 4.84e+04
# x_pred min= 5.87e+02 x_pred max 1.99e+05
# ESS of normalized weights= 410.673045
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15829892565
# likelihood: -4061.18528342
# ------------------------
# n= 135
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 4.47e+04
# x_pred min= 1.64e+03 x_pred max 1.28e+05
# ESS of normalized weights= 651.501071
# ESS>=0.5*M
# new ESS= 651.501071
# 6.56912580558
# likelihood: -1913.20798668
# ------------------------
# n= 136
# No heating effect
# x_pred_mean = 5.01e+04 real consumption= 3.98e+04
# x_pred min= 5.09e+01 x_pred max 1.87e+05
# ESS of normalized weights= 422.139833
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20287013234
# likelihood: -3008.10010218
# ------------------------
# n= 137
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 5.18e+04
# x_pred min= 1.17e+02 x_pred max 1.43e+05
# ESS of normalized weights= 655.557186
# ESS>=0.5*M
# new ESS= 655.557186
# 6.57136337955
# likelihood: -1994.90959642
# ------------------------
# n= 138
# No heating effect
# x_pred_mean = 5.24e+04 real consumption= 5.32e+04
# x_pred min= 2.34e+00 x_pred max 2.52e+05
# ESS of normalized weights= 405.034413
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15236078211
# likelihood: -3992.47743365
# ------------------------
# n= 139
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 5.41e+04
# x_pred min= 9.53e+02 x_pred max 1.38e+05
# ESS of normalized weights= 694.758611
# ESS>=0.5*M
# new ESS= 694.758611
# 6.61625620508
# likelihood: -1662.82897223
# ------------------------
# n= 140
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.36e+04
# x_pred min= 5.94e+02 x_pred max 2.42e+05
# ESS of normalized weights= 444.130406
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23714946374
# likelihood: -3535.85630836
# ------------------------
# n= 141
# No heating effect
# x_pred_mean = 5.42e+04 real consumption= 5.20e+04
# x_pred min= 5.17e+01 x_pred max 1.54e+05
# ESS of normalized weights= 629.002445
# ESS>=0.5*M
# new ESS= 629.002445
# 6.53738988281
# likelihood: -2374.77792321
# ------------------------
# n= 142
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 4.45e+04
# x_pred min= 8.54e+01 x_pred max 2.25e+05
# ESS of normalized weights= 371.999719
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.08391154443
# likelihood: -4931.67455166
# ------------------------
# n= 143
# No heating effect
# x_pred_mean = 4.41e+04 real consumption= 3.90e+04
# x_pred min= 2.83e+01 x_pred max 1.44e+05
# ESS of normalized weights= 625.139554
# ESS>=0.5*M
# new ESS= 625.139554
# 6.53322155584
# likelihood: -2070.02354083
# ------------------------
# n= 144
# No heating effect
# x_pred_mean = 4.80e+04 real consumption= 4.27e+04
# x_pred min= 3.18e+01 x_pred max 2.00e+05
# ESS of normalized weights= 385.955411
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11779777225
# likelihood: -3473.47120541
# ------------------------
# n= 145
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 5.24e+04
# x_pred min= 4.71e+02 x_pred max 1.58e+05
# ESS of normalized weights= 677.65452
# ESS>=0.5*M
# new ESS= 677.65452
# 6.59549019275
# likelihood: -1893.27026999
# ------------------------
# n= 146
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 5.24e+04
# x_pred min= 8.42e+02 x_pred max 2.03e+05
# ESS of normalized weights= 426.66822
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20069542177
# likelihood: -3575.04144101
# ------------------------
# n= 147
# No heating effect
# x_pred_mean = 5.39e+04 real consumption= 5.28e+04
# x_pred min= 3.29e+03 x_pred max 1.38e+05
# ESS of normalized weights= 716.826836
# ESS>=0.5*M
# new ESS= 716.826836
# 6.63857697023
# likelihood: -1618.12984446
# ------------------------
# n= 148
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.18e+04
# x_pred min= 3.00e+02 x_pred max 2.22e+05
# ESS of normalized weights= 428.691726
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20416702398
# likelihood: -3983.54324785
# ------------------------
# n= 149
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 4.41e+04
# x_pred min= 1.41e+03 x_pred max 1.52e+05
# ESS of normalized weights= 618.009149
# ESS>=0.5*M
# new ESS= 618.009149
# 6.52091599296
# likelihood: -2383.34854518
# ------------------------
# n= 150
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 4.00e+04
# x_pred min= 4.88e+02 x_pred max 1.78e+05
# ESS of normalized weights= 410.878741
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18067660015
# likelihood: -3406.30807696
# ------------------------
# n= 151
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 5.20e+04
# x_pred min= 7.64e+02 x_pred max 1.80e+05
# ESS of normalized weights= 667.293734
# ESS>=0.5*M
# new ESS= 667.293734
# 6.58740576676
# likelihood: -1941.91647579
# ------------------------
# n= 152
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.31e+04
# x_pred min= 1.76e+02 x_pred max 2.24e+05
# ESS of normalized weights= 427.061885
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20692651428
# likelihood: -3697.48650737
# ------------------------
# n= 153
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 5.38e+04
# x_pred min= 1.21e+02 x_pred max 1.74e+05
# ESS of normalized weights= 676.568937
# ESS>=0.5*M
# new ESS= 676.568937
# 6.59005786429
# likelihood: -1913.27523315
# ------------------------
# n= 154
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 5.43e+04
# x_pred min= 2.79e+02 x_pred max 2.09e+05
# ESS of normalized weights= 432.86285
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20772467507
# likelihood: -3519.13134061
# ------------------------
# n= 155
# No heating effect
# x_pred_mean = 5.28e+04 real consumption= 5.44e+04
# x_pred min= 1.92e+02 x_pred max 1.45e+05
# ESS of normalized weights= 636.980665
# ESS>=0.5*M
# new ESS= 636.980665
# 6.55154009058
# likelihood: -2124.78710442
# ------------------------
# n= 156
# No heating effect
# x_pred_mean = 5.59e+04 real consumption= 4.49e+04
# x_pred min= 1.66e+03 x_pred max 1.89e+05
# ESS of normalized weights= 362.570711
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.0626325338
# likelihood: -4941.07211738
# ------------------------
# n= 157
# No heating effect
# x_pred_mean = 4.47e+04 real consumption= 3.99e+04
# x_pred min= 1.44e+02 x_pred max 1.48e+05
# ESS of normalized weights= 625.467432
# ESS>=0.5*M
# new ESS= 625.467432
# 6.53294707896
# likelihood: -2055.31784323
# ------------------------
# n= 158
# No heating effect
# x_pred_mean = 4.69e+04 real consumption= 5.25e+04
# x_pred min= 1.47e+02 x_pred max 2.23e+05
# ESS of normalized weights= 387.931726
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12088019127
# likelihood: -3451.60964937
# ------------------------
# n= 159
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 5.29e+04
# x_pred min= 4.06e+02 x_pred max 1.69e+05
# ESS of normalized weights= 698.218122
# ESS>=0.5*M
# new ESS= 698.218122
# 6.61424155785
# likelihood: -1994.38656044
# ------------------------
# n= 160
# No heating effect
# x_pred_mean = 5.51e+04 real consumption= 5.30e+04
# x_pred min= 3.40e+02 x_pred max 2.53e+05
# ESS of normalized weights= 464.11544
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26954120824
# likelihood: -3555.74114764
# ------------------------
# n= 161
# No heating effect
# x_pred_mean = 5.39e+04 real consumption= 5.43e+04
# x_pred min= 2.28e+02 x_pred max 1.48e+05
# ESS of normalized weights= 692.972305
# ESS>=0.5*M
# new ESS= 692.972305
# 6.61248305997
# likelihood: -1848.65509391
# ------------------------
# n= 162
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.26e+04
# x_pred min= 3.80e+02 x_pred max 2.21e+05
# ESS of normalized weights= 445.520619
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23494123741
# likelihood: -4091.95885516
# ------------------------
# n= 163
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 4.41e+04
# x_pred min= 2.37e+03 x_pred max 1.45e+05
# ESS of normalized weights= 667.143683
# ESS>=0.5*M
# new ESS= 667.143683
# 6.59724279022
# likelihood: -1956.31103213
# ------------------------
# n= 164
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 3.96e+04
# x_pred min= 2.76e+02 x_pred max 2.28e+05
# ESS of normalized weights= 433.847216
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23556517242
# likelihood: -3517.0490194
# ------------------------
# n= 165
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.18e+04
# x_pred min= 7.24e+02 x_pred max 1.54e+05
# ESS of normalized weights= 651.279805
# ESS>=0.5*M
# new ESS= 651.279805
# 6.56960806501
# likelihood: -2056.15734785
# ------------------------
# n= 166
# No heating effect
# x_pred_mean = 5.36e+04 real consumption= 5.23e+04
# x_pred min= 4.02e+01 x_pred max 2.21e+05
# ESS of normalized weights= 401.612247
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15636927324
# likelihood: -3590.746777
# ------------------------
# n= 167
# No heating effect
# x_pred_mean = 5.87e+04 real consumption= 5.27e+04
# x_pred min= 3.89e+02 x_pred max 1.78e+05
# ESS of normalized weights= 687.804566
# ESS>=0.5*M
# new ESS= 687.804566
# 6.59954304191
# likelihood: -2148.77290998
# ------------------------
# n= 168
# No heating effect
# x_pred_mean = 6.16e+04 real consumption= 5.34e+04
# x_pred min= 1.38e+02 x_pred max 2.08e+05
# ESS of normalized weights= 447.296351
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22501444821
# likelihood: -4040.70011392
# ------------------------
# n= 169
# No heating effect
# x_pred_mean = 5.85e+04 real consumption= 5.13e+04
# x_pred min= 8.76e+02 x_pred max 1.21e+05
# ESS of normalized weights= 644.422599
# ESS>=0.5*M
# new ESS= 644.422599
# 6.55855469114
# likelihood: -2042.84171377
# ------------------------
# n= 170
# No heating effect
# x_pred_mean = 5.97e+04 real consumption= 4.36e+04
# x_pred min= 3.17e+02 x_pred max 1.92e+05
# ESS of normalized weights= 358.116697
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05634075827
# likelihood: -4572.38059062
# ------------------------
# n= 171
# No heating effect
# x_pred_mean = 4.83e+04 real consumption= 3.96e+04
# x_pred min= 1.47e+03 x_pred max 1.81e+05
# ESS of normalized weights= 628.778031
# ESS>=0.5*M
# new ESS= 628.778031
# 6.53143970123
# likelihood: -2183.21996757
# ------------------------
# n= 172
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.29e+04
# x_pred min= 1.48e+02 x_pred max 2.04e+05
# ESS of normalized weights= 387.613041
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11242479654
# likelihood: -3868.28789375
# ------------------------
# n= 173
# No heating effect
# x_pred_mean = 5.52e+04 real consumption= 5.31e+04
# x_pred min= 1.12e+03 x_pred max 1.59e+05
# ESS of normalized weights= 702.883688
# ESS>=0.5*M
# new ESS= 702.883688
# 6.62345103311
# likelihood: -1944.03426646
# ------------------------
# n= 174
# No heating effect
# x_pred_mean = 5.66e+04 real consumption= 5.31e+04
# x_pred min= 2.61e+02 x_pred max 3.28e+05
# ESS of normalized weights= 468.114191
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27328108371
# likelihood: -3848.86861034
# ------------------------
# n= 175
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.41e+04
# x_pred min= 1.25e+03 x_pred max 1.44e+05
# ESS of normalized weights= 708.743093
# ESS>=0.5*M
# new ESS= 708.743093
# 6.63572342676
# likelihood: -1573.69026181
# ------------------------
# n= 176
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.40e+04
# x_pred min= 4.75e+02 x_pred max 2.33e+05
# ESS of normalized weights= 450.532748
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24220438496
# likelihood: -3961.83774605
# ------------------------
# n= 177
# No heating effect
# x_pred_mean = 5.02e+04 real consumption= 4.52e+04
# x_pred min= 4.60e+01 x_pred max 1.54e+05
# ESS of normalized weights= 646.352723
# ESS>=0.5*M
# new ESS= 646.352723
# 6.56468828729
# likelihood: -2096.00891918
# ------------------------
# n= 178
# No heating effect
# x_pred_mean = 5.24e+04 real consumption= 4.11e+04
# x_pred min= 1.23e+02 x_pred max 1.75e+05
# ESS of normalized weights= 426.645131
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21586311702
# likelihood: -3110.97855033
# ------------------------
# n= 179
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.50e+04
# x_pred min= 1.59e+03 x_pred max 1.58e+05
# ESS of normalized weights= 689.897062
# ESS>=0.5*M
# new ESS= 689.897062
# 6.61035336823
# likelihood: -1869.41097664
# ------------------------
# n= 180
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.66e+04
# x_pred min= 5.95e+02 x_pred max 2.06e+05
# ESS of normalized weights= 429.226894
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21864606883
# likelihood: -3433.70844611
# ------------------------
# n= 181
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.77e+04
# x_pred min= 6.46e+02 x_pred max 1.45e+05
# ESS of normalized weights= 654.214902
# ESS>=0.5*M
# new ESS= 654.214902
# 6.57062449892
# likelihood: -1955.61104318
# ------------------------
# n= 182
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.71e+04
# x_pred min= 1.41e+02 x_pred max 1.66e+05
# ESS of normalized weights= 435.22578
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22546718542
# likelihood: -3165.61267232
# ------------------------
# n= 183
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 5.70e+04
# x_pred min= 3.91e+03 x_pred max 1.61e+05
# ESS of normalized weights= 644.026926
# ESS>=0.5*M
# new ESS= 644.026926
# 6.56170727148
# likelihood: -2235.11000754
# ------------------------
# n= 184
# No heating effect
# x_pred_mean = 5.93e+04 real consumption= 4.83e+04
# x_pred min= 2.03e+02 x_pred max 1.83e+05
# ESS of normalized weights= 356.679664
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.05293550626
# likelihood: -5028.04275733
# ------------------------
# n= 185
# No heating effect
# x_pred_mean = 4.74e+04 real consumption= 4.27e+04
# x_pred min= 1.08e+03 x_pred max 1.26e+05
# ESS of normalized weights= 640.11127
# ESS>=0.5*M
# new ESS= 640.11127
# 6.54886330434
# likelihood: -2037.32242549
# ------------------------
# n= 186
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.63e+04
# x_pred min= 2.50e+02 x_pred max 1.90e+05
# ESS of normalized weights= 380.924981
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10734884158
# likelihood: -3531.64159272
# ------------------------
# n= 187
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.71e+04
# x_pred min= 8.42e+02 x_pred max 2.33e+05
# ESS of normalized weights= 658.853425
# ESS>=0.5*M
# new ESS= 658.853425
# 6.56796233958
# likelihood: -2315.8998613
# ------------------------
# n= 188
# No heating effect
# x_pred_mean = 5.78e+04 real consumption= 5.45e+04
# x_pred min= 3.10e+02 x_pred max 1.88e+05
# ESS of normalized weights= 418.531653
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18101694894
# likelihood: -3950.34192225
# ------------------------
# n= 189
# No heating effect
# ...
# new ESS= 1000.0
# 6.2920255904
# likelihood: -3155.60776748
# ------------------------
# n= 652
# No heating effect
# x_pred_mean = 5.78e+04 real consumption= 5.96e+04
# x_pred min= 5.07e+02 x_pred max 1.83e+05
# ESS of normalized weights= 671.566654
# ESS>=0.5*M
# new ESS= 671.566654
# 6.5903169834
# likelihood: -2147.19215282
# ------------------------
# n= 653
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 4.86e+04
# x_pred min= 1.43e+03 x_pred max 2.13e+05
# ESS of normalized weights= 390.602557
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1233851228
# likelihood: -4568.20808763
# ------------------------
# n= 654
# No heating effect
# x_pred_mean = 4.78e+04 real consumption= 4.44e+04
# x_pred min= 5.82e+01 x_pred max 1.52e+05
# ESS of normalized weights= 696.406753
# ESS>=0.5*M
# new ESS= 696.406753
# 6.61873283521
# likelihood: -1725.41245633
# ------------------------
# n= 655
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 5.59e+04
# x_pred min= 8.70e+00 x_pred max 2.72e+05
# ESS of normalized weights= 468.484923
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.28142909005
# likelihood: -3134.86411924
# ------------------------
# n= 656
# No heating effect
# x_pred_mean = 4.87e+04 real consumption= 5.61e+04
# x_pred min= 1.19e+02 x_pred max 1.40e+05
# ESS of normalized weights= 638.22395
# ESS>=0.5*M
# new ESS= 638.22395
# 6.56120379131
# likelihood: -1887.99964962
# ------------------------
# n= 657
# No heating effect
# x_pred_mean = 5.09e+04 real consumption= 5.82e+04
# x_pred min= 4.80e+02 x_pred max 1.69e+05
# ESS of normalized weights= 382.754206
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12365310965
# likelihood: -3080.19761097
# ------------------------
# n= 658
# No heating effect
# x_pred_mean = 5.78e+04 real consumption= 5.86e+04
# x_pred min= 6.73e+02 x_pred max 1.53e+05
# ESS of normalized weights= 645.036575
# ESS>=0.5*M
# new ESS= 645.036575
# 6.55894578173
# likelihood: -1994.84298955
# ------------------------
# n= 659
# No heating effect
# x_pred_mean = 5.91e+04 real consumption= 5.78e+04
# x_pred min= 6.52e+02 x_pred max 2.03e+05
# ESS of normalized weights= 431.033276
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21354137729
# likelihood: -3538.18181392
# ------------------------
# n= 660
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 5.08e+04
# x_pred min= 2.29e+03 x_pred max 1.68e+05
# ESS of normalized weights= 659.205772
# ESS>=0.5*M
# new ESS= 659.205772
# 6.57182854686
# likelihood: -2101.49726891
# ------------------------
# n= 661
# No heating effect
# x_pred_mean = 5.94e+04 real consumption= 4.94e+04
# x_pred min= 2.06e+02 x_pred max 1.84e+05
# ESS of normalized weights= 388.899003
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1420435664
# likelihood: -3682.99273637
# ------------------------
# n= 662
# x_pred_mean = 1.79e+05 real consumption= 5.85e+04
# x_pred min= 2.49e+04 x_pred max 5.90e+05
# ESS of normalized weights= 94.188552
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -98114.6511831
# ------------------------
# n= 663
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.83e+04
# x_pred min= 2.02e+02 x_pred max 1.49e+05
# ESS of normalized weights= 487.854932
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.31314513773
# likelihood: -3635.3010792
# ------------------------
# n= 664
# No heating effect
# x_pred_mean = 6.75e+04 real consumption= 5.84e+04
# x_pred min= 2.59e+03 x_pred max 1.85e+05
# ESS of normalized weights= 629.678463
# ESS>=0.5*M
# new ESS= 629.678463
# 6.53074203924
# likelihood: -2558.89040313
# ------------------------
# n= 665
# No heating effect
# x_pred_mean = 6.85e+04 real consumption= 5.79e+04
# x_pred min= 1.31e+03 x_pred max 2.35e+05
# ESS of normalized weights= 365.749901
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06434175221
# likelihood: -5397.56178831
# ------------------------
# n= 666
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 5.72e+04
# x_pred min= 2.07e+02 x_pred max 1.84e+05
# ESS of normalized weights= 672.626917
# ESS>=0.5*M
# new ESS= 672.626917
# 6.58096499041
# likelihood: -2141.06010859
# ------------------------
# n= 667
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 5.02e+04
# x_pred min= 7.24e+02 x_pred max 2.36e+05
# ESS of normalized weights= 421.279867
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.17898684238
# likelihood: -4370.75865419
# ------------------------
# n= 668
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 4.42e+04
# x_pred min= 2.44e+03 x_pred max 1.84e+05
# ESS of normalized weights= 596.042084
# ESS>=0.5*M
# new ESS= 596.042084
# 6.49862379133
# likelihood: -2376.67071193
# ------------------------
# n= 669
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 5.10e+04
# x_pred min= 4.86e+02 x_pred max 2.23e+05
# ESS of normalized weights= 363.791298
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06643901761
# likelihood: -4138.20992914
# ------------------------
# n= 670
# No heating effect
# x_pred_mean = 6.45e+04 real consumption= 4.62e+04
# x_pred min= 1.99e+03 x_pred max 1.61e+05
# ESS of normalized weights= 686.686564
# ESS>=0.5*M
# new ESS= 686.686564
# 6.6053494069
# likelihood: -1843.34577408
# ------------------------
# n= 671
# No heating effect
# x_pred_mean = 6.57e+04 real consumption= 5.84e+04
# x_pred min= 4.88e+01 x_pred max 1.97e+05
# ESS of normalized weights= 434.564655
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21366180464
# likelihood: -3694.74487653
# ------------------------
# n= 672
# No heating effect
# x_pred_mean = 6.42e+04 real consumption= 5.92e+04
# x_pred min= 9.15e+02 x_pred max 2.43e+05
# ESS of normalized weights= 679.427322
# ESS>=0.5*M
# new ESS= 679.427322
# 6.59627832616
# likelihood: -2049.2677143
# ------------------------
# n= 673
# No heating effect
# x_pred_mean = 6.52e+04 real consumption= 6.22e+04
# x_pred min= 1.91e+03 x_pred max 2.42e+05
# ESS of normalized weights= 407.891463
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16493256609
# likelihood: -4153.00937569
# ------------------------
# n= 674
# No heating effect
# x_pred_mean = 6.13e+04 real consumption= 5.39e+04
# x_pred min= 4.32e+02 x_pred max 2.24e+05
# ESS of normalized weights= 644.779978
# ESS>=0.5*M
# new ESS= 644.779978
# 6.5592260734
# likelihood: -2376.90894952
# ------------------------
# n= 675
# No heating effect
# x_pred_mean = 6.37e+04 real consumption= 5.17e+04
# x_pred min= 8.50e+01 x_pred max 2.33e+05
# ESS of normalized weights= 421.874431
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19865185682
# likelihood: -4069.66158475
# ------------------------
# n= 676
# No heating effect
# x_pred_mean = 6.05e+04 real consumption= 6.75e+04
# x_pred min= 5.54e+02 x_pred max 1.98e+05
# ESS of normalized weights= 673.380022
# ESS>=0.5*M
# new ESS= 673.380022
# 6.58995180964
# likelihood: -2033.16747419
# ------------------------
# n= 677
# No heating effect
# x_pred_mean = 6.25e+04 real consumption= 6.90e+04
# x_pred min= 2.88e+02 x_pred max 2.60e+05
# ESS of normalized weights= 440.146636
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2225273678
# likelihood: -3822.39460989
# ------------------------
# n= 678
# No heating effect
# x_pred_mean = 6.33e+04 real consumption= 7.00e+04
# x_pred min= 2.10e+03 x_pred max 1.60e+05
# ESS of normalized weights= 696.969555
# ESS>=0.5*M
# new ESS= 696.969555
# 6.61701960232
# likelihood: -1872.32649636
# ------------------------
# n= 679
# No heating effect
# x_pred_mean = 6.53e+04 real consumption= 6.71e+04
# x_pred min= 8.31e+02 x_pred max 2.28e+05
# ESS of normalized weights= 481.724902
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29762034393
# likelihood: -3634.3113942
# ------------------------
# n= 680
# No heating effect
# x_pred_mean = 6.40e+04 real consumption= 5.54e+04
# x_pred min= 6.94e+01 x_pred max 1.59e+05
# ESS of normalized weights= 660.682207
# ESS>=0.5*M
# new ESS= 660.682207
# 6.57663011962
# likelihood: -2052.00678873
# ------------------------
# n= 681
# No heating effect
# x_pred_mean = 6.58e+04 real consumption= 5.98e+04
# x_pred min= 2.98e+01 x_pred max 2.98e+05
# ESS of normalized weights= 399.578009
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13961923595
# likelihood: -4627.35942317
# ------------------------
# n= 682
# x_pred_mean = 3.39e+05 real consumption= 5.49e+04
# x_pred min= 3.57e+04 x_pred max 1.51e+06
# ESS of normalized weights= 68.71885
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -688124.674512
# ------------------------
# n= 683
# x_pred_mean = 2.17e+05 real consumption= 6.67e+04
# x_pred min= 2.53e+04 x_pred max 1.29e+06
# ESS of normalized weights= 91.262989
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -216811.960343
# ------------------------
# n= 684
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 6.60e+04
# x_pred min= 1.73e+02 x_pred max 1.82e+05
# ESS of normalized weights= 385.376796
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10771056118
# likelihood: -4945.30223927
# ------------------------
# n= 685
# x_pred_mean = 7.65e+04 real consumption= 6.47e+04
# x_pred min= 8.24e+03 x_pred max 3.10e+05
# ESS of normalized weights= 572.869501
# ESS>=0.5*M
# new ESS= 572.869501
# 6.44484936982
# likelihood: -3294.74936497
# ------------------------
# n= 686
# x_pred_mean = 1.09e+05 real consumption= 6.25e+04
# x_pred min= 3.99e+03 x_pred max 3.89e+05
# ESS of normalized weights= 232.360746
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.63163697706
# likelihood: -20076.3828601
# ------------------------
# n= 687
# x_pred_mean = 9.81e+04 real consumption= 6.37e+04
# x_pred min= 1.68e+04 x_pred max 3.68e+05
# ESS of normalized weights= 308.090119
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.87158747261
# likelihood: -12650.9356668
# ------------------------
# n= 688
# x_pred_mean = 7.84e+04 real consumption= 5.66e+04
# x_pred min= 4.66e+03 x_pred max 2.65e+05
# ESS of normalized weights= 480.911805
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.28698783901
# likelihood: -5928.05389465
# ------------------------
# n= 689
# No heating effect
# x_pred_mean = 5.02e+04 real consumption= 5.19e+04
# x_pred min= 3.47e+02 x_pred max 2.29e+05
# ESS of normalized weights= 421.472806
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18791143175
# likelihood: -4382.25651461
# ------------------------
# n= 690
# No heating effect
# x_pred_mean = 6.48e+04 real consumption= 6.25e+04
# x_pred min= 1.49e+03 x_pred max 1.95e+05
# ESS of normalized weights= 606.663009
# ESS>=0.5*M
# new ESS= 606.663009
# 6.50302654024
# likelihood: -2694.12592649
# ------------------------
# n= 691
# No heating effect
# x_pred_mean = 6.64e+04 real consumption= 6.38e+04
# x_pred min= 6.99e+02 x_pred max 2.38e+05
# ESS of normalized weights= 366.735911
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.065401982
# likelihood: -4504.01179654
# ------------------------
# n= 692
# No heating effect
# x_pred_mean = 6.94e+04 real consumption= 6.37e+04
# x_pred min= 2.16e+03 x_pred max 1.94e+05
# ESS of normalized weights= 678.173699
# ESS>=0.5*M
# new ESS= 678.173699
# 6.59245658933
# likelihood: -2136.0611197
# ------------------------
# n= 693
# No heating effect
# x_pred_mean = 7.05e+04 real consumption= 6.32e+04
# x_pred min= 1.17e+03 x_pred max 2.24e+05
# ESS of normalized weights= 444.763305
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23209424525
# likelihood: -3787.37337545
# ------------------------
# n= 694
# No heating effect
# x_pred_mean = 6.86e+04 real consumption= 6.44e+04
# x_pred min= 1.14e+03 x_pred max 1.82e+05
# ESS of normalized weights= 671.868104
# ESS>=0.5*M
# new ESS= 671.868104
# 6.59756026293
# likelihood: -1872.31932933
# ------------------------
# n= 695
# x_pred_mean = 7.16e+04 real consumption= 5.69e+04
# x_pred min= 1.66e+03 x_pred max 2.81e+05
# ESS of normalized weights= 402.208785
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1485192348
# likelihood: -4439.07462575
# ------------------------
# n= 696
# x_pred_mean = 8.76e+04 real consumption= 5.33e+04
# x_pred min= 1.15e+04 x_pred max 2.88e+05
# ESS of normalized weights= 495.751235
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.3082132406
# likelihood: -5970.00999839
# ------------------------
# n= 697
# No heating effect
# x_pred_mean = 5.82e+04 real consumption= 6.74e+04
# x_pred min= 6.71e+02 x_pred max 1.84e+05
# ESS of normalized weights= 548.994967
# ESS>=0.5*M
# new ESS= 548.994967
# 6.4157052594
# likelihood: -2939.83709637
# ------------------------
# n= 698
# No heating effect
# x_pred_mean = 6.22e+04 real consumption= 7.18e+04
# x_pred min= 3.72e+02 x_pred max 2.46e+05
# ESS of normalized weights= 353.794569
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.02859227013
# likelihood: -4406.80327072
# ------------------------
# n= 699
# No heating effect
# x_pred_mean = 6.77e+04 real consumption= 7.05e+04
# x_pred min= 2.28e+03 x_pred max 1.78e+05
# ESS of normalized weights= 673.676367
# ESS>=0.5*M
# new ESS= 673.676367
# 6.59115885478
# likelihood: -2177.10308193
# ------------------------
# n= 700
# No heating effect
# x_pred_mean = 6.76e+04 real consumption= 7.11e+04
# x_pred min= 1.05e+03 x_pred max 2.51e+05
# ESS of normalized weights= 433.163935
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20278381596
# likelihood: -3955.4990394
# ------------------------
# n= 701
# No heating effect
# x_pred_mean = 6.79e+04 real consumption= 7.27e+04
# x_pred min= 2.86e+03 x_pred max 1.72e+05
# ESS of normalized weights= 649.635977
# ESS>=0.5*M
# new ESS= 649.635977
# 6.5632784787
# likelihood: -2189.06552092
# ------------------------
# n= 702
# x_pred_mean = 1.95e+05 real consumption= 6.42e+04
# x_pred min= 1.21e+04 x_pred max 8.48e+05
# ESS of normalized weights= 48.477135
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -145265.926439
# ------------------------
# n= 703
# x_pred_mean = 1.21e+05 real consumption= 6.08e+04
# x_pred min= 7.21e+03 x_pred max 4.61e+05
# ESS of normalized weights= 315.781021
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -29515.2608723
# ------------------------
# n= 704
# x_pred_mean = 1.28e+05 real consumption= 6.92e+04
# x_pred min= 8.84e+03 x_pred max 5.61e+05
# ESS of normalized weights= 281.118191
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -41356.3844081
# ------------------------
# n= 705
# x_pred_mean = 7.54e+04 real consumption= 6.89e+04
# x_pred min= 2.62e+03 x_pred max 3.20e+05
# ESS of normalized weights= 498.38944
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.3271125221
# likelihood: -4436.13008211
# ------------------------
# n= 706
# x_pred_mean = 6.98e+04 real consumption= 6.97e+04
# x_pred min= 5.77e+03 x_pred max 2.03e+05
# ESS of normalized weights= 613.762266
# ESS>=0.5*M
# new ESS= 613.762266
# 6.50566402501
# likelihood: -2718.73592117
# ------------------------
# n= 707
# x_pred_mean = 7.24e+04 real consumption= 6.89e+04
# x_pred min= 5.86e+03 x_pred max 2.74e+05
# ESS of normalized weights= 380.150542
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.09056608819
# likelihood: -5225.37214022
# ------------------------
# n= 708
# No heating effect
# x_pred_mean = 6.03e+04 real consumption= 6.70e+04
# x_pred min= 1.43e+03 x_pred max 1.66e+05
# ESS of normalized weights= 644.083842
# ESS>=0.5*M
# new ESS= 644.083842
# 6.55106955588
# likelihood: -2294.32729529
# ------------------------
# n= 709
# No heating effect
# x_pred_mean = 6.28e+04 real consumption= 6.18e+04
# x_pred min= 1.60e+03 x_pred max 2.21e+05
# ESS of normalized weights= 389.620431
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11499699968
# likelihood: -4712.24947905
# ------------------------
# n= 710
# No heating effect
# x_pred_mean = 5.43e+04 real consumption= 5.88e+04
# x_pred min= 3.60e+02 x_pred max 1.46e+05
# ESS of normalized weights= 668.013488
# ESS>=0.5*M
# new ESS= 668.013488
# 6.58488756133
# likelihood: -1872.67434232
# ------------------------
# n= 711
# x_pred_mean = 1.10e+05 real consumption= 7.02e+04
# x_pred min= 6.91e+03 x_pred max 4.80e+05
# ESS of normalized weights= 169.656635
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -25918.720919
# ------------------------
# n= 712
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 6.93e+04
# x_pred min= 5.16e+02 x_pred max 1.91e+05
# ESS of normalized weights= 542.069841
# ESS>=0.5*M
# new ESS= 542.069841
# 6.40345460483
# likelihood: -2972.59702387
# ------------------------
# n= 713
# x_pred_mean = 1.48e+05 real consumption= 6.80e+04
# x_pred min= 6.07e+03 x_pred max 9.91e+05
# ESS of normalized weights= 92.766649
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -73642.7439265
# ------------------------
# n= 714
# x_pred_mean = 1.21e+05 real consumption= 7.01e+04
# x_pred min= 6.27e+03 x_pred max 8.74e+05
# ESS of normalized weights= 315.423404
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -38896.2185321
# ------------------------

# %%
print(np.sum(log_lh_init))
# Out:
# -140317063.83

# %% [markdown]
# #### PMMH Algorithm

# %%
for step in range(len_iter_mha):
    print("___________________________________________________________")
    print("Metropolis Hastings step:",step)
    #we need 6 inputs to compute the (log) acceptance probability log(r):
    #log_likelihood, joint prior density, log proposal density for both current parameters and proposed parameters
    #sample proposal for u_h, sigma, sigma_g, sigma_s
    u_h_prop=npr.normal(u_h_current,std_hyp_u,size=1)
    sigma_prop=stats.truncnorm.rvs(a=(0-sigma_current)/std_hyp_sigma,b=np.inf,loc=sigma_current,scale=std_hyp_sigma,size=1)
    sigma_g_prop=stats.truncnorm.rvs(a=(0-sigma_g_current)/std_hyp_sigma_g,b=np.inf,loc=sigma_g_current,scale=std_hyp_sigma_g,size=1)
    sigma_s_prop=stats.truncnorm.rvs(a=(0-sigma_s_current)/std_hyp_sigma_s,b=np.inf,loc=sigma_s_current,scale=std_hyp_sigma_s,size=1)
    print("proposed parameters:","u_heat:",u_h_prop,"sigma:",sigma_prop,"sigma_g:",sigma_g_prop,"sigma_s:",sigma_s_prop)
    #1/run a particle filter with the proposed parameters to obtain a an estimation of likelihood proposed
    #  consider the likelihood of the last day of the fitering
    lh_y_prop=particle_filter(0,len_init,len_filter_pmmh,s_init,
                              g_heat_init,sigma_s_prop,sigma_g_prop,sigma_prop,lh_y_n)[0]
    print("log likelihood proposal of y:",np.sum(lh_y_prop))
    #2/generate prior proposals and compute joint log density of them
    log_prior_prop = log_joint_prior(u_h_prop,sigma_prop,sigma_g_prop,sigma_s_prop)
    print("proposed log prior:",log_prior_prop)
    #3/compute log proposal density h(current parameter|proposed parameter)
    current_log_density=np.log(stats.norm.cdf(sigma_current/std_hyp_sigma,loc=0,scale=1))+np.log(
        stats.norm.cdf(sigma_s_current/std_hyp_sigma_s,loc=0,scale=1))+np.log(
        stats.norm.cdf(sigma_g_current/std_hyp_sigma_g,loc=0,scale=1))
    print("proposal log density initial parameters given proposed param:",current_log_density)
    #4/log likelihood from initial parameters --> already done: log_lh_init
    #5/joint prior of the initial parameters: we already have them
    #6/compute log proposal density h(proposed parameter|current parameter)
    prop_log_density=np.log(stats.norm.cdf(sigma_prop/std_hyp_sigma,loc=0,scale=1))+np.log(
    stats.norm.cdf(sigma_s_prop/std_hyp_sigma_s,loc=0,scale=1))+np.log(
    stats.norm.cdf(sigma_g_prop/std_hyp_sigma_g,loc=0,scale=1))
    print("proposal log density proposed parameters given current param:",prop_log_density)
    #we add up these elements to construct the log acceptance probability
    #numerator
    accept_log_proba[step]=np.sum(lh_y_prop)+log_prior_prop+current_log_density
    #denominator
    accept_log_proba[step]=accept_log_proba[step]-np.sum(log_lh_init)-log_prior_init-prop_log_density
    print("acceptance log probability:",accept_log_proba[step])
    u=npr.random()
    #to get an acceptance rate > 5%, we need log_proba to be at least -3
    if(np.log(u)<min(0,accept_log_proba[step])):
        print("ACCEPT")
        accept_rate=accept_rate+1
        log_lh_init=lh_y_prop
        sigma_current=sigma_prop
        sigma_g_current=sigma_g_prop
        sigma_s_current=sigma_s_prop
        u_h_current=u_h_prop
        #store the accepted values
        u_h_list.append(u_h_current)
        sigma_list.append(sigma_current)
        sigma_g_list.append(sigma_g_current)
        sigma_s_list.append(sigma_s_current)
    else:
        print("REJECT")
# Out:
# ___________________________________________________________
# Metropolis Hastings step: 0
# proposed parameters: u_heat: [ 10.85386035] sigma: [ 15184.41406293] sigma_g: [ 9064.17862483] sigma_s: [ 13314.581213]
# n= 1
# x_pred_mean = 5.06e+04 real consumption= 6.86e+04
# x_pred min= 2.27e+03 x_pred max 7.18e+05
# ESS of normalized weights= 509.973827
# ESS>=0.5*M
# new ESS= 509.973827
# nan
# likelihood: -2799.96665892
# ------------------------
# n= 2
# x_pred_mean = 7.68e+04 real consumption= 6.41e+04
# x_pred min= 1.94e+03 x_pred max 7.27e+05
# ESS of normalized weights= 275.891402
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -5748.70670624
# ------------------------
# n= 3
# x_pred_mean = 9.86e+04 real consumption= 5.74e+04
# x_pred min= 4.97e+03 x_pred max 4.33e+05
# ESS of normalized weights= 471.990765
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.27205364041
# likelihood: -7067.72275468
# ------------------------
# n= 4
# x_pred_mean = 1.08e+05 real consumption= 7.31e+04
# x_pred min= 1.93e+03 x_pred max 4.66e+05
# ESS of normalized weights= 449.853451
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22191757234
# likelihood: -9028.46558295
# ------------------------
# n= 5
# x_pred_mean = 9.77e+04 real consumption= 7.68e+04
# x_pred min= 9.55e+03 x_pred max 4.14e+05
# ESS of normalized weights= 488.510015
# ESS>=0.001*M and ESS_0<0.5*M
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
# /Users/antoinegrelety/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in multiply
# new ESS= 1000.0
# 6.29992041057
# likelihood: -6468.16426863
# ------------------------
# n= 6
# x_pred_mean = 9.92e+04 real consumption= 7.49e+04
# x_pred min= 7.76e+03 x_pred max 4.58e+05
# ESS of normalized weights= 504.046089
# ESS>=0.5*M
# new ESS= 504.046089
# 6.33405415496
# likelihood: -5919.45964528
# ------------------------
# n= 7
# x_pred_mean = 1.30e+05 real consumption= 7.21e+04
# x_pred min= 3.52e+03 x_pred max 5.30e+05
# ESS of normalized weights= 226.411306
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -18737.0879025
# ------------------------
# n= 8
# x_pred_mean = 8.99e+04 real consumption= 6.90e+04
# x_pred min= 1.47e+03 x_pred max 3.73e+05
# ESS of normalized weights= 530.942219
# ESS>=0.5*M
# new ESS= 530.942219
# 6.37222086468
# likelihood: -5140.39460031
# ------------------------
# n= 9
# x_pred_mean = 9.80e+04 real consumption= 5.72e+04
# x_pred min= 7.10e+03 x_pred max 4.09e+05
# ESS of normalized weights= 303.047898
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.89108857515
# likelihood: -9457.55828586
# ------------------------
# n= 10
# x_pred_mean = 7.85e+04 real consumption= 5.55e+04
# x_pred min= 5.25e+03 x_pred max 2.86e+05
# ESS of normalized weights= 587.101499
# ESS>=0.5*M
# new ESS= 587.101499
# 6.48246236676
# likelihood: -2965.69623558
# ------------------------
# n= 11
# x_pred_mean = 8.94e+04 real consumption= 6.91e+04
# x_pred min= 2.33e+03 x_pred max 3.51e+05
# ESS of normalized weights= 341.931639
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.02084343425
# likelihood: -5322.08427634
# ------------------------
# n= 12
# x_pred_mean = 5.90e+04 real consumption= 6.88e+04
# x_pred min= 5.66e+03 x_pred max 1.93e+05
# ESS of normalized weights= 541.83921
# ESS>=0.5*M
# new ESS= 541.83921
# 6.42602029804
# likelihood: -2151.20103519
# ------------------------
# n= 13
# x_pred_mean = 9.26e+04 real consumption= 6.92e+04
# x_pred min= 5.26e+03 x_pred max 3.08e+05
# ESS of normalized weights= 303.817318
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.94517934832
# likelihood: -4611.88133863
# ------------------------
# n= 14
# x_pred_mean = 1.16e+05 real consumption= 7.03e+04
# x_pred min= 2.11e+04 x_pred max 4.58e+05
# ESS of normalized weights= 407.681932
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13300790696
# likelihood: -8570.20471541
# ------------------------
# n= 15
# x_pred_mean = 1.08e+05 real consumption= 7.00e+04
# x_pred min= 1.03e+04 x_pred max 4.24e+05
# ESS of normalized weights= 413.173457
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14638084813
# likelihood: -9064.68977469
# ------------------------
# n= 16
# x_pred_mean = 1.07e+05 real consumption= 6.31e+04
# x_pred min= 4.65e+03 x_pred max 5.67e+05
# ESS of normalized weights= 420.057335
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16471680739
# likelihood: -9709.26506968
# ------------------------
# n= 17
# x_pred_mean = 1.02e+05 real consumption= 6.25e+04
# x_pred min= 6.54e+03 x_pred max 3.84e+05
# ESS of normalized weights= 498.817338
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.31383185797
# likelihood: -7347.0156529
# ------------------------
# n= 18
# x_pred_mean = 1.22e+05 real consumption= 7.72e+04
# x_pred min= 9.36e+02 x_pred max 9.92e+05
# ESS of normalized weights= 415.310399
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -15175.3179906
# ------------------------
# n= 19
# x_pred_mean = 1.16e+05 real consumption= 7.79e+04
# x_pred min= 2.07e+03 x_pred max 4.88e+05
# ESS of normalized weights= 444.54803
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20626239061
# likelihood: -11116.8001619
# ------------------------
# n= 20
# x_pred_mean = 1.25e+05 real consumption= 7.92e+04
# x_pred min= 5.97e+03 x_pred max 5.30e+05
# ESS of normalized weights= 402.20932
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11839487725
# likelihood: -13971.8266987
# ------------------------
# n= 21
# x_pred_mean = 1.28e+05 real consumption= 7.84e+04
# x_pred min= 1.14e+03 x_pred max 5.91e+05
# ESS of normalized weights= 401.278936
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11837778876
# likelihood: -15596.5907074
# ------------------------
# n= 22
# x_pred_mean = 9.51e+04 real consumption= 7.89e+04
# x_pred min= 5.08e+03 x_pred max 3.31e+05
# ESS of normalized weights= 527.505483
# ESS>=0.5*M
# new ESS= 527.505483
# 6.36513834337
# likelihood: -6010.08312598
# ------------------------
# n= 23
# x_pred_mean = 1.05e+05 real consumption= 7.12e+04
# x_pred min= 3.93e+03 x_pred max 4.04e+05
# ESS of normalized weights= 268.319743
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.77957539445
# likelihood: -9909.08603439
# ------------------------
# n= 24
# x_pred_mean = 6.70e+04 real consumption= 6.55e+04
# x_pred min= 1.24e+02 x_pred max 2.10e+05
# ESS of normalized weights= 568.859063
# ESS>=0.5*M
# new ESS= 568.859063
# 6.46073967408
# likelihood: -2228.71503801
# ------------------------
# n= 25
# x_pred_mean = 6.58e+04 real consumption= 7.75e+04
# x_pred min= 3.49e+03 x_pred max 2.26e+05
# ESS of normalized weights= 330.879585
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.00381109862
# likelihood: -2893.77375083
# ------------------------
# n= 26
# No heating effect
# x_pred_mean = 5.63e+04 real consumption= 7.54e+04
# x_pred min= 5.05e+02 x_pred max 2.61e+05
# ESS of normalized weights= 582.226533
# ESS>=0.5*M
# new ESS= 582.226533
# 6.48442919072
# likelihood: -2148.15837247
# ------------------------
# n= 27
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 7.65e+04
# x_pred min= 1.52e+03 x_pred max 2.63e+05
# ESS of normalized weights= 359.990853
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.0642382154
# likelihood: -2940.9072482
# ------------------------
# n= 28
# No heating effect
# x_pred_mean = 7.06e+04 real consumption= 7.78e+04
# x_pred min= 1.97e+02 x_pred max 2.05e+05
# ESS of normalized weights= 751.489502
# ESS>=0.5*M
# new ESS= 751.489502
# 6.68534720037
# likelihood: -1309.00432489
# ------------------------
# n= 29
# x_pred_mean = 1.03e+05 real consumption= 7.59e+04
# x_pred min= 9.92e+02 x_pred max 3.57e+05
# ESS of normalized weights= 314.321962
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.93739677073
# likelihood: -7457.58314923
# ------------------------
# n= 30
# x_pred_mean = 7.94e+04 real consumption= 6.84e+04
# x_pred min= 3.32e+03 x_pred max 2.54e+05
# ESS of normalized weights= 578.544391
# ESS>=0.5*M
# new ESS= 578.544391
# 6.47434099036
# likelihood: -2444.59091656
# ------------------------
# n= 31
# x_pred_mean = 9.80e+04 real consumption= 6.67e+04
# x_pred min= 8.45e+03 x_pred max 2.92e+05
# ESS of normalized weights= 333.516147
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.98997009651
# likelihood: -5382.69364119
# ------------------------
# n= 32
# x_pred_mean = 7.65e+04 real consumption= 7.71e+04
# x_pred min= 3.18e+03 x_pred max 2.19e+05
# ESS of normalized weights= 690.692557
# ESS>=0.5*M
# new ESS= 690.692557
# 6.61706591033
# likelihood: -1757.73594246
# ------------------------
# n= 33
# x_pred_mean = 6.45e+04 real consumption= 7.99e+04
# x_pred min= 2.63e+03 x_pred max 2.51e+05
# ESS of normalized weights= 434.843847
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.24199421463
# likelihood: -2246.27669469
# ------------------------
# n= 34
# No heating effect
# x_pred_mean = 6.29e+04 real consumption= 8.21e+04
# x_pred min= 1.57e+02 x_pred max 2.20e+05
# ESS of normalized weights= 714.926881
# ESS>=0.5*M
# new ESS= 714.926881
# 6.64962489366
# likelihood: -1362.29492928
# ------------------------
# n= 35
# No heating effect
# x_pred_mean = 6.55e+04 real consumption= 8.29e+04
# x_pred min= 4.97e+01 x_pred max 2.74e+05
# ESS of normalized weights= 496.097213
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.33579377245
# likelihood: -2191.47191799
# ------------------------
# n= 36
# x_pred_mean = 1.64e+05 real consumption= 8.59e+04
# x_pred min= 1.53e+04 x_pred max 7.02e+05
# ESS of normalized weights= 151.932224
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -36519.3489074
# ------------------------
# n= 37
# x_pred_mean = 7.84e+04 real consumption= 7.30e+04
# x_pred min= 5.73e+03 x_pred max 2.57e+05
# ESS of normalized weights= 579.102914
# ESS>=0.5*M
# new ESS= 579.102914
# 6.46514450314
# likelihood: -2863.43695087
# ------------------------
# n= 38
# No heating effect
# x_pred_mean = 6.08e+04 real consumption= 6.70e+04
# x_pred min= 5.17e+01 x_pred max 2.39e+05
# ESS of normalized weights= 360.270183
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.09276570537
# likelihood: -2291.26216085
# ------------------------
# n= 39
# x_pred_mean = 8.90e+04 real consumption= 7.57e+04
# x_pred min= 6.16e+03 x_pred max 2.74e+05
# ESS of normalized weights= 591.489105
# ESS>=0.5*M
# new ESS= 591.489105
# 6.47646562642
# likelihood: -3165.3126207
# ------------------------
# n= 40
# No heating effect
# x_pred_mean = 6.56e+04 real consumption= 7.55e+04
# x_pred min= 1.70e+02 x_pred max 2.21e+05
# ESS of normalized weights= 379.731809
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12086213722
# likelihood: -2345.33338905
# ------------------------
# n= 41
# No heating effect
# x_pred_mean = 6.80e+04 real consumption= 7.16e+04
# x_pred min= 6.02e+01 x_pred max 2.36e+05
# ESS of normalized weights= 708.470495
# ESS>=0.5*M
# new ESS= 708.470495
# 6.63352606432
# likelihood: -1504.01806014
# ------------------------
# n= 42
# x_pred_mean = 9.96e+04 real consumption= 7.21e+04
# x_pred min= 7.35e+03 x_pred max 3.08e+05
# ESS of normalized weights= 350.990411
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.0378450647
# likelihood: -6115.12803368
# ------------------------
# n= 43
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 7.10e+04
# x_pred min= 3.09e+01 x_pred max 2.21e+05
# ESS of normalized weights= 729.096507
# ESS>=0.5*M
# new ESS= 729.096507
# 6.6590223808
# likelihood: -1349.93336935
# ------------------------
# n= 44
# No heating effect
# x_pred_mean = 6.54e+04 real consumption= 6.39e+04
# x_pred min= 5.35e+02 x_pred max 3.21e+05
# ESS of normalized weights= 504.807269
# ESS>=0.5*M
# new ESS= 504.807269
# 6.35179214342
# likelihood: -2482.25082142
# ------------------------
# n= 45
# No heating effect
# x_pred_mean = 6.93e+04 real consumption= 5.91e+04
# x_pred min= 4.40e+02 x_pred max 3.12e+05
# ESS of normalized weights= 370.345322
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.08366287545
# likelihood: -3263.43181613
# ------------------------
# n= 46
# No heating effect
# x_pred_mean = 6.38e+04 real consumption= 7.23e+04
# x_pred min= 1.99e+03 x_pred max 2.05e+05
# ESS of normalized weights= 766.541697
# ESS>=0.5*M
# new ESS= 766.541697
# 6.70171623022
# likelihood: -1182.03132166
# ------------------------
# n= 47
# x_pred_mean = 2.20e+05 real consumption= 7.28e+04
# x_pred min= 1.68e+04 x_pred max 1.14e+06
# ESS of normalized weights= 105.92109
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -98412.0188287
# ------------------------
# n= 48
# x_pred_mean = 6.26e+04 real consumption= 7.15e+04
# x_pred min= 5.69e+03 x_pred max 2.04e+05
# ESS of normalized weights= 712.308041
# ESS>=0.5*M
# new ESS= 712.308041
# 6.64677150823
# likelihood: -1290.54407327
# ------------------------
# n= 49
# No heating effect
# x_pred_mean = 5.80e+04 real consumption= 7.06e+04
# x_pred min= 1.13e+02 x_pred max 1.80e+05
# ESS of normalized weights= 489.20995
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.32798413465
# likelihood: -1797.79944684
# ------------------------
# n= 50
# No heating effect
# x_pred_mean = 6.25e+04 real consumption= 7.11e+04
# x_pred min= 1.85e+03 x_pred max 1.73e+05
# ESS of normalized weights= 741.208593
# ESS>=0.5*M
# new ESS= 741.208593
# 6.67781904226
# likelihood: -1253.20292084
# ------------------------
# n= 51
# No heating effect
# x_pred_mean = 6.51e+04 real consumption= 6.54e+04
# x_pred min= 5.05e+02 x_pred max 2.06e+05
# ESS of normalized weights= 497.413834
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.34260887561
# likelihood: -2765.60423372
# ------------------------
# n= 52
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.97e+04
# x_pred min= 7.27e+02 x_pred max 1.82e+05
# ESS of normalized weights= 735.490855
# ESS>=0.5*M
# new ESS= 735.490855
# 6.67196137526
# likelihood: -1163.58151632
# ------------------------
# n= 53
# No heating effect
# x_pred_mean = 5.79e+04 real consumption= 7.10e+04
# x_pred min= 3.39e+01 x_pred max 2.32e+05
# ESS of normalized weights= 500.978872
# ESS>=0.5*M
# new ESS= 500.978872
# 6.34296084211
# likelihood: -2071.94539965
# ------------------------
# n= 54
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 7.19e+04
# x_pred min= 2.76e+02 x_pred max 3.79e+05
# ESS of normalized weights= 355.32818
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.03749265081
# likelihood: -3207.72553027
# ------------------------
# n= 55
# No heating effect
# x_pred_mean = 6.06e+04 real consumption= 7.05e+04
# x_pred min= 2.05e+03 x_pred max 2.09e+05
# ESS of normalized weights= 802.418068
# ESS>=0.5*M
# new ESS= 802.418068
# 6.74309410063
# likelihood: -930.704564504
# ------------------------
# n= 56
# x_pred_mean = 1.11e+05 real consumption= 6.99e+04
# x_pred min= 8.93e+03 x_pred max 4.19e+05
# ESS of normalized weights= 313.569537
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.91728899761
# likelihood: -11973.7285558
# ------------------------
# n= 57
# x_pred_mean = 1.39e+05 real consumption= 6.90e+04
# x_pred min= 2.27e+03 x_pred max 5.01e+05
# ESS of normalized weights= 201.718425
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.44450237973
# likelihood: -26185.9742958
# ------------------------
# n= 58
# x_pred_mean = 9.92e+04 real consumption= 6.19e+04
# x_pred min= 4.69e+03 x_pred max 4.65e+05
# ESS of normalized weights= 440.715626
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19880076413
# likelihood: -11261.9646406
# ------------------------
# n= 59
# No heating effect
# x_pred_mean = 4.26e+04 real consumption= 5.57e+04
# x_pred min= 2.06e+02 x_pred max 1.48e+05
# ESS of normalized weights= 543.400545
# ESS>=0.5*M
# new ESS= 543.400545
# 6.41584498111
# likelihood: -2145.65377859
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 4.79e+04 real consumption= 6.53e+04
# x_pred min= 2.44e+02 x_pred max 2.70e+05
# ESS of normalized weights= 348.543365
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.02598471178
# likelihood: -2649.67794333
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 6.18e+04 real consumption= 6.47e+04
# x_pred min= 6.64e+02 x_pred max 1.69e+05
# ESS of normalized weights= 734.709389
# ESS>=0.5*M
# new ESS= 734.709389
# 6.66243801628
# likelihood: -1377.70660715
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 6.48e+04 real consumption= 6.74e+04
# x_pred min= 3.95e+02 x_pred max 2.35e+05
# ESS of normalized weights= 529.421125
# ESS>=0.5*M
# new ESS= 529.421125
# 6.3852919437
# likelihood: -2295.5848823
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 6.73e+04 real consumption= 6.53e+04
# x_pred min= 1.29e+02 x_pred max 3.02e+05
# ESS of normalized weights= 365.263085
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07415488648
# likelihood: -3251.11634794
# ------------------------
# n= 64
# x_pred_mean = 8.93e+04 real consumption= 6.30e+04
# x_pred min= 9.95e+03 x_pred max 2.96e+05
# ESS of normalized weights= 484.124432
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30244576267
# likelihood: -5022.97893479
# ------------------------
# n= 65
# x_pred_mean = 8.53e+04 real consumption= 5.49e+04
# x_pred min= 7.31e+03 x_pred max 2.67e+05
# ESS of normalized weights= 479.464823
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29161162053
# likelihood: -4287.53521198
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 4.53e+04 real consumption= 4.87e+04
# x_pred min= 1.52e+02 x_pred max 1.79e+05
# ESS of normalized weights= 615.960201
# ESS>=0.5*M
# new ESS= 615.960201
# 6.52213311605
# likelihood: -1734.40775839
# ------------------------
# n= 67
# x_pred_mean = 7.33e+04 real consumption= 6.02e+04
# x_pred min= 3.51e+03 x_pred max 2.47e+05
# ESS of normalized weights= 397.618914
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15774436628
# likelihood: -2552.74513994
# ------------------------
# n= 68
# x_pred_mean = 1.25e+05 real consumption= 6.20e+04
# x_pred min= 1.09e+04 x_pred max 5.25e+05
# ESS of normalized weights= 313.704737
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.87964734003
# likelihood: -14949.8432811
# ------------------------
# n= 69
# x_pred_mean = 5.69e+04 real consumption= 6.01e+04
# x_pred min= 4.89e+03 x_pred max 1.82e+05
# ESS of normalized weights= 680.673974
# ESS>=0.5*M
# new ESS= 680.673974
# 6.61224692253
# likelihood: -1409.20818439
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 5.96e+04
# x_pred min= 8.71e+01 x_pred max 3.06e+05
# ESS of normalized weights= 470.941078
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.30052709557
# likelihood: -2038.15472465
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 6.19e+04 real consumption= 6.18e+04
# x_pred min= 2.95e+03 x_pred max 2.03e+05
# ESS of normalized weights= 743.475585
# ESS>=0.5*M
# new ESS= 743.475585
# 6.67576327318
# likelihood: -1417.10155408
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 6.46e+04 real consumption= 5.74e+04
# x_pred min= 9.12e+01 x_pred max 2.50e+05
# ESS of normalized weights= 536.021905
# ESS>=0.5*M
# new ESS= 536.021905
# 6.40200427936
# likelihood: -2675.41264729
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 6.75e+04 real consumption= 5.60e+04
# x_pred min= 1.55e+02 x_pred max 2.66e+05
# ESS of normalized weights= 373.488075
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10162530337
# likelihood: -3173.69778088
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.90e+04 real consumption= 6.36e+04
# x_pred min= 7.05e+02 x_pred max 1.91e+05
# ESS of normalized weights= 744.301627
# ESS>=0.5*M
# new ESS= 744.301627
# 6.68046496445
# likelihood: -1229.16737213
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 6.16e+04 real consumption= 6.06e+04
# x_pred min= 2.39e+02 x_pred max 2.11e+05
# ESS of normalized weights= 521.35177
# ESS>=0.5*M
# new ESS= 521.35177
# 6.380483596
# likelihood: -2151.2237482
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 6.42e+04 real consumption= 5.89e+04
# x_pred min= 3.60e+02 x_pred max 2.87e+05
# ESS of normalized weights= 365.451757
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.0727321924
# likelihood: -3161.87937131
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 6.35e+04 real consumption= 6.31e+04
# x_pred min= 1.94e+02 x_pred max 1.53e+05
# ESS of normalized weights= 786.134641
# ESS>=0.5*M
# new ESS= 786.134641
# 6.72479441777
# likelihood: -962.526668843
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 6.49e+04 real consumption= 6.33e+04
# x_pred min= 6.46e+02 x_pred max 2.18e+05
# ESS of normalized weights= 569.78351
# ESS>=0.5*M
# new ESS= 569.78351
# 6.45716969393
# likelihood: -1917.20835867
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 6.60e+04 real consumption= 5.73e+04
# x_pred min= 9.24e+01 x_pred max 2.86e+05
# ESS of normalized weights= 382.314698
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.11898818566
# likelihood: -3187.75432989
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 5.55e+04 real consumption= 5.46e+04
# x_pred min= 2.51e+02 x_pred max 1.82e+05
# ESS of normalized weights= 761.5778
# ESS>=0.5*M
# new ESS= 761.5778
# 6.7005672093
# likelihood: -1125.44455101
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 6.05e+04
# x_pred min= 2.92e+02 x_pred max 2.36e+05
# ESS of normalized weights= 549.660447
# ESS>=0.5*M
# new ESS= 549.660447
# 6.43100010344
# likelihood: -1861.20699068
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 6.14e+04 real consumption= 6.54e+04
# x_pred min= 2.46e+02 x_pred max 2.31e+05
# ESS of normalized weights= 381.672182
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1216431474
# likelihood: -2856.87905807
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.85e+04 real consumption= 6.75e+04
# x_pred min= 2.05e+03 x_pred max 2.03e+05
# ESS of normalized weights= 757.041664
# ESS>=0.5*M
# new ESS= 757.041664
# 6.6921205982
# likelihood: -1234.01306281
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 6.80e+04
# x_pred min= 1.28e+01 x_pred max 3.06e+05
# ESS of normalized weights= 552.33136
# ESS>=0.5*M
# new ESS= 552.33136
# 6.42968891064
# likelihood: -2301.29798637
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 6.33e+04 real consumption= 6.20e+04
# x_pred min= 2.90e+02 x_pred max 3.26e+05
# ESS of normalized weights= 381.64981
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1057770723
# likelihood: -3435.28498872
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.41e+04
# x_pred min= 5.64e+02 x_pred max 1.75e+05
# ESS of normalized weights= 763.369956
# ESS>=0.5*M
# new ESS= 763.369956
# 6.70383490777
# likelihood: -1239.17205828
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 5.19e+04
# x_pred min= 7.70e+02 x_pred max 2.82e+05
# ESS of normalized weights= 549.983302
# ESS>=0.5*M
# new ESS= 549.983302
# 6.43864405571
# likelihood: -1897.30177137
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 5.67e+04 real consumption= 6.07e+04
# x_pred min= 1.07e+01 x_pred max 2.68e+05
# ESS of normalized weights= 401.467144
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16121429661
# likelihood: -2555.12282674
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 5.29e+04 real consumption= 6.07e+04
# x_pred min= 3.56e+02 x_pred max 2.06e+05
# ESS of normalized weights= 767.786417
# ESS>=0.5*M
# new ESS= 767.786417
# 6.70234168042
# likelihood: -1151.2357724
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 5.54e+04 real consumption= 6.23e+04
# x_pred min= 2.50e+02 x_pred max 2.21e+05
# ESS of normalized weights= 570.286164
# ESS>=0.5*M
# new ESS= 570.286164
# 6.46019966947
# likelihood: -1828.80426969
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.89e+04 real consumption= 6.36e+04
# x_pred min= 1.95e+01 x_pred max 3.01e+05
# ESS of normalized weights= 412.01495
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18835641753
# likelihood: -2839.12820765
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 6.11e+04
# x_pred min= 3.16e+02 x_pred max 1.51e+05
# ESS of normalized weights= 765.927438
# ESS>=0.5*M
# new ESS= 765.927438
# 6.70944431264
# likelihood: -1080.74032131
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 5.51e+04 real consumption= 5.54e+04
# x_pred min= 6.27e+02 x_pred max 1.96e+05
# ESS of normalized weights= 532.08051
# ESS>=0.5*M
# new ESS= 532.08051
# 6.4095277299
# likelihood: -1964.81235271
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 5.75e+04 real consumption= 4.91e+04
# x_pred min= 1.33e+02 x_pred max 2.80e+05
# ESS of normalized weights= 396.891202
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16337369254
# likelihood: -2310.12729129
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 4.96e+04
# x_pred min= 6.80e+02 x_pred max 1.82e+05
# ESS of normalized weights= 772.776029
# ESS>=0.5*M
# new ESS= 772.776029
# 6.71191607974
# likelihood: -1065.7722108
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 5.87e+04
# x_pred min= 1.12e+03 x_pred max 2.49e+05
# ESS of normalized weights= 575.907388
# ESS>=0.5*M
# new ESS= 575.907388
# 6.46711433493
# likelihood: -1911.79994537
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 5.66e+04 real consumption= 5.70e+04
# x_pred min= 2.28e+01 x_pred max 2.48e+05
# ESS of normalized weights= 418.292656
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19844609552
# likelihood: -2748.4801741
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.49e+04
# x_pred min= 6.67e+01 x_pred max 1.76e+05
# ESS of normalized weights= 766.057614
# ESS>=0.5*M
# new ESS= 766.057614
# 6.69943384188
# likelihood: -1173.83933008
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 5.69e+04 real consumption= 5.35e+04
# x_pred min= 1.72e+02 x_pred max 3.03e+05
# ESS of normalized weights= 571.320704
# ESS>=0.5*M
# new ESS= 571.320704
# 6.45512520058
# likelihood: -2354.42408104
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 5.99e+04 real consumption= 4.79e+04
# x_pred min= 1.26e+02 x_pred max 2.84e+05
# ESS of normalized weights= 405.139358
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16532985832
# likelihood: -3447.97149786
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.72e+04 real consumption= 4.19e+04
# x_pred min= 1.11e+02 x_pred max 1.46e+05
# ESS of normalized weights= 759.170887
# ESS>=0.5*M
# new ESS= 759.170887
# 6.70091881305
# likelihood: -982.376251651
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 5.02e+04 real consumption= 5.26e+04
# x_pred min= 2.59e+01 x_pred max 2.26e+05
# ESS of normalized weights= 548.530867
# ESS>=0.5*M
# new ESS= 548.530867
# 6.42542405446
# likelihood: -1655.58920032
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.47e+04 real consumption= 5.22e+04
# x_pred min= 3.09e+02 x_pred max 2.82e+05
# ESS of normalized weights= 383.439963
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12078487842
# likelihood: -2646.48489763
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.49e+04 real consumption= 5.23e+04
# x_pred min= 4.40e+01 x_pred max 1.85e+05
# ESS of normalized weights= 791.628156
# ESS>=0.5*M
# new ESS= 791.628156
# 6.73250454443
# likelihood: -939.865863535
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.76e+04 real consumption= 5.27e+04
# x_pred min= 2.52e+02 x_pred max 2.84e+05
# ESS of normalized weights= 560.737382
# ESS>=0.5*M
# new ESS= 560.737382
# 6.44536164998
# likelihood: -2211.61158245
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 6.07e+04 real consumption= 5.24e+04
# x_pred min= 1.20e+03 x_pred max 3.38e+05
# ESS of normalized weights= 400.201659
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15490239695
# likelihood: -3356.5558287
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 4.52e+04
# x_pred min= 7.36e+02 x_pred max 1.49e+05
# ESS of normalized weights= 775.353761
# ESS>=0.5*M
# new ESS= 775.353761
# 6.71620449339
# likelihood: -1023.63047209
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 5.24e+04 real consumption= 4.20e+04
# x_pred min= 9.59e-01 x_pred max 1.83e+05
# ESS of normalized weights= 577.594029
# ESS>=0.5*M
# new ESS= 577.594029
# 6.47736312871
# likelihood: -1585.97303282
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.22e+04
# x_pred min= 2.31e+01 x_pred max 2.29e+05
# ESS of normalized weights= 406.98537
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.18323865941
# likelihood: -2459.534511
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 5.18e+04 real consumption= 5.22e+04
# x_pred min= 4.73e+02 x_pred max 1.53e+05
# ESS of normalized weights= 768.238545
# ESS>=0.5*M
# new ESS= 768.238545
# 6.70615395307
# likelihood: -1019.30167964
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 5.20e+04
# x_pred min= 9.45e+01 x_pred max 1.81e+05
# ESS of normalized weights= 579.793741
# ESS>=0.5*M
# new ESS= 579.793741
# 6.4726377803
# likelihood: -1622.39031076
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.59e+04 real consumption= 5.22e+04
# x_pred min= 2.84e+02 x_pred max 2.19e+05
# ESS of normalized weights= 416.264894
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19014041813
# likelihood: -2750.15335639
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 4.89e+04 real consumption= 5.14e+04
# x_pred min= 2.45e+02 x_pred max 1.35e+05
# ESS of normalized weights= 790.559943
# ESS>=0.5*M
# new ESS= 790.559943
# 6.7310143968
# likelihood: -914.83260838
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 4.47e+04
# x_pred min= 3.58e+02 x_pred max 2.20e+05
# ESS of normalized weights= 558.213506
# ESS>=0.5*M
# new ESS= 558.213506
# 6.44656975801
# likelihood: -2209.13588856
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 5.55e+04 real consumption= 4.14e+04
# x_pred min= 2.28e+02 x_pred max 2.46e+05
# ESS of normalized weights= 398.369588
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16225299861
# likelihood: -2620.59053212
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 4.87e+04 real consumption= 5.42e+04
# x_pred min= 1.83e+01 x_pred max 1.90e+05
# ESS of normalized weights= 756.016493
# ESS>=0.5*M
# new ESS= 756.016493
# 6.69134913772
# likelihood: -1172.55641719
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 5.22e+04 real consumption= 5.47e+04
# x_pred min= 1.06e+02 x_pred max 2.62e+05
# ESS of normalized weights= 550.453244
# ESS>=0.5*M
# new ESS= 550.453244
# 6.42739702507
# likelihood: -2197.9487315
# ------------------------
# n= 118
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.47e+04
# x_pred min= 1.54e+02 x_pred max 2.97e+05
# ESS of normalized weights= 402.274664
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16659782392
# likelihood: -3430.25614796
# ------------------------
# n= 119
# No heating effect
# x_pred_mean = 4.82e+04 real consumption= 5.60e+04
# x_pred min= 3.17e+01 x_pred max 1.43e+05
# ESS of normalized weights= 778.532337
# ESS>=0.5*M
# new ESS= 778.532337
# 6.72002316127
# likelihood: -960.310297235
# ------------------------
# n= 120
# No heating effect
# x_pred_mean = 5.15e+04 real consumption= 4.54e+04
# x_pred min= 7.00e+01 x_pred max 1.82e+05
# ESS of normalized weights= 560.326791
# ESS>=0.5*M
# new ESS= 560.326791
# 6.44509964565
# likelihood: -1942.3357133
# ------------------------
# n= 121
# No heating effect
# x_pred_mean = 5.57e+04 real consumption= 4.68e+04
# x_pred min= 4.59e+02 x_pred max 2.60e+05
# ESS of normalized weights= 394.113098
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15521916455
# likelihood: -3420.64617437
# ------------------------
# n= 122
# No heating effect
# x_pred_mean = 4.60e+04 real consumption= 4.28e+04
# x_pred min= 6.08e+00 x_pred max 1.51e+05
# ESS of normalized weights= 760.437096
# ESS>=0.5*M
# new ESS= 760.437096
# 6.69964823469
# likelihood: -1003.86670573
# ------------------------
# n= 123
# No heating effect
# x_pred_mean = 4.93e+04 real consumption= 5.29e+04
# x_pred min= 3.37e+02 x_pred max 2.81e+05
# ESS of normalized weights= 541.34652
# ESS>=0.5*M
# new ESS= 541.34652
# 6.42111189646
# likelihood: -1651.44437043
# ------------------------
# n= 124
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 5.25e+04
# x_pred min= 3.87e+02 x_pred max 2.69e+05
# ESS of normalized weights= 383.222625
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12193881115
# likelihood: -2411.00016549
# ------------------------
# n= 125
# No heating effect
# x_pred_mean = 5.42e+04 real consumption= 5.30e+04
# x_pred min= 9.76e+01 x_pred max 1.89e+05
# ESS of normalized weights= 766.855328
# ESS>=0.5*M
# new ESS= 766.855328
# 6.70077033744
# likelihood: -1087.6101083
# ------------------------
# n= 126
# No heating effect
# x_pred_mean = 5.76e+04 real consumption= 5.26e+04
# x_pred min= 3.76e+02 x_pred max 2.26e+05
# ESS of normalized weights= 556.023009
# ESS>=0.5*M
# new ESS= 556.023009
# 6.43832435279
# likelihood: -1942.45342092
# ------------------------
# n= 127
# No heating effect
# x_pred_mean = 5.96e+04 real consumption= 4.37e+04
# x_pred min= 4.68e+02 x_pred max 2.30e+05
# ESS of normalized weights= 393.702613
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14110660086
# likelihood: -3195.93551459
# ------------------------
# n= 128
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 4.34e+04
# x_pred min= 4.66e+02 x_pred max 2.27e+05
# ESS of normalized weights= 728.531669
# ESS>=0.5*M
# new ESS= 728.531669
# 6.6662182793
# likelihood: -1424.1542437
# ------------------------
# n= 129
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 3.94e+04
# x_pred min= 3.28e+02 x_pred max 2.08e+05
# ESS of normalized weights= 552.174105
# ESS>=0.5*M
# new ESS= 552.174105
# 6.43873117744
# likelihood: -1794.78147216
# ------------------------
# n= 130
# No heating effect
# x_pred_mean = 5.42e+04 real consumption= 5.15e+04
# x_pred min= 3.27e+02 x_pred max 3.57e+05
# ESS of normalized weights= 413.374139
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19611643786
# likelihood: -2302.18771111
# ------------------------
# n= 131
# No heating effect
# x_pred_mean = 4.97e+04 real consumption= 5.20e+04
# x_pred min= 1.16e+02 x_pred max 1.60e+05
# ESS of normalized weights= 766.376364
# ESS>=0.5*M
# new ESS= 766.376364
# 6.70976764618
# likelihood: -1011.47893956
# ------------------------
# n= 132
# No heating effect
# x_pred_mean = 5.10e+04 real consumption= 5.20e+04
# x_pred min= 3.67e+02 x_pred max 2.08e+05
# ESS of normalized weights= 548.414482
# ESS>=0.5*M
# new ESS= 548.414482
# 6.43476021109
# likelihood: -1616.97334405
# ------------------------
# n= 133
# No heating effect
# x_pred_mean = 5.38e+04 real consumption= 4.28e+04
# x_pred min= 2.27e+02 x_pred max 3.34e+05
# ESS of normalized weights= 393.582996
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15393887881
# likelihood: -2432.26957164
# ------------------------
# n= 134
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 4.84e+04
# x_pred min= 2.87e+03 x_pred max 1.97e+05
# ESS of normalized weights= 779.700985
# ESS>=0.5*M
# new ESS= 779.700985
# 6.71494075286
# likelihood: -1169.12984199
# ------------------------
# n= 135
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 4.47e+04
# x_pred min= 5.50e+02 x_pred max 2.13e+05
# ESS of normalized weights= 574.694131
# ESS>=0.5*M
# new ESS= 574.694131
# 6.46829100076
# likelihood: -2141.89302024
# ------------------------
# n= 136
# No heating effect
# x_pred_mean = 5.84e+04 real consumption= 3.98e+04
# x_pred min= 1.54e+03 x_pred max 2.55e+05
# ESS of normalized weights= 427.998261
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22579887816
# likelihood: -2533.11591468
# ------------------------
# n= 137
# No heating effect
# x_pred_mean = 5.03e+04 real consumption= 5.18e+04
# x_pred min= 1.80e+03 x_pred max 1.40e+05
# ESS of normalized weights= 782.409093
# ESS>=0.5*M
# new ESS= 782.409093
# 6.72165515642
# likelihood: -911.482003491
# ------------------------
# n= 138
# No heating effect
# x_pred_mean = 5.29e+04 real consumption= 5.32e+04
# x_pred min= 5.27e+02 x_pred max 2.13e+05
# ESS of normalized weights= 570.07975
# ESS>=0.5*M
# new ESS= 570.07975
# 6.46069957325
# likelihood: -1652.33817135
# ------------------------
# n= 139
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.41e+04
# x_pred min= 6.26e+02 x_pred max 2.35e+05
# ESS of normalized weights= 401.279433
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16624693321
# likelihood: -2575.26148724
# ------------------------
# n= 140
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 5.36e+04
# x_pred min= 1.56e+03 x_pred max 1.95e+05
# ESS of normalized weights= 789.933909
# ESS>=0.5*M
# new ESS= 789.933909
# 6.73014168842
# likelihood: -977.80108225
# ------------------------
# n= 141
# No heating effect
# x_pred_mean = 5.67e+04 real consumption= 5.20e+04
# x_pred min= 5.70e+02 x_pred max 2.61e+05
# ESS of normalized weights= 558.723409
# ESS>=0.5*M
# new ESS= 558.723409
# 6.44471329405
# likelihood: -2204.82590785
# ------------------------
# n= 142
# No heating effect
# x_pred_mean = 6.03e+04 real consumption= 4.45e+04
# x_pred min= 2.00e+01 x_pred max 2.50e+05
# ESS of normalized weights= 392.065798
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14389049992
# likelihood: -3600.12625457
# ------------------------
# n= 143
# No heating effect
# x_pred_mean = 4.57e+04 real consumption= 3.90e+04
# x_pred min= 7.48e+02 x_pred max 1.52e+05
# ESS of normalized weights= 764.921243
# ESS>=0.5*M
# new ESS= 764.921243
# 6.70564458677
# likelihood: -982.440460656
# ------------------------
# n= 144
# No heating effect
# x_pred_mean = 4.89e+04 real consumption= 4.27e+04
# x_pred min= 5.18e+02 x_pred max 2.04e+05
# ESS of normalized weights= 546.471098
# ESS>=0.5*M
# new ESS= 546.471098
# 6.433120141
# likelihood: -1615.36143669
# ------------------------
# n= 145
# No heating effect
# x_pred_mean = 5.23e+04 real consumption= 5.24e+04
# x_pred min= 3.27e+02 x_pred max 2.44e+05
# ESS of normalized weights= 393.556088
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.15103805879
# likelihood: -2259.93064306
# ------------------------
# n= 146
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 5.24e+04
# x_pred min= 5.14e+02 x_pred max 1.71e+05
# ESS of normalized weights= 766.677845
# ESS>=0.5*M
# new ESS= 766.677845
# 6.70511288882
# likelihood: -1027.23368778
# ------------------------
# n= 147
# No heating effect
# x_pred_mean = 5.64e+04 real consumption= 5.28e+04
# x_pred min= 8.61e+02 x_pred max 2.06e+05
# ESS of normalized weights= 557.301395
# ESS>=0.5*M
# new ESS= 557.301395
# 6.44200107576
# likelihood: -1669.45776922
# ------------------------
# n= 148
# No heating effect
# x_pred_mean = 5.92e+04 real consumption= 5.18e+04
# x_pred min= 6.36e+01 x_pred max 2.53e+05
# ESS of normalized weights= 393.552179
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14309933012
# likelihood: -3143.79159555
# ------------------------
# n= 149
# No heating effect
# x_pred_mean = 4.99e+04 real consumption= 4.41e+04
# x_pred min= 5.16e+02 x_pred max 1.51e+05
# ESS of normalized weights= 745.251107
# ESS>=0.5*M
# new ESS= 745.251107
# 6.68491106895
# likelihood: -1252.22603086
# ------------------------
# n= 150
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 4.00e+04
# x_pred min= 1.25e+03 x_pred max 2.40e+05
# ESS of normalized weights= 546.348169
# ESS>=0.5*M
# new ESS= 546.348169
# 6.42984097835
# likelihood: -1828.90396332
# ------------------------
# n= 151
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 5.20e+04
# x_pred min= 3.48e+02 x_pred max 3.33e+05
# ESS of normalized weights= 391.84014
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14356859366
# likelihood: -2712.97024696
# ------------------------
# n= 152
# No heating effect
# x_pred_mean = 5.26e+04 real consumption= 5.31e+04
# x_pred min= 5.57e+02 x_pred max 1.62e+05
# ESS of normalized weights= 773.655192
# ESS>=0.5*M
# new ESS= 773.655192
# 6.71237759192
# likelihood: -1001.12112822
# ------------------------
# n= 153
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.38e+04
# x_pred min= 1.50e+02 x_pred max 1.81e+05
# ESS of normalized weights= 564.89161
# ESS>=0.5*M
# new ESS= 564.89161
# 6.45237376856
# likelihood: -1587.66318428
# ------------------------
# n= 154
# No heating effect
# x_pred_mean = 5.80e+04 real consumption= 5.43e+04
# x_pred min= 6.14e+02 x_pred max 2.23e+05
# ESS of normalized weights= 405.79525
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.16433726914
# likelihood: -2623.0692795
# ------------------------
# n= 155
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 5.44e+04
# x_pred min= 4.71e+02 x_pred max 2.04e+05
# ESS of normalized weights= 765.592932
# ESS>=0.5*M
# new ESS= 765.592932
# 6.70439333052
# likelihood: -1210.95311786
# ------------------------
# n= 156
# No heating effect
# x_pred_mean = 5.53e+04 real consumption= 4.49e+04
# x_pred min= 4.64e+02 x_pred max 3.88e+05
# ESS of normalized weights= 533.076587
# ESS>=0.5*M
# new ESS= 533.076587
# 6.40651378823
# likelihood: -2426.74683024
# ------------------------
# n= 157
# No heating effect
# x_pred_mean = 5.86e+04 real consumption= 3.99e+04
# x_pred min= 7.57e+02 x_pred max 3.79e+05
# ESS of normalized weights= 380.385708
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12507214815
# likelihood: -2898.86944725
# ------------------------
# n= 158
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 5.25e+04
# x_pred min= 5.34e+01 x_pred max 2.00e+05
# ESS of normalized weights= 794.794914
# ESS>=0.5*M
# new ESS= 794.794914
# 6.73471921313
# likelihood: -934.000689588
# ------------------------
# n= 159
# No heating effect
# x_pred_mean = 5.30e+04 real consumption= 5.29e+04
# x_pred min= 7.39e+02 x_pred max 2.72e+05
# ESS of normalized weights= 602.710029
# ESS>=0.5*M
# new ESS= 602.710029
# 6.50017700194
# likelihood: -1708.64481837
# ------------------------
# n= 160
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 5.30e+04
# x_pred min= 6.05e+01 x_pred max 3.27e+05
# ESS of normalized weights= 438.124132
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22864389445
# likelihood: -2795.0555428
# ------------------------
# n= 161
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.43e+04
# x_pred min= 8.12e+02 x_pred max 1.77e+05
# ESS of normalized weights= 780.641958
# ESS>=0.5*M
# new ESS= 780.641958
# 6.71613102073
# likelihood: -1010.39216162
# ------------------------
# n= 162
# No heating effect
# x_pred_mean = 5.82e+04 real consumption= 5.26e+04
# x_pred min= 1.07e+02 x_pred max 1.88e+05
# ESS of normalized weights= 556.262275
# ESS>=0.5*M
# new ESS= 556.262275
# 6.43627990089
# likelihood: -2094.81942813
# ------------------------
# n= 163
# No heating effect
# x_pred_mean = 6.23e+04 real consumption= 4.41e+04
# x_pred min= 3.16e+02 x_pred max 2.83e+05
# ESS of normalized weights= 389.701969
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13549949733
# likelihood: -3656.83904109
# ------------------------
# n= 164
# No heating effect
# x_pred_mean = 4.85e+04 real consumption= 3.96e+04
# x_pred min= 2.79e+02 x_pred max 2.46e+05
# ESS of normalized weights= 745.867109
# ESS>=0.5*M
# new ESS= 745.867109
# 6.68615237588
# likelihood: -1191.20362245
# ------------------------
# n= 165
# No heating effect
# x_pred_mean = 5.20e+04 real consumption= 5.18e+04
# x_pred min= 3.81e+02 x_pred max 2.42e+05
# ESS of normalized weights= 508.484714
# ESS>=0.5*M
# new ESS= 508.484714
# 6.36616460634
# likelihood: -1865.10666597
# ------------------------
# n= 166
# No heating effect
# x_pred_mean = 5.65e+04 real consumption= 5.23e+04
# x_pred min= 2.66e+01 x_pred max 2.38e+05
# ESS of normalized weights= 360.750941
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.06777937833
# likelihood: -2703.54028166
# ------------------------
# n= 167
# No heating effect
# x_pred_mean = 5.76e+04 real consumption= 5.27e+04
# x_pred min= 4.56e+02 x_pred max 1.84e+05
# ESS of normalized weights= 761.918837
# ESS>=0.5*M
# new ESS= 761.918837
# 6.6983197927
# likelihood: -1079.48377588
# ------------------------
# n= 168
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 5.34e+04
# x_pred min= 6.98e+02 x_pred max 2.28e+05
# ESS of normalized weights= 552.088021
# ESS>=0.5*M
# new ESS= 552.088021
# 6.42391220897
# likelihood: -1910.93955999
# ------------------------
# n= 169
# No heating effect
# x_pred_mean = 6.34e+04 real consumption= 5.13e+04
# x_pred min= 2.27e+02 x_pred max 2.34e+05
# ESS of normalized weights= 398.109129
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14276906862
# likelihood: -3072.32011352
# ------------------------
# n= 170
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 4.36e+04
# x_pred min= 8.66e+01 x_pred max 1.57e+05
# ESS of normalized weights= 739.721246
# ESS>=0.5*M
# new ESS= 739.721246
# 6.6791733347
# likelihood: -1250.90417429
# ------------------------
# n= 171
# No heating effect
# x_pred_mean = 5.69e+04 real consumption= 3.96e+04
# x_pred min= 2.04e+02 x_pred max 2.53e+05
# ESS of normalized weights= 543.882692
# ESS>=0.5*M
# new ESS= 543.882692
# 6.41960942686
# likelihood: -1997.64932281
# ------------------------
# n= 172
# No heating effect
# x_pred_mean = 5.90e+04 real consumption= 5.29e+04
# x_pred min= 2.03e+02 x_pred max 2.84e+05
# ESS of normalized weights= 387.907473
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13289925742
# likelihood: -2691.70668326
# ------------------------
# n= 173
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.31e+04
# x_pred min= 1.88e+02 x_pred max 2.02e+05
# ESS of normalized weights= 767.193133
# ESS>=0.5*M
# new ESS= 767.193133
# 6.70433719862
# likelihood: -1150.77801696
# ------------------------
# n= 174
# No heating effect
# x_pred_mean = 5.86e+04 real consumption= 5.31e+04
# x_pred min= 2.47e+02 x_pred max 2.02e+05
# ESS of normalized weights= 550.550241
# ESS>=0.5*M
# new ESS= 550.550241
# 6.43305464664
# likelihood: -1842.30672024
# ------------------------
# n= 175
# No heating effect
# x_pred_mean = 6.10e+04 real consumption= 5.41e+04
# x_pred min= 3.87e+02 x_pred max 3.26e+05
# ESS of normalized weights= 389.075806
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12794500236
# likelihood: -2950.15975062
# ------------------------
# n= 176
# No heating effect
# x_pred_mean = 5.51e+04 real consumption= 5.40e+04
# x_pred min= 2.77e+02 x_pred max 1.76e+05
# ESS of normalized weights= 745.992448
# ESS>=0.5*M
# new ESS= 745.992448
# 6.68645473205
# likelihood: -1207.29237809
# ------------------------
# n= 177
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 4.52e+04
# x_pred min= 5.86e+01 x_pred max 1.99e+05
# ESS of normalized weights= 522.05649
# ESS>=0.5*M
# new ESS= 522.05649
# 6.39208787029
# likelihood: -2101.67025649
# ------------------------
# n= 178
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 4.11e+04
# x_pred min= 5.25e+02 x_pred max 2.28e+05
# ESS of normalized weights= 374.708829
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1054015855
# likelihood: -2679.01350012
# ------------------------
# n= 179
# No heating effect
# x_pred_mean = 4.90e+04 real consumption= 5.50e+04
# x_pred min= 8.17e+01 x_pred max 1.86e+05
# ESS of normalized weights= 785.187555
# ESS>=0.5*M
# new ESS= 785.187555
# 6.72475592401
# likelihood: -1031.39084654
# ------------------------
# n= 180
# No heating effect
# x_pred_mean = 5.19e+04 real consumption= 5.66e+04
# x_pred min= 6.83e+02 x_pred max 1.93e+05
# ESS of normalized weights= 551.601124
# ESS>=0.5*M
# new ESS= 551.601124
# 6.43689276567
# likelihood: -1823.76340275
# ------------------------
# n= 181
# No heating effect
# x_pred_mean = 5.61e+04 real consumption= 5.77e+04
# x_pred min= 8.29e+01 x_pred max 3.23e+05
# ESS of normalized weights= 390.21927
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13550744888
# likelihood: -2657.67908087
# ------------------------
# n= 182
# No heating effect
# x_pred_mean = 5.48e+04 real consumption= 5.71e+04
# x_pred min= 2.85e+01 x_pred max 2.09e+05
# ESS of normalized weights= 783.423749
# ESS>=0.5*M
# new ESS= 783.423749
# 6.72238929796
# likelihood: -1027.44662387
# ------------------------
# n= 183
# No heating effect
# x_pred_mean = 5.60e+04 real consumption= 5.70e+04
# x_pred min= 5.77e+02 x_pred max 2.65e+05
# ESS of normalized weights= 585.679158
# ESS>=0.5*M
# new ESS= 585.679158
# 6.48203961147
# likelihood: -1891.94271174
# ------------------------
# n= 184
# No heating effect
# x_pred_mean = 5.87e+04 real consumption= 4.83e+04
# x_pred min= 3.09e+02 x_pred max 2.26e+05
# ESS of normalized weights= 411.635652
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1851085772
# likelihood: -3013.47126001
# ------------------------
# n= 185
# No heating effect
# x_pred_mean = 4.77e+04 real consumption= 4.27e+04
# x_pred min= 4.85e+02 x_pred max 1.41e+05
# ESS of normalized weights= 746.575411
# ESS>=0.5*M
# new ESS= 746.575411
# 6.68669428203
# likelihood: -1040.22763939
# ------------------------
# n= 186
# No heating effect
# x_pred_mean = 4.96e+04 real consumption= 5.63e+04
# x_pred min= 4.27e+01 x_pred max 1.94e+05
# ESS of normalized weights= 526.685151
# ESS>=0.5*M
# new ESS= 526.685151
# 6.40107590243
# likelihood: -1561.95616522
# ------------------------
# n= 187
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.71e+04
# x_pred min= 6.62e+02 x_pred max 2.31e+05
# ESS of normalized weights= 363.337687
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07649141863
# likelihood: -2415.01408598
# ------------------------
# n= 188
# No heating effect
# x_pred_mean = 5.58e+04 real consumption= 5.45e+04
# x_pred min= 1.70e+03 x_pred max 1.65e+05
# ESS of normalized weights= 770.492443
# ESS>=0.5*M
# new ESS= 770.492443
# 6.7063813815
# likelihood: -1040.666539
# ------------------------
# n= 189
# No heating effect
# x_pred_mean = 5.86e+04 real consumption= 5.43e+04
# x_pred min= 2.90e+02 x_pred max 2.38e+05
# ESS of normalized weights= 570.971252
# ESS>=0.5*M
# new ESS= 570.971252
# 6.45412921758
# likelihood: -1925.34624949
# ...
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.09432528012
# likelihood: -4409.27372799
# ------------------------
# n= 60
# No heating effect
# x_pred_mean = 5.98e+04 real consumption= 6.53e+04
# x_pred min= 1.56e+03 x_pred max 1.66e+05
# ESS of normalized weights= 598.226574
# ESS>=0.5*M
# new ESS= 598.226574
# 6.48470264946
# likelihood: -2835.09731733
# ------------------------
# n= 61
# No heating effect
# x_pred_mean = 6.21e+04 real consumption= 6.47e+04
# x_pred min= 1.29e+01 x_pred max 2.67e+05
# ESS of normalized weights= 355.887505
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.02671506628
# likelihood: -5445.18174019
# ------------------------
# n= 62
# No heating effect
# x_pred_mean = 5.88e+04 real consumption= 6.74e+04
# x_pred min= 6.24e+02 x_pred max 1.72e+05
# ESS of normalized weights= 692.188406
# ESS>=0.5*M
# new ESS= 692.188406
# 6.61106712453
# likelihood: -1861.89214827
# ------------------------
# n= 63
# No heating effect
# x_pred_mean = 6.06e+04 real consumption= 6.53e+04
# x_pred min= 7.57e+01 x_pred max 2.61e+05
# ESS of normalized weights= 459.813864
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.25324604773
# likelihood: -3684.75258578
# ------------------------
# n= 64
# x_pred_mean = 8.84e+04 real consumption= 6.30e+04
# x_pred min= 9.88e+03 x_pred max 3.14e+05
# ESS of normalized weights= 338.97692
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.99090555325
# likelihood: -9067.24863206
# ------------------------
# n= 65
# x_pred_mean = 8.00e+04 real consumption= 5.49e+04
# x_pred min= 6.10e+03 x_pred max 2.13e+05
# ESS of normalized weights= 396.343536
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.12539522541
# likelihood: -6863.40230842
# ------------------------
# n= 66
# No heating effect
# x_pred_mean = 4.74e+04 real consumption= 4.87e+04
# x_pred min= 2.17e+02 x_pred max 1.32e+05
# ESS of normalized weights= 498.749341
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.32912283824
# likelihood: -3246.05230534
# ------------------------
# n= 67
# x_pred_mean = 7.85e+04 real consumption= 6.02e+04
# x_pred min= 4.08e+03 x_pred max 2.24e+05
# ESS of normalized weights= 514.320803
# ESS>=0.5*M
# new ESS= 514.320803
# 6.34454721463
# likelihood: -4761.60186242
# ------------------------
# n= 68
# x_pred_mean = 1.46e+05 real consumption= 6.20e+04
# x_pred min= 9.69e+03 x_pred max 7.30e+05
# ESS of normalized weights= 138.565186
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# nan
# likelihood: -62504.6802472
# ------------------------
# n= 69
# x_pred_mean = 5.60e+04 real consumption= 6.01e+04
# x_pred min= 2.35e+03 x_pred max 1.73e+05
# ESS of normalized weights= 538.161687
# ESS>=0.5*M
# new ESS= 538.161687
# 6.39077689494
# likelihood: -3277.83834859
# ------------------------
# n= 70
# No heating effect
# x_pred_mean = 5.46e+04 real consumption= 5.96e+04
# x_pred min= 1.08e+03 x_pred max 2.62e+05
# ESS of normalized weights= 331.331488
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 5.96080243536
# likelihood: -4450.93017822
# ------------------------
# n= 71
# No heating effect
# x_pred_mean = 6.24e+04 real consumption= 6.18e+04
# x_pred min= 9.96e+02 x_pred max 2.07e+05
# ESS of normalized weights= 627.402465
# ESS>=0.5*M
# new ESS= 627.402465
# 6.52836524311
# likelihood: -2557.80931516
# ------------------------
# n= 72
# No heating effect
# x_pred_mean = 6.53e+04 real consumption= 5.74e+04
# x_pred min= 7.02e+02 x_pred max 3.03e+05
# ESS of normalized weights= 372.503681
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.07763331498
# likelihood: -5078.14699586
# ------------------------
# n= 73
# No heating effect
# x_pred_mean = 5.45e+04 real consumption= 5.60e+04
# x_pred min= 7.10e+02 x_pred max 1.43e+05
# ESS of normalized weights= 676.182631
# ESS>=0.5*M
# new ESS= 676.182631
# 6.59061905043
# likelihood: -1868.78081017
# ------------------------
# n= 74
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 6.36e+04
# x_pred min= 1.11e+02 x_pred max 1.87e+05
# ESS of normalized weights= 429.068909
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20068743487
# likelihood: -3414.34489439
# ------------------------
# n= 75
# No heating effect
# x_pred_mean = 6.11e+04 real consumption= 6.06e+04
# x_pred min= 1.92e+03 x_pred max 1.74e+05
# ESS of normalized weights= 680.885418
# ESS>=0.5*M
# new ESS= 680.885418
# 6.60363512785
# likelihood: -1837.64380151
# ------------------------
# n= 76
# No heating effect
# x_pred_mean = 6.28e+04 real consumption= 5.89e+04
# x_pred min= 1.86e+03 x_pred max 2.11e+05
# ESS of normalized weights= 450.656946
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2470182805
# likelihood: -3507.89879907
# ------------------------
# n= 77
# No heating effect
# x_pred_mean = 6.22e+04 real consumption= 6.31e+04
# x_pred min= 1.20e+02 x_pred max 1.61e+05
# ESS of normalized weights= 666.932674
# ESS>=0.5*M
# new ESS= 666.932674
# 6.57559577668
# likelihood: -2006.88526878
# ------------------------
# n= 78
# No heating effect
# x_pred_mean = 6.41e+04 real consumption= 6.33e+04
# x_pred min= 1.24e+02 x_pred max 2.12e+05
# ESS of normalized weights= 440.645531
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21329615702
# likelihood: -4020.01327294
# ------------------------
# n= 79
# No heating effect
# x_pred_mean = 5.75e+04 real consumption= 5.73e+04
# x_pred min= 1.11e+03 x_pred max 1.67e+05
# ESS of normalized weights= 624.70313
# ESS>=0.5*M
# new ESS= 624.70313
# 6.52982418198
# likelihood: -2321.54635629
# ------------------------
# n= 80
# No heating effect
# x_pred_mean = 6.09e+04 real consumption= 5.46e+04
# x_pred min= 1.44e+03 x_pred max 2.06e+05
# ESS of normalized weights= 395.453359
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14105251326
# likelihood: -4035.80787019
# ------------------------
# n= 81
# No heating effect
# x_pred_mean = 5.37e+04 real consumption= 6.05e+04
# x_pred min= 7.77e+02 x_pred max 2.01e+05
# ESS of normalized weights= 626.213751
# ESS>=0.5*M
# new ESS= 626.213751
# 6.52922240258
# likelihood: -2473.70589644
# ------------------------
# n= 82
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 6.54e+04
# x_pred min= 1.66e+02 x_pred max 2.22e+05
# ESS of normalized weights= 401.066143
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.14054092108
# likelihood: -3954.55138792
# ------------------------
# n= 83
# No heating effect
# x_pred_mean = 5.73e+04 real consumption= 6.75e+04
# x_pred min= 6.35e+02 x_pred max 2.11e+05
# ESS of normalized weights= 696.795055
# ESS>=0.5*M
# new ESS= 696.795055
# 6.61620974445
# likelihood: -2007.2800214
# ------------------------
# n= 84
# No heating effect
# x_pred_mean = 5.95e+04 real consumption= 6.80e+04
# x_pred min= 6.45e+02 x_pred max 2.48e+05
# ESS of normalized weights= 446.796799
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23464454759
# likelihood: -4221.26185337
# ------------------------
# n= 85
# No heating effect
# x_pred_mean = 5.52e+04 real consumption= 6.20e+04
# x_pred min= 2.11e+03 x_pred max 1.49e+05
# ESS of normalized weights= 677.170846
# ESS>=0.5*M
# new ESS= 677.170846
# 6.59858169642
# likelihood: -2109.85599412
# ------------------------
# n= 86
# No heating effect
# x_pred_mean = 5.67e+04 real consumption= 5.41e+04
# x_pred min= 3.86e+02 x_pred max 2.07e+05
# ESS of normalized weights= 413.879209
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.17982222159
# likelihood: -4351.68762028
# ------------------------
# n= 87
# No heating effect
# x_pred_mean = 4.75e+04 real consumption= 5.19e+04
# x_pred min= 7.26e+01 x_pred max 2.28e+05
# ESS of normalized weights= 666.67168
# ESS>=0.5*M
# new ESS= 666.67168
# 6.57995013172
# likelihood: -1979.25050952
# ------------------------
# n= 88
# No heating effect
# x_pred_mean = 5.05e+04 real consumption= 6.07e+04
# x_pred min= 1.23e+02 x_pred max 2.66e+05
# ESS of normalized weights= 444.327811
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.22299017152
# likelihood: -3527.6964614
# ------------------------
# n= 89
# No heating effect
# x_pred_mean = 5.25e+04 real consumption= 6.07e+04
# x_pred min= 1.45e+03 x_pred max 1.40e+05
# ESS of normalized weights= 706.354481
# ESS>=0.5*M
# new ESS= 706.354481
# 6.6335729413
# likelihood: -1514.14491318
# ------------------------
# n= 90
# No heating effect
# x_pred_mean = 5.41e+04 real consumption= 6.23e+04
# x_pred min= 6.97e+02 x_pred max 2.44e+05
# ESS of normalized weights= 460.2531
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.26825166675
# likelihood: -2975.24116225
# ------------------------
# n= 91
# No heating effect
# x_pred_mean = 5.40e+04 real consumption= 6.36e+04
# x_pred min= 1.21e+03 x_pred max 1.63e+05
# ESS of normalized weights= 700.042437
# ESS>=0.5*M
# new ESS= 700.042437
# 6.62472846141
# likelihood: -1647.01566799
# ------------------------
# n= 92
# No heating effect
# x_pred_mean = 5.71e+04 real consumption= 6.11e+04
# x_pred min= 4.68e+01 x_pred max 3.08e+05
# ESS of normalized weights= 434.242103
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2139987913
# likelihood: -4558.42784156
# ------------------------
# n= 93
# No heating effect
# x_pred_mean = 4.95e+04 real consumption= 5.54e+04
# x_pred min= 6.58e+01 x_pred max 1.68e+05
# ESS of normalized weights= 652.82444
# ESS>=0.5*M
# new ESS= 652.82444
# 6.57195095346
# likelihood: -2066.22867937
# ------------------------
# n= 94
# No heating effect
# x_pred_mean = 5.13e+04 real consumption= 4.91e+04
# x_pred min= 3.15e+02 x_pred max 1.73e+05
# ESS of normalized weights= 422.050534
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.19942998788
# likelihood: -3032.2784561
# ------------------------
# n= 95
# No heating effect
# x_pred_mean = 5.00e+04 real consumption= 4.96e+04
# x_pred min= 5.88e+02 x_pred max 1.56e+05
# ESS of normalized weights= 692.213228
# ESS>=0.5*M
# new ESS= 692.213228
# 6.61573594267
# likelihood: -1743.45499355
# ------------------------
# n= 96
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.87e+04
# x_pred min= 3.34e+02 x_pred max 2.33e+05
# ESS of normalized weights= 447.406572
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23550434723
# likelihood: -3381.93903761
# ------------------------
# n= 97
# No heating effect
# x_pred_mean = 5.32e+04 real consumption= 5.70e+04
# x_pred min= 1.22e+03 x_pred max 1.62e+05
# ESS of normalized weights= 712.778964
# ESS>=0.5*M
# new ESS= 712.778964
# 6.63685983832
# likelihood: -1633.71347419
# ------------------------
# n= 98
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.49e+04
# x_pred min= 7.12e+02 x_pred max 2.09e+05
# ESS of normalized weights= 477.440991
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.29118713771
# likelihood: -3369.7903625
# ------------------------
# n= 99
# No heating effect
# x_pred_mean = 5.16e+04 real consumption= 5.35e+04
# x_pred min= 2.18e+02 x_pred max 1.43e+05
# ESS of normalized weights= 684.588712
# ESS>=0.5*M
# new ESS= 684.588712
# 6.60651896479
# likelihood: -1734.79869753
# ------------------------
# n= 100
# No heating effect
# x_pred_mean = 5.35e+04 real consumption= 4.79e+04
# x_pred min= 4.86e+02 x_pred max 2.11e+05
# ESS of normalized weights= 429.94089
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.20822263438
# likelihood: -3626.38638197
# ------------------------
# n= 101
# No heating effect
# x_pred_mean = 4.60e+04 real consumption= 4.19e+04
# x_pred min= 1.42e+02 x_pred max 1.80e+05
# ESS of normalized weights= 629.895177
# ESS>=0.5*M
# new ESS= 629.895177
# 6.53905619371
# likelihood: -2118.3293457
# ------------------------
# n= 102
# No heating effect
# x_pred_mean = 4.73e+04 real consumption= 5.26e+04
# x_pred min= 7.05e+01 x_pred max 1.81e+05
# ESS of normalized weights= 387.546429
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.1153981624
# likelihood: -3286.32652558
# ------------------------
# n= 103
# No heating effect
# x_pred_mean = 5.31e+04 real consumption= 5.22e+04
# x_pred min= 2.15e+03 x_pred max 1.48e+05
# ESS of normalized weights= 686.36791
# ESS>=0.5*M
# new ESS= 686.36791
# 6.60984748237
# likelihood: -1701.99425218
# ------------------------
# n= 104
# No heating effect
# x_pred_mean = 5.56e+04 real consumption= 5.23e+04
# x_pred min= 6.42e+02 x_pred max 2.02e+05
# ESS of normalized weights= 453.08701
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.25016170837
# likelihood: -3080.05932809
# ------------------------
# n= 105
# No heating effect
# x_pred_mean = 5.62e+04 real consumption= 5.27e+04
# x_pred min= 1.59e+03 x_pred max 1.37e+05
# ESS of normalized weights= 623.658467
# ESS>=0.5*M
# new ESS= 623.658467
# 6.52899628825
# likelihood: -2357.20136451
# ------------------------
# n= 106
# No heating effect
# x_pred_mean = 5.85e+04 real consumption= 5.24e+04
# x_pred min= 4.28e+02 x_pred max 1.92e+05
# ESS of normalized weights= 380.824404
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.10769475287
# likelihood: -4178.28581073
# ------------------------
# n= 107
# No heating effect
# x_pred_mean = 4.93e+04 real consumption= 4.52e+04
# x_pred min= 2.79e+02 x_pred max 1.39e+05
# ESS of normalized weights= 682.142029
# ESS>=0.5*M
# new ESS= 682.142029
# 6.60247937322
# likelihood: -1842.29655659
# ------------------------
# n= 108
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 4.20e+04
# x_pred min= 3.29e+02 x_pred max 2.16e+05
# ESS of normalized weights= 449.093149
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.25261353341
# likelihood: -3290.02539783
# ------------------------
# n= 109
# No heating effect
# x_pred_mean = 5.12e+04 real consumption= 5.22e+04
# x_pred min= 3.50e+02 x_pred max 2.20e+05
# ESS of normalized weights= 683.180142
# ESS>=0.5*M
# new ESS= 683.180142
# 6.60280937269
# likelihood: -2025.56602285
# ------------------------
# n= 110
# No heating effect
# x_pred_mean = 5.33e+04 real consumption= 5.22e+04
# x_pred min= 4.90e+02 x_pred max 2.90e+05
# ESS of normalized weights= 456.269628
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.2627425444
# likelihood: -3494.669257
# ------------------------
# n= 111
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.20e+04
# x_pred min= 1.74e+03 x_pred max 1.27e+05
# ESS of normalized weights= 709.296429
# ESS>=0.5*M
# new ESS= 709.296429
# 6.63135261209
# likelihood: -1562.83241598
# ------------------------
# n= 112
# No heating effect
# x_pred_mean = 5.53e+04 real consumption= 5.22e+04
# x_pred min= 2.27e+02 x_pred max 1.91e+05
# ESS of normalized weights= 435.291613
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.21684380823
# likelihood: -4096.99437621
# ------------------------
# n= 113
# No heating effect
# x_pred_mean = 4.81e+04 real consumption= 5.14e+04
# x_pred min= 6.29e+01 x_pred max 1.48e+05
# ESS of normalized weights= 688.64329
# ESS>=0.5*M
# new ESS= 688.64329
# 6.61019162945
# likelihood: -1784.82666129
# ------------------------
# n= 114
# No heating effect
# x_pred_mean = 4.98e+04 real consumption= 4.47e+04
# x_pred min= 7.11e+02 x_pred max 2.10e+05
# ESS of normalized weights= 438.341765
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.23110965901
# likelihood: -3797.67288137
# ------------------------
# n= 115
# No heating effect
# x_pred_mean = 4.37e+04 real consumption= 4.14e+04
# x_pred min= 4.55e+02 x_pred max 1.56e+05
# ESS of normalized weights= 630.416971
# ESS>=0.5*M
# new ESS= 630.416971
# 6.54183696911
# likelihood: -2070.99523224
# ------------------------
# n= 116
# No heating effect
# x_pred_mean = 4.68e+04 real consumption= 5.42e+04
# x_pred min= 4.32e+02 x_pred max 2.12e+05
# ESS of normalized weights= 398.567824
# ESS>=0.001*M and ESS_0<0.5*M
# new ESS= 1000.0
# 6.13760497512
# likelihood: -3404.47041447
# ------------------------
# n= 117
# No heating effect
# x_pred_mean = 5.21e+04 real consumption= 5.47e+04
# x_pred min= 1.07e+03 x_pred max 1.80e+05
# ESS of normalized weights= 672.167081
# ESS>=0.5*M
# new ESS= 672.167081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-15e5f1b777a6> in <module>()
#      13     #  consider the likelihood of the last day of the fitering
#      14     lh_y_prop=particle_filter(0,len_init,len_filter_pmmh,s_init,
# ---> 15                               g_heat_init,sigma_s_prop,sigma_g_prop,sigma_prop,lh_y_n)[0]
#      16     print("log likelihood proposal of y:",np.sum(lh_y_prop))
#      17     #2/generate prior proposals and compute joint log density of them
#
# <ipython-input-18-e2789babfdba> in particle_filter(nbdays_pred_today, len_init, len_filtering, s, g_h, sigma_s, sigma_g, sigma, lh_y)
#      22         #regularization
#      23         x_pred[n,:],w[n,:],ESS[n],lh_y_n[n],sigma_s,sigma_g,g_h,s,w_h[n,:]=resample(x_pred[n,:],w[n-1,:],nbdays_pred_today,len_init,n,sigma_s,sigma_g,g_h,s,sigma,ESS)
# ---> 24         entrop_n[nbdays_pred_today,n-1]=-sum(w_h[n,:]*np.log(w_h[n,:]))
#      25         print(entrop_n[nbdays_pred_today,n-1])
#      26         print("likelihood:",lh_y_n[n])
#
# KeyboardInterrupt:
